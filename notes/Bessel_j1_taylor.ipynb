# %%
from scipy.special import j1
from scipy.optimize import brentq
from sage.all import *
import struct

DR = RealField(52)

DD = RealField(157)

def double_to_hex(f):
    # Converts Python float (f64) to hex string
    packed = struct.pack('>d', float(f))
    return '0x' + packed.hex()

def split_double_double(x):
    # Split RR value x into hi + lo (double-double)
    x_hi = DR(x)  # convert to f64
    x_lo = x - DD(x_hi)
    return (x_lo,x_hi)

def format_dyadic_hex(value):
    l = hex(value)[2:]
    n = 8
    x = [l[i:i + n] for i in range(0, len(l), n)]
    return "0x" + "_".join(x) + "_u128"

def print_dyadic(value):
    (s, m, e) = RealField(128)(value).sign_mantissa_exponent();
    print("DyadicFloat128 {")
    print(f"    sign: DyadicSign::{'Pos' if s >= 0 else 'Neg'},")
    print(f"    exponent: {e},")
    print(f"    mantissa: {format_dyadic_hex(m)},")
    print("},")

# %%
# from scipy.special import j1, jvp
# from scipy.optimize import brentq
from mpmath import mp, mpf, findroot, j1, besselj
from sage.all import *
import struct

DR = RealField(53)

DD = RealField(190)

def double_to_hex(f):
    packed = struct.pack('>d', float(f))
    return '0x' + packed.hex()

def split_double_double(x):
    # Split RR value x into hi + lo (double-double)
    x = RealField(190)(x).exact_rational()
    x_hi = DR(x)  # convert to f64
    x_lo = x - DD(x_hi)
    return (x_lo,x_hi)

def split_triple_double(x):
    # Split RR value x into hi + lo (double-double)
    x_hi = DR(x)  # convert to f64
    x_mid = DR(x - DD(x_hi))
    x_lo = x - DD(x_hi) - DD(x_mid)
    return (x_lo, x_mid, x_hi)

def print_double_double(mark, x):
    splat = split_double_double(x)
    print(f"{mark}({double_to_hex(splat[0])}, {double_to_hex(splat[1])}),")

def print_triple_double(mark, x):
    splat = split_triple_double(x)
    print(f"{mark}({double_to_hex(splat[0])}, {double_to_hex(splat[1])}, {double_to_hex(splat[2])}),")
    
# Use Sage's RDF for high-precision floats
R120 = RealField(120)

# List of zeros
zeros = []

# Step size to detect sign changes
# step = R120(0.001)
# x = R120(0.0)

mp.prec = 200

step = mpf("0.01")
epsilon = mpf("1e-35")
x = mpf("0.0")

def j1_prime(x):
    return diff(lambda t: besselj(1, t), x)

previous_zero = R120(0)
# epsilon = 1e-12
j1_zeros = []

# while x < 77:
#     if j1(float(x)) * j1(float(x + step)) < 0:  # Sign change => zero in interval
#         previous_zero = brentq(j1, x, x + step)
#         j1_zeros.append(R120(previous_zero))
#     if abs(x - round(x)) < epsilon:
#         zeros.append(R120(previous_zero))
#     x += step

while x < mpf("76.0"):
    f1 = besselj(1, x)
    f2 = besselj(1, x + step)
    if f1 * f2 < 0:
        zero = findroot(lambda t: j1(t), (x, x + step), solver='bisect', tol=mp.mpf("1e-41"))
        previous_zero = zero
        j1_zeros.append(zero)
    if previous_zero is not None and abs(x - mpf(f'{round(x)}')) < epsilon:
        zeros.append(previous_zero)
    x += step

j1_extrema = []

# x = R120(0.0)
# while x < 77:
#     dfx = jvp(1, float(x), n=1)  # Derivative of J1
#     dfx_next = jvp(1, float(x + step), n=1)
#     if dfx * dfx_next < 0:
#         extremum = brentq(lambda x: jvp(1, x, n=1), float(x), float(x + step))
#         j1_extrema.append(R120(extremum))
#     x += step

x = mpf("0.0")
while x < mpf("76.0"):
    d1 = mp.diff(lambda t: j1(t), x)
    d2 = mp.diff(lambda t: j1(t), x + step)
    if d1 * d2 < 0:
        extremum = findroot(lambda t: mp.diff(lambda u: j1(u), t), (x, x + step), solver='bisect', tol=mp.mpf("1e-41"))
        j1_extrema.append(extremum)
    x += step

# Print results
for i, z in enumerate(j1_zeros):
    print(f"Zero {i+1}: x ≈ {z}")

print("Extrema (peaks/valleys) of J1(x):")
for e in j1_extrema:
    print(f"nExtrema: {e}")

j1_zeros.extend(j1_extrema)

j1_zeros = sorted(j1_zeros)

# Print results
for i, z in enumerate(j1_zeros):
    print(f"Peak or zero {i+1}: x ≈ {z}")

print("")

print("pub(crate) static J1_ZEROS: [(u64, u64); 48] = [")
print(f"(0x0, 0x0),")
for z in j1_zeros:
    k = split_double_double(z)
    # print_dyadic(z)
    hi = double_to_hex(k[1])
    lo = double_to_hex(k[0])
    print(f"({lo}, {hi}),")
    
print("];")

from mpmath import *
from sage.all import *

from mpmath import mp, j1, taylor, expm1

prev_zero = 0

CDR = RealField(120)

var('x')

def get_constant_term(poly, y):
    for term in poly.operands():
        if term.is_constant():
            return term

def print_taylor_coeffs(poly, x0):
    print("J1TaylorExtendedSeries {")
    print_double_double("a0: ", poly[0])
    print_double_double("a1: ", poly[1])
    print_double_double("a2: ", poly[2])
    print_double_double("a3: ", poly[3])
    print_double_double("a4: ", poly[4])
    print_double_double("a5: ", poly[5])
    print_double_double("a6: ", poly[6])
    print_double_double("a7: ", poly[7])
    print_double_double("a8: ", poly[8])
    print_double_double("a9: ", poly[9])
    print_double_double("a10: ", poly[10])
    print_double_double("a11: ", poly[11])
    print_double_double("a12: ", poly[12])
    print_double_double("a13: ", poly[13])
    print_double_double("a14: ", poly[14])
    print_double_double("a15: ", poly[15])
    print("c: [")
    for i in range(16, 24):
        coeff = poly[i]
        print(f"{double_to_hex(coeff)},")
    print("],")
    print("},")

def print_taylor_coeffs_dyad(poly):
    print("[")
    for i in range(0, 24):
        coeff = poly[i]
        print_dyadic(coeff)
    print("],")

# print(f"pub(crate) static J1_COEFFS: [J1TaylorExtendedSeries; {len(j1_zeros)}] = [")

# for i in range(0, len(j1_zeros)):
#     k_range = j1_zeros[i]
#     range_diff = k_range - prev_zero
#     g_c = 1

#     x0 = mp.mpf(k_range)
#     from mpmath import mp, j1, taylor
#     poly = taylor(lambda val: j1(val), x0, 25)
#     print_taylor_coeffs(poly, CDR(k_range))
#     prev_zero = j1_zeros[i]

# print("];")

print(f"pub(crate) static J1_COEFFS_RATIONAL128: [DyadicFloat128; {len(j1_zeros)}] = [")

for i in range(0, len(j1_zeros)):
    k_range = j1_zeros[i]
    range_diff = k_range - prev_zero
    g_c = 1

    x0 = mp.mpf(k_range)
    from mpmath import mp, j1, taylor
    poly = taylor(lambda val: j1(val), x0, 25)
    print_taylor_coeffs_dyad(poly)
    prev_zero = j1_zeros[i]

print("];")
# Out:
# Zero 1: x ≈ 3.8317059702075123156144358863081609582911078521244950401886
# Zero 2: x ≈ 7.0155866698156187535370499814765222133211799657697498562727
# Zero 3: x ≈ 10.173468135062722077185711776775842874118325466668199285671
# Zero 4: x ≈ 13.323691936314223032393684126947876836246966256828906387054
# Zero 5: x ≈ 16.47063005087763281255246047098955460257890840875283477081
# Zero 6: x ≈ 19.615858510468242021125065884137511712322940855970695228805
# Zero 7: x ≈ 22.760084380592771898053005152182260032194822293609582761429
# Zero 8: x ≈ 25.903672087618382625495855445979875220850924725526971473225
# Zero 9: x ≈ 29.046828534916855066647819883531963887188166731590534232106
# Zero 10: x ≈ 32.189679910974403626622984104460371875478032041055034115317
# Zero 11: x ≈ 35.332307550083865102634479022519015000383928144530784171094
# Zero 12: x ≈ 38.47476623477161511205219755771661236717103805681843387566
# Zero 13: x ≈ 41.617094212814450885863516805060288649321765027325910311976
# Zero 14: x ≈ 44.759318997652821732779352713212144805527050106004245235266
# Zero 15: x ≈ 47.901460887185447121274008722507510606090340432217198664216
# Zero 16: x ≈ 51.043535183571509468733034633224064223940401220527595825313
# Zero 17: x ≈ 54.185553641061320532099966214533888722863601345165535245984
# Zero 18: x ≈ 57.327525437901010745090504243750521990195239019055722165916
# Zero 19: x ≈ 60.469457845347491559398749808383148215264825792836696672175
# Zero 20: x ≈ 63.611356698481232631039762417873623076713264180867051323918
# Zero 21: x ≈ 66.753226734098493415305259750042396239171789203090216697113
# Zero 22: x ≈ 69.895071837495773969730536435499809980997967252113712925054
# Zero 23: x ≈ 73.036895225573834826506117569092051498329725501044154535344
# Extrema (peaks/valleys) of J1(x):
# nExtrema: 1.841183781340659302643629513644439520964818374318352014927
# nExtrema: 5.3314427735250326368840161834339132081547293413224236441488
# nExtrema: 8.5363163663462858343589608864120482965837358587753983517152
# nExtrema: 11.706004902592064100192670477239524000448927061310287253099
# nExtrema: 14.863588633909033105004905304985977691427348785932252434149
# nExtrema: 18.015527862681803727025625542010494601693647252747417376607
# nExtrema: 21.164369859188790027767973293705129247975983996953386626527
# nExtrema: 24.311326857210776091733221673753676306378480011942360360454
# nExtrema: 27.457050571059245888223275587901978010370806843697132034285
# nExtrema: 30.601922972669094192330163628525055274165359139581824366136
# nExtrema: 33.746182898667382556147730594290576334249423037008184846603
# nExtrema: 36.889987409236810736184291115055094401160040486328494345988
# nExtrema: 40.033444053350675483595577824821022828463547144934866936034
# nExtrema: 43.176628965448822065171326670934501571066365344001255868622
# nExtrema: 46.319597561173912431514896922520702473277867957869702305385
# nExtrema: 49.462391139702755522817961514250937385678740975236699817546
# nExtrema: 52.605041111556684816016445795619378892481337744928955035137
# nExtrema: 55.747571792251006871041271951261258413853108852487038435094
# nExtrema: 58.890002299185703524557516663955600609834094444605673558084
# nExtrema: 62.032347870661986904980183177973296987103767798776122898255
# nExtrema: 65.17462080254445314091307969916123952087003501418858119203
# nExtrema: 68.31683112595180831007553283620391416177243057400015156204
# nExtrema: 71.458987105851000181223748893951481700627639700184149171624
# nExtrema: 74.601095613456402477925006047822591617571255814146598762252
# Peak or zero 1: x ≈ 1.841183781340659302643629513644439520964818374318352014927
# Peak or zero 2: x ≈ 3.8317059702075123156144358863081609582911078521244950401886
# Peak or zero 3: x ≈ 5.3314427735250326368840161834339132081547293413224236441488
# Peak or zero 4: x ≈ 7.0155866698156187535370499814765222133211799657697498562727
# Peak or zero 5: x ≈ 8.5363163663462858343589608864120482965837358587753983517152
# Peak or zero 6: x ≈ 10.173468135062722077185711776775842874118325466668199285671
# Peak or zero 7: x ≈ 11.706004902592064100192670477239524000448927061310287253099
# Peak or zero 8: x ≈ 13.323691936314223032393684126947876836246966256828906387054
# Peak or zero 9: x ≈ 14.863588633909033105004905304985977691427348785932252434149
# Peak or zero 10: x ≈ 16.47063005087763281255246047098955460257890840875283477081
# Peak or zero 11: x ≈ 18.015527862681803727025625542010494601693647252747417376607
# Peak or zero 12: x ≈ 19.615858510468242021125065884137511712322940855970695228805
# Peak or zero 13: x ≈ 21.164369859188790027767973293705129247975983996953386626527
# Peak or zero 14: x ≈ 22.760084380592771898053005152182260032194822293609582761429
# Peak or zero 15: x ≈ 24.311326857210776091733221673753676306378480011942360360454
# Peak or zero 16: x ≈ 25.903672087618382625495855445979875220850924725526971473225
# Peak or zero 17: x ≈ 27.457050571059245888223275587901978010370806843697132034285
# Peak or zero 18: x ≈ 29.046828534916855066647819883531963887188166731590534232106
# Peak or zero 19: x ≈ 30.601922972669094192330163628525055274165359139581824366136
# Peak or zero 20: x ≈ 32.189679910974403626622984104460371875478032041055034115317
# Peak or zero 21: x ≈ 33.746182898667382556147730594290576334249423037008184846603
# Peak or zero 22: x ≈ 35.332307550083865102634479022519015000383928144530784171094
# Peak or zero 23: x ≈ 36.889987409236810736184291115055094401160040486328494345988
# Peak or zero 24: x ≈ 38.47476623477161511205219755771661236717103805681843387566
# Peak or zero 25: x ≈ 40.033444053350675483595577824821022828463547144934866936034
# Peak or zero 26: x ≈ 41.617094212814450885863516805060288649321765027325910311976
# Peak or zero 27: x ≈ 43.176628965448822065171326670934501571066365344001255868622
# Peak or zero 28: x ≈ 44.759318997652821732779352713212144805527050106004245235266
# Peak or zero 29: x ≈ 46.319597561173912431514896922520702473277867957869702305385
# Peak or zero 30: x ≈ 47.901460887185447121274008722507510606090340432217198664216
# Peak or zero 31: x ≈ 49.462391139702755522817961514250937385678740975236699817546
# Peak or zero 32: x ≈ 51.043535183571509468733034633224064223940401220527595825313
# Peak or zero 33: x ≈ 52.605041111556684816016445795619378892481337744928955035137
# Peak or zero 34: x ≈ 54.185553641061320532099966214533888722863601345165535245984
# Peak or zero 35: x ≈ 55.747571792251006871041271951261258413853108852487038435094
# Peak or zero 36: x ≈ 57.327525437901010745090504243750521990195239019055722165916
# Peak or zero 37: x ≈ 58.890002299185703524557516663955600609834094444605673558084
# Peak or zero 38: x ≈ 60.469457845347491559398749808383148215264825792836696672175
# Peak or zero 39: x ≈ 62.032347870661986904980183177973296987103767798776122898255
# Peak or zero 40: x ≈ 63.611356698481232631039762417873623076713264180867051323918
# Peak or zero 41: x ≈ 65.17462080254445314091307969916123952087003501418858119203
# Peak or zero 42: x ≈ 66.753226734098493415305259750042396239171789203090216697113
# Peak or zero 43: x ≈ 68.31683112595180831007553283620391416177243057400015156204
# Peak or zero 44: x ≈ 69.895071837495773969730536435499809980997967252113712925054
# Peak or zero 45: x ≈ 71.458987105851000181223748893951481700627639700184149171624
# Peak or zero 46: x ≈ 73.036895225573834826506117569092051498329725501044154535344
# Peak or zero 47: x ≈ 74.601095613456402477925006047822591617571255814146598762252
#
# pub(crate) static J1_ZEROS: [(u64, u64); 48] = [
# (0x0, 0x0),
# (0x3c5616d820cfdae6, 0x3ffd757d1fec8a3a),
# (0xbca60155a9d1b256, 0x400ea75575af6f09),
# (0x3ca5c646a75d7539, 0x40155365bc032467),
# (0xbc9b226d9d243827, 0x401c0ff5f3b47250),
# (0xbca63e17ec20a31d, 0x402112980f0b88a1),
# (0x3cc02610a51562b6, 0x402458d0d0bdfc29),
# (0x3cc9a84d3a5fedc2, 0x40276979797ee5ac),
# (0x3cb2bce7fd18e693, 0x402aa5baf310e5a2),
# (0xbcc6932b987094f0, 0x402dba284a17ac59),
# (0xbcdd2a68e88ab317, 0x4030787b360508c5),
# (0xbca022f6b2b54db8, 0x403203f9a24e6527),
# (0xbcd21830197e9e86, 0x40339da8e7416ca4),
# (0x3cdeaafeaf8ec1af, 0x40352a1424a1a9fa),
# (0xbcc1bf33afef88f1, 0x4036c294e3d4d8ac),
# (0xbcb2d773b50cf8b8, 0x40384fb31dee1635),
# (0x3cc1a2686480d882, 0x4039e7570dcea106),
# (0x3cd0bdee27293d79, 0x403b75014427514d),
# (0xbcb42ce39ec976fb, 0x403d0bfcf471fccc),
# (0x3cbda49c2c143484, 0x403e9a179fba532a),
# (0xbcdbe3a1cd066b66, 0x404018476e6b2bf0),
# (0xbce6b00c1279ef0a, 0x4040df82ebd54e32),
# (0xbced5fbbff045068, 0x4041aa890dc5e97c),
# (0x3cd7d864bbf17a31, 0x404271eb1b80430e),
# (0x3cc9eafeca0ca4fd, 0x40433cc523d5cb69),
# (0xbce5cecac300a9a1, 0x40440447e50db184),
# (0x3cc489bd556e510a, 0x4044cefcf1734b62),
# (0x3cdd0fd96f29c212, 0x4045969bc7271083),
# (0x3ce4f716f3179d90, 0x404661315d6b133f),
# (0xbce158b763edd0e8, 0x404728e892a88fc9),
# (0xbcef3950a842db79, 0x4047f36312028ad6),
# (0x3ce97656bbc2396e, 0x4048bb2fa2037de3),
# (0x3ce85d7bdb30baf1, 0x404985928f96d51e),
# (0xbce71f8560ac9f18, 0x404a4d71fcb56f8c),
# (0x3ce3d41e041caa68, 0x404b17c038c2018c),
# (0xbcde6d04716d8d20, 0x404bdfb06eb790aa),
# (0x3cda139ce2cd08ac, 0x404ca9ec5a82324b),
# (0x3cc8b5cc7b4501c2, 0x404d71eb98682f07),
# (0xbcb12e6ef2e594e1, 0x404e3c1731d64f1e),
# (0x3cb399bfca430022, 0x404f0423f99b4b53),
# (0x3cdfd1ee8286358a, 0x404fce40efb1156e),
# (0x3c800660b51502f1, 0x40504b2cfcbb084d),
# (0x3ced3cacfc720419, 0x4050b034dde75b42),
# (0x3cc4b877d4f6d901, 0x40511446f60f1458),
# (0xbcee669304bfe748, 0x40517948db63675c),
# (0x3cfad20ca758a715, 0x4051dd600b743a9b),
# (0x3cf8eb4a94b63936, 0x4052425c7dcacdf6),
# (0xbcfa196892f68385, 0x4052a67859bc641e),
# ];
# pub(crate) static J1_COEFFS_RATIONAL128: [DyadicFloat128; 47] = [
# ];

# %%
def print_expansion_at_0():
    print(f"static C: [DyadicFloat128; 13] = ")
    from mpmath import mp, j1, taylor, expm1
    poly = taylor(lambda val: j1(val), 0, 26)
    # print(poly)
    real_i = 0
    print("[")
    for i in range(1, len(poly), 2):
        print_dyadic(poly[i])
        real_i = real_i + 1
    print("],")

    print("];")

mp.prec = 180

print_expansion_at_0()
# Out:
# pub(crate) static C: DyadicFloat128 = [
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -128,
#     mantissa: 0x80000000_00000000_00000000_00000000_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -131,
#     mantissa: 0x80000000_00000000_00000000_00000000_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -136,
#     mantissa: 0xaaaaaaaa_aaaaaaaa_aaaaaaaa_aaaaaaab_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -142,
#     mantissa: 0xe38e38e3_8e38e38e_38e38e38_e38e38e4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -148,
#     mantissa: 0xb60b60b6_0b60b60b_60b60b60_b60b60b6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -155,
#     mantissa: 0xc22e4506_72894ab6_cd8efb11_d33f5618_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -162,
#     mantissa: 0x93f27dbb_c4fae397_780b69f5_333c725b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -170,
#     mantissa: 0xa91521fb_2a434d3f_649f5485_f169a743_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -178,
#     mantissa: 0x964bac6d_7ae67d8d_aec68405_485dea03_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -187,
#     mantissa: 0xd5c0f53a_fe6fa17f_8c7b0b68_39691f4e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -196,
#     mantissa: 0xf8bb4be7_8e7896b0_58fee362_01a4370c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -205,
#     mantissa: 0xf131bdf7_cff8d02e_e1ef6820_f9d58ab6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -214,
#     mantissa: 0xc5e72c48_0d1aec75_3caa2e0d_edd008ca_u128,
# },
# ],
# [;

# %%
def compute_intervals(zeros):
    intervals = []
    for i in range(0, len(zeros)):
        if i == 0:
            a = (zeros[i]) / 2 - 0.05 - zeros[i]
            b = (zeros[i] + zeros[i + 1]) / 2 + 0.05 - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
        elif i + 1 > len(zeros) - 1:
            a = (zeros[i - 1] + zeros[i]) / 2 - 0.05 - zeros[i]
            b = (zeros[i]) + 0.83 + 0.05 - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
        else:
            a = (zeros[i - 1] + zeros[i]) / 2 - zeros[i] - 0.05
            b = (zeros[i] + zeros[i + 1]) / 2 + 0.05  - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
    return intervals

intervals = compute_intervals(j1_zeros)
print(intervals)

def build_sollya_script(a, b, zero, deg):
    return f"""
prec = 500;
bessel_j1 = library("/Users/radzivon/RustroverProjects/pxfm/notes/bessel_sollya/cmake-build-release/libbessel_sollya.dylib");
f = bessel_j1(x + {zero});
d = [{a}, {b}];
pf = remez(f, {deg}, d, 1, 1e-25);
for i from 0 to degree(pf) do {{
    write(coeff(pf, i)) >> "coefficients.txt";
    write("\\n") >> "coefficients.txt";
}};
"""

def load_coefficients(filename):
    with open(filename, "r") as f:
        return [RR(line.strip()) for line in f if line.strip()]

def call_sollya_on_interval(a, b, zero, degree=12):
    sollya_script = build_sollya_script(a, b, zero, degree)
    with open("tmp_interval.sollya", "w") as f:
        f.write(sollya_script)
    import subprocess
    if os.path.exists("coefficients.txt"):
        os.remove("coefficients.txt")
    try:
        result = subprocess.run(
            ["sollya", "tmp_interval.sollya"],
            check=True,
            capture_output=True,
            text=True
        )
    except subprocess.CalledProcessError as e:
        return

degree = 13

print(f"pub(crate) static J1F_COEFFS: [[u64;{degree + 1}]; {len(intervals)}] = [")
for i in range(0, len(intervals)):
    interval = intervals[i]
    call_sollya_on_interval(interval[0], interval[1], interval[2], degree)
    coeffs = load_coefficients(f"coefficients.txt")
    print("[")
    for c in coeffs:
        print(double_to_hex(c) + ",")
    print("],")
print("];")
# Out:
# [(-0.97059, 1.0453, 1.8411837813406593026436295136444), (-1.0453, 0.79987, 3.8317059702075123156144358863082), (-0.79987, 0.89207, 5.3314427735250326368840161834339), (-0.89207, 0.81036, 7.0155866698156187535370499814765), (-0.81036, 0.86858, 8.5363163663462858343589608864121), (-0.86858, 0.81627, 10.173468135062722077185711776776), (-0.81627, 0.85884, 11.706004902592064100192670477240), (-0.85884, 0.81995, 13.323691936314223032393684126948), (-0.81995, 0.85352, 14.863588633909033105004905304986), (-0.85352, 0.82245, 16.470630050877632812552460470990), (-0.82245, 0.85017, 18.015527862681803727025625542010), (-0.85017, 0.82426, 19.615858510468242021125065884137), (-0.82426, 0.84786, 21.164369859188790027767973293705), (-0.84786, 0.82562, 22.760084380592771898053005152182), (-0.82562, 0.84617, 24.311326857210776091733221673754), (-0.84617, 0.82669, 25.903672087618382625495855445980), (-0.82669, 0.84489, 27.457050571059245888223275587902), (-0.84489, 0.82755, 29.046828534916855066647819883532), (-0.82755, 0.84388, 30.601922972669094192330163628525), (-0.84388, 0.82825, 32.189679910974403626622984104460), (-0.82825, 0.84306, 33.746182898667382556147730594291), (-0.84306, 0.82884, 35.332307550083865102634479022519), (-0.82884, 0.84239, 36.889987409236810736184291115055), (-0.84239, 0.82934, 38.474766234771615112052197557717), (-0.82934, 0.84182, 40.033444053350675483595577824821), (-0.84182, 0.82977, 41.617094212814450885863516805060), (-0.82977, 0.84135, 43.176628965448822065171326670935), (-0.84135, 0.83014, 44.759318997652821732779352713212), (-0.83014, 0.84093, 46.319597561173912431514896922521), (-0.84093, 0.83046, 47.901460887185447121274008722507), (-0.83046, 0.84057, 49.462391139702755522817961514251), (-0.84057, 0.83075, 51.043535183571509468733034633224), (-0.83075, 0.84026, 52.605041111556684816016445795619), (-0.84026, 0.83101, 54.185553641061320532099966214534), (-0.83101, 0.83998, 55.747571792251006871041271951261), (-0.83998, 0.83124, 57.327525437901010745090504243751), (-0.83124, 0.83973, 58.890002299185703524557516663956), (-0.83973, 0.83144, 60.469457845347491559398749808383), (-0.83144, 0.83950, 62.032347870661986904980183177973), (-0.83950, 0.83163, 63.611356698481232631039762417874), (-0.83163, 0.83930, 65.174620802544453140913079699161), (-0.83930, 0.83180, 66.753226734098493415305259750042), (-0.83180, 0.83912, 68.316831125951808310075532836204), (-0.83912, 0.83196, 69.895071837495773969730536435500), (-0.83196, 0.83895, 71.458987105851000181223748893952), (-0.83895, 0.83210, 73.036895225573834826506117569092), (-0.83210, 0.88000, 74.601095613456402477925006047823)]
# pub(crate) static J1F_COEFFS: [[u64;14]; 47] = [
# [
# 0x3fe29ea3d19f035d,
# 0xbce22d3695a081b6,
# 0xbfca41115c5deeab,
# 0x3f78d1448e710c46,
# 0x3f8c441a2f9a4f69,
# 0xbf386671c22a634e,
# 0xbf39e2504b2e7b5b,
# 0x3ee34ccc14eef789,
# 0x3eda49718b72405e,
# 0xbe810474efe3c9c6,
# 0xbe70fa29fb791201,
# 0x3e1362d76c062ab0,
# 0x3dfdd76f07295520,
# 0xbda1a753bf39cb58,
# ],
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 60
#      58 for i in range(0, len(intervals)):
#      59     interval = intervals[i]
# ---> 60     call_sollya_on_interval(interval[0], interval[1], interval[2], degree)
#      61     coeffs = load_coefficients(f"coefficients.txt")
#      62     print("[")
#
# Cell In[3], line 46, in call_sollya_on_interval(a, b, zero, degree)
#      44     os.remove("coefficients.txt")
#      45 try:
# ---> 46     result = subprocess.run(
#      47         ["sollya", "tmp_interval.sollya"],
#      48         check=True,
#      49         capture_output=True,
#      50         text=True
#      51     )
#      52 except subprocess.CalledProcessError as e:
#      53     return
#
# File /private/var/tmp/sage-10.6-current/venv/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /private/var/tmp/sage-10.6-current/venv/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /private/var/tmp/sage-10.6-current/venv/lib/python3.12/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /private/var/tmp/sage-10.6-current/venv/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
def compute_intervals(zeros):
    intervals = []
    for i in range(0, len(zeros)):
        if i == 0:
            a = (zeros[i]) / 2 - 0.05 - zeros[i]
            b = (zeros[i] + zeros[i + 1]) / 2 + 0.05 - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
        elif i + 1 > len(zeros) - 1:
            a = (zeros[i - 1] + zeros[i]) / 2 - 0.05 - zeros[i]
            b = (zeros[i]) + 0.83 + 0.05 - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
        else:
            a = (zeros[i - 1] + zeros[i]) / 2 - zeros[i] - 0.05
            b = (zeros[i] + zeros[i + 1]) / 2 + 0.05  - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
    return intervals

intervals = compute_intervals(j1_zeros)
# print(intervals)

def build_sollya_script(a, b, zero, deg):
    return f"""
prec = 500;
bessel_j1 = library("/Users/radzivon/RustroverProjects/pxfm/notes/bessel_sollya/cmake-build-release/libbessel_sollya.dylib");
f = bessel_j1(x + {zero});
d = [{a}, {b}];
pf = remez(f, {deg}, d);
for i from 0 to degree(pf) do {{
    write(coeff(pf, i)) >> "coefficients.txt";
    write("\\n") >> "coefficients.txt";
}};
"""

def load_coefficients(filename):
    with open(filename, "r") as f:
        return [RealField(500)(line.strip()) for line in f if line.strip()]

def call_sollya_on_interval(a, b, zero, degree=12):
    sollya_script = build_sollya_script(a, b, zero, degree)
    with open("tmp_interval.sollya", "w") as f:
        f.write(sollya_script)
    import subprocess
    if os.path.exists("coefficients.txt"):
        os.remove("coefficients.txt")
    try:
        result = subprocess.run(
            ["sollya", "tmp_interval.sollya"],
            check=True,
            capture_output=True,
            text=True
        )
    except subprocess.CalledProcessError as e:
        return

def print_remez_coeffs(poly):
    print("[")
    for i in range(len(poly)):
        coeff = poly[i]
        print_dyadic(coeff)
        # print_double_double("", coeff)
    print("],")

degree = 23

print(f"pub(crate) static J1_COEFFS_RATIONAL128: [[(u64, u64); {degree + 1}]; {len(intervals)}] = [")
for i in range(0, len(intervals)):
    interval = intervals[i]
    call_sollya_on_interval(interval[0], interval[1], interval[2], degree)
    coeffs = load_coefficients(f"coefficients.txt")
    print_remez_coeffs(coeffs)
print("];")
# Out:
# pub(crate) static J1_COEFFS_RATIONAL128: [[(u64, u64); 24]; 47] = [
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -128,
#     mantissa: 0x94f51e8c_f81af88f_8e192229_d91047b9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -228,
#     mantissa: 0xca46cc63_caa267e5_f27b7ab3_0af363e0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xd2088ae2_ef921bc6_c635c2e0_4cad5d9d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -135,
#     mantissa: 0xc68a2473_7f6a3cea_675e008d_ac2cb88b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -134,
#     mantissa: 0xe220d17c_ef1158f4_2d3e7fed_cc2ecd54_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -139,
#     mantissa: 0xc3338e0c_58444cd6_6bcd50aa_df3adfed_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -139,
#     mantissa: 0xcf12826e_e3b03cd5_e6684535_193f142e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -144,
#     mantissa: 0x9a665e50_63ae8772_628bbd8b_e6e5a0c0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -145,
#     mantissa: 0xd24b9bc2_68843b57_1edc1ca6_51792b50_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -150,
#     mantissa: 0x88229915_555a260b_f1933985_c2ad4972_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -151,
#     mantissa: 0x87d706d3_66e77691_58c70613_095b5bea_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -157,
#     mantissa: 0x9aa3677a_f6806c8a_a590f40d_c27bf35a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -159,
#     mantissa: 0xf2f74173_33b7899c_3da0f7d1_46752806_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -165,
#     mantissa: 0xf6406645_b226a962_fd170d5d_bacc8db2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -166,
#     mantissa: 0x9f5974cb_13fd6a60_6d79e36a_1a47c76b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -172,
#     mantissa: 0x915fe6d9_08cb3c71_3d2a1a8c_153c7b49_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -174,
#     mantissa: 0x9fd99bb3_b7e4bef6_034a74fb_2a943208_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -180,
#     mantissa: 0x84809487_64c96528_2344ed92_deecd63b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -183,
#     mantissa: 0xfd354551_2c172414_551e38b7_0d67a8d0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -189,
#     mantissa: 0xc03c1292_a2f44db9_dfc2a3fe_9ace24a7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -191,
#     mantissa: 0xa259aa50_c8f77074_4f21902a_edf2c548_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -198,
#     mantissa: 0xe3ae8f92_f9afe2f4_d2f8cdbb_69f3e4c5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -200,
#     mantissa: 0xaa4fe723_c8518454_b4ffd11a_4a605ad3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -207,
#     mantissa: 0xfede3161_19937124_6c0eb5ba_71ba3980_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -233,
#     mantissa: 0xb985dacb_b05624c4_0ae3ad9c_0e9ce6a7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -129,
#     mantissa: 0xce367ac1_65fbf6d2_1eebc89a_5677c83f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0xd7451cfa_8d681d28_e5199acb_1ea93c33_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0xdac4e8ed_09c82511_304d2ce9_878ea163_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -135,
#     mantissa: 0xa9baa261_98ed3619_a1be08ea_68cacb15_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -136,
#     mantissa: 0x9259a04c_ac831fdd_d05d4f00_cf99ff98_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -140,
#     mantissa: 0xb72616a9_aa11218c_81b4b053_8206a356_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0xc1d03718_62084985_9e946b98_719018d5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -146,
#     mantissa: 0xcbccea64_f92a46e0_263fd1df_4ef1be89_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -148,
#     mantissa: 0x99c12e69_7160b3ff_8168140f_3cabee3d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -152,
#     mantissa: 0x8b834919_f48b60da_8196319c_fa6f0b26_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -155,
#     mantissa: 0xa2b4d915_7e1e4010_c496c8db_027f70eb_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -159,
#     mantissa: 0x81dcf4b2_882b7b46_e960d151_a8256af5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -163,
#     mantissa: 0xf6311885_7afd0e3a_8676a623_d724275d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -167,
#     mantissa: 0xaf642723_dbecedc4_7666bfad_9f0d29a3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -170,
#     mantissa: 0x8bd2064a_154b212c_f2c8d7c6_129fdb0e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -175,
#     mantissa: 0xb3e58e80_d01e3770_04a596eb_d8749144_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0xf73ffc9b_9709293d_a1ee0003_f80ae235_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0x90fdc691_e732e730_fb39b8ab_3ece0942_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -187,
#     mantissa: 0xaf029e0a_09bc9312_ecb89e2c_c2fed8b4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -192,
#     mantissa: 0xbc932d21_df50885d_6ceac712_55e0cdf5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0xcaeb664a_7c0878e3_dfab5f78_31761c65_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -201,
#     mantissa: 0xc9995bf3_44227d48_a559ab66_79796f77_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -205,
#     mantissa: 0xd160ed92_5732a9c6_10ae03b7_f76a3c71_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -129,
#     mantissa: 0xb137741a_805f9305_ac4e2c0e_2937e2a8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -234,
#     mantissa: 0xb2eb5bd2_b76d6242_b06595a6_db384fd0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -130,
#     mantissa: 0xaafb5f64_f7cb135d_12a5cde3_aef6801c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -134,
#     mantissa: 0x9e9199b7_e8871f16_7872e7d5_d9aa35fb_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -134,
#     mantissa: 0xc63bd4c1_d0409d2d_4794ec52_3c50f294_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -138,
#     mantissa: 0xae6e4c6d_8e5f1342_401e85e9_61169d7e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -139,
#     mantissa: 0xb9abb7fa_3771da68_64915dd0_cb571956_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -143,
#     mantissa: 0x9230a23e_bda11657_32c39c55_9f512f20_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0xbdc29a2b_5b754e57_56125341_9019fa33_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -149,
#     mantissa: 0x855fe341_3a54bfc1_93b42aa0_4a079075_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -152,
#     mantissa: 0xf53d0f71_3092672c_d9ff6774_edd4d61d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -156,
#     mantissa: 0x9ae0209f_00a0c421_761dd7c6_0d231560_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -159,
#     mantissa: 0xdae2ea89_7dd7f081_032af0cf_9cb4718b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -164,
#     mantissa: 0xfa62f137_eb7a48a9_11a2dee4_db0e30f3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -166,
#     mantissa: 0x8f26219c_bddc6656_3e260219_4505ee2b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -171,
#     mantissa: 0x956ef7e2_7213f785_4a0f1e6b_3711bd46_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -174,
#     mantissa: 0x8f27d6e0_39c41e10_7d9d9e98_c1071f54_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -179,
#     mantissa: 0x89505c4f_48ab14f6_0e0a2d25_67ed609a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0xe2123443_7ab0e239_e7b235ef_ddda7087_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -188,
#     mantissa: 0xc8770de8_5b07284c_ac5f2d48_05cb6cec_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -191,
#     mantissa: 0x9088b7f7_b0d47e07_45800fed_78b71f1b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -197,
#     mantissa: 0xee5eb0da_fe7e6064_f5c20040_a01d548c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -200,
#     mantissa: 0x97bc19e9_d3704f89_49dcdaca_7077c013_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -206,
#     mantissa: 0xfbad1991_6b56dafd_2c185023_8902df79_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -234,
#     mantissa: 0x9d580228_610d266d_c0536d67_b6871533_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -129,
#     mantissa: 0x99a8c59c_3a74535e_45a067dc_14f053ab_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -133,
#     mantissa: 0xaf386e30_1b15f93b_4d629847_01e1602a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -132,
#     mantissa: 0xc0641def_772d82ed_b0e2bbee_69c32ddf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -136,
#     mantissa: 0xcd259497_1ef2127b_584155f3_a7b6ffd9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -136,
#     mantissa: 0x89fde3eb_4c10b862_1fbb5efc_bd28d10d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0x839ac5de_dffc88e2_9548a34c_9cb17d6d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -142,
#     mantissa: 0xbcb53a8f_c4828828_ec893064_dfd05269_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -146,
#     mantissa: 0xa12ad80a_d6f69c41_323ab48f_e64c5bed_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -148,
#     mantissa: 0x98137067_4bd5c651_a4429494_84e4449a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -153,
#     mantissa: 0xea46e6d7_497962a7_8626568a_82bfc86b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -155,
#     mantissa: 0xa231cebf_75852ecd_654a7320_a3809d57_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -160,
#     mantissa: 0xe31665a5_19758edd_8c9e1c94_b6e4aa01_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -163,
#     mantissa: 0xf6574974_2a247136_c156b981_e3c09a23_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -167,
#     mantissa: 0x9ddb44c6_b9c0dab2_017680ee_f2099617_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -170,
#     mantissa: 0x8c1f6ddc_79dd4f08_a876574c_e6860637_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -175,
#     mantissa: 0xa571f3f2_0c0c8fe9_4e616fe5_c0d599c0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -179,
#     mantissa: 0xf7dd8f3f_3f835272_593a3620_a10420d0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -183,
#     mantissa: 0x87946c8f_95dc63af_15197951_f9069408_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -187,
#     mantissa: 0xaf6193d8_00d1b114_12abdb69_9817a150_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -192,
#     mantissa: 0xb2a9b0ca_03cd48b6_3ba93ed2_eff063fa_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -196,
#     mantissa: 0xcb225152_4670f806_0f0dd85a_d8074481_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -201,
#     mantissa: 0xc034d4e2_47286b85_e21b2767_7b3a4fdf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -205,
#     mantissa: 0xc7c33350_7dea8dae_7d37b84a_4665e57e_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -129,
#     mantissa: 0x8bedf84e_a0692456_e480be2b_cb747d5b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -233,
#     mantissa: 0xd964233a_46404a25_e1c341d4_4bd0424f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0x8a025fb2_3e147a3d_7229a678_5698e70f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -135,
#     mantissa: 0xa7a6f93b_4fc18198_a23a393f_86633158_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -134,
#     mantissa: 0xae3142a1_4db36a95_d27b9737_f32c337f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -139,
#     mantissa: 0xeb455b91_440de444_9b4c6d96_5ce29562_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -139,
#     mantissa: 0xab565b22_96c30319_ae637280_056a5c74_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -144,
#     mantissa: 0xe085a3e7_bf7b4886_96053cc3_d539af63_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -145,
#     mantissa: 0xb3f5574b_dde42fc6_6e806c60_c557e99f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -150,
#     mantissa: 0xddb29863_1f96f76f_1408387c_8977a369_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -152,
#     mantissa: 0xec3900f2_2876e97d_003a6f8a_389ac815_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -156,
#     mantissa: 0x87a3e41f_62a857f8_825f45be_a4f6a64c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -159,
#     mantissa: 0xd4c198fb_753cb8c2_6617de6a_d9e32824_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -164,
#     mantissa: 0xe3820a51_1b56ee50_fd533a2b_ba59a7fa_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -166,
#     mantissa: 0x8be02bd2_fe49b9ac_13921472_7fe8fae9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -171,
#     mantissa: 0x8b7f50a6_94c4906f_ad394b39_badb15af_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -174,
#     mantissa: 0x8c4de9f5_cf9e32d4_bfc30aa7_f5eb2019_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0x82d7a25d_91e2f695_5cbe01e4_dac29c0a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -183,
#     mantissa: 0xddeda2ec_9727deef_17a0a131_d43360cc_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -188,
#     mantissa: 0xc21b0520_76c4e792_c8dc4b6a_2392dfd0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -191,
#     mantissa: 0x8dfdcb3a_984998bc_eb700fc4_3b4bf6b0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -197,
#     mantissa: 0xe9bd4305_33547119_8845d133_5e30cd68_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -200,
#     mantissa: 0x9505dd65_58ce42d2_e9582e86_87750346_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -206,
#     mantissa: 0xf2b0c8b0_7e99c106_170939ea_2eb59546_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -232,
#     mantissa: 0xc93243b7_ef9ee356_9a87f0ec_e01b7851_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xffb2a2a2_75e68905_2a3a2541_c576895c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -134,
#     mantissa: 0xc911ff96_03c2d772_5fe95e8a_8d65dd6e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0xa5862eae_d33c46dc_5d8aa6f6_3a1356e8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0xfc8d4f70_6944b7d8_2b56a65c_c010ab38_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0xfa8e1244_dcf37477_c10140e6_43f40ba0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -141,
#     mantissa: 0xb5a64e50_7bb869d7_af9dcc67_12927bc3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0xb1e2a3aa_1ce58c45_97dd2c0b_9bc31b51_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -147,
#     mantissa: 0xf1b92ed7_b4c334c1_2256e639_a230e994_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -148,
#     mantissa: 0x92e091c5_9972c770_7fe3f2c9_a66031fe_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -153,
#     mantissa: 0xba437b5c_d54a8643_056e3377_04899d05_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -155,
#     mantissa: 0x9f1df924_13bf736c_01a4bcba_1f8023e4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -160,
#     mantissa: 0xbc51c539_f3e03875_dd188300_d9ca416c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -163,
#     mantissa: 0xf42275b5_908e7cc3_73676fba_267133c3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -167,
#     mantissa: 0x871255da_03596336_1834ec8d_28489b1e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -170,
#     mantissa: 0x8bcbf2f5_682e890a_87b33c9a_fecf70ac_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -175,
#     mantissa: 0x90fe0788_cf9d2f20_98f21466_4628473a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0xf8609726_41a086dd_5e8ce182_f79427db_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -184,
#     mantissa: 0xf221197d_74254b77_bfe3b5ca_f3fa6ab1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -187,
#     mantissa: 0xb0402738_dd1a1330_896d4fa0_737eeac6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -192,
#     mantissa: 0xa1f09f09_bdd5c5b6_1a78610a_f2d8c255_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0xcc818496_9e0e3114_bfff0c04_9847843b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -201,
#     mantissa: 0xb048dc69_5306fea2_c4e34d93_79f499fe_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -205,
#     mantissa: 0xc7459302_0acbf8c4_6cdfe76e_f6e43c3e_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xeee75a67_0dfa4ef0_76bd2c06_fd4f0505_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -230,
#     mantissa: 0x96ffb60f_0ab98479_4433aa45_16607999_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -131,
#     mantissa: 0xed2908b6_05320133_d5334b42_b3c8e942_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -136,
#     mantissa: 0xd4ed2301_db3f50b9_2345145a_221bc71c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -134,
#     mantissa: 0x998f3a75_2cd5c0e2_f0418bb8_ef298ba0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -139,
#     mantissa: 0x9f2e5b75_d3754ca7_750c9c9c_1485fb21_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -139,
#     mantissa: 0x9c42ff4d_7d2a0a15_b2e73352_612b38bf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -144,
#     mantissa: 0xa4a607a5_8340594d_732b8ca0_df7ec91d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0xa895ce9b_bb16b4f8_2ff80029_4d103e09_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -150,
#     mantissa: 0xad430841_5fdbf938_2127dd60_cd5e9322_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -152,
#     mantissa: 0xe191f505_02161544_30e4e821_98001255_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -157,
#     mantissa: 0xde64b17b_dc8f5b4c_2db345a1_59ae883e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -159,
#     mantissa: 0xcde4a717_94d27b20_fcb827a9_7ea62d28_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -164,
#     mantissa: 0xc15e37e7_d4770445_d3e52ce6_d00ca8a4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -166,
#     mantissa: 0x88a0e73d_bbffbf00_a1cf171d_a2425554_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -172,
#     mantissa: 0xf3ce658c_37762971_ce5b90d5_1b708458_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -174,
#     mantissa: 0x89f0fdf0_0179a04a_6d570a16_c2e0992b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -180,
#     mantissa: 0xe9b68964_32c37b6f_696651b7_a6d6887d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0xdb303865_9d616278_977170bf_49045b27_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -188,
#     mantissa: 0xb065d566_b22e8c16_4a09ea9d_773f110e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -191,
#     mantissa: 0x8cb02a9b_e7a55a5e_dbed07bc_7bc1f326_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -197,
#     mantissa: 0xd76b5c32_6e68bfa7_bb61b905_6b2fd330_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -200,
#     mantissa: 0x93f654fc_a373278f_6ebbfa33_1e4ec35d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -206,
#     mantissa: 0xdff7c360_6b1eb1c6_0e9a1146_a46cc789_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -232,
#     mantissa: 0x8acd652e_db2b9238_2c48ef93_576dab6f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -130,
#     mantissa: 0xdf999bc3_9d3ec391_8cda5c84_0c5778c0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -134,
#     mantissa: 0x8641d16b_d6e99542_fc768aaf_1451d4c9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -132,
#     mantissa: 0x928c2c00_8c0b557c_db2da507_3eb51e69_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -137,
#     mantissa: 0xacf58b05_fb96c082_3ae247ea_00abf0c1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -137,
#     mantissa: 0xe2de719d_796bb80f_026a1057_8d632398_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -141,
#     mantissa: 0x8209f183_7001c7c2_96dd26f4_098e8b8d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -142,
#     mantissa: 0xa5338268_2d6859e3_a42c4a3f_c866a689_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -147,
#     mantissa: 0xb621f76f_f6b644b6_150b0b15_f8de8f1f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -148,
#     mantissa: 0x8b55ebc0_aef3a0e9_861ab8ae_3fcffe1c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -153,
#     mantissa: 0x92bf8b7a_ea1a3138_1d774667_70fa282c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -155,
#     mantissa: 0x996d8da5_97fc5a49_eed747a5_9587517d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -160,
#     mantissa: 0x99d6667b_dfee54f2_92821723_e411f6fe_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -163,
#     mantissa: 0xee47ab41_2b36710f_79d1cb77_e6fce277_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -168,
#     mantissa: 0xe32899c3_6d047102_059cbf2d_c1ad1787_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -170,
#     mantissa: 0x89ac2d4d_bb05003d_cd8de092_e09ac2e4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -176,
#     mantissa: 0xf9917516_5381409c_cdc43c09_e03b0f25_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -179,
#     mantissa: 0xf63a4dd4_1f6c3ae2_6f55e24a_dba0cef0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -184,
#     mantissa: 0xd455d484_676c0bd1_a113166f_4c2a09e1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -187,
#     mantissa: 0xaf955f99_e9d032a7_f958ef0e_55dc7229_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -192,
#     mantissa: 0x903715b4_fe4905c5_d6e05954_ee81d507_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -196,
#     mantissa: 0xcc777bc0_e2e1acde_1d62f810_f4769165_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -201,
#     mantissa: 0x9efa1e60_a9be49a2_0a48a9f1_5a69f1e3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -205,
#     mantissa: 0xc6c9d5e2_04fddde7_81c2e68d_62fe4b61_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -130,
#     mantissa: 0xd3fb1ff5_40f92fd3_8d1ed56f_0888dac0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -234,
#     mantissa: 0xb384b981_065a9744_4b01a092_22ca3c54_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -131,
#     mantissa: 0xd3057d83_320676cb_e26d1450_dd02fe17_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -136,
#     mantissa: 0x960f4984_9ae9e354_19efdc04_e529e1f9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -134,
#     mantissa: 0x8a283233_6bf8fa4a_62eb6b8c_47a56cfa_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0xe6546060_7551f414_d6128883_29ec935d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -139,
#     mantissa: 0x8efc10e6_09bbf123_306b101d_b0be9108_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -145,
#     mantissa: 0xf7440a76_8562260b_d907ec45_e30ea246_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -145,
#     mantissa: 0x9d1b2d20_ccee882a_61c12032_1e077090_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -150,
#     mantissa: 0x87697ce1_f22c72a7_8f863ec7_a3f61ab9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -152,
#     mantissa: 0xd59d9be2_938d98b6_b71e9aeb_d7b434e1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -157,
#     mantissa: 0xb426b731_5ae32d4f_122b84ba_6d4aa026_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -159,
#     mantissa: 0xc5882d28_907677bb_ae55e3b4_ce28c1e1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -164,
#     mantissa: 0xa16e2cc8_dcea2cd0_3ef6fa36_19472f6e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -166,
#     mantissa: 0x846b202f_fefa69c9_3b9ca699_94ec6c43_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -172,
#     mantissa: 0xd0a9019b_32d22e46_3f99964e_7c4f8271_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -174,
#     mantissa: 0x86be08c5_8bd412f5_643476c0_6321d4ab_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -180,
#     mantissa: 0xcc27fe9d_606be552_f1bed64b_9f85f2fd_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -183,
#     mantissa: 0xd765959b_daa60e63_7d978336_a625c6f7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -188,
#     mantissa: 0x9cb802f7_46ec5417_a93a6cd2_1ad6c4b0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -191,
#     mantissa: 0x8ae4e349_5add9e91_ca23d66e_fbe57667_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -197,
#     mantissa: 0xc218fddb_c3236a5d_95b3f256_d5346b41_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -200,
#     mantissa: 0x9294e79a_30994d3a_1ed306e8_4d684549_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -206,
#     mantissa: 0xcb241bd9_7674bb34_959dce90_3389e892_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -231,
#     mantissa: 0xe45aa320_5b914eed_f5870dea_c736d8ab_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xc92e37e5_047aa42d_550665d1_f7e63374_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -135,
#     mantissa: 0xc36e9970_2cd87191_bef69239_6e760141_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0x84a31dde_81b3f9da_c1b118bb_e7053df8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -138,
#     mantissa: 0xfed014c6_43b455b9_c01cda3d_8e5ac6ec_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0xcfa5f303_ac7d8a03_0aa4fec1_b16b0bd7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0xc3bcc8d7_ce8dd477_17f123b1_6c9d0ea9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0x99658077_460f98ab_1974218f_e5518de7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -147,
#     mantissa: 0x8cec6746_1afabe95_f852e5d9_9c250835_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -148,
#     mantissa: 0x8350217d_dd22a578_d7613dd6_5de42d8b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -154,
#     mantissa: 0xe9d344f3_3bb98497_5cf2a263_980f8101_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -155,
#     mantissa: 0x92884626_715b1c0c_bce84593_4670a831_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -161,
#     mantissa: 0xfbdc74d5_a98a6150_5bb4a198_179aad8e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -163,
#     mantissa: 0xe620682b_29327ca5_6f0b4885_0aaf4d84_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -168,
#     mantissa: 0xbe6bb716_beca178c_1994f68f_a8eb9add_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -170,
#     mantissa: 0x862c3b81_1967eefd_b1b0dd5c_f7548c99_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -176,
#     mantissa: 0xd57f6266_1b27f7b4_1c3ea17d_38f81653_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0xf1b6eab9_f3531761_eeb79bd4_4b89435e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -184,
#     mantissa: 0xb8ccf2ff_b4fb9f80_a7daded4_6dfb16eb_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -187,
#     mantissa: 0xad5c5dcd_38ed601f_3830f4ff_63d68773_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -193,
#     mantissa: 0xfeb7c5b8_73bc546a_ec6b06d6_e81a8a05_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0xcacc536d_07961a86_53d06c50_25d248aa_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -201,
#     mantissa: 0x8e21b1b1_320f2ba5_8556fbd3_1c43dc8b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -205,
#     mantissa: 0xc54ff626_acc1eb01_4a6a98e9_8276b6fc_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xc087a811_2d8257cb_41cd8fff_813feb7c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -231,
#     mantissa: 0xe82ab252_8461c748_8bebc793_da0b60f5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -131,
#     mantissa: 0xbfefcbd6_1b58fa8c_5790d8a1_ccb7af68_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0xe1e12b54_65502651_04f2c30c_acf8315a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -135,
#     mantissa: 0xfcc7f5b9_435a3b23_b7b7c93b_3e9c33a4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -140,
#     mantissa: 0xafb2acf2_b4370c5e_72962b97_f93185cf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -139,
#     mantissa: 0x8407abd6_10ad74c4_36b2de69_77044dd4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0xc06289cb_f2f5d19e_d0a7174b_68dcb0f6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0x92b6daa1_e689fffe_f90d6ccc_9f4b6739_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -151,
#     mantissa: 0xd7bacc51_0cc1235e_edf9aaa5_140d6d1a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -152,
#     mantissa: 0xc9cc1136_51182aca_2a42e0c5_87376f72_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -157,
#     mantissa: 0x9304c2ec_92c3e832_bb61770e_2a6a2ba2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -159,
#     mantissa: 0xbc95d9f7_537b38a5_415183d8_0cd5f9c5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -164,
#     mantissa: 0x86c3134a_f0d59181_7c8f7ec2_b4c31487_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -167,
#     mantissa: 0xff2956e1_5d0cdc8f_16cab646_bbb123a2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -172,
#     mantissa: 0xb1c009bb_a1463c4b_8b18bcf5_9e81053a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -174,
#     mantissa: 0x82d0df7e_8b10717a_6607141d_b315181d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -180,
#     mantissa: 0xb1028213_1b0172e7_1f75f3ce_58539814_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0xd270a71f_c2d67b35_9a16e0a2_ed6099a2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -188,
#     mantissa: 0x89f791d0_d122ce43_1656341f_3dcee771_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -191,
#     mantissa: 0x88657127_fa195d8f_10da8a36_5992608b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -197,
#     mantissa: 0xad20dad8_148f4a26_b72f24cc_84e82aab_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -200,
#     mantissa: 0x9089f114_e0c57ac6_1be6c482_a0742313_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -206,
#     mantissa: 0xb6b31eb5_66ef4f98_ff6cbdb4_49fdfe18_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -231,
#     mantissa: 0xeebb2d23_3435505e_704485cc_f017aca5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -130,
#     mantissa: 0xb8628891_3ead525b_400aff09_a7efa1b7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -135,
#     mantissa: 0x9665874b_aac6d0da_ba728366_a3676843_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -133,
#     mantissa: 0xf3ee0473_874cce19_ed882121_05b41ad0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -138,
#     mantissa: 0xc566e2d8_2c60702e_f2a5b32e_de7e6de9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -137,
#     mantissa: 0xc0281b92_56984d97_e1640dfb_b13b5667_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -142,
#     mantissa: 0x99772650_fe57da22_bed0ad1e_a89f3a05_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -142,
#     mantissa: 0x8f2e941b_646cc52b_32460b87_5c21502a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -148,
#     mantissa: 0xe094f83b_dd8b1726_c63a28aa_81421058_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -149,
#     mantissa: 0xf78b0ac8_8c0d1270_4b669e78_9c8824e2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -154,
#     mantissa: 0xbdcdd83f_8cfc0d63_6cc53cc5_32bfa5a8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -155,
#     mantissa: 0x8b79c9ba_caecaee5_faa4a258_106d5896_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -161,
#     mantissa: 0xd05e4332_db43aca5_20c1c681_6ade2fff_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -163,
#     mantissa: 0xdd09afcc_d4f11603_73b0ffe4_336cb907_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -168,
#     mantissa: 0xa06aa1e9_65aa2a0e_27c8850b_70ca86ee_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -170,
#     mantissa: 0x81e82c90_c3551188_06fb4e05_7c8471d8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -176,
#     mantissa: 0xb6daf116_0014316e_bbceb304_53991223_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -179,
#     mantissa: 0xeba2d0fc_d965fc60_66e59349_ab9bbf2f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -184,
#     mantissa: 0xa0a0e16d_2ef328c2_5ed02951_251ca56a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -187,
#     mantissa: 0xa9fa7464_a5dd2626_ddadcdd0_806099c7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -193,
#     mantissa: 0xe04c4569_ea2eadd4_8df638ee_3fa34b7e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -196,
#     mantissa: 0xc7cc53de_f192efee_bc818ad7_b3a38f12_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -202,
#     mantissa: 0xfd297967_1cba82a2_0270fb6b_d1594707_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -205,
#     mantissa: 0xc2cf6134_6c71ad4c_7921b05b_28649a63_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -130,
#     mantissa: 0xb19f3fbf_8298049d_325cfe55_0c63036f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -233,
#     mantissa: 0xcbd096ad_b3ee03fd_c3511898_fb68a9d4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -131,
#     mantissa: 0xb139bc26_0e037020_0cb340eb_9e5e4c2e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -137,
#     mantissa: 0xb1d74a56_f0c6a396_e97a10f6_740d40fd_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -135,
#     mantissa: 0xea33329b_6445c92a_45d71249_3c685ee4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0x8b6a941a_2e5087db_42ca7e50_bfc42c59_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0xf606e6dd_be2fee46_bfa34761_cbb2103f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -145,
#     mantissa: 0x9a74b358_584fbc69_24267bef_324a5a53_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -145,
#     mantissa: 0x89ae326e_16c67cb0_c1e5121e_68a0ac93_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -151,
#     mantissa: 0xafbde3c5_afe156ed_f6234525_ca0c2297_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -152,
#     mantissa: 0xbee1ad83_b204b160_0f169603_9824c643_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -158,
#     mantissa: 0xf36b4b9b_0f529e1a_781fee50_b4201423_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -159,
#     mantissa: 0xb3cf1b82_4c3d8ba8_7971c019_634ced51_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -165,
#     mantissa: 0xe2caf93c_526e4ba5_ef094a98_ba808b46_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -167,
#     mantissa: 0xf51b577a_b72c9e19_ec27407e_8836da03_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -172,
#     mantissa: 0x97eb35a7_34cf81ad_5b0fa90b_31ce9966_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -175,
#     mantissa: 0xfd0264fc_af20fec1_b36e95a2_c842beda_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -180,
#     mantissa: 0x997a3f88_066850ce_71ed8f87_224a8c40_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -183,
#     mantissa: 0xccb2c140_be5407dc_46eb5cc7_2e8997dc_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -189,
#     mantissa: 0xf2613d09_433ebba1_85147eca_38a91d7b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -191,
#     mantissa: 0x8557e8ed_b1bb8a7b_bea2443e_c96fad38_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -197,
#     mantissa: 0x99d94b54_ff160dba_e3c520a9_b9b14380_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -200,
#     mantissa: 0x8de72b9d_75ec6a4d_582593a0_79727aaa_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -206,
#     mantissa: 0xa3b761f5_8d2dc2df_98c82a8c_14e72abc_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -232,
#     mantissa: 0xe05086a5_c6824544_daaf6a73_925186ba_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xab32709d_b8310cb7_0a97b7ca_c1a18a72_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -136,
#     mantissa: 0xf0b2aaf0_846e329a_f184a9e6_f18c32e8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -133,
#     mantissa: 0xe2f0d6cf_d97a00ff_3ad7eb67_5bf06c35_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -138,
#     mantissa: 0x9e9b4fca_c72b4dec_c035e243_93bab3ba_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0xb37a7613_d4b74a7d_ae1bc79c_b1a2154e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -143,
#     mantissa: 0xf86f0299_3296a499_e1edbc4d_7215da05_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0x8679321a_0a04efae_01c62e59_86a38928_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -148,
#     mantissa: 0xb7a36a8f_2bb37419_fa0d7480_92ac8a64_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -149,
#     mantissa: 0xea03fbe1_246a2ae1_21aa533e_5792b9fc_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -154,
#     mantissa: 0x9d19e6ce_fb34ac23_abc93ad0_bf9ee8c1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -155,
#     mantissa: 0x84c80d85_40b72a6d_dbe99cb7_4efc31d3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -161,
#     mantissa: 0xaec2b52c_221f8197_97c9a665_947e25e9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -163,
#     mantissa: 0xd3e5e6c7_e03af4fc_be4356f7_96747ed3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -168,
#     mantissa: 0x885b1617_ea010141_61aad550_2dbb248e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -171,
#     mantissa: 0xfab504ed_0d78b892_14b42b90_ddacf957_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -176,
#     mantissa: 0x9d73424d_0c8cb2dd_b6bc85c9_bdfc5c14_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0xe4bba925_ec24f2d0_c15199c6_c1993c4b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -184,
#     mantissa: 0x8bfe4e05_40d4329e_4a725856_95ff3953_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -187,
#     mantissa: 0xa5df21ce_431fd75e_ed39cddf_c60207ed_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -193,
#     mantissa: 0xc5a99370_afb5b712_2c8f1765_d7252eec_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0xc3dea9d6_ef58fb95_9a88550b_97bcdf2f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -202,
#     mantissa: 0xe1552a6c_6c093453_f216246f_7329a720_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -205,
#     mantissa: 0xbf7f64bd_d47b079c_f17334fc_7bca1451_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xa5b8ea65_166348fb_799c893c_c9e1f712_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -231,
#     mantissa: 0x8de90210_a22f281a_4f8d42ff_3857a25b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -131,
#     mantissa: 0xa57122b4_bfdd3284_583435d1_c371910e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0x90af270d_2f8eb29f_eae5831d_4172f152_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -135,
#     mantissa: 0xdb19f6b6_ce7b0892_cf64d537_bb531b45_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -141,
#     mantissa: 0xe3f8bda5_bedde9b3_3aa4933e_ffd07827_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -140,
#     mantissa: 0xe700dc5b_551a5fe6_ccc4080f_5d77ef7c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -146,
#     mantissa: 0xfe76b8d8_8f1ad60b_1a6a658d_bd257fca_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0x81e4eac1_1930e740_64d652d5_1b48873f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -151,
#     mantissa: 0x92284048_831d8d46_b8b40523_67a4b4dc_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -152,
#     mantissa: 0xb5169008_8f181a4f_0f2ff690_7994e444_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -158,
#     mantissa: 0xccad0c7c_73443d73_a4dd6683_2dcf832e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -159,
#     mantissa: 0xab968d03_a7b2225a_5ed1fcf7_7e5e590f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -165,
#     mantissa: 0xc0ef81e0_c892045a_028529b4_6d1d1997_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -167,
#     mantissa: 0xeb44af24_79f24c41_5cbd2b5c_6a9c9fc2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -172,
#     mantissa: 0x82c43f85_a231e7e6_03c1e765_a78a1284_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -175,
#     mantissa: 0xf43381ee_538433de_cd420af2_444c9733_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -180,
#     mantissa: 0x859e386a_91401e56_d3d1c99d_868e2422_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0xc6945c20_5dfcedad_65e19185_d39058a6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -189,
#     mantissa: 0xd54945ee_3e34d93a_c6e917d9_87d0d23e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -191,
#     mantissa: 0x81f35ded_34a6e990_57510b03_76afbf77_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -197,
#     mantissa: 0x88ba10e2_dc180c4b_debba048_6532c45f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -200,
#     mantissa: 0x8ad947b6_8a8f356b_bb3fff9b_8a23b9ba_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -206,
#     mantissa: 0x92a06132_04a2775d_b852cd08_2ef1df92_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -233,
#     mantissa: 0xcb5404c2_9d7e2308_6b7d2a25_a17d2eee_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -130,
#     mantissa: 0xa07c83c9_b02dda62_df1ffa52_977a936e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -136,
#     mantissa: 0xc641983b_fdf57050_46b4d438_e453c8a3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -133,
#     mantissa: 0xd5067021_0e8d3fab_85243d89_759d98fa_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -138,
#     mantissa: 0x82fd2cc7_7ae8e47e_030ea534_42303c17_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -137,
#     mantissa: 0xa8e986bc_55a933e4_10ab2df2_78878aee_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -143,
#     mantissa: 0xce2c03b3_ae2fada9_9c95ebe0_14013dde_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -143,
#     mantissa: 0xfe0ddfab_f1d710e5_ad82e62a_2d16ef61_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -148,
#     mantissa: 0x996ff512_8c6731cc_24f7215e_ccb816ad_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -149,
#     mantissa: 0xde109042_ee5e30c6_494a2aba_d8a759b9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -154,
#     mantissa: 0x845ca36b_262e139b_be6669ac_2b17258d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -156,
#     mantissa: 0xfd47cec6_d39b4de9_cb01ac6f_b29dd76a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -161,
#     mantissa: 0x949ff0a5_78e85553_9be5c90f_a519b07a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -163,
#     mantissa: 0xcb2a265b_ad2c8c38_8644512b_a81a8248_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -169,
#     mantissa: 0xea3a83a4_70f625ea_dd29c399_1d397ee3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -171,
#     mantissa: 0xf1a0c091_94d6f7da_abbfba8b_fc0e1691_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -176,
#     mantissa: 0x8895524a_0ba700f2_d4ca2cba_04e59693_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -179,
#     mantissa: 0xdd8b2b6e_a7c3ab53_4b76439a_b9ca44ab_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -185,
#     mantissa: 0xf53dcaf7_c704544d_a694d006_a2d0cc3f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -187,
#     mantissa: 0xa1656c43_c6a526d5_59c7b459_44251d9c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -193,
#     mantissa: 0xaebb5637_340a8675_98ef8f2c_ba47d390_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -196,
#     mantissa: 0xbf60ff9b_5c000f67_70512990_87a09029_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -202,
# ...
#     exponent: -178,
#     mantissa: 0x9c101ff9_e8c6f4f5_ea9c1056_559bf575_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0x9a92260a_4c8d6ea5_b40912c5_9d9b2ac7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -186,
#     mantissa: 0x9196dcdb_0657fc29_f1f2d661_432d1119_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -188,
#     mantissa: 0xe617977e_8f028754_a8355366_6b2a06c5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -195,
#     mantissa: 0xd7d321e0_ff73f82f_469d6832_c9cdb9ec_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0x8b5fc0f7_1dbc36e6_3a8937ba_d5674ca3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -203,
#     mantissa: 0x8117dff1_3a125a0e_dec4fd86_844d42e9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -205,
#     mantissa: 0x8b209d86_571e0e7f_e97c2b78_7b8600b0_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -131,
#     mantissa: 0xc5b3d124_083be6ed_c4d0f183_6228a2f1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -234,
#     mantissa: 0xb5286d41_3fa02c45_4d729869_ab68be81_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0xc5a8f908_34750c96_6adc833e_78d0b302_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0xf6c9ae3d_77d186da_114f389d_9f573ee1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -135,
#     mantissa: 0x83a91528_1bf9688f_4bb14ce4_e32bc645_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -143,
#     mantissa: 0xc50cb030_fc5de354_05654c68_8b3b5ab0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -140,
#     mantissa: 0x8c3a523f_1e0f1aa0_7bb89201_6ead05e3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -148,
#     mantissa: 0xe08679a6_0278b755_03be0693_eaf3a468_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -146,
#     mantissa: 0x9feb616a_7d1521b1_d29b7107_39fcb433_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -153,
#     mantissa: 0x84836aaa_913c2647_3ab9f716_d7df6461_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -153,
#     mantissa: 0xe2d0e092_6fd03fbc_f58fd5a4_7096aaad_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -160,
#     mantissa: 0xbfc41d98_d2fac9aa_4d02da2e_1f4700d4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -160,
#     mantissa: 0xdb3467a9_81470174_79710356_92d5bcf2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -167,
#     mantissa: 0xbba9b968_2d958372_70f2b865_cd910319_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -167,
#     mantissa: 0x998ec38e_b388be30_13974605_e9e60282_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -174,
#     mantissa: 0x84808124_4fa403c7_552731cb_4af09f91_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -175,
#     mantissa: 0xa30e2033_687253d3_9d8ab2f4_c6068891_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -182,
#     mantissa: 0x8d5fcca0_d1a1194d_eb7f36c5_b0499249_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0x87b8af18_fa7a97c1_331e84d5_e0699809_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -191,
#     mantissa: 0xebf6a2e9_b3aa6907_6dcbbb6b_bc638ba0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -192,
#     mantissa: 0xb5d6fac8_04fc4568_20b696c0_120f8947_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -199,
#     mantissa: 0x9e4056da_e3e8d516_f684e4c6_5dbdc3f5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -201,
#     mantissa: 0xc6cbf3cb_9227e16b_cd3e344f_fce26013_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -208,
#     mantissa: 0xb0dd220a_a10896ff_d1ff6613_aae87645_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -233,
#     mantissa: 0xba08b02d_ce6c66ea_8c66df59_fbe2d800_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -131,
#     mantissa: 0xc3728df0_548a9b63_930432e8_28ee63c3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -138,
#     mantissa: 0xb2f68d9c_3f2ed354_92870bb4_d6f28391_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -133,
#     mantissa: 0x8237e2d1_0c542f98_c0fb2701_4dc89421_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -141,
#     mantissa: 0xee530bff_7d489be2_ff8ab250_81a2ddea_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -138,
#     mantissa: 0xd0180110_a945357d_c4458187_03ebe664_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0xbe3b0c48_378f102b_245612c8_c991a0b5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -143,
#     mantissa: 0x9e41c44b_e850ecf4_790afe1c_19bdb63e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -150,
#     mantissa: 0x9076f4fc_eebee630_2e1bdd6b_25ec676f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -149,
#     mantissa: 0x8c54a0b2_ac95dba6_6fe19263_aec534e5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -157,
#     mantissa: 0xffbb1028_8c7844bb_f367a213_bebfa2c6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -156,
#     mantissa: 0xa2cceff7_780d069d_e9910ec1_2b26ed02_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -163,
#     mantissa: 0x9401f2cc_c18976ef_b79e5359_006a8200_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -163,
#     mantissa: 0x85199017_f5820bd6_f20018ec_e33b77b9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -171,
#     mantissa: 0xf15ffb9c_3378578a_566daa62_8e04ce19_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -171,
#     mantissa: 0xa194e799_5e3585fa_0f0fb71e_9f5a2589_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -178,
#     mantissa: 0x92124487_3881e71f_02a68515_b13dee7f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -179,
#     mantissa: 0x975d32ba_d2c7da2c_be597dd6_b2293637_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -186,
#     mantissa: 0x885ed159_7f6fd3c9_1168b632_60495659_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -188,
#     mantissa: 0xe16cb5db_6aaa55d2_dcd01317_613ef2be_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -195,
#     mantissa: 0xca530abc_9aeb9731_05001f63_6e784a0f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -196,
#     mantissa: 0x889db0a3_bfae2270_267ef3f1_5def2c12_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -204,
#     mantissa: 0xf23fb98c_31fdba80_173eebe6_382eb78c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -205,
#     mantissa: 0x8870928d_c76d23ed_b5bb9860_70cd5763_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -131,
#     mantissa: 0xc14e837f_7493318c_aabfef07_d2b6f581_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -231,
#     mantissa: 0x80cd3e6b_80bf638f_859ca3b9_2869e65c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -132,
#     mantissa: 0xc144d293_6bbc2ade_fe48a446_b1b7e7ec_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -140,
#     mantissa: 0xe6b401aa_e4f5ae2a_a0a6c9fd_b0b4c0a0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -135,
#     mantissa: 0x80beb87a_89430b3b_5f5f78c8_477d8bef_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -143,
#     mantissa: 0xb83cbc71_506dbd62_0db70085_cecebb37_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0x8923e70a_f39c2984_f6dc795e_258e0eda_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -148,
#     mantissa: 0xd1fb092a_42f609c1_54e3f91c_b1efe863_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -146,
#     mantissa: 0x9c6d4242_00df456f_43de1322_79466542_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -154,
#     mantissa: 0xf7f1cec6_da66c304_5d0672a3_100a2637_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -153,
#     mantissa: 0xddea078e_d874a214_b3e05f3b_4d601c4b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -160,
#     mantissa: 0xb37bea4a_1b7c1b1c_ae636da5_e9e723e1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -160,
#     mantissa: 0xd68740a4_114d77e1_8625eea4_5ad5d3da_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -167,
#     mantissa: 0xafbc2ca8_99eac803_340607b0_e131004d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -167,
#     mantissa: 0x9654dd88_18d857db_0c89d82f_5d5d6bf4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -175,
#     mantissa: 0xf84f24e4_4a33e1dc_73294489_cd573f8c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -175,
#     mantissa: 0x9fb0775a_bed58e3b_6c45b633_540d349b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -182,
#     mantissa: 0x848eb453_8fab4302_0fbb1b65_db47ed8d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -183,
#     mantissa: 0x84f99a3e_db678cb7_94dd7bb9_12ceace4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -191,
#     mantissa: 0xdd69abee_c35f7e42_81b4c203_32b95d69_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -192,
#     mantissa: 0xb23d9b26_842b70d0_500c75ed_a1afcbfe_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -199,
#     mantissa: 0x949cfb42_2cd8341e_e5ed8ddc_d0a06b7a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -201,
#     mantissa: 0xc2f49fda_05f541a8_07173f17_da7dc5c7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -208,
#     mantissa: 0xa6399cc9_4550f48f_f2ba83fd_67360386_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -235,
#     mantissa: 0xbf51204d_5f23548b_9e639f59_2da87e74_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -131,
#     mantissa: 0xbf32b77d_804d6fb9_be029a97_df57a015_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -138,
#     mantissa: 0xa78a8337_9ec3b34a_70454a59_bfe998a8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -134,
#     mantissa: 0xfec99613_556c9fc0_e1c6d193_c0d4e166_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -141,
#     mantissa: 0xdf2306ec_3505214e_6bbdef5d_49110ac7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -138,
#     mantissa: 0xcb99dac8_c3cfbe25_ea4c10eb_a56e121c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -145,
#     mantissa: 0xb224462b_01170361_cc3ce988_2773d679_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -143,
#     mantissa: 0x9add2c5f_97cc975d_3ba459d3_c4877f00_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -150,
#     mantissa: 0x87523de7_5cd47ba0_21a7150c_d5455bcf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -149,
#     mantissa: 0x89599382_ae8748c1_ca42814f_54f77cf3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -157,
#     mantissa: 0xefa17e27_12415df6_91c04118_8ebb5469_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -156,
#     mantissa: 0x9f61f3b4_3b6dcfec_d5d019e2_9ea9cc13_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -163,
#     mantissa: 0x8ac01c9f_a39df223_cfb711f9_cf7a5824_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -163,
#     mantissa: 0x82581a9e_1ac99b6a_8498c392_2acbf796_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -171,
#     mantissa: 0xe265187f_f0c99667_a94f8bde_3724009c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -171,
#     mantissa: 0x9e4a3dc9_b5f13173_8eb74a7f_61d407ee_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -178,
#     mantissa: 0x891639fb_1f003080_284b1912_26e1e7dc_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0x9456394a_2e146fd2_502a3d18_bc9aeab2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -186,
#     mantissa: 0x801120dd_9b600518_bf5b0bad_737e9d01_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -188,
#     mantissa: 0xdd0213b6_b689635a_40d3a882_87e9d5db_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -195,
#     mantissa: 0xbe247bba_9d372c93_6957804d_25b8779d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0x85ffdddb_ad281300_e557e2f9_a6950d62_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -204,
#     mantissa: 0xe3d702a3_1cea675b_24284572_e5c27c6e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -205,
#     mantissa: 0x85e240e9_28d732a8_7298a5c4_7cfbcc19_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -131,
#     mantissa: 0xbd311903_cc0ba87e_548d0691_8430be87_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -232,
#     mantissa: 0xe7bd254b_eeb4db1a_f541be67_4264fe96_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0xbd286522_825dc3eb_55bff0d1_08050953_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0xd84ae65a_85346284_bda3c72a_a7810bc2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -136,
#     mantissa: 0xfc07788e_d51bcdee_e37d1d21_d6a53e74_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -143,
#     mantissa: 0xacc116e3_ad831e4e_4b6483ca_1abde9a0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -140,
#     mantissa: 0x863f353e_33318244_8aba783f_42a43a87_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -148,
#     mantissa: 0xc4f005ae_1ac67c69_0bff98b1_1f84f418_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -146,
#     mantissa: 0x9926a91c_59367f1d_08db3f38_cf0bcfd6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -154,
#     mantissa: 0xe89d4446_aee9823a_2fa383f2_8b2f15f8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -153,
#     mantissa: 0xd94fca0d_4ad837a2_380326d8_b3d56f9e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -160,
#     mantissa: 0xa87375d9_e8efb8ae_1d47d565_be4fef5c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -160,
#     mantissa: 0xd221a635_c94ec878_7e8ac45c_d228c21f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -167,
#     mantissa: 0xa501ff16_23d71b54_67a72218_e78649af_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -167,
#     mantissa: 0x934b1479_6f9338e3_79e86378_0bb6139a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -175,
#     mantissa: 0xe9466047_ae5d6ce5_f11ee367_28284a49_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -175,
#     mantissa: 0x9c838319_2692482a_afe3e2b2_22d35f65_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0xf9361fa6_a7a5311d_36b70d2e_2f3cf194_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0x8260e5df_49e9f0ab_71403ac3_aaec34a1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -191,
#     mantissa: 0xd044e6f2_69162873_ac9a348e_2e20317e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -192,
#     mantissa: 0xaed48399_a546632f_11630933_e440bfc8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -199,
#     mantissa: 0x8c0f716e_f5f90a61_57c68779_43c59859_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -201,
#     mantissa: 0xbf49d6cd_65e61a09_b1f21367_aebbfb2c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -208,
#     mantissa: 0xb246b738_df61b5b6_d7d05b76_ec2cfdaa_u128,
# },
# ],
# ];

# %%
def print_expansion_at_0_f():
    print(f"pub(crate) const J1_MACLAURIN_SERIES: [u64; 9] = [")
    from mpmath import mp, j1, taylor, expm1
    mp.prec = 60
    poly = taylor(lambda val: j1(val), 0, 18)
    z = 0
    for i in range(1, 18, 2):
        print(f"{double_to_hex(poly[i])},")
    print("];")

    print(f"poly {poly}")

print_expansion_at_0_f()
# Out:
# pub(crate) const J1_MACLAURIN_SERIES: [u64; 9] = [
# 0x3fe0000000000000,
# 0xbfb0000000000000,
# 0x3f65555555555555,
# 0xbf0c71c71c71c71c,
# 0x3ea6c16c16c16c17,
# 0xbe3845c8a0ce5129,
# 0x3dc27e4fb7789f5c,
# 0xbd4522a43f65486a,
# 0x3cc2c9758daf5cd0,
# ];
# poly [mpf('0.0'), mpf('0.5'), mpf('0.0'), mpf('-0.0625'), mpf('0.0'), mpf('0.0026041666666666666678'), mpf('0.0'), mpf('-0.000054253472222222222228'), mpf('0.0'), mpf('6.7816840277777777802e-7'), mpf('0.0'), mpf('-5.6514033564814814787e-9'), mpf('0.0'), mpf('3.3639305693342151652e-11'), mpf('0.0'), mpf('-1.5017547184527746284e-13'), mpf('0.0'), mpf('5.2144261057388007941e-16'), mpf('0.0')]

# %%
# Taylor series for f32
mp.prec = 60
print(f"pub(crate) static J1F_COEFFS: [[u64; 15]; {len(j1_zeros)}] = [")

def get_constant_term(poly, y):
    for term in poly.operands():
        if term.is_constant():
            return term

def print_taylor_coeffsf(poly, x0):
    print("[")
    for i in range(0, 15):
        coeff = poly[i]
        print(f"{double_to_hex(coeff)},")
    print("],")

prev_zero = 0

for i in range(0, len(j1_zeros)):
    k_range = j1_zeros[i]
    range_diff = k_range - prev_zero
    g_c = 1

    x0 = mp.mpf(k_range)
    from mpmath import mp, j1, taylor, expm1
    # The j1 (Bessel J_1) function from mpmath will compute with mp.dps precision
    # The Taylor series computation will also respect mp.dps
    poly = taylor(lambda val: j1(val), x0, 16)
    # print(poly)
    print_taylor_coeffsf(poly, CDR(k_range))
    prev_zero = j1_zeros[i]

print("];")
# Out:
# pub(crate) static J1F_COEFFS: [[u64; 15]; 47] = [
# [mpf('0.58186522428159637935'), mpf('0.0'), mpf('-0.20511071214777319618'), mpf('0.0060589483246034702712'), mpf('0.013801769807956073966'), mpf('-0.00037231709715624585667'), mpf('-0.00039495907354755762771'), mpf('9.2029497991652741433e-6'), mpf('6.2672896817308790948e-6'), mpf('-1.2678573687215959376e-7'), mpf('-6.3255405008454650371e-8'), mpf('1.1251416998452125018e-9'), mpf('4.4195229281806885938e-10'), mpf('-6.9988903007532951552e-12'), mpf('-2.2644917176837842057e-12'), mpf('3.2279649218764984938e-14')]
# [
# 0x3fe29ea3d19f035f,
# 0x0000000000000000,
# 0xbfca41115c5df243,
# 0x3f78d1448e6fed48,
# 0x3f8c441a2f9de22b,
# 0xbf386671c18b088a,
# 0xbf39e2504ddc7608,
# 0x3ee34ccbca0c75d1,
# 0x3eda4973784d1087,
# 0xbe81045322aaab45,
# 0xbe70fae0da6cdcef,
# 0x3e13546cef5ed00a,
# 0x3dfe5ee82e667708,
# 0xbd9ec80cc8b63c39,
# 0xbd83eb2e99629b44,
# ],
# [mpf('0.0'), mpf('-0.40275939570255297204'), mpf('0.05255614585697723529'), mpf('0.053410444132724809124'), mpf('-0.0051797192456385702015'), mpf('-0.0022331253391474781904'), mpf('0.00017466429072012055577'), mpf('0.000046208701297458375041'), mpf('-3.0368633802997825054e-6'), mpf('-5.7278057351403828758e-7'), mpf('3.248286298212016063e-8'), mpf('4.7353805694230912062e-9'), mpf('-2.3621961879300647998e-10'), mpf('-2.798876498866189761e-11'), mpf('1.24622958871638405e-12'), mpf('1.2418546943452456094e-13')]
# [
# 0x0000000000000000,
# 0xbfd9c6cf582cbf7f,
# 0x3faae8a39f51ad04,
# 0x3fab589d1da13905,
# 0xbf7537544c331da7,
# 0xbf624b3409959064,
# 0x3f26e4c2d5354224,
# 0x3f083a06e30c4109,
# 0xbec9799d4c9f2549,
# 0xbea33825cd2e2c16,
# 0x3e617069233e916c,
# 0x3e34569b22afc3c8,
# 0xbdf03b9e9651056a,
# 0xbdbec62310af5f52,
# 0x3d75ec84e47b6f4f,
# ],
# [mpf('-0.34612620185379152499'), mpf('0.0'), mpf('0.16697453550109304715'), mpf('-0.0096782685428781834634'), mpf('-0.012099225779142165017'), mpf('0.00066540090064248448297'), mpf('0.00035413890079969189734'), mpf('-0.000017427203138287973507'), mpf('-5.6552936118188389545e-6'), mpf('2.4842947979085213322e-7'), mpf('5.7099041733534499266e-8'), mpf('-2.253735114333317759e-9'), mpf('-3.9815202626737523496e-10'), mpf('1.423282431012698274e-11'), mpf('2.0342689365206355806e-12'), mpf('-6.6361791580308299188e-14')]
# [
# 0xbfd626ee83500bf2,
# 0x0000000000000000,
# 0x3fc55f6bec9ef962,
# 0xbf83d23336fd10e4,
# 0xbf88c77a983a0814,
# 0x3f45cdc98db1cbe2,
# 0x3f373576ff46ee3b,
# 0xbef2461447d7b423,
# 0xbed7b853456b6eaa,
# 0x3e90abfc68274a98,
# 0x3e6ea7a1ee26124d,
# 0xbe235c0413e01418,
# 0xbdfb5c5d512fbb00,
# 0x3daf4c5e26fd6e90,
# 0x3d81e4c43397be51,
# ],
# [mpf('0.0'), mpf('0.30011575252613256325'), mpf('-0.021389212809341581604'), mpf('-0.046970478949741492397'), mpf('0.0031302917260480910314'), mpf('0.0021055871432482764524'), mpf('-0.00012550790955145584594'), mpf('-0.000044991475302930677458'), mpf('2.4015807963093220637e-6'), mpf('5.6652700115483305252e-7'), mpf('-2.7273427677991571622e-8'), mpf('-4.7204830035449803097e-9'), mpf('2.0653486761001609926e-10'), mpf('2.8005725262750139892e-11'), mpf('-1.1216380229417615937e-12'), mpf('-1.2445402051043784197e-13')]
# [
# 0x0000000000000000,
# 0x3fd33518b3874e8a,
# 0xbf95e70dc60362bf,
# 0xbfa80c83bdeee5b0,
# 0x3f69a4b292e3de42,
# 0x3f613fbc7d698217,
# 0xbf207358bbdbff91,
# 0xbf0796a751f89051,
# 0x3ec4255b015aded4,
# 0x3ea3026e0ce97ab9,
# 0xbe5d48dcdae92f2c,
# 0xbe344639d7eeb0a6,
# 0x3dec62ccb4a32eb4,
# 0x3dbecae92e854457,
# 0xbd73bb6898d73cd2,
# ],
# [mpf('0.27329994163319984652'), mpf('0.0'), mpf('-0.13477468037992366371'), mpf('0.0051163403464880437583'), mpf('0.010631861751984684542'), mpf('-0.0004487436837355104409'), mpf('-0.00032680001852314866825'), mpf('0.000013382555976264054131'), mpf('5.3631771590310306119e-6'), mpf('-2.0647201477005368657e-7'), mpf('-5.4999876460932523786e-8'), mpf('1.9738246864962383629e-9'), mpf('3.8700134714235867337e-10'), mpf('-1.2932330828461372144e-11'), mpf('-1.9877528061462670066e-12'), mpf('6.1949256560561771715e-14')]
# [
# 0x3fd17dbf09d40d25,
# 0x0000000000000000,
# 0xbfc1404bf647c28f,
# 0x3f74f4df2769f830,
# 0x3f85c6285429b66d,
# 0xbf3d68ab722881bd,
# 0xbf356acb6452d860,
# 0x3eec10b47cf7ef69,
# 0x3ed67eaae97bbc86,
# 0xbe8bb6530c63f2df,
# 0xbe6d87201e450edd,
# 0x3e20f47c83ec550b,
# 0x3dfa98331f6ea799,
# 0xbdac70414a236a67,
# 0xbd817c057a5fcd3d,
# ],
# [mpf('0.0'), mpf('-0.24970487705784319768'), mpf('0.012272357555101523016'), mpf('0.040411169390792762014'), mpf('-0.0019268187972607869614'), mpf('-0.0019115826893826532914'), mpf('0.000086617294541704344343'), mpf('0.000042411162810834605721'), mpf('-1.8009794578804266187e-6'), mpf('-5.4716029875821084779e-7'), mpf('2.1683937068370021148e-8'), mpf('4.6309166017117001797e-9'), mpf('-1.7127551080711048348e-10'), mpf('-2.7754891630185889922e-11'), mpf('9.5974160168809293401e-13'), mpf('1.2416439077261460564e-13')]
# [
# 0x0000000000000000,
# 0xbfcff654544ebcd1,
# 0x3f89223ff2c0785b,
# 0x3fa4b0c5d5da6789,
# 0xbf5f91a9ee0d2897,
# 0xbf5f51c2489b9e6f,
# 0x3f16b4c9ca0f770d,
# 0x3f063c5475439cb2,
# 0xbebe3725daf69867,
# 0xbea25c1238b32e59,
# 0x3e57486f6b9aa951,
# 0x3e33e3bf248277ee,
# 0xbde78a38a73e7c0a,
# 0xbdbe844eb6b211b0,
# 0x3d70e24abb40708e,
# ],
# [mpf('-0.23330441717143407163'), mpf('0.0'), mpf('0.11580092244607787173'), mpf('-0.0032489977328227131391'), mpf('-0.0093725272060515148708'), mpf('0.00030361382116848387787'), mpf('0.00029804555532438402212'), mpf('-9.8138185844927528334e-6'), mpf('-5.0242299986728071413e-6'), mpf('1.6136266730440164581e-7'), mpf('5.2519642038231082736e-8'), mpf('-1.6181244659556868191e-9'), mpf('-3.7451750290225519442e-10'), mpf('1.0991700523364741105e-11'), mpf('1.9416081678963447356e-12'), mpf('-5.4135859571506795954e-14')]
# [
# 0xbfcddceb4ce1bf4a,
# 0x0000000000000000,
# 0x3fbda52116c0a640,
# 0xbf6a9da4603b67ea,
# 0xbf8331e74ea59ab8,
# 0x3f33e5cb6eba6eaa,
# 0x3f33885fe9afa541,
# 0xbee494c0f4b0680b,
# 0xbed512b9d37762d7,
# 0x3e85a861082bfb7f,
# 0x3e6c323ea0a042c3,
# 0xbe1bcc962f7b91eb,
# 0xbdf9bc94e2f29a52,
# 0x3da82bc6fcfa8e89,
# 0x3d81141ce7b78460,
# ],
# [mpf('0.0'), mpf('0.21835940724787296211'), mpf('-0.008194403183877517927'), mpf('-0.035778209575030602615'), mpf('0.0013195736128103676684'), mpf('0.0017308725061749555204'), mpf('-0.000062007351614213552148'), mpf('-0.000039387037420757643546'), mpf('1.3569942254160055383e-6'), mpf('5.1906566526836006101e-7'), mpf('-1.7083741497242886404e-8'), mpf('-4.4653408290297706985e-9'), mpf('1.3991439234814039386e-10'), mpf('2.708929479095925876e-11'), mpf('-8.0702945212994599312e-13'), mpf('-1.2227780235323198076e-13')]
# [
# 0x0000000000000000,
# 0x3fcbf3337873a7d8,
# 0xbf80c83a2d7add33,
# 0xbfa251858011816b,
# 0x3f559eb160bf72d8,
# 0x3f5c5bce33af2d77,
# 0xbf10413e306e0039,
# 0xbf04a6704d05ad0b,
# 0x3eb6c43eedfed6c9,
# 0x3ea16abd7815de74,
# 0xbe5257f16f5d4346,
# 0xbe332db1b4b2ff8b,
# 0x3de33acccf7bfdce,
# 0x3dbdc8f5682566ba,
# 0xbd6c6513386daae2,
# ],
# [mpf('0.20701265272531904561'), mpf('0.0'), mpf('-0.10303781563402768034'), mpf('0.0022897295462872819796'), mpf('0.0084324350588640949335'), mpf('-0.00021965941962538873663'), mpf('-0.0002727215439833826185'), mpf('7.3690946296541228767e-6'), mpf('4.6821283504536998329e-6'), mpf('-1.2611231003634097541e-7'), mpf('-4.9736271581451709565e-8'), mpf('1.3107727339970544703e-9'), mpf('3.5930850401806135325e-10'), mpf('-9.1762541875983448868e-12'), mpf('-1.8817794951369846518e-12'), mpf('4.6331867400008658346e-14')]
# [
# 0x3fca7f63fea81f26,
# 0x0000000000000000,
# 0xbfba60afb06640cf,
# 0x3f62c1e930935d3c,
# 0x3f814506466d7f1f,
# 0xbf2cca8c0c0eaa3f,
# 0xbf31df821cc1377e,
# 0x3edee8814ed0ac45,
# 0x3ed3a365a4199dd1,
# 0xbe80ed2f9c3e458e,
# 0xbe6ab3b37c5271b3,
# 0x3e1684d6e62b5c66,
# 0x3df8b105a5120ed2,
# 0xbda42dc5991b9d01,
# 0xbd808d6405ffe3dc,
# ],
# [mpf('0.0'), mpf('-0.19646537146865718291'), mpf('0.0059641122064480035393'), mpf('0.032382122684890818592'), mpf('-0.00097203375623040993631'), mpf('-0.001584230341756570203'), mpf('0.000046667442231393631168'), mpf('0.000036572573538843407202'), mpf('-1.0499615284344570279e-6'), mpf('-4.8917908609698244358e-7'), mpf('1.3610422078373997128e-8'), mpf('4.264651809545571522e-9'), mpf('-1.1453319428019084657e-10'), mpf('-2.6162364234398161592e-11'), mpf('6.7651044753415446295e-13'), mpf('1.1916937033915236338e-13')]
# [
# 0x0000000000000000,
# 0xbfc925c6fca08f55,
# 0x3f786dd32e059b0e,
# 0x3fa09463bbd0367f,
# 0xbf4fda0298c8768b,
# 0xbf59f4be60758fb1,
# 0x3f0877991af9d1bb,
# 0x3f032cb00ee8c1f3,
# 0xbeb19d8ce8c35f58,
# 0xbea06a042fbba455,
# 0x3e4d3a689e677731,
# 0x3e325108c4ce2b63,
# 0xbddf7b8e9ab53152,
# 0xbdbcc40d05652642,
# 0x3d67cd76e2d7e2cb,
# ],
# [mpf('-0.18801748852581776019'), mpf('0.0'), mpf('0.093719093772432139904'), mpf('-0.0017233243363060656687'), mpf('-0.0077142667601276035727'), mpf('0.00016755862376976238962'), mpf('0.00025182717468682616633'), mpf('-5.7335172626499247136e-6'), mpf('-4.3724260796916482492e-6'), mpf('1.0045696055698888501e-7'), mpf('4.6984557443518690411e-8'), mpf('-1.0697010970466780361e-9'), mpf('-3.4303476631796167721e-10'), mpf('7.6603335590907537838e-12'), mpf('1.8130313743728005892e-12'), mpf('-3.9468461501640107271e-14')]
# [
# 0xbfc810f50225b04b,
# 0x0000000000000000,
# 0x3fb7fdf97ac36b1f,
# 0xbf5c3c256a8caa05,
# 0xbf7f98feb7286b47,
# 0x3f25f6559e5686e2,
# 0x3f3080f57ac215af,
# 0xbed80c51397e5eba,
# 0xbed256db543cd140,
# 0x3e7af7598a219824,
# 0x3e69398226ca2305,
# 0xbe1260985d92587d,
# 0xbdf792bb3eea6f6a,
# 0x3da0d862695e1a7a,
# 0x3d7fe52adc2baacf,
# ],
# [mpf('0.0'), mpf('0.18006337534431555427'), mpf('-0.004589739858906061618'), mpf('-0.029776581472313524138'), mpf('0.00075302848385339223811'), mpf('0.0014660390526561338733'), mpf('-0.000036589009383100233434'), mpf('-0.00003413723646008697731'), mpf('8.3663282076993441633e-7'), mpf('4.6108501645071014599e-7'), mpf('-1.1048051583135713088e-8'), mpf('-4.0592781268151169221e-9'), mpf('9.4754892811648019785e-11'), mpf('2.5129092903968349706e-11'), mpf('-5.6991401136718529955e-13'), mpf('-1.1538053180898008511e-13')]
# [
# 0x0000000000000000,
# 0x3fc70c511227d5aa,
# 0xbf72ccb0e97558da,
# 0xbf9e7dc08e70e99a,
# 0x3f48acdc5b058c0e,
# 0x3f580503724ad30a,
# 0xbf032ee4ca1fcafb,
# 0xbf01e5d2836c8d99,
# 0x3eac129f077bb163,
# 0x3e9ef161591181a2,
# 0xbe47b9bb07f19f82,
# 0xbe316f3937595d96,
# 0x3dda0bc8665b687b,
# 0x3dbba135f99a9e19,
# 0xbd640d543d2cbdf0,
# ],
# [mpf('0.17345904928574641885'), mpf('0.0'), mpf('-0.086535901938761234037'), mpf('0.0013568189856143958374'), mpf('0.0071472165207372924636'), mpf('-0.00013295776592377230269'), mpf('-0.00023462959312285641247'), mpf('4.6031433817449970156e-6'), mpf('4.1031973660369767959e-6'), mpf('-8.1836132695052081749e-8'), mpf('-4.4443075049241166797e-8'), mpf('8.8555360853740138601e-10'), mpf('3.2707069022519079013e-10'), mpf('-6.4458409250944729908e-12'), mpf('-1.7415885876852885479e-12'), mpf('3.3732747135854115034e-14')]
# [
# 0x3fc633e7f7f05301,
# 0x0000000000000000,
# 0xbfb6273784c1c06e,
# 0x3f563ae94ade18d4,
# 0x3f7d4666536c88b9,
# 0xbf216d528345ca11,
# 0xbf2ec0dcdbb7c5fe,
# 0x3ed34e966b0b09f8,
# 0x3ed135c64dc2d8d0,
# 0xbe75f7bc78b5fc2b,
# 0xbe67dc35b0764096,
# 0x3e0e6d697361ea54,
# 0x3df679e3704987b4,
# 0xbd9c595f278a4d6c,
# 0xbd7ea36aef56eec0,
# ],
# [mpf('0.0'), mpf('-0.16718460047381804539'), mpf('0.0036727588017286566178'), mpf('0.027702731661334967662'), mpf('-0.00060503649246538873817'), mpf('-0.0013693112504510835584'), mpf('0.000029615596937998213397'), mpf('0.000032060961900116606979'), mpf('-6.8410614399343638744e-7'), mpf('-4.3588795163776394705e-7'), mpf('9.144492104447539661e-9'), mpf('3.8644489921496516588e-9'), mpf('-7.947190941712038235e-11'), mpf('-2.4090019529127878926e-11'), mpf('4.844331366939744486e-13'), mpf('1.1133632079140188325e-13')]
# [
# 0x0000000000000000,
# 0xbfc5664e13b70622,
# 0x3f6e16555e108dc6,
# 0x3f9c5e1ad9fb2f40,
# 0xbf43d369f958e56a,
# 0xbf566f4ec27a96e9,
# 0x3eff0de0532652d5,
# 0x3f00cf264341409e,
# 0xbea6f46d51e5766f,
# 0xbe9d407f7c248d45,
# 0x3e43a33cd9df6696,
# 0x3e309901b0a816e5,
# 0xbdd5d856a58443f5,
# 0xbdba7cbcd8fc0758,
# 0x3d610b62c2fd47f6,
# ],
# [mpf('-0.1618382095526585164'), mpf('0.0'), mpf('0.080782195225750007446'), mpf('-0.0011038527651115924277'), mpf('-0.0066864447268136515803'), mpf('0.00010870535077588026585'), mpf('0.00022030197370284177491'), mpf('-3.7918054763244086637e-6'), mpf('-3.8711490352810117618e-6'), mpf('6.8059764283039660805e-8'), mpf('4.2162867094338606536e-8'), mpf('-7.4460684763210260148e-10'), mpf('-3.1211691604242614993e-10'), mpf('5.4835588665561701385e-12'), mpf('1.6716817971649224399e-12'), mpf('-2.9036016761662095926e-14')]
# [
# 0xbfc4b71d4ca2cc69,
# 0x0000000000000000,
# 0x3fb4ae245697fba6,
# 0xbf5215e4e1a5f1d6,
# 0xbf7b633ed6d9cf61,
# 0x3f1c7f17b4b7dbbd,
# 0x3f2ce01b8b6aa34c,
# 0xbecfced71b11e35b,
# 0xbed03c9d5823261d,
# 0x3e724508091063b2,
# 0x3e66a2d20111e303,
# 0xbe0995a18f8e6888,
# 0xbdf572d1a074f647,
# 0x3d981df03c1911f1,
# 0x3d7d6895e48f475d,
# ],
# [mpf('0.0'), mpf('0.1567249862528522302'), mpf('-0.0030251499811056658906'), mpf('-0.026004046442226119582'), mpf('0.00049968324480690083845'), mpf('0.0012886979076641241942'), mpf('-0.000024577609477776825142'), mpf('-0.000030285619999010918203'), mpf('5.7159860901122563806e-7'), mpf('4.1362773860810494807e-7'), mpf('-7.7044747635491453928e-9'), mpf('-3.6857163491591207957e-9'), mpf('6.7586718488333867274e-11'), mpf('2.3097146345017692933e-11'), mpf('-4.1607352443927805465e-13'), mpf('-1.0730436022610238832e-13')]
# [
# 0x0000000000000000,
# 0x3fc40f90793605bb,
# 0xbf68c833077fbeae,
# 0xbf9aa0ce0421d1a8,
# 0x3f405fa598ef5d1d,
# 0x3f551d30d78ab526,
# 0xbef9c5807675c5f6,
# 0xbeffc1bbf57e3ae2,
# 0x3ea32dfea2518ce6,
# 0x3e9bc212085dcbc6,
# 0xbe408b946d64c5c2,
# 0xbe2fa8f9d8da736a,
# 0x3dd293fe14af1d0f,
# 0x3db96544cb75a58d,
# 0xbd5d4750748e2ce8,
# ],
# [mpf('0.15228206634189006899'), mpf('0.0'), mpf('-0.076040035583846372143'), mpf('0.0009206869010854983218'), mpf('0.0063031377382864250006'), mpf('-0.000090970053990075185986'), mpf('-0.00020818857704001538427'), mpf('3.1893311520043682698e-6'), mpf('3.6705205791972406023e-6'), mpf('-5.7623989978039676433e-8'), mpf('-4.0136830087665377774e-8'), mpf('6.3533272959999965554e-10'), mpf('2.9841687721674000928e-10'), mpf('-4.7187363556971390774e-12'), mpf('-1.6055273678339172038e-12'), mpf('2.5208428185615752596e-14')]
# [
# 0x3fc37dfa8f5a550a,
# 0x0000000000000000,
# 0xbfb3775c1a04f09c,
# 0x3f4e2b4810a46c60,
# 0x3f79d151a72b83a8,
# 0xbf17d8e5a090e4e6,
# 0xbf2b49a6427386a0,
# 0x3ecac10957ddd2eb,
# 0x3ececa620745d3d3,
# 0xbe6eefc7e795dcdd,
# 0xbe658c5d2a0da41d,
# 0x3e05d4721f44a8f9,
# 0x3df481ce2314af59,
# 0xbd94c0d3279e920c,
# 0xbd7c3ea707530563,
# ],
# [mpf('0.0'), mpf('-0.14801110997277754414'), mpf('0.0025478015576615379632'), mpf('0.02458080474056066546'), mpf('-0.00042161386264394085718'), mpf('-0.0012203728389620493503'), mpf('0.00002080746359569829308'), mpf('0.0000287548675998798571'), mpf('-4.8621923672992888475e-7'), mpf('-3.9400451865642030503e-7'), mpf('6.5925374446715391421e-9'), mpf('3.523979205857853173e-9'), mpf('-5.822692462094286559e-11'), mpf('-2.217217180651544635e-11'), mpf('3.6110666676518030368e-13'), mpf('1.0342982977987302316e-13')]
# [
# 0x0000000000000000,
# 0xbfc2f2072e638cf4,
# 0x3f64df208bbd44f1,
# 0x3f992bb5e1e159fc,
# 0xbf3ba181c06897cd,
# 0xbf53fe9d5baa4a3d,
# 0x3ef5d17602b01cac,
# 0x3efe26d3747fe829,
# 0xbea0509768ab6ecb,
# 0xbe9a70f232d9d06c,
# 0x3e3c509252de33f9,
# 0x3e2e454fee07116e,
# 0xbdd0015b062ba125,
# 0xbdb860e95adf840f,
# 0x3d59691e90f7d9c0,
# ],
# [mpf('-0.14424290218193798279'), mpf('0.0'), mpf('0.072044437562627664092'), mpf('-0.00078307073022993910608'), mpf('-0.0059781141915457615681'), mpf('0.000077554773205678707992'), mpf('0.00019780236837872788842'), mpf('-2.7288104932140985886e-6'), mpf('-3.4958120742280083257e-6'), mpf('4.9536406033915099305e-8'), mpf('3.8338261429071824386e-8'), mpf('-5.4924724311985451484e-10'), mpf('-2.859827049984700689e-10'), mpf('4.1051898763709794572e-12'), mpf('1.5440195398890325414e-12'), mpf('-2.2079134307152385546e-14')]
# [
# 0xbfc2768d29c69936,
# 0x0000000000000000,
# 0x3fb271811730b0ef,
# 0xbf49a8df96a1225e,
# 0xbf787c81cf1c6fc4,
# 0x3f14549cdbb77978,
# 0x3f29ed2568116e19,
# 0xbec6e4136f033ace,
# 0xbecd53330316cde7,
# 0x3e6a983b5782dfca,
# 0x3e64952ba7c5a1dc,
# 0xbe02df3ad6f82e0d,
# 0xbdf3a70f9a89d2c2,
# 0x3d920e086c17f5dc,
# 0x3d7b29a554c1159f,
# ],
# [mpf('0.0'), mpf('0.14060579818398225406'), mpf('-0.0021840198251869790085'), mpf('-0.023366451249280341401'), mpf('0.00036189553399826029025'), mpf('0.0011616031973470813372'), mpf('-0.000017903598614259314602'), mpf('-0.000027422245345846301253'), mpf('4.1980686260628888719e-7'), mpf('3.7665128146866751195e-7'), mpf('-5.7168211453121149255e-9'), mpf('-3.3782385492932150376e-9'), mpf('5.0748836429127423531e-11'), mpf('2.1320762911883112676e-11'), mpf('-3.164977963993869816e-13'), mpf('-9.9780070194985945396e-14')]
# [
# 0x0000000000000000,
# 0x3fc1ff5eec6a01cd,
# 0xbf61e438b722c3b5,
# 0xbf97ed5fffc1c774,
# 0x3f37b7997babd9ca,
# 0x3f53081def9612c5,
# 0xbef2c5f5edafc4e9,
# 0xbefcc11a59e13739,
# 0x3e9c2c3a1b8014a3,
# 0x3e9946d1dab7bd01,
# 0xbe388db61946be64,
# 0xbe2d04d33be580e8,
# 0x3dcbe64386d2c5d0,
# 0x3db77142e0e4497b,
# 0xbd56458476679697,
# ],
# [mpf('0.13735719367686963677'), mpf('0.0'), mpf('-0.068618289230663856351'), mpf('0.00067659675980545606419'), mpf('0.0056981411902270204405'), mpf('-0.000067125116991851375395'), mpf('-0.00018878432147593585483'), mpf('2.3680904387636439188e-6'), mpf('3.3424149628029455411e-6'), mpf('-4.3138368684968676721e-8'), mpf('-3.6736795307417882556e-8'), mpf('4.8032593672720015895e-10'), mpf('2.7472821982052313852e-10'), mpf('-3.6072959659380978455e-12'), mpf('-1.4873239313390727629e-12'), mpf('1.9502641038116447443e-14')]
# [
# 0x3fc194eba75b32f9,
# 0x0000000000000000,
# 0xbfb190f7dc27362b,
# 0x3f462bb47a5c5f7f,
# 0x3f7756ef20f5d2e2,
# 0xbf1198b0ba97ecfb,
# 0xbf28be8cf9358d55,
# 0x3ec3dd6f7c8cc3c0,
# 0x3ecc09c80ee7f9af,
# 0xbe6728e46a451e32,
# 0xbe63b91113508622,
# 0x3e0080fddad62bf8,
# 0x3df2e111e88dae1f,
# 0xbd8fbae88bdab215,
# 0xbd7a2a4fbea868a8,
# ],
# [mpf('0.0'), mpf('-0.13421124031000068798'), mpf('0.0018992708036370826122'), mpf('0.02231478554381458829'), mpf('-0.00031502373577507190387'), mpf('-0.0011104068860942181078'), mpf('0.000015612943996162537742'), mpf('0.000026251114160604394424'), mpf('-3.67040152858382818e-7'), mpf('-3.6122468214170927615e-7'), mpf('5.0146404025683968102e-9'), mpf('3.2468644619907708949e-9'), mpf('-4.4687784404154502775e-11'), mpf('-2.0540951231528793857e-11'), mpf('2.7990743664438689948e-13'), mpf('9.6377993542495655026e-14')]
# [
# 0x0000000000000000,
# 0xbfc12dd57bf18ada,
# 0x3f5f1e1e7f393e83,
# 0x3f96d9afe88301fa,
# 0xbf34a538a482979b,
# 0xbf52316250b4ae37,
# 0x3ef05f11577b4627,
# 0x3efb86bad42fc220,
# 0xbe98a1b3a9e92749,
# 0xbe983dcaf3f8fcc5,
# 0x3e3589a7ca5fdcf1,
# 0x3e2be3ee3298bb99,
# 0xbdc8913f1d0ff12a,
# 0xbdb695c386660813,
# 0x3d53b25d364762e7,
# ],
# [mpf('-0.13137285618706717803'), mpf('0.0'), mpf('0.06563816016818494923'), mpf('-0.0005922259572351858309'), mpf('-0.0054537928406342264581'), mpf('0.000058831028520129374116'), mpf('0.00018086723514251230378'), mpf('-2.0796379637933189105e-6'), mpf('-3.2066223725228292883e-6'), mpf('3.7984267026736048842e-8'), mpf('3.530414976385124442e-8'), mpf('-4.2430381399132635892e-10'), mpf('-2.6453433841309821168e-10'), mpf('3.1984047351879080478e-12'), mpf('1.4352477227546607395e-12'), mpf('-1.7362821828332264282e-14')]
# [
# 0xbfc0d0d36473e98c,
# 0x0000000000000000,
# 0x3fb0cda9974abe2b,
# 0xbf4367f38f201c25,
# 0xbf7656b75e3c242e,
# 0x3f0ed82abf7489f1,
# 0x3f27b4e5b83eeb36,
# 0xbec171fd0fb670e7,
# 0xbecae62b4ad017fb,
# 0x3e64648495a7b49e,
# 0x3e62f42a577135ad,
# 0xbdfd286e7fa32656,
# 0xbdf22dbcbf76a1c7,
# 0x3d8c222accc0d2d2,
# 0x3d793fc7f6c8d355,
# ],
# [mpf('0.0'), mpf('0.12861662207206995471'), mpf('-0.0016714412413483688902'), mpf('-0.021392661147250082777'), mpf('0.00027744442273605626775'), mpf('0.0010653181511813165137'), mpf('-0.000013769481459014210127'), mpf('-0.000025212865164017827834'), mpf('3.2434377566741388442e-7'), mpf('3.4742933337009585248e-7'), mpf('-4.4425127738781929125e-9'), mpf('-3.1281347722274219089e-9'), mpf('3.970846653305358902e-11'), mpf('1.9827532690681618295e-11'), mpf('-2.495673464433207663e-13'), mpf('-9.3222944134563171038e-14')]
# [
# 0x0000000000000000,
# 0x3fc076826cc2c191,
# 0xbf5b62885e0070c6,
# 0xbf95e7f53001e4b1,
# 0x3f322ebeb8dc2202,
# 0x3f517444a7a04cd0,
# 0xbeece06f1f1fcd7e,
# 0xbefa7006e6ad9cfe,
# 0x3e95c42f02cf15ca,
# 0x3e9750ca5e1366b4,
# 0xbe3314982df7eaa2,
# 0xbe2aded75306b3b3,
# 0x3dc5d47847d8ebf1,
# 0x3db5ccf44d287a21,
# 0xbd518fce3e04028a,
# ],
# [mpf('0.12610881373023247946'), mpf('0.0'), mpf('-0.063015063678111263496'), mpf('0.00052403166729155237061'), mpf('0.0052381654592657222777'), mpf('-0.000052108952530121534115'), mpf('-0.00017384929009660832777'), mpf('1.8448696857641598153e-6'), mpf('3.0854858035018361065e-6'), mpf('-3.3765713662376143148e-8'), mpf('-3.4015778101107583915e-8'), mpf('3.7813289723926428058e-10'), mpf('2.5527851056481057277e-10'), mpf('-2.8587137150130485859e-12'), mpf('-1.3874438089351992559e-12'), mpf('1.5569367714354429436e-14')]
# [
# 0x3fc02455675ab6d2,
# 0x0000000000000000,
# 0xbfb021c155a720df,
# 0x3f412be56fc1449a,
# 0x3f75749d556ad61c,
# 0xbf0b51f1f9bea93e,
# 0xbf26c96a07e236bd,
# 0x3ebef3a7abd5ac6b,
# 0x3ec9e207c257433a,
# 0xbe6220b96eef8058,
# 0xbe624317cb296737,
# 0x3df9fc2f2cd3917f,
# 0x3df18ae8347e8256,
# 0xbd892540423f2dda,
# 0xbd78687dcdc2e3a9,
# ],
# [mpf('0.0'), mpf('-0.12366796076983712553'), mpf('0.0014857832233245892167'), mpf('0.020575625522420598617'), mpf('-0.0002467726860606215756'), mpf('-0.0010252317618176783395'), mpf('0.000012260493246807405047'), mpf('0.00002428509482378614297'), mpf('-2.892474248649144559e-7'), mpf('-3.3501900411905544966e-7'), mpf('3.9696871646433667259e-9'), mpf('3.0204454462249066396e-9'), mpf('-3.5566813238643349943e-11'), mpf('-1.9174244290466465183e-11'), mpf('2.2414588098737333594e-13'), mpf('9.0302684391464567514e-14')]
# [
# 0x0000000000000000,
# 0xbfbfa8b41711c83a,
# 0x3f5857d3969997d1,
# 0x3f9511c6dadaaa12,
# 0xbf302c289dbdbd4f,
# 0xbf50cc2238d229f9,
# 0x3ee9b64d5c63668f,
# 0x3ef976fb023f0f79,
# 0xbe93693ba0b5ba70,
# 0xbe967b952987350c,
# 0x3e310cb79a2addac,
# 0x3e29f2079f8e397f,
# 0xbdc38d957eaa53ad,
# 0xbdb51511e93ba74c,
# 0x3d4f8bb4d9d2f3a4,
# ],
# [mpf('-0.12143117472506242591'), mpf('0.0'), mpf('0.06068301848901461377'), mpf('-0.00046798373869105269614'), mpf('-0.0050460793867432656603'), mpf('0.00004657248334010626799'), mpf('0.00016757561346322504388'), mpf('-1.6508729078842472609e-6'), mpf('-2.9766582142050264065e-6'), mpf('3.026442193985882438e-8'), mpf('3.2850977324541320745e-8'), mpf('-3.3960401211034057052e-10'), mpf('-2.4684678559501814245e-10'), mpf('2.5734519929705973743e-12'), mpf('1.3435163361599110044e-12'), mpf('-1.4052621438068119981e-14')]
# [
# 0xbfbf161d0c28b48c,
# 0x0000000000000000,
# 0x3faf11d837aa6f64,
# 0xbf3eab76da4d07a0,
# 0xbf74ab329f067aea,
# 0x3f086ada57bc1c51,
# 0x3f25f6e78f11ab9a,
# 0xbebbb271f54c8965,
# 0xbec8f85328c26cb7,
# 0x3e603f82aebdeac1,
# 0x3e61a3010279a195,
# 0xbdf75660809cdedf,
# 0xbdf0f6931774a05f,
# 0x3d86a2e61267070b,
# 0x3d77a2a8e0311c3a,
# ],
# [mpf('0.0'), mpf('0.11924981201068947389'), mpf('-0.0013321227252914966475'), mpf('-0.019845206760646177583'), mpf('0.00022135552211912821184'), mpf('0.00098929900297625096204'), mpf('-0.000011007155899517397606'), mpf('-0.000023450118334627794185'), mpf('2.6000062802475015804e-7'), mpf('3.2379070001649506525e-7'), mpf('-3.5739871846906196357e-9'), mpf('-2.9223781669901756779e-9'), mpf('3.2082938047881017166e-11'), mpf('1.8574790148799141929e-11'), mpf('-2.0263600003929869535e-13'), mpf('-8.7599981026004179116e-14')]
# [
# 0x0000000000000000,
# 0x3fbe8727daa3daed,
# 0xbf55d353e2854a37,
# 0xbf94524d4813cc25,
# 0x3f2d037574e28370,
# 0x3f50356bb747a763,
# 0xbee7156bfccef376,
# 0xbef896d7dc819faf,
# 0x3e9172c6dadf4149,
# 0x3e95baae8efc2e31,
# 0xbe2eb347eb4d6941,
# 0xbe291a60a72a20e0,
# 0x3dc1a345a9a6a5f7,
# 0x3db46c56b01906be,
# 0xbd4c84bb37677838,
# ],
# [mpf('0.11723850698826188924'), mpf('0.0'), mpf('-0.058591931604755768015'), mpf('0.0004212564508913367181'), mpf('0.0048735664050833566691'), mpf('-0.000041948963235994156563'), mpf('-0.00016192551179550872492'), mpf('1.488442749615247626e-6'), mpf('2.8782603436163280391e-6'), mpf('-2.7322574187104928635e-8'), mpf('-3.1792477143666852709e-8'), mpf('3.0709092330172714681e-10'), mpf('2.3913786177203120479e-10'), mpf('-2.3315063622280832608e-12'), mpf('-1.3030723486672298974e-12'), mpf('1.275882329931853387e-14')]
# [
# 0x3fbe0357c158b119,
# 0x0000000000000000,
# 0xbfadffc2fc1a91f5,
# 0x3f3b9b82ae07da44,
# 0x3f73f64e05320ac6,
# 0xbf05fe4b66cf19d8,
# 0xbf2539518e1b00f5,
# 0x3eb8f8d01c487905,
# 0x3ec825045b97e2dc,
# 0xbe5d565f3bb61dea,
# 0xbe611186586f4f74,
# 0x3df51a669158191b,
# 0x3df06ef52f6715ac,
# 0xbd848215e95caa77,
# 0xbd76ec8422019b0d,
# ],
# [mpf('0.0'), mpf('-0.11527369412016796109'), mpf('0.0012032377717211320913'), mpf('0.019187163332992513391'), mpf('-0.00020001523917770440769'), mpf('-0.00095685721186639321177'), mpf('9.9529214636049313319e-6'), mpf('0.000022693837092493148082'), mpf('-2.3533465884428004375e-7'), mpf('-3.1357737141400849799e-7'), mpf('3.2391196416795372609e-9'), mpf('2.8327080615337696584e-9'), mpf('-2.9122430332545317206e-11'), mpf('-1.8023290089818150302e-11'), mpf('1.842700788272845082e-13'), mpf('8.5096104951123437343e-14')]
# [
# 0x0000000000000000,
# 0xbfbd8293aa55d18f,
# 0x3f53b6beb83f2596,
# 0x3f93a5ccbc12a67b,
# 0xbf2a3765d26aa42b,
# 0xbf4f5ab33748c215,
# 0x3ee4df6f1c257a5c,
# 0x3ef7cbd49c315be0,
# 0xbe8f96098cf07175,
# 0xbe950b37dd43531f,
# 0x3e2bd2e6405c605d,
# 0x3e285530df0d4b70,
# 0xbdc0029e21930f25,
# 0xbdb3d11aeba731a1,
# 0x3d49ef077e065d17,
# ],
# [mpf('-0.11345236875372799966'), mpf('0.0'), mpf('0.056702997975075682135'), mpf('-0.00038181618980959173131'), mpf('-0.004717530507927776673'), mpf('0.000038041180091757478737'), mpf('0.0001568035623766057419'), mpf('-1.3508679811621934642e-6'), mpf('-2.7887753727811054734e-6'), mpf('2.4823831348881216792e-8'), mpf('3.0825907833937410634e-8'), mpf('-2.7937785004333194433e-10'), mpf('-2.3206359017746757914e-10'), mpf('2.124425982927991973e-12'), mpf('1.2657451063731089465e-12'), mpf('-1.1646272854044076024e-14')]
# [
# 0xbfbd0b36e5737458,
# 0x0000000000000000,
# 0x3fad082ce3c6b59b,
# 0xbf3905d00c5e6800,
# 0xbf7352b073fdac7b,
# 0x3f03f1ccfec2fc88,
# 0x3f248d74583834bc,
# 0xbeb6a9ef0d896bae,
# 0xbec764d9798d6a80,
# 0x3e5aa785d6736f5c,
# 0x3e608cae36118cdb,
# 0xbdf332ddfb39cd01,
# 0xbdefe502ff1a8f0d,
# 0x3d82afc83348eeb2,
# 0x3d764468c0a31511,
# ],
# [mpf('0.0'), mpf('0.11167049685921129061'), mpf('-0.0010938750270489956341'), mpf('-0.018590319240108309814'), mpf('0.00018189266218435677901'), mpf('0.00092738116354388256092'), mpf('-9.0563087033760390883e-6'), mpf('-0.000022004894407132897823'), mpf('2.1431124771698214093e-7'), mpf('3.0424117784782828097e-7'), mpf('-2.952904910282455379e-9'), mpf('-2.7503882498933139404e-9'), mpf('2.6583466029907528906e-11'), mpf('1.7514444489909926449e-11'), mpf('-1.6845733189471409962e-13'), mpf('-8.2772617408598910116e-14')]
# [
# 0x0000000000000000,
# 0x3fbc96700bf039e2,
# 0xbf51ec0b5de4befe,
# 0xbf93095734a24496,
# 0x3f27d74e12285cb2,
# 0x3f4e636fe259352c,
# 0xbee2fe11972bc0c6,
# 0xbef712e4d44c4a74,
# 0x3e8cc3adabae0452,
# 0x3e946ad2d9cbeb5c,
# 0xbe295d81ae83f621,
# 0xbe27a02aefea3d60,
# 0x3dbd3a949a72239d,
# 0x3db341e0bb193b49,
# 0xbd47b550a4f77497,
# ],
# [mpf('0.11001101229397791746'), mpf('0.0'), mpf('-0.054985629119578350915'), mpf('0.00034816609399491054892'), mpf('0.0045755172670098514113'), mpf('-0.000034703389729877506672'), mpf('-0.00015213331573688497587'), mpf('1.2331571119500546195e-6'), mpf('2.7069682357785392548e-6'), mpf('-2.2680902706374642863e-8'), mpf('-2.9939292855895413156e-8'), mpf('2.5554231686142950649e-10'), mpf('2.2554802583856783502e-10'), mpf('-1.9457113714619332979e-12'), mpf('-1.2312029003178268593e-12'), mpf('1.0682387564835286559e-14')]
# [
# 0x3fbc29ae8400a320,
# 0x0000000000000000,
# 0xbfac27138da31c2b,
# 0x3f36d141fcbea853,
# 0x3f72bdc71062acd6,
# 0xbf0231cf643ffc17,
# 0xbf23f0bf3b3fe8be,
# 0x3eb4b05e955de175,
# 0x3ec6b52b868fa5e2,
# 0xbe585a7aa3e84cc3,
# 0xbe6012d3384c9164,
# 0x3df18f8c4872544f,
# 0x3deeffc4029f2f06,
# 0xbd811d5a3daf70fa,
# 0xbd75a8d84ce12a33,
# ],
# [mpf('0.0'), mpf('-0.1083853489436825497'), mpf('0.0010001314156689645446'), mpf('0.018045767295169327612'), mpf('-0.00016634793367443450774'), mpf('-0.00090044889834600844293'), mpf('8.286287770748178429e-6'), mpf('0.00002137404856697333671'), mpf('-1.9622391930884340383e-7'), mpf('-2.9566782272967089359e-7'), mpf('2.7060925583828969036e-9'), mpf('2.6745271978916839195e-9'), mpf('-2.4387875197199748322e-11'), mpf('-1.7043563642276806337e-11'), mpf('1.5473840093474820457e-13'), mpf('8.0612220129867857019e-14')]
# [
# 0x0000000000000000,
# 0xbfbbbf246914235f,
# 0x3f5062daee35411a,
# 0x3f927a96f174b6d1,
# 0xbf25cdb5dea9c121,
# 0xbf4d818348f98a0f,
# 0x3ee160aab829409d,
# 0x3ef6698d6ee99eb9,
# 0xbe8a5633d8f0b3bf,
# 0xbe93d788d61154a7,
# 0x3e273ec2ae0084b9,
# 0x3e26f958f6235deb,
# 0xbdbad0939c43a9fe,
# 0xbdb2bd56309cf195,
# 0x3d45c709d717f2e4,
# ],
# [mpf('-0.10686507535075525103'), mpf('0.0'), mpf('0.053415344587233653758'), mpf('-0.0003191825622460907532'), mpf('-0.0044455532184737894778'), mpf('0.000031825832572327258872'), mpf('0.00014785277784550322145'), mpf('-1.1315315363867808994e-6'), mpf('-2.6318243414797812446e-6'), mpf('2.0827236208299949692e-8'), mpf('2.9122611371894437657e-8'), mpf('-2.3487461296909401513e-10'), mpf('-2.1952598754866933852e-10'), mpf('1.7903070114614162343e-12'), mpf('1.1991506743860569981e-12'), mpf('-9.8414970496750869555e-15')]
# [
# 0xbfbb5b8273b75055,
# 0x0000000000000000,
# 0x3fab59418c36a684,
# 0xbf34eafeaa92aa79,
# 0xbf7235801af9be44,
# 0x3f00af9747d0be92,
# 0x3f23611db0e1566f,
# 0xbeb2fbe414da1250,
# 0xbec613ccbb9cbe59,
# 0x3e565cf274e84d31,
# 0x3e5f452996e3dc2b,
# 0xbdf023f5382da3ad,
# 0xbdee2be24fbad63f,
# 0x3d7f7ed3740f8cf5,
# 0x3d75187e998a1997,
# ],
# [mpf('0.0'), mpf('0.10537405539523521034'), mpf('-0.00091905288594202204669'), mpf('-0.017546310949665106584'), mpf('0.00015289583144877787632'), mpf('0.00087571726396494971413'), mpf('-7.6192421229311937245e-6'), mpf('-0.000020793705480462024803'), mpf('1.8053209475048557309e-7'), mpf('2.8776196882831319164e-7'), mpf('-2.4915540978496535426e-9'), mpf('-2.6043655973828521026e-9'), mpf('2.2474888248609966193e-11'), mpf('1.6606535949284576112e-11'), mpf('-1.4275243751549612083e-13'), mpf('-7.8599102161372103307e-14')]
# [
# 0x0000000000000000,
# 0x3fbaf9cb49c4f935,
# 0xbf4e1d930b513228,
# 0xbf91f7a8fec6eba8,
# 0x3f240a55310866fc,
# 0x3f4cb20c812fd3aa,
# 0xbedff51953c6b6cc,
# 0xbef5cdc48f5d75eb,
# 0x3e883b091952c721,
# 0x3e934fb685e58ab7,
# 0xbe2566fc4369ab71,
# 0xbe265f0f7de29720,
# 0x3db8b61e5f9b7a00,
# 0x3db24253069b78a9,
# 0xbd441732d722b422,
# ],
# [mpf('0.10397455861256390403'), mpf('0.0'), mpf('-0.051972288881237471182'), mpf('0.00029400750553696127899'), mpf('0.0043260315875465203049'), mpf('-0.00002932445908010619185'), mpf('-0.0001439111200657332205'), mpf('1.0430853729020322728e-6'), mpf('2.5625030170233119336e-6'), mpf('-1.9211350387294044552e-8'), mpf('-2.8367436879276048653e-8'), mpf('2.1682163909473344535e-10'), mpf('2.1394155348420923249e-10'), mpf('-1.6542373435932738478e-12'), mpf('-1.1693282689232714527e-12'), mpf('9.1032010436153507612e-15')]
# [
# 0x3fba9e13a0db642a,
# 0x0000000000000000,
# 0xbfaa9c1ca2161b9b,
# 0x3f3344a09efdc635,
# 0x3f71b82c430a2381,
# 0xbefebfb97bca01f2,
# 0xbf22dcdb1bc1d038,
# 0x3eb180047f0b79ae,
# 0x3ec57eeeee84d0d0,
# 0xbe54a0c699c8318b,
# 0xbe5e7594e8a2c760,
# 0x3dedccbbb4c0ba7f,
# 0x3ded6766337b5c95,
# 0xbd7d1a05cea18a02,
# 0xbd74922fb50a29f1,
# ],
# [mpf('0.0'), mpf('-0.10260056710339717423'), mpf('0.00084836685129376632915'), mpf('0.017086064842062572404'), mpf('-0.0001411624626315861832'), mpf('-0.00085290411144180015077'), mpf('7.0369187625099623987e-6'), mpf('0.000020257567646663438134'), mpf('-1.6681610676160948753e-7'), mpf('-2.8044358846377546361e-7'), mpf('2.3037229301322924001e-9'), mpf('2.539255362032374819e-9'), mpf('-2.0796704275232000962e-11'), mpf('-1.6199771830851734415e-11'), mpf('1.3221313774039008044e-13'), mpf('7.6719022129281063229e-14')]
# [
# 0x0000000000000000,
# 0xbfba4407e04298d1,
# 0x3f4bcc9df0cf00b2,
# 0x3f917f0266db2149,
# 0xbf2280a052234a05,
# 0xbf4bf2ada1f44071,
# 0x3edd83d58032b48d,
# 0x3ef53dd972d8f232,
# 0xbe8663c1fe202028,
# 0xbe92d1fbf2203ff6,
# 0x3e23c9f0b759c5f9,
# 0x3e25cfe1b012696d,
# 0xbdb6ddc0795781e9,
# 0xbdb1cfd49504266a,
# 0x3d429b7af5214fbc,
# ],
# [mpf('-0.10130665873405690441'), mpf('0.0'), mpf('0.05064016586156986602'), mpf('-0.00027197551271251256927'), mpf('-0.0042156294075031986387'), mpf('0.00002713394525093374988'), mpf('0.00014026624811818422052'), mpf('-9.655520943126805162e-7'), mpf('-2.4983019654441094841e-6'), mpf('1.7792894459695768376e-8'), mpf('2.7666644458391307961e-8'), mpf('-2.0094718665114134832e-10'), mpf('-2.0874666878940311929e-10'), mpf('1.534343409298639562e-12'), mpf('1.1415072536648587747e-12'), mpf('-8.4511469623885421182e-15')]
# [
# 0xbfb9ef3bb2213b0b,
# 0x0000000000000000,
# 0x3fa9ed82007a9a45,
# 0xbf31d2fdeeb29f8a,
# 0xbf71446866ff1b83,
# 0x3efc73b684f93259,
# 0x3f22628de594b6c9,
# 0xbeb03303c1427449,
# 0xbec4f51007c51087,
# 0x3e531adfa36f2213,
# 0x3e5db4f306b19095,
# 0xbdeb9e33598f899e,
# 0xbdecb09ed6ecb896,
# 0x3d7afe1183148a99,
# 0x3d7414e442aa8d57,
# ],
# [mpf('0.0'), mpf('0.1000351468115232617'), mpf('-0.00078629942830563519099'), mpf('-0.016660163477262458228'), mpf('0.00013085558420683066916'), mpf('0.00083177512953911054456'), mpf('-6.5250145198582105878e-6'), mpf('-0.000019760368082689363922'), mpf('1.5474587443709632705e-7'), mpf('2.736450743277933514e-7'), mpf('-2.1381991882249784312e-9'), mpf('-2.4786415053408337153e-9'), mpf('1.9315310287133023631e-11'), mpf('1.5820141285487122965e-11'), mpf('-1.2289116699088650868e-13'), mpf('-7.4959257099167780235e-14')]
# [
# 0x0000000000000000,
# 0x3fb99be744018c90,
# 0xbf49c3f52a2af724,
# 0xbf910f5ca51f98b0,
# 0x3f2126c8e8ca2766,
# 0x3f4b416f7d4fc313,
# 0xbedb5e2e5580e1ce,
# 0xbef4b862279de756,
# 0x3e84c5071b39dc13,
# 0x3e925d2fc3b19021,
# 0xbe225df322279972,
# 0xbe254a971eb6fe3b,
# 0x3db53cc6c9922f2b,
# 0x3db164f95180d8c1,
# 0xbd414b9ef404ed89,
# ],
# [mpf('0.098834184596222183876'), mpf('0.0'), mpf('-0.049405458536460670831'), mpf('0.00025256349994869946121'), mpf('0.0041132463629726776592'), mpf('-0.000025202841594906565653'), mpf('-0.0001368829808319239182'), mpf('8.9714121014927428183e-7'), mpf('2.4386299418914361688e-6'), mpf('-1.6539861311327607996e-8'), mpf('-2.7014175513361372061e-8'), mpf('1.8690343722178003018e-10'), mpf('2.038999250416499923e-10'), mpf('-1.4280904253427435801e-12'), mpf('-1.1154873435993946843e-12'), mpf('7.8721161931972536006e-15')]
# [
# 0x3fb94d3276914e51,
# 0x0000000000000000,
# 0xbfa94bac1950e319,
# 0x3f308d4ff8f2059e,
# 0x3f70d90d29bfeecd,
# 0xbefa6d56162f7fb4,
# 0xbf21f107da23807d,
# 0x3eae1a626277437b,
# 0x3ec474eafd0cc642,
# 0xbe51c27144f42d78,
# 0xbe5d01999b1a4fe9,
# 0x3de9b014801da87a,
# 0x3dec061740bc8a45,
# 0xbd791f8c2972547e,
# 0xbd739fb558b7aa4d,
# ],
# [mpf('0.0'), mpf('-0.097653015783173307152'), mpf('0.00073144790567323065329'), mpf('0.016264545139161660511'), mpf('-0.00012174383503990132813'), mpf('-0.00081213396686711768399'), mpf('6.0721815762788217075e-6'), mpf('0.000019297666677419638672'), mpf('-1.4405869140360647463e-7'), mpf('-2.6730895275681491999e-7'), mpf('1.9914664822881933103e-9'), mpf('2.4220468979100526358e-9'), mpf('-1.8000169030184880714e-11'), mpf('-1.5464913442462141562e-11'), mpf('1.1460115819491910409e-13'), mpf('7.3308489586119513174e-14')]
# [
# 0x0000000000000000,
# 0xbfb8ffc9bd24fe08,
# 0x3f47f7d46ab33721,
# 0x3f90a7a725d3fbc4,
# 0xbf1fea1728f216b4,
# 0xbf4a9cac69f0ed64,
# 0x3ed977f48ff1056b,
# 0x3ef43c2d8e698c10,
# 0xbe8355d1a6765ea6,
# 0xbe91f0553501d121,
# 0x3e211b47f6a44829,
# 0x3e24ce23303889a9,
# 0xbdb3ca98df62221f,
# 0xbdb100fc746529d7,
# 0x3d4020f11e2dca08,
# ],
# [mpf('-0.0965343798752921876'), mpf('0.0'), mpf('0.048256848126837736739'), mpf('-0.00023535520071323167442'), mpf('-0.0040179589561544606493'), mpf('0.000023490138467151720763'), mpf('0.00013373166797904434411'), mpf('-8.3642189841130020971e-7'), mpf('-2.3829855799638399216e-6'), mpf('1.5426583861495063866e-8'), mpf('2.6404849101912898507e-8'), mpf('-1.7441023066013380126e-10'), mpf('-1.9936551940059712276e-10'), mpf('1.3334257100117285396e-12'), mpf('1.0910928798294402314e-12'), mpf('-7.3553369254921115951e-15')]
# [
# 0xbfb8b67a2481077d,
# 0x0000000000000000,
# 0x3fa8b51f21068ea2,
# 0xbf2ed935c7aefa31,
# 0xbf707522a5037f2d,
# 0x3ef8a196061f8bbc,
# 0x3f21874a47e3c1e3,
# 0xbeac10cf34c04f17,
# 0xbec3fd6c2d4fa2a4,
# 0x3e50906d55522785,
# 0x3e5c5a1c124dfa08,
# 0xbde7f883b31a5f59,
# 0xbdeb668cf53028e4,
# 0x3d7775372d05b25d,
# 0x3d7331d871d677e0,
# ],
# [mpf('0.0'), mpf('0.095433339020535349088'), mpf('-0.00068269004174153639031'), mpf('-0.015895789147530446449'), mpf('0.00011364193049670885699'), mpf('0.00079381472111463433329'), mpf('-5.6693153429013185048e-6'), mpf('-0.000018865692793976654867'), mpf('1.3454321373299606924e-7'), mpf('2.6138606864225107376e-7'), mpf('-1.8606858452222984138e-9'), mpf('-2.3690596077487094041e-9'), mpf('1.6826517262570876729e-11'), mpf('1.5131701609754333781e-11'), mpf('-1.0719200328090639457e-13'), mpf('-7.1756671236823762396e-14')]
# [
# 0x0000000000000000,
# 0x3fb86e51be0a9153,
# 0xbf465ed1b387e5da,
# 0xbf9046fc5a218a86,
# 0x3f1dca617fefa913,
# 0x3f4a0300221528a7,
# 0xbed7c7618906f1e2,
# 0xbef3c838897d0a1e,
# 0x3e820ede9f9dd7dd,
# 0x3e918a94165592bb,
# 0xbe1ff76205118f09,
# 0xbe24599dfeef01a1,
# 0x3db2803e59983134,
# 0x3db0a33202feb043,
# 0xbd3e2bff738680f8,
# ],
# [mpf('0.094388034178857080293'), mpf('0.0'), mpf('-0.047184774934733867964'), mpf('0.00022001566929329634253'), mpf('0.0039289856695835246854'), mpf('-0.000021962791729735716415'), mpf('-0.00013078712862304664638'), mpf('7.8223872407558275716e-7'), mpf('2.3309408465651831655e-6'), mpf('-1.4432272956073114317e-8'), mpf('-2.5834210429547877517e-8'), mpf('1.6323978681956180938e-10'), mpf('1.9511237959858629649e-10'), mpf('-1.2486726776908588314e-12'), mpf('-1.0681695904995622782e-12'), mpf('6.8919635740651658607e-15')]
# [
# 0x3fb829d06fee9266,
# 0x0000000000000000,
# 0xbfa8289a526d7785,
# 0x3f2cd680355c9eb6,
# 0x3f7017d70f512861,
# 0xbef707978e2a0db8,
# 0xbf21247ce15e7385,
# 0x3eaa3f6125485ec1,
# 0x3ec38da848401be9,
# 0xbe4efe39d8db4cd8,
# 0xbe5bbd40f1db0e94,
# 0x3de66f7d49436f83,
# 0x3dead0e8148229b3,
# 0xbd75f78595133d0b,
# 0xbd72ca9bb10321b3,
# ],
# [mpf('0.0'), mpf('-0.093358453290454973105'), mpf('0.00063911844145426895193'), mpf('0.015550991590621156214'), mpf('-0.00010639992922867547593'), mpf('-0.00077667615750326345998'), mpf('5.3090362453010040925e-6'), mpf('0.000018461222450077951618'), mpf('-1.2602774154061398181e-7'), mpf('-2.5583413817217867922e-7'), mpf('1.7435437707627237553e-9'), mpf('2.3193224461052905671e-9'), mpf('-1.5774098387888381677e-11'), mpf('-1.4818414928445975014e-11'), mpf('1.0053953451412704343e-13'), mpf('7.0294883384864148163e-14')]
# [
# 0x0000000000000000,
# 0xbfb7e656efb009ae,
# 0x3f44f15066f3d876,
# 0x3f8fd932c26aad94,
# 0xbf1be460dd86a0a4,
# 0xbf49733b591879f8,
# 0x3ed64488c56022e0,
# 0x3ef35ba58bf2f993,
# 0xbe80ea47bceb9a8f,
# 0xbe912b327055d0e9,
# 0x3e1df42fc4e2482c,
# 0x3e23ec3e76876dba,
# 0xbdb1580393f473c3,
# 0xbdb04b0353c35935,
# 0x3d3c4ca30ffe2a12,
# ],
# [mpf('-0.092378802708031519143'), mpf('0.0'), mpf('0.046181101854151976967'), mpf('-0.00020627267591182377249'), mpf('-0.0038456601458460277282'), mpf('0.000020593912066699587302'), mpf('0.00012802782647440689028'), mpf('-7.3364968102942266305e-7'), mpf('-2.2821280051030681707e-6'), mpf('1.353993564033335372e-8'), mpf('2.5298408793480731944e-8'), mpf('-1.5320530748500725546e-10'), mpf('-1.9111343355225588559e-10'), mpf('1.1724509261116985428e-12'), mpf('1.046581709573312598e-12'), mpf('-6.4746793094789554707e-15')]
# [
# 0xbfb7a62320798175,
# 0x0000000000000000,
# 0x3fa7a50ca4504bb8,
# 0xbf2b095ccb50a68c,
# 0xbf6f80ef11daa37a,
# 0x3ef59822dc75b064,
# 0x3f20c7e6a7c66630,
# 0xbea89e00b5c358d0,
# 0xbec324d5238b26d0,
# 0x3e4d13a888d5dd30,
# 0x3e5b29f941a95b07,
# 0xbde50e6ebb3d1df6,
# 0xbdea4434c6b929dd,
# 0x3d74a03fe2c47842,
# 0x3d7269628f2df98c,
# ],
# ];

# %%
from mpmath import mp, j1, taylor, linspace, chebyfit

# Set precision (decimal places)
mp.prec = 107

# Generate degree-46 Taylor series of J1(x) at x = 0
poly = taylor(lambda val: j1(val), mp.mpf('1.8411837813407134767373918293742463'), 25)

def polyeval(coeffs, x, center):
    """Evaluate Taylor polynomial centered at `center` using Horner's method."""
    u = x - center
    # result = mpf(0)
    # for c in reversed(coeffs):
    #     result = result * u + c
    # return result
    result = RealField(53)(0)
    for (index, c) in enumerate(reversed(coeffs)):
        if index < 8:
            result = RealField(53)(result) * RealField(53)(u) + RealField(53)(c)
        else:
            result = RealField(107)(result) * RealField(107)(u) + RealField(107)(c)
    return result

xs = linspace(0.991, 2, 1000)  # 1000 evenly spaced points
max_rel_error = 0
max_abs_error = 0
worst_x = None

for x in xs:
    true_val = j1(x)
    approx_val = polyeval(poly, x, DD('1.8411837813407134767373918293742463'))
    if true_val != 0:
        rel_error = abs((approx_val - true_val) / true_val)
        if rel_error > max_rel_error:
            max_rel_error = rel_error
            worst_x = x

print(f"Max relative error over [0, 1]: {max_rel_error}")
print(f"Occurs at x = {worst_x}")
worst_x = None

for x in xs:
    true_val = j1(x)
    approx_val = polyeval(poly, x, DD('1.8411837813407134767373918293742463'))
    abs_error = abs(approx_val - true_val)
    if abs_error > max_abs_error:
        max_abs_error = abs_error
        worst_x = x

print(f"Max abs error over [0, 1]: {max_rel_error}")
print(f"Occurs at x = {worst_x}")

print(double_to_hex(DD(max_rel_error)))
print(polyeval(poly, mp.mpf('0.9750000000213042'), mp.mpf('1.8411837813407134767373918293742463')))
def make_e(eps, p):
    return float((DD(1) + DD(2)**DD(-p)) / (DD(1) - eps - DD(2) ** DD(p + 1)*eps)) * 2**(-p)
print(double_to_hex(make_e(DD('1.192857060732688978535982892962e-26'), 55)))
print(polyeval(poly, DD('0.9218750000227204'), DD('1.8411837813407134767373918293742463')))
# Out:
# Max relative error over [0, 1]: 1.224074717441528028996975552824e-29
# Occurs at x = 0.9909999999999999920063942226989
# Max abs error over [0, 1]: 1.224074717441528028996975552824e-29
# Occurs at x = 0.9909999999999999920063942226989
# 0x39ef08b2faac819b
# 0.4318209025803349383680360368051
# 0x3c800000003b1143
# 0.4136748745759469052209620580648
