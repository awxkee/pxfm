# %%
from scipy.special import j1
from scipy.optimize import brentq
from sage.all import *
import struct

DR = RealField(52)

DD = RealField(157)

def double_to_hex(f):
    # Converts Python float (f64) to hex string
    packed = struct.pack('>d', float(f))
    return '0x' + packed.hex()

def split_double_double(x):
    # Split RR value x into hi + lo (double-double)
    x_hi = DR(x)  # convert to f64
    x_lo = x - DD(x_hi)
    return (x_lo,x_hi)

# %%
from scipy.special import j1, jvp
from scipy.optimize import brentq
from sage.all import *
import struct

DR = RealField(52)

DD = RealField(190)

def double_to_hex(f):
    packed = struct.pack('>d', float(f))
    return '0x' + packed.hex()

def split_double_double(x):
    # Split RR value x into hi + lo (double-double)
    x_hi = DR(x)  # convert to f64
    x_lo = x - DD(x_hi)
    return (x_lo,x_hi)

def print_double_double(mark, x):
    splat = split_double_double(x)
    print(f"{mark}({double_to_hex(splat[0])}, {double_to_hex(splat[1])}),")
    
# Use Sage's RDF for high-precision floats
R120 = RealField(120)

# List of zeros
zeros = []

# Step size to detect sign changes
step = R120(0.001)
x = R120(0.0)

previous_zero = R120(0)
epsilon = 1e-12
j1_zeros = []

while x < 77:
    if j1(float(x)) * j1(float(x + step)) < 0:  # Sign change => zero in interval
        previous_zero = brentq(j1, x, x + step)
        j1_zeros.append(R120(previous_zero))
    if abs(x - round(x)) < epsilon:
        zeros.append(R120(previous_zero))
    x += step

j1_extrema = []

x = R120(0.0)
while x < 77:
    dfx = jvp(1, float(x), n=1)  # Derivative of J1
    dfx_next = jvp(1, float(x + step), n=1)
    if dfx * dfx_next < 0:
        extremum = brentq(lambda x: jvp(1, x, n=1), float(x), float(x + step))
        j1_extrema.append(R120(extremum))
    x += step

# Print results
for i, z in enumerate(j1_zeros):
    print(f"Zero {i+1}: x ≈ {z}")

print("Extrema (peaks/valleys) of J1(x):")
for e in j1_extrema:
    print(f"nExtrema: {e}")

j1_zeros.extend(j1_extrema)

j1_zeros = sorted(j1_zeros)

# Print results
for i, z in enumerate(j1_zeros):
    print(f"Peak or zero {i+1}: x ≈ {z}")

print("")

print("static J1_ZEROS: [(u64, u64); 46] = [")
for z in j1_zeros:
    k = split_double_double(DD(f"{z}"))
    hi = double_to_hex(k[1])
    lo = double_to_hex(k[0])
    print(f"({lo}, {hi}),")
    
print("];")

from mpmath import *
from sage.all import *

from mpmath import mp, j1, taylor, expm1

# Precision
mp.prec = 106

prev_zero = 0

CDR = RealField(107)

var('x')

def get_constant_term(poly, y):
    for term in poly.operands():
        if term.is_constant():
            return term

def print_taylor_coeffs(poly, x0):
    print("TaylorExtendedSeries {")
    print_double_double("a0: ", poly[0])
    print_double_double("a1: ", poly[1])
    print_double_double("a2: ", poly[2])
    print_double_double("a3: ", poly[3])
    print_double_double("a4: ", poly[4])
    print_double_double("a5: ", poly[5])
    print_double_double("a6: ", poly[6])
    print("c: [")
    for i in range(7, 23):
        coeff = poly[i]
        print(f"{double_to_hex(coeff)},")
    print("],")
    print("},")

mp.prec = 106

def print_expansion_at_0():
    print(f"pub(crate) static J1_MACLAURIN_SERIES: J1MaclaurinSeries = J1MaclaurinSeries {{")
    from mpmath import mp, j1, taylor, expm1
    # The j1 (Bessel J_1) function from mpmath will compute with mp.dps precision
    # The Taylor series computation will also respect mp.dps
    poly = taylor(lambda val: j1(val), 0, 46)
    # print(poly)
    real_i = 0
    print_double_double("a0: ", DD(poly[1]))
    print_double_double("a1: ", DD(poly[3]))
    print_double_double("a2: ", DD(poly[5]))
    print_double_double("a3: ", DD(poly[7]))
    print_double_double("a4: ", DD(poly[9]))
    print("series: [")
    for i in range(11, 46, 2):
        print(f"{double_to_hex(poly[i])},")
        real_i = real_i + 1
    print("],")

    print("};")

    print(f"poly {poly}")

print_expansion_at_0()

print(f"static J1_COEFFS: [TaylorExtendedSeries; {len(j1_zeros) + 1}] = [")

for i in range(0, len(j1_zeros)):
    k_range = j1_zeros[i]
    range_diff = k_range - prev_zero
    g_c = 1

    f_poly = bessel_J(1, x)
    x0 = mp.mpf(k_range)
    from mpmath import mp, j1, taylor, expm1
    # The j1 (Bessel J_1) function from mpmath will compute with mp.dps precision
    # The Taylor series computation will also respect mp.dps
    poly = taylor(lambda val: j1(val), x0, 23)
    # print(poly)
    print_taylor_coeffs(poly, CDR(k_range))
    prev_zero = j1_zeros[i]

print("];")
# Out:
# Zero 1: x ≈ 3.8317059702075111360386472370009869
# Zero 2: x ≈ 7.0155866698156179595002868154551834
# Zero 3: x ≈ 10.173468135063002293350109539460391
# Zero 4: x ≈ 13.323691936314220995996038254816085
# Zero 5: x ≈ 16.470630050877630878858326468616724
# Zero 6: x ≈ 19.615858510468239472857021610252559
# Zero 7: x ≈ 22.760084380592772390627942513674498
# Zero 8: x ≈ 25.903672087618382136042782803997397
# Zero 9: x ≈ 29.046828534916855346637021284550428
# Zero 10: x ≈ 32.189679910974405174783896654844284
# Zero 11: x ≈ 35.332307550083875469226768473163247
# Zero 12: x ≈ 38.474766234771614392684568883851171
# Zero 13: x ≈ 41.617094212814450315818248782306910
# Zero 14: x ≈ 44.759318997652826510602608323097229
# Zero 15: x ≈ 47.901460887185457693249190924689174
# Zero 16: x ≈ 51.043535183571506763655634131282568
# Zero 17: x ≈ 54.185553641061318330685026012361050
# Zero 18: x ≈ 57.327525437901009297547716414555907
# Zero 19: x ≈ 60.469457845347498903265659464523196
# Zero 20: x ≈ 63.611356698481237970099755330011249
# Zero 21: x ≈ 66.753226734098504380199301522225142
# Zero 22: x ≈ 69.895071837495777344884118065237999
# Zero 23: x ≈ 73.036895225573843504207616206258535
# Zero 24: x ≈ 76.178699584641464070955407805740833
# Extrema (peaks/valleys) of J1(x):
# nExtrema: 1.8411837813407134767373918293742463
# nExtrema: 5.3314427735248548501090226636733860
# nExtrema: 8.5363163663465062569457586505450308
# nExtrema: 11.706004902592065164412815647665411
# nExtrema: 14.863588633909033731583804183173925
# nExtrema: 18.015527862681800286281941225752234
# nExtrema: 21.164369859188838063346338458359241
# nExtrema: 24.311326857210804774922507931478322
# nExtrema: 27.457050571059244958860290353186429
# nExtrema: 30.601922972669093780950788641348481
# nExtrema: 33.746182898667385074986668769270182
# nExtrema: 36.889987409236809412504953797906637
# nExtrema: 40.033444053350692115600395482033491
# nExtrema: 43.176628965448820451911160489544272
# nExtrema: 46.319597561173914357368630589917302
# nExtrema: 49.462391139702766906793840462341905
# nExtrema: 52.605041111556687383199459873139858
# nExtrema: 55.747571792251008560015179682523012
# nExtrema: 58.890002299185702838713041273877025
# nExtrema: 62.032347870661993738394812680780888
# nExtrema: 65.174620802544453113114286679774523
# nExtrema: 68.316831125951807734963949769735336
# nExtrema: 71.458987105850994225875183474272490
# nExtrema: 74.601095613456408273123088292777538
# Peak or zero 1: x ≈ 1.8411837813407134767373918293742463
# Peak or zero 2: x ≈ 3.8317059702075111360386472370009869
# Peak or zero 3: x ≈ 5.3314427735248548501090226636733860
# Peak or zero 4: x ≈ 7.0155866698156179595002868154551834
# Peak or zero 5: x ≈ 8.5363163663465062569457586505450308
# Peak or zero 6: x ≈ 10.173468135063002293350109539460391
# Peak or zero 7: x ≈ 11.706004902592065164412815647665411
# Peak or zero 8: x ≈ 13.323691936314220995996038254816085
# Peak or zero 9: x ≈ 14.863588633909033731583804183173925
# Peak or zero 10: x ≈ 16.470630050877630878858326468616724
# Peak or zero 11: x ≈ 18.015527862681800286281941225752234
# Peak or zero 12: x ≈ 19.615858510468239472857021610252559
# Peak or zero 13: x ≈ 21.164369859188838063346338458359241
# Peak or zero 14: x ≈ 22.760084380592772390627942513674498
# Peak or zero 15: x ≈ 24.311326857210804774922507931478322
# Peak or zero 16: x ≈ 25.903672087618382136042782803997397
# Peak or zero 17: x ≈ 27.457050571059244958860290353186429
# Peak or zero 18: x ≈ 29.046828534916855346637021284550428
# Peak or zero 19: x ≈ 30.601922972669093780950788641348481
# Peak or zero 20: x ≈ 32.189679910974405174783896654844284
# Peak or zero 21: x ≈ 33.746182898667385074986668769270182
# Peak or zero 22: x ≈ 35.332307550083875469226768473163247
# Peak or zero 23: x ≈ 36.889987409236809412504953797906637
# Peak or zero 24: x ≈ 38.474766234771614392684568883851171
# Peak or zero 25: x ≈ 40.033444053350692115600395482033491
# Peak or zero 26: x ≈ 41.617094212814450315818248782306910
# Peak or zero 27: x ≈ 43.176628965448820451911160489544272
# Peak or zero 28: x ≈ 44.759318997652826510602608323097229
# Peak or zero 29: x ≈ 46.319597561173914357368630589917302
# Peak or zero 30: x ≈ 47.901460887185457693249190924689174
# Peak or zero 31: x ≈ 49.462391139702766906793840462341905
# Peak or zero 32: x ≈ 51.043535183571506763655634131282568
# Peak or zero 33: x ≈ 52.605041111556687383199459873139858
# Peak or zero 34: x ≈ 54.185553641061318330685026012361050
# Peak or zero 35: x ≈ 55.747571792251008560015179682523012
# Peak or zero 36: x ≈ 57.327525437901009297547716414555907
# Peak or zero 37: x ≈ 58.890002299185702838713041273877025
# Peak or zero 38: x ≈ 60.469457845347498903265659464523196
# Peak or zero 39: x ≈ 62.032347870661993738394812680780888
# Peak or zero 40: x ≈ 63.611356698481237970099755330011249
# Peak or zero 41: x ≈ 65.174620802544453113114286679774523
# Peak or zero 42: x ≈ 66.753226734098504380199301522225142
# Peak or zero 43: x ≈ 68.316831125951807734963949769735336
# Peak or zero 44: x ≈ 69.895071837495777344884118065237999
# Peak or zero 45: x ≈ 71.458987105850994225875183474272490
# Peak or zero 46: x ≈ 73.036895225573843504207616206258535
# Peak or zero 47: x ≈ 74.601095613456408273123088292777538
# Peak or zero 48: x ≈ 76.178699584641464070955407805740833
#
# static J1_ZEROS: [(u64, u64); 46] = [
# (0x386f2facf760acb0, 0x3ffd757d1fec8b2e),
# (0xb8c66726c861ed00, 0x400ea75575af6f06),
# (0xbcd0000000000000, 0x40155365bc0323a0),
# (0xbcd0000000000000, 0x401c0ff5f3b47250),
# (0x3ce0000000000000, 0x402112980f0b891c),
# (0xbce0000000000000, 0x402458d0d0bdfcc8),
# (0x3ce0000000000000, 0x40276979797ee5ac),
# (0x3ce0000000000000, 0x402aa5baf310e5a0),
# (0xbce0000000000000, 0x402dba284a17ac5a),
# (0xb8b2fbfd677020aa, 0x4030787b360508c4),
# (0xb903101c299c1cf8, 0x403203f9a24e6526),
# (0x3cf0000000000000, 0x40339da8e7416ca2),
# (0xb9042bbd3de722b4, 0x40352a1424a1aa08),
# (0x39006f0efbcc3570, 0x4036c294e3d4d8ac),
# (0xbcf0000000000000, 0x40384fb31dee163e),
# (0xb9018fe14a7529b4, 0x4039e7570dcea106),
# (0xbcf0000000000000, 0x403b75014427514e),
# (0xb900388a16f1ecde, 0x403d0bfcf471fccc),
# (0xb8ed9f597ce355fa, 0x403e9a179fba532a),
# (0xb8d325873a5f94e9, 0x404018476e6b2bf0),
# (0x38fc968adc2cd0ea, 0x4040df82ebd54e32),
# (0x3d00000000000000, 0x4041aa890dc5e97c),
# (0xb8efdd192e6ecb9c, 0x404271eb1b80430e),
# (0xbd00000000000000, 0x40433cc523d5cb6a),
# (0xb8e65f1a7ab6bb47, 0x40440447e50db186),
# (0x39023a93a9452b66, 0x4044cefcf1734b62),
# (0x3d00000000000000, 0x4045969bc7271082),
# (0xb894c4e977ba1f5c, 0x404661315d6b1340),
# (0x3d00000000000000, 0x404728e892a88fc8),
# (0xbd00000000000000, 0x4047f36312028ad8),
# (0xbd00000000000000, 0x4048bb2fa2037de6),
# (0x38bd5e72234d3058, 0x404985928f96d51e),
# (0xb8f46ca4977d4856, 0x404a4d71fcb56f8c),
# (0x38fce705e4dcc223, 0x404b17c038c2018c),
# (0xb8eacb062eb3daf4, 0x404bdfb06eb790aa),
# (0x3d00000000000000, 0x404ca9ec5a82324a),
# (0xbd00000000000000, 0x404d71eb98682f08),
# (0x3d00000000000000, 0x404e3c1731d64f1e),
# (0x3900758c84c19f9a, 0x404f0423f99b4b54),
# (0xbd00000000000000, 0x404fce40efb11570),
# (0xbd10000000000000, 0x40504b2cfcbb084e),
# (0xbd10000000000000, 0x4050b034dde75b44),
# (0xb8f93b37a0731c18, 0x40511446f60f1458),
# (0x38c8fce8e40bedba, 0x40517948db63675c),
# (0xbd10000000000000, 0x4051dd600b743a9c),
# (0x3d10000000000000, 0x4052425c7dcacdf6),
# (0xb8f8e2f2c0364513, 0x4052a67859bc641e),
# (0xb8f7777cca870bee, 0x40530b6fd061f602),
# ];
# pub(crate) static J1_MACLAURIN_SERIES: J1MaclaurinSeries = J1MaclaurinSeries {
# a0: (0x0000000000000000, 0x3fe0000000000000),
# a1: (0x0000000000000000, 0xbfb0000000000000),
# a2: (0xbc1555555555554e, 0x3f65555555555556),
# a3: (0xbbac71c71c71c717, 0xbf0c71c71c71c71c),
# a4: (0x3b582d82d82d82da, 0x3ea6c16c16c16c16),
# series: [
# 0xbe3845c8a0ce512a,
# 0x3dc27e4fb7789f5c,
# 0xbd4522a43f65486a,
# 0x3cc2c9758daf5ccf,
# 0xbc3ab81ea75fcdf5,
# 0x3baf17697cf1cf12,
# 0xbb1e2637bef9ff1b,
# 0x3a88bce58901a35d,
# 0xb9f165e7c2d153f4,
# 0x39553585cdcbfb0f,
# 0xb8b69f7da8510bcd,
# 0x38154ad09e6a6575,
# 0xb771d028acb00492,
# 0x36caaae78f4066a6,
# 0xb621f72d8389b3a4,
# 0x3575e69de22df5ce,
# 0xb4c84564b82a1185,
# 0x34188f11edf3ed4c,
# ],
# };
# poly [mpf('0.0'), mpf('0.5'), mpf('0.0'), mpf('-0.0625'), mpf('0.0'), mpf('0.002604166666666666666666666666666683'), mpf('0.0'), mpf('-0.00005425347222222222222222222222222206'), mpf('0.0'), mpf('0.0000006781684027777777777777777777777757'), mpf('0.0'), mpf('-0.000000005651403356481481481481481481481482'), mpf('0.0'), mpf('3.363930569334215167548500881834219e-11'), mpf('0.0'), mpf('-1.50175471845277462836986646510457e-13'), mpf('0.0'), mpf('5.21442610573880079295092522605745e-16'), mpf('0.0'), mpf('-1.448451696038555775819701451682647e-18'), mpf('0.0'), mpf('3.291935672814899490499321481096925e-21'), mpf('0.0'), mpf('-6.234726653058521762309320986925933e-24'), mpf('0.0'), mpf('9.991549123491220772931604145714641e-27'), mpf('0.0'), mpf('-1.372465538941101754523571998037746e-29'), mpf('0.0'), mpf('1.633887546358454469670919045283015e-32'), mpf('0.0'), mpf('-1.701966194123390072573874005503148e-35'), mpf('0.0'), mpf('1.564307163716351169645104784469785e-38'), mpf('0.0'), mpf('-1.278028728526430694154497372932828e-41'), mpf('0.0'), mpf('9.342315267006072325690770269976841e-45'), mpf('0.0'), mpf('-6.146260044082942319533401493405855e-48'), mpf('0.0'), mpf('3.658488121477941856865119936551088e-51'), mpf('0.0'), mpf('-1.979701364436115723411861437527685e-54'), mpf('0.0'), mpf('9.781133223498595471402477458140435e-58'), mpf('0.0')]
# static J1_COEFFS: [TaylorExtendedSeries; 49] = [
# TaylorExtendedSeries {
# a0: (0xbc9dc1c79b78175f, 0x3fe29ea3d19f0360),
# a1: (0xb9b8ce9e47eff062, 0xbd19057390399e50),
# a2: (0x3c089a9dc3dd2180, 0xbfca41115c5df220),
# a3: (0xbc0e2230f813832c, 0x3f78d1448e6ffac0),
# a4: (0x3c3f776eb4044d25, 0x3f8c441a2f9de1f0),
# a5: (0x3bcb8c73b568912c, 0xbf386671c18b11ca),
# a6: (0x3be8bfbfa4919250, 0xbf39e2504ddc75c8),
# c: [
# 0x3ee34ccbca0c7c14,
# 0x3eda4973784d103e,
# 0xbe81045322aab054,
# 0xbe70fae0da6cdcbd,
# 0x3e13546cef5ed577,
# 0x3dfe5ee82e6676a8,
# 0xbd9ec80cc8b64488,
# 0xbd83eb2e99629b04,
# 0x3d222bfcdb195ade,
# 0x3d03fb3376a42df1,
# 0xbca0901287d109ed,
# 0xbc7fa6a90c6a0bc6,
# 0x3c180774f17c4e76,
# 0x3bf44b79578fc6b4,
# 0xbb8c6ab05fe77a13,
# 0xbb65805fbd38e1cb,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb93051d291e4d980, 0x3cc11de349a22a92),
# a1: (0x3c8d3e21589aeada, 0xbfd9c6cf582cbf82),
# a2: (0x3c4a03b85ce1d65e, 0x3faae8a39f51ace8),
# a3: (0x3c33e73a0d46a7d0, 0x3fab589d1da13908),
# a4: (0x3c1b067d54436cfc, 0xbf7537544c331d98),
# a5: (0xbc1aae026b4c35b0, 0xbf624b3409959066),
# a6: (0x3badf5004afaa520, 0x3f26e4c2d5354216),
# c: [
# 0x3f083a06e30c410d,
# 0xbec9799d4c9f253b,
# 0xbea33825cd2e2c1b,
# 0x3e617069233e9162,
# 0x3e34569b22afc3cb,
# 0xbdf03b9e96510562,
# 0xbdbec62310af5f59,
# 0x3d75ec84e47b6f44,
# 0x3d417a40c9422e1a,
# 0xbcf67cb1d0030c91,
# 0xbcbee7ff918f9b71,
# 0x3c721fb8bdc4d7f1,
# 0x3c35e0517dd0b5cd,
# 0xbbe792595a1eec5d,
# 0xbba95a682022dcbe,
# 0x3b59438c464a0b8d,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc782d6271464ef0, 0xbfd626ee83500bf2),
# a1: (0x39dd4e7b587ec23c, 0xbd30b62f13f81858),
# a2: (0x3c69ae2f8ccfe432, 0x3fc55f6bec9efa1c),
# a3: (0x3c160a1d8a1f729c, 0xbf83d23336fcfd84),
# a4: (0xbc33e89ea615f13b, 0xbf88c77a983a0968),
# a5: (0x3bce83a9165ceb60, 0x3f45cdc98db1be46),
# a6: (0xbbe3dda8eaf59ed0, 0x3f373576ff46efcc),
# c: [
# 0xbef2461447d7aadd,
# 0xbed7b853456b7080,
# 0x3e90abfc6827431a,
# 0x3e6ea7a1ee2614e6,
# 0xbe235c0413e00c13,
# 0xbdfb5c5d512fbd7c,
# 0x3daf4c5e26fd6252,
# 0x3d81e4c43397c006,
# 0xbd32addefc4d4ac6,
# 0xbd01e4fadc0e4525,
# 0x3cb12a0b88508900,
# 0x3c7c4246a0343121,
# 0xbc290ede5816e9fb,
# 0xbbf211307906e4fe,
# 0x3b9dc7bf703960e5,
# 0x3b6316e7f158a474,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb96d9d7a80f32a21, 0xbcb12be9d1ea6504),
# a1: (0xbc8ef22c3ce67ee8, 0x3fd33518b3874e8c),
# a2: (0xbc4cef1aeb527ad8, 0xbf95e70dc603629e),
# a3: (0x3c39bdeabdbbea40, 0xbfa80c83bdeee5b2),
# a4: (0xbc1ee6655bac8209, 0x3f69a4b292e3de30),
# a5: (0x3c0b4ecded2acbde, 0x3f613fbc7d698218),
# a6: (0x3bad8fa61005b938, 0xbf207358bbdbff88),
# c: [
# 0xbf0796a751f89054,
# 0x3ec4255b015adec9,
# 0x3ea3026e0ce97aba,
# 0xbe5d48dcdae92f20,
# 0xbe344639d7eeb0a9,
# 0x3dec62ccb4a32ea9,
# 0x3dbecae92e85445a,
# 0xbd73bb6898d73ccc,
# 0xbd4183edbb8ef561,
# 0x3cf4ae3e7e4cce36,
# 0x3cbefbb1e700730e,
# 0xbc70f28da3efa3c2,
# 0xbc35ec318df9b46a,
# 0x3be6555a952345f2,
# 0x3ba9633c7f133c96,
# 0xbb583145f93c70a6,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c815b9202e878c7, 0x3fd17dbf09d40d24),
# a1: (0xb9d2197519bd08b4, 0xbd30b94902020478),
# a2: (0x3c73af8aa5987645, 0xbfc1404bf647c216),
# a3: (0xbc1362ac17135496, 0x3f74f4df276a2268),
# a4: (0x3c1cd16e745627ac, 0x3f85c6285429b550),
# a5: (0x3be65818ac75f8b3, 0xbf3d68ab7228a0e2),
# a6: (0x3be0741bed20144d, 0xbf356acb6452d6e4),
# c: [
# 0x3eec10b47cf80537,
# 0x3ed67eaae97bbaa2,
# 0xbe8bb6530c6404c3,
# 0xbe6d87201e450c0a,
# 0x3e20f47c83ec5eb5,
# 0x3dfa98331f6ea4cc,
# 0xbdac70414a23793c,
# 0xbd817c057a5fcb43,
# 0x3d316fea14d206fc,
# 0x3d0189bd3ec36019,
# 0xbcb05af44aaf3245,
# 0xbc7bbdb47ae6b5d0,
# 0x3c28435e8461f7f8,
# 0x3bf1bfd66fba78e3,
# 0xbb9d3526fa2c7263,
# 0xbb62c1e2b3f20644,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb9c3f28ae5df16e8, 0xbd33b1f774616baa),
# a1: (0x3c7583410514cc90, 0xbfcff654544ebbda),
# a2: (0x3c1bf48f7f697004, 0x3f89223ff2c0c4da),
# a3: (0xbc48dbd2a27b2e94, 0x3fa4b0c5d5da6652),
# a4: (0xbbf8081306af66d0, 0xbf5f91a9ee0d58d6),
# a5: (0xbc0ec3f9f0135e80, 0xbf5f51c2489b9bce),
# a6: (0xbbbb56c99a3f18c0, 0x3f16b4c9ca0f8f08),
# c: [
# 0x3f063c5475439a5d,
# 0xbebe3725daf6b1dc,
# 0xbea25c1238b32c1c,
# 0x3e57486f6b9aba2a,
# 0x3e33e3bf24827536,
# 0xbde78a38a73e8b52,
# 0xbdbe844eb6b20d23,
# 0x3d70e24abb407aa6,
# 0x3d41797e5eacdb2f,
# 0xbcf21fc0f12664a6,
# 0xbcbf0c12e445c603,
# 0x3c6e4423559090d1,
# 0x3c36080463b41b37,
# 0xbbe43e38b2631195,
# 0xbba98fa121c81118,
# 0x3b56325cba170553,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c50f8942d3f90d4, 0xbfcddceb4ce1bf4a),
# a1: (0xb949e745909c8fbc, 0x3cb1c2aaed4bc700),
# a2: (0xbc631bc68ea58fad, 0x3fbda52116c0a640),
# a3: (0xbbe69ac233f8cb78, 0xbf6a9da4603b6846),
# a4: (0x3c3a4182d6ecbe42, 0xbf8331e74ea59ab8),
# a5: (0x3be604a9f9254c71, 0x3f33e5cb6eba6ecc),
# a6: (0xbbb68852900354f8, 0x3f33885fe9afa540),
# c: [
# 0xbee494c0f4b06825,
# 0xbed512b9d37762d5,
# 0x3e85a861082bfb94,
# 0x3e6c323ea0a042bf,
# 0xbe1bcc962f7b9203,
# 0xbdf9bc94e2f29a50,
# 0x3da82bc6fcfa8e9b,
# 0x3d81141ce7b7845e,
# 0xbd2e79ccb1860d8f,
# 0xbd013e1fbe0a596f,
# 0x3cad36d12b0d24af,
# 0x3c7b66072bbdf473,
# 0xbc260cb923a35440,
# 0xbbf196237500b24c,
# 0x3b9aeba1005e183f,
# 0x3b62a07d164c6a6c,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb97b6094d21709f4, 0xbcc005534893ee30),
# a1: (0xbc667efdbdb00a56, 0x3fcbf3337873a7da),
# a2: (0xbc350809ba664890, 0xbf80c83a2d7adcb4),
# a3: (0xbc3e15078a740b7c, 0xbfa251858011816c),
# a4: (0x3c093b78abe07ce8, 0x3f559eb160bf7286),
# a5: (0x3c000a7afb01970e, 0x3f5c5bce33af2d7a),
# a6: (0x3bbd4f266bdfdd50, 0xbf10413e306e0010),
# c: [
# 0xbf04a6704d05ad0f,
# 0x3eb6c43eedfed69b,
# 0x3ea16abd7815de77,
# 0xbe5257f16f5d4328,
# 0xbe332db1b4b2ff90,
# 0x3de33acccf7bfdb2,
# 0x3dbdc8f5682566c1,
# 0xbd6c6513386daabe,
# 0xbd413585a9b74744,
# 0x3cef322ea2e20d90,
# 0x3cbec749ba31d0f5,
# 0xbc6a8abab44a59f8,
# 0xbc35f2aba27d015d,
# 0x3be20705169a0871,
# 0x3ba98e9c9fa10652,
# 0xbb540557c89d65b5,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc26397095487d60, 0x3fca7f63fea81f26),
# a1: (0x395e97309f90fb7c, 0xbca29bc8dfecc704),
# a2: (0xbc6142da376a9bc0, 0xbfba60afb06640ce),
# a3: (0xbc1b3f221ea1b6c9, 0x3f62c1e930935d6e),
# a4: (0x3c3c77c17495b945, 0x3f814506466d7f1e),
# a5: (0xbbc58c18ca8a085a, 0xbf2cca8c0c0eaa64),
# a6: (0x3bdd0efb05a52b48, 0xbf31df821cc1377e),
# c: [
# 0x3edee8814ed0ac60,
# 0x3ed3a365a4199dd0,
# 0xbe80ed2f9c3e459b,
# 0xbe6ab3b37c5271b2,
# 0x3e1684d6e62b5c72,
# 0x3df8b105a5120ed0,
# 0xbda42dc5991b9d0c,
# 0xbd808d6405ffe3db,
# 0x3d2a15203365a9eb,
# 0x3d00d7c118bbeb35,
# 0xbca984ffd2857b58,
# 0xbc7aecb2d322693e,
# 0x3c2396ff2d246049,
# 0x3bf15cbae441ca22,
# 0xbb9841be044fa297,
# 0xbb627467b799ccfb,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb957059a5e5fe96c, 0x3cbb5ffd9d9e72b0),
# a1: (0x3c74b2ed27b37150, 0xbfc925c6fca08f56),
# a2: (0xbc186def9ba6a380, 0x3f786dd32e059a36),
# a3: (0x3c442e86182d2d88, 0x3fa09463bbd03680),
# a4: (0x3bf1e7304bcaede0, 0xbf4fda0298c875fe),
# a5: (0x3bf0195d33bc3daa, 0xbf59f4be60758fb4),
# a6: (0xbbafcf6b76088d4a, 0x3f0877991af9d172),
# c: [
# 0x3f032cb00ee8c1f5,
# 0xbeb19d8ce8c35f30,
# 0xbea06a042fbba458,
# 0x3e4d3a689e6776f9,
# 0x3e325108c4ce2b66,
# 0xbddf7b8e9ab5311f,
# 0xbdbcc40d05652648,
# 0x3d67cd76e2d7e2a8,
# 0x3d40c58770231c0d,
# 0xbceaafec4cd91fe4,
# 0xbcbe36dd57088c4a,
# 0x3c67199e80bb8ea6,
# 0x3c35ab8b86951bb7,
# 0xbbdfd7377ba12bbf,
# 0xbba9595b17afa794,
# 0x3b51e6cee419b33f,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc7f2d07363ffc9d, 0xbfc810f50225b04a),
# a1: (0xb9609653569a810a, 0xbcc73c6641f58028),
# a2: (0x3c6335e03c5b7c0d, 0x3fb7fdf97ac36b20),
# a3: (0x3c0ad8aa2b6aba6b, 0xbf5c3c256a8ca81c),
# a4: (0xbc26e88de290176b, 0xbf7f98feb7286b4a),
# a5: (0xbbc0744c02285686, 0x3f25f6559e568622),
# a6: (0xbbeb6b2136364366, 0x3f3080f57ac215b2),
# c: [
# 0xbed80c51397e5e2d,
# 0xbed256db543cd144,
# 0x3e7af7598a2197aa,
# 0x3e69398226ca230b,
# 0xbe1260985d925839,
# 0xbdf792bb3eea6f71,
# 0x3da0d862695e1a44,
# 0x3d7fe52adc2baad9,
# 0xbd263801377398b1,
# 0xbd005a1befdbe432,
# 0x3ca6205041739a6c,
# 0x3c7a4e1503b6d0ed,
# 0xbc213ef141f6d618,
# 0xbbf10ccc96cd4c09,
# 0x3b95a2fe023ae9f5,
# 0x3b6232d7c90d33c4,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3974a38444754139, 0xbcc08824543a9c04),
# a1: (0xbc7b9af74b1dede8, 0x3fc70c511227d5ac),
# a2: (0x3c15bf278d86003e, 0xbf72ccb0e97557d4),
# a3: (0x3bf993ba47507020, 0xbf9e7dc08e70e99c),
# a4: (0xbbe0d8c7a37fd1fa, 0x3f48acdc5b058b62),
# a5: (0x3bf1dc80686d12d2, 0x3f580503724ad30c),
# a6: (0x3bb3133b39534000, 0xbf032ee4ca1fcaa2),
# c: [
# 0xbf01e5d2836c8d9c,
# 0x3eac129f077bb0ff,
# 0x3e9ef161591181a7,
# 0xbe47b9bb07f19f3d,
# 0xbe316f3937595d9a,
# 0x3dda0bc8665b683a,
# 0x3dbba135f99a9e1f,
# 0xbd640d543d2cbdc5,
# 0xbd403d0592185f21,
# 0x3ce6db5e22d3be48,
# 0x3cbd745a1f778598,
# 0xbc64141c4b5a40e1,
# 0xbc353f4e6ca53f6c,
# 0x3bdc09c1732e9315,
# 0x3ba8f971fa1f3752,
# 0xbb4fe39c23f51b3a,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c7274c973f85714, 0x3fc633e7f7f05300),
# a1: (0xb9b85f5957821fe0, 0xbd02b8776e87c140),
# a2: (0x3c32d36716f05ca0, 0xbfb6273784c1c060),
# a3: (0xbbf9c44ee3147690, 0x3f563ae94ade3192),
# a4: (0x3c150b1f1642cfb2, 0x3f7d4666536c8894),
# a5: (0x3bb3c6617dba7528, 0xbf216d528345d3d0),
# a6: (0xbbd5c85e35a27c33, 0xbf2ec0dcdbb7c5c4),
# c: [
# 0x3ed34e966b0b113d,
# 0x3ed135c64dc2d8a5,
# 0xbe75f7bc78b60278,
# 0xbe67dc35b0764050,
# 0x3e0e6d697361f172,
# 0x3df679e370498766,
# 0xbd9c595f278a5316,
# 0xbd7ea36aef56ee48,
# 0x3d22fd66b4e624dc,
# 0x3cffa04c9faace36,
# 0xbca32f47f0385ae2,
# 0xbc799658479ebab8,
# 0x3c1e4c26032e624b,
# 0x3bf0ab1b47f9c730,
# 0xbb933a3c782959ef,
# 0xbb61de19b956fffc,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb9258f5af1ed4f1c, 0xbc97bc6d5a660382),
# a1: (0x3c714fbe71423e9e, 0xbfc5664e13b70622),
# a2: (0x3c170a1a95dfc606, 0x3f6e16555e108e24),
# a3: (0xbc2c076b4d0d84b0, 0x3f9c5e1ad9fb2f40),
# a4: (0xbbfb118484155b79, 0xbf43d369f958e588),
# a5: (0xbc0d0c0751224fcd, 0xbf566f4ec27a96e8),
# a6: (0xbba982434dc38475, 0x3eff0de0532652f6),
# c: [
# 0x3f00cf264341409d,
# 0xbea6f46d51e57681,
# 0xbe9d407f7c248d45,
# 0x3e43a33cd9df66a2,
# 0x3e309901b0a816e4,
# 0xbdd5d856a5844401,
# 0xbdba7cbcd8fc0758,
# 0x3d610b62c2fd47fd,
# 0x3d3f56a09da19f6e,
# 0xbce3ae6849b3642f,
# 0xbcbc977524a64327,
# 0x3c617fc9db74cf04,
# 0x3c34bbe426d77a27,
# 0xbbd8b5659628a8ec,
# 0xbba87bcc22e21170,
# 0x3b4c62cff42626b7,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c7c12198ddb6118, 0xbfc4b71d4ca2cc6a),
# a1: (0x39a6e3c61124a252, 0x3cf4ded91b86b8a8),
# a2: (0xbc60f47dbe837896, 0x3fb4ae245697fba0),
# a3: (0xbbe9ed93785c9cec, 0xbf5215e4e1a5ffa8),
# a4: (0x3c2ce0e8c12ef8bc, 0xbf7b633ed6d9cf50),
# a5: (0x3bc82e419d336dcd, 0x3f1c7f17b4b7e6aa),
# a6: (0xbba9af650c9cd838, 0x3f2ce01b8b6aa330),
# c: [
# 0xbecfced71b11eb8d,
# 0xbed03c9d58232609,
# 0x3e72450809106743,
# 0x3e66a2d20111e2df,
# 0xbe0995a18f8e6c97,
# 0xbdf572d1a074f620,
# 0x3d981df03c19152f,
# 0x3d7d6895e48f471e,
# 0xbd205887f0b3e165,
# 0xbcfe86703ddf1b74,
# 0x3ca0b3c70ca73fb5,
# 0x3c78d28ba328c148,
# 0xbc1aa9275d688530,
# 0xbbf03e89774aa94a,
# 0x3b911679204a4bbc,
# 0x3b617bd36a04e514,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb947fa205658482a, 0xbc961c29fac28fde),
# a1: (0xbc730a7b22637094, 0x3fc40f90793605bc),
# a2: (0x3ba657dca7bfc600, 0xbf68c833077fbe56),
# a3: (0xbc2ecff8ab4a380c, 0xbf9aa0ce0421d1a8),
# a4: (0xbbf0dd44319a1283, 0x3f405fa598ef5d00),
# a5: (0x3c0a370ccdc801ce, 0x3f551d30d78ab526),
# a6: (0x3bad5eda948cfb3a, 0xbef9c5807675c5d8),
# c: [
# 0xbeffc1bbf57e3ae3,
# 0x3ea32dfea2518cd5,
# 0x3e9bc212085dcbc6,
# 0xbe408b946d64c5b7,
# 0xbe2fa8f9d8da736b,
# 0x3dd293fe14af1d03,
# 0x3db96544cb75a58d,
# 0xbd5d4750748e2cd9,
# 0xbd3e341812329074,
# 0x3ce112aa4951879c,
# 0x3cbbb1656dc67704,
# 0xbc5ea7b98f478c89,
# 0xbc342cad7eaaf63b,
# 0x3bd5d798d87eadcb,
# 0x3ba7ec2199e9d0db,
# 0xbb494f3573e03528,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c4f5ffd01953538, 0x3fc37dfa8f5a550a),
# a1: (0x3905951f3d98d3a0, 0x3ca45e6fc9176b26),
# a2: (0xbc6411ac9d5a7ed4, 0xbfb3775c1a04f09c),
# a3: (0x3bb2ad422bdd4200, 0x3f4e2b4810a46b88),
# a4: (0x3beccc5130bd0090, 0x3f79d151a72b83a8),
# a5: (0x3b9c75676f551aa8, 0xbf17d8e5a090e490),
# a6: (0x3bd9c1bb73f3b84d, 0xbf2b49a6427386a2),
# c: [
# 0x3ecac10957ddd2aa,
# 0x3ececa620745d3d4,
# 0xbe6eefc7e795dca5,
# 0xbe658c5d2a0da41e,
# 0x3e05d4721f44a8d9,
# 0x3df481ce2314af5a,
# 0xbd94c0d3279e91f3,
# 0xbd7c3ea707530565,
# 0x3d1c61d5b165f7bb,
# 0x3cfd72bf189b67b6,
# 0xbc9d427a9769e9d1,
# 0xbc780c965370569b,
# 0x3c178e36fc02b9ca,
# 0x3bef9a2c168b6444,
# 0xbb8e71f82f6f0211,
# 0xbb6111ac11e28164,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb932bde986d25167, 0xbc87e3b01386785e),
# a1: (0x3c6be74e2eb5f61c, 0xbfc2f2072e638cf4),
# a2: (0xbc1cdf9e6feb2db1, 0x3f64df208bbd4522),
# a3: (0xbc34cc0052c45492, 0x3f992bb5e1e159fc),
# a4: (0xbbdb978e226e3b70, 0xbf3ba181c06897ec),
# a5: (0x3c0e8f38285ad302, 0xbf53fe9d5baa4a3e),
# a6: (0x3b8fb503d2156f7c, 0x3ef5d17602b01cbc),
# c: [
# 0x3efe26d3747fe828,
# 0xbea0509768ab6ed5,
# 0xbe9a70f232d9d06c,
# 0x3e3c509252de3406,
# 0x3e2e454fee07116d,
# 0xbdd0015b062ba12c,
# 0xbdb860e95adf840f,
# 0x3d59691e90f7d9c9,
# 0x3d3d1ce7997b3c0c,
# 0xbcdddcd1c54cee5d,
# 0xbcbacd10a03552dc,
# 0x3c5b043a7a089621,
# 0x3c3399ba2ef94a89,
# 0xbbd3650fec070f6d,
# 0xbba7538b0e0444f1,
# 0x3b46a2dce760f8aa,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc6b9fbd89653a02, 0xbfc2768d29c69936),
# a1: (0x3940b26fabe1eb90, 0xbc9115bcb55801a6),
# a2: (0x3c65a44f378d9dda, 0x3fb271811730b0ee),
# a3: (0x3bf3bd5e05d24713, 0xbf49a8df96a12204),
# a4: (0xbc0b5ac68f91cb30, 0xbf787c81cf1c6fc4),
# a5: (0x3b9ac51c15b72970, 0x3f14549cdbb77954),
# a6: (0x3bdb40a83c36c2b5, 0x3f29ed2568116e18),
# c: [
# 0xbec6e4136f033ab4,
# 0xbecd53330316cde8,
# 0x3e6a983b5782dfb2,
# 0x3e64952ba7c5a1dc,
# 0xbe02df3ad6f82e00,
# 0xbdf3a70f9a89d2c3,
# 0x3d920e086c17f5d0,
# 0x3d7b29a554c1159f,
# 0xbd18dbe08f4a9f5d,
# 0xbcfc6bd9fc45c381,
# 0x3c99ce5a735b2904,
# 0x3c774ade0ebbb04a,
# 0xbc14eb88e02b0086,
# 0xbbeeb63f264071fd,
# 0x3b8b39319da680ba,
# 0x3b60a4325ae8cea7,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb94bd22b49961f02, 0x3caf5efd41f756b6),
# a1: (0x3c7cb281b83104fa, 0x3fc1ff5eec6a01cc),
# a2: (0x3c00fc9ccc1ecef2, 0xbf61e438b722c4b0),
# a3: (0xbc4e82045139df97, 0xbf97ed5fffc1c772),
# a4: (0xbbe2511739a7919d, 0x3f37b7997babda70),
# a5: (0x3bd46dd772b0e4d0, 0x3f53081def9612c4),
# a6: (0xbba170b3b3acace2, 0xbef2c5f5edafc540),
# c: [
# 0xbefcc11a59e13738,
# 0x3e9c2c3a1b801506,
# 0x3e9946d1dab7bcff,
# 0xbe388db61946beaa,
# 0xbe2d04d33be580e6,
# 0x3dcbe64386d2c611,
# 0x3db77142e0e44978,
# 0xbd564584766796c5,
# 0xbd3c15e96b25adb7,
# 0x3cda545e6ec71d50,
# 0x3cb9f0a9b74e034b,
# 0xbc57f751eaad596b,
# 0xbc33083bfba900b1,
# 0x3bd14f7886799e77,
# 0x3ba6b8756a3461e6,
# 0xbb44533c12e3142d,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc7ac1701377cf67, 0x3fc194eba75b32fa),
# a1: (0x393dea302f7421b8, 0xbcb8e89cb62e7486),
# a2: (0xbc4cebf5e7d2f5b8, 0xbfb190f7dc27362a),
# a3: (0x3be4a99d542142ae, 0x3f462bb47a5c6190),
# a4: (0xbc26f905e6e91c2d, 0x3f7756ef20f5d2e2),
# a5: (0x3bc7de213d730094, 0xbf1198b0ba97edce),
# a6: (0x3bcaa3ed1c587efa, 0xbf28be8cf9358d54),
# c: [
# 0x3ec3dd6f7c8cc45f,
# 0x3ecc09c80ee7f9ac,
# 0xbe6728e46a451ebf,
# 0xbe63b91113508621,
# 0x3e0080fddad62c48,
# 0x3df2e111e88dae1c,
# 0xbd8fbae88bdab298,
# 0xbd7a2a4fbea868a5,
# 0x3d15f540e9769ed9,
# 0x3cfb74c0b2686def,
# 0xbc96eb75a7dd13eb,
# 0xbc76910c1dc865bf,
# 0x3c12af36490b5ca5,
# 0x3bedd7036ea48d4f,
# 0xbb88734f1fdd10a8,
# 0xbb6036af368c39f9,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x398679d6e450e55c, 0xbcd9104cb75e8580),
# a1: (0xbc4b066a83ec27e0, 0xbfc12dd57bf18ad8),
# a2: (0xbc0853c0fd7268e6, 0x3f5f1e1e7f394b04),
# a3: (0x3c40c79bc8c2a221, 0x3f96d9afe88301f6),
# a4: (0x3bef6fda7b01e99f, 0xbf34a538a4829bc2),
# a5: (0xbbf19e9c32db5594, 0xbf52316250b4ae32),
# a6: (0x3bad4af4e7a81b93, 0x3ef05f11577b4858),
# c: [
# 0x3efb86bad42fc217,
# 0xbe98a1b3a9e929c6,
# 0xbe983dcaf3f8fcbb,
# 0x3e3589a7ca5fdeb0,
# 0x3e2be3ee3298bb8b,
# 0xbdc8913f1d0ff2d6,
# 0xbdb695c386660807,
# 0x3d53b25d3647640f,
# 0x3d3b20c42e642cbb,
# 0xbcd7650532b4f318,
# 0xbcb91f514b70b3f9,
# 0x3c55661aac4dd0de,
# 0x3c327b48d9478af7,
# 0xbbcf11115f1e08b3,
# 0xbba61f1bd021309b,
# 0x3b4254646f0f987f,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc27736b1f56d260, 0xbfc0d0d36473e98c),
# a1: (0x390ce6ef889029c0, 0xbca90ae605bb1c2e),
# a2: (0x3c6cad9cd0ddd7db, 0x3fb0cda9974abe2a),
# a3: (0xbbfe8b365cfcd11a, 0xbf4367f38f201b1a),
# a4: (0xbc2a4610efc87e0f, 0xbf7656b75e3c242e),
# a5: (0xbbba50b3f23c1b69, 0x3f0ed82abf74891e),
# a6: (0x3bc273b7d9ae20c8, 0x3f27b4e5b83eeb36),
# c: [
# 0xbec171fd0fb67097,
# 0xbecae62b4ad017fd,
# 0x3e64648495a7b457,
# 0x3e62f42a577135ae,
# 0xbdfd286e7fa32605,
# 0xbdf22dbcbf76a1c9,
# 0x3d8c222accc0d290,
# 0x3d793fc7f6c8d356,
# 0xbd138c7e1f668e8c,
# 0xbcfa8e4efc6deb64,
# 0x3c947e808eb72cbe,
# 0x3c75e0f075f73394,
# 0xbc10c866ba43aea1,
# 0xbbecffe1c0e02086,
# 0x3b86102f988e0a66,
# 0x3b5f96a57efd09fd,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x394680a605e73143, 0xbc9aaaf726a29e98),
# a1: (0xbc74699e44d4763a, 0x3fc076826cc2c192),
# a2: (0x3c0b69b4e1af753d, 0xbf5b62885e006ff2),
# a3: (0xbc4c6f10e0e56b44, 0xbf95e7f53001e4b0),
# a4: (0x3beb41c72471d4d1, 0x3f322ebeb8dc21ba),
# a5: (0xbbd66e31e7c57860, 0x3f517444a7a04cd0),
# a6: (0xbb9b04abfc9c3887, 0xbeece06f1f1fcd32),
# c: [
# 0xbefa7006e6ad9cff,
# 0x3e95c42f02cf159f,
# 0x3e9750ca5e1366b4,
# 0xbe3314982df7ea85,
# 0xbe2aded75306b3b4,
# 0x3dc5d47847d8ebd4,
# 0x3db5ccf44d287a21,
# 0xbd518fce3e040276,
# 0xbd3a3d6bcad0c3fe,
# 0x3cd4efbd76727bf0,
# 0x3cb85a4b163fcc05,
# 0xbc5339ddeca79cf9,
# 0xbc31f48b47bc441b,
# 0x3bcc06bd6710b444,
# 0x3ba58a1ad9e65449,
# 0xbb409abe2b8be0e1,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c61a6e025536bdc, 0x3fc02455675ab6d2),
# a1: (0xb99ea2bf7b5ce04a, 0xbce2e15aeeb30250),
# a2: (0x3c5e3c568464eb20, 0xbfb021c155a720de),
# a3: (0xbbd9ffab0e34db84, 0x3f412be56fc15128),
# a4: (0xbc2b70ed2f334e71, 0x3f75749d556ad618),
# a5: (0xbba1346bd550ee7c, 0xbf0b51f1f9beb33e),
# a6: (0xbbd65e2a0655e74d, 0xbf26c96a07e236b4),
# c: [
# 0x3ebef3a7abd5b3fd,
# 0x3ec9e207c257432d,
# 0xbe6220b96eef83b0,
# 0xbe624317cb29672d,
# 0x3df9fc2f2cd39558,
# 0x3df18ae8347e824a,
# 0xbd892540423f30fa,
# 0xbd78687dcdc2e396,
# 0x3d1187909103d655,
# 0x3cf9b8362872c30d,
# 0xbc92711ecdaaee5f,
# 0xbc753b342a248139,
# 0x3c0e50eba2ee49f4,
# 0x3bec32aa5f596a43,
# 0xbb8400cf17d2fe60,
# 0xbb5ec6ef456ce7d5,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb9461cf61ce4304c, 0x3c9451b6225acbfc),
# a1: (0x3c55acedf33d41f8, 0xbfbfa8b41711c83a),
# a2: (0xbc0da2c6eba56aad, 0x3f5857d396999730),
# a3: (0xbc2df732290b55b8, 0x3f9511c6dadaaa12),
# a4: (0xbbea73e9fd0266d1, 0xbf302c289dbdbd18),
# a5: (0x3c05fe6f847b85c4, 0xbf50cc2238d229fa),
# a6: (0x3b68952ea975d7d0, 0x3ee9b64d5c636656),
# c: [
# 0x3ef976fb023f0f79,
# 0xbe93693ba0b5ba50,
# 0xbe967b952987350d,
# 0x3e310cb79a2add94,
# 0x3e29f2079f8e397f,
# 0xbdc38d957eaa5398,
# 0xbdb51511e93ba74d,
# 0x3d4f8bb4d9d2f385,
# 0x3d396afe82155a3d,
# 0xbcd2dc3c5a412fb9,
# 0xbcb7a1c8dec76ff8,
# 0x3c51600c3d779cbf,
# 0x3c3174c64bf0b16a,
# 0xbbc969e37524ef6b,
# 0xbba4faf03e3cc2d6,
# 0x3b3e37a63e276926,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c50e4250a158af0, 0xbfbf161d0c28b48c),
# a1: (0xb95196c2ac84c5ec, 0xbcac378f6cbd379e),
# a2: (0x3c538112b4360e08, 0x3faf11d837aa6f64),
# a3: (0x3bee51e6b3aeaaf4, 0xbf3eab76da4d0548),
# a4: (0x3be830920bd9ef20, 0xbf74ab329f067aea),
# a5: (0xbba8dc8494defecc, 0x3f086ada57bc1b62),
# a6: (0x3bde1f31b1faed5a, 0x3f25f6e78f11ab9a),
# c: [
# 0xbebbb271f54c88b0,
# 0xbec8f85328c26cb8,
# 0x3e603f82aebdea71,
# 0x3e61a3010279a196,
# 0xbdf75660809cde83,
# 0xbdf0f6931774a061,
# 0x3d86a2e6126706bf,
# 0x3d77a2a8e0311c3b,
# 0xbd0fa4c8e3ce00e6,
# 0xbcf8f1926f4e33b0,
# 0x3c90b165b2615b9d,
# 0x3c749fd329a93d0f,
# 0xbc0b864a3935977f,
# 0xbbeb70236cfe6bda,
# 0x3b823801bcba9688,
# 0x3b5dffc2deb31094,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3973c6b774aaa5f2, 0x3cc4870ed616b3ec),
# a1: (0x3c3733b2790a6e08, 0x3fbe8727daa3daec),
# a2: (0x3c0fea1867e05552, 0xbf55d353e2854f58),
# a3: (0x3c40b57bb57a6784, 0xbf94524d4813cc24),
# a4: (0xbbc08a2bcbc74e02, 0x3f2d037574e286d8),
# a5: (0xbbd4bf2fec2acf20, 0x3f50356bb747a762),
# a6: (0xbb99f2a765551495, 0xbee7156bfccef544),
# c: [
# 0xbef896d7dc819fad,
# 0x3e9172c6dadf4250,
# 0x3e95baae8efc2e2d,
# 0xbe2eb347eb4d6ab5,
# 0xbe291a60a72a20dc,
# 0x3dc1a345a9a6a6a9,
# 0x3db46c56b01906b9,
# 0xbd4c84bb37677931,
# 0xbd38a83e6e4c1686,
# 0x3cd11796d017a5af,
# 0x3cb6f5675cf3bea7,
# 0xbc4f936d06630a5c,
# 0xbc30fc2f8042c9f5,
# 0x3bc7281c276f9166,
# 0x3ba4725b73c8781d,
# 0xbb3b9d22918cef58,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c6259b387961d12, 0x3fbe0357c158b118),
# a1: (0x396232c6543a4e75, 0xbcb0430ada74ada4),
# a2: (0xbc5d46dbedd6fcc0, 0xbfadffc2fc1a91f4),
# a3: (0x3bed3e720bb581bd, 0x3f3b9b82ae07dcf8),
# a4: (0xbc239d4cc1a5f7c9, 0x3f73f64e05320ac6),
# a5: (0xbbb3ed99cc9cb674, 0xbf05fe4b66cf1aec),
# a6: (0xbbd2effaebd653bc, 0xbf2539518e1b00f4),
# c: [
# 0x3eb8f8d01c4879d6,
# 0x3ec825045b97e2da,
# 0xbe5d565f3bb61ea4,
# 0xbe611186586f4f73,
# 0x3df51a6691581986,
# 0x3df06ef52f6715aa,
# 0xbd848215e95caace,
# 0xbd76ec8422019b0c,
# 0x3d0cbaf5fc1393a1,
# 0x3cf8393ffa4f5afa,
# 0xbc8e6232fb7e099e,
# 0xbc740e69bcb200c7,
# 0x3c091cd1de02ec3d,
# 0x3beab86d72560db5,
# 0xbb80aa949dd6057e,
# 0xbb5d41db239438e9,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x39709a9e57d266d4, 0xbcd5f4205694a1f2),
# a1: (0x3c58a1b844da728e, 0xbfbd8293aa55d18e),
# a2: (0x3bf4afbc400e3842, 0x3f53b6beb83f308c),
# a3: (0x3c4d5cddd88dc3c7, 0x3f93a5ccbc12a678),
# a4: (0xbbd589bce949d513, 0xbf2a3765d26aab74),
# a5: (0x3bfce2aa0ad768a4, 0xbf4f5ab33748c210),
# a6: (0xbb9fd4eb9cb37f3b, 0x3ee4df6f1c257e3c),
# c: [
# 0x3ef7cbd49c315bd9,
# 0xbe8f96098cf075dc,
# 0xbe950b37dd435319,
# 0x3e2bd2e6405c6379,
# 0x3e285530df0d4b66,
# 0xbdc0029e219310a4,
# 0xbdb3d11aeba7319a,
# 0x3d49ef077e065f2d,
# 0x3d37f3d211d80c9a,
# 0xbccf2617ced0512d,
# 0xbcb654785f904742,
# 0x3c4cd5d490baf534,
# 0x3c308aa98d1885f0,
# 0xbbc53243b8f4a406,
# 0xbba3f0a1e04e0f78,
# 0x3b39568fa5547ad5,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc57ac02118cbaf2, 0xbfbd0b36e5737458),
# a1: (0xb986d15de09b31bd, 0x3cd741bce9d3c2ea),
# a2: (0x3c5735fb668eb81c, 0x3fad082ce3c6b598),
# a3: (0xbbce9e8b47c0fa9c, 0xbf3905d00c5e777a),
# a4: (0xbc2a89d2452a5d11, 0xbf7352b073fdac78),
# a5: (0x3bbe3947046b2655, 0x3f03f1ccfec302b4),
# a6: (0xbb522d060964f900, 0x3f248d74583834b8),
# c: [
# 0xbeb6a9ef0d89705e,
# 0xbec764d9798d6a7b,
# 0x3e5aa785d6737380,
# 0x3e608cae36118cd6,
# 0xbdf332ddfb39cf66,
# 0xbdefe502ff1a8f01,
# 0x3d82afc83348f0a5,
# 0x3d764468c0a31507,
# 0xbd0a399e849c4186,
# 0xbcf78e09772ae1dc,
# 0x3c8bc9dea67a7684,
# 0x3c738663e1804172,
# 0xbc07042a23846206,
# 0xbbea0b467e151122,
# 0x3b7e9e53f034f3fd,
# 0x3b5c8d6dc762abe5,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb96a6ca61e3988a7, 0xbcb5c457e4a6a2f0),
# a1: (0x3c4cb670867e40d4, 0x3fbc96700bf039e2),
# a2: (0xbbe7de16e6b862f0, 0xbf51ec0b5de4bc46),
# a3: (0xbc47b57e507973ed, 0xbf93095734a24496),
# a4: (0xbbdff34709f017e3, 0x3f27d74e12285ae4),
# a5: (0xbbf29e4d1595ad56, 0x3f4e636fe259352e),
# a6: (0x3b6e4037d7e7e2d8, 0xbee2fe11972bbfd0),
# c: [
# 0xbef712e4d44c4a76,
# 0x3e8cc3adabae033a,
# 0x3e946ad2d9cbeb5d,
# 0xbe295d81ae83f55b,
# 0xbe27a02aefea3d63,
# 0x3dbd3a949a7222dd,
# 0x3db341e0bb193b4a,
# 0xbd47b550a4f77412,
# 0xbd374c654a2656af,
# 0x3ccc861736a2cad9,
# 0x3cb5be2db467cb29,
# 0xbc4a7433021b8134,
# 0xbc301fe901a012d1,
# 0x3bc37bf8ae8852aa,
# 0x3ba375bd0bad91a4,
# 0xbb37570ac690554b,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c2c279ff462b510, 0x3fbc29ae8400a320),
# a1: (0x396321507ac8848d, 0xbcb457d14034cf9a),
# a2: (0xbc5f78a4f76ae05f, 0xbfac27138da31c2a),
# a3: (0xbbd9c60c5b468dc2, 0x3f36d141fcbeabb6),
# a4: (0xbc0c4e53c7dbe8cc, 0x3f72bdc71062acd6),
# a5: (0xbba4b389c0b4cddc, 0xbf0231cf643ffd70),
# a6: (0x3bda6628cb06f94b, 0xbf23f0bf3b3fe8be),
# c: [
# 0x3eb4b05e955de27b,
# 0x3ec6b52b868fa5e1,
# 0xbe585a7aa3e84dab,
# 0xbe6012d3384c9163,
# 0x3df18f8c487254d5,
# 0x3deeffc4029f2f03,
# 0xbd811d5a3daf7168,
# 0xbd75a8d84ce12a31,
# 0x3d080dfa27f21438,
# 0x3cf6eec07f1e9fea,
# 0xbc8987d6f3b6b9f3,
# 0xbc7307196963d257,
# 0x3c052f0ef3a486f2,
# 0x3be968357fda6844,
# 0xbb7c3bf9076424b5,
# 0xbb5be25cb690eab8,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3954b9510896416a, 0x3cb13169f65efc7c),
# a1: (0xbc6da7561df93ee4, 0xbfbbbf246914235e),
# a2: (0x3bf750d1cb10a8ea, 0x3f5062daee353ef4),
# a3: (0xbc3dfec1d425fc8e, 0x3f927a96f174b6d2),
# a4: (0xbbdefcabf775b3a9, 0xbf25cdb5dea9bfb2),
# a5: (0x3bd0c0778448d924, 0xbf4d818348f98a10),
# a6: (0x3b6ecf0bcdbc3ff8, 0x3ee160aab8293fda),
# c: [
# 0x3ef6698d6ee99eb9,
# 0xbe8a5633d8f0b2e2,
# 0xbe93d788d61154a8,
# 0x3e273ec2ae00841c,
# 0x3e26f958f6235dec,
# 0xbdbad0939c43a967,
# 0xbdb2bd56309cf197,
# 0x3d45c709d717f27a,
# 0x3d36b0b8fe737497,
# 0xbcca3cece6eae963,
# 0xbcb531b157cc8878,
# 0x3c485f3495a5567c,
# 0x3c2f771622298664,
# 0xbbc1fb1e956ae177,
# 0xbba30179264b3e38,
# 0x3b3593d8b3319aa2,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c69390a97dceebd, 0xbfbb5b8273b75056),
# a1: (0xb95ffe8e33ee2176, 0x3caa00d946d1d7e6),
# a2: (0xbc420b7a06a867a8, 0x3fab59418c36a684),
# a3: (0xbbe6600132d24fa5, 0xbf34eafeaa92aca2),
# a4: (0xbc056ea128a34278, 0xbf7235801af9be44),
# a5: (0xbbb57237079f3485, 0x3f00af9747d0bf70),
# a6: (0x3bc899758a675ebe, 0x3f23611db0e1566e),
# c: [
# 0xbeb2fbe414da12f9,
# 0xbec613ccbb9cbe59,
# 0x3e565cf274e84dc5,
# 0x3e5f452996e3dc29,
# 0xbdf023f5382da403,
# 0xbdee2be24fbad63e,
# 0x3d7f7ed3740f8d81,
# 0x3d75187e998a1995,
# 0xbd06293c9e781bcc,
# 0xbcf65a49786c4514,
# 0x3c878dbf02334279,
# 0x3c728fde2c70ddb5,
# 0xbc0392b8f616718f,
# 0xbbe8cea59f44a3e1,
# 0x3b7a213dbaca92aa,
# 0x3b5b40576765c08b,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb935aa4f92090294, 0xbca5fb7dbd93e256),
# a1: (0x3c6e10870a63fff7, 0x3fbaf9cb49c4f934),
# a2: (0x3bfe7849abda1897, 0xbf4e1d930b512f6a),
# a3: (0xbc3bad84cad76316, 0xbf91f7a8fec6eba8),
# a4: (0xbbc24c62ca91876a, 0x3f240a5531086612),
# a5: (0x3bdba2ca276a7e78, 0x3f4cb20c812fd3aa),
# a6: (0xbb8a29145033e141, 0xbedff51953c6b5d2),
# c: [
# 0xbef5cdc48f5d75ec,
# 0x3e883b091952c693,
# 0x3e934fb685e58ab8,
# 0xbe2566fc4369ab0d,
# 0xbe265f0f7de29721,
# 0x3db8b61e5f9b799f,
# 0x3db24253069b78a9,
# 0xbd441732d722b3df,
# 0xbd361fa985a16928,
# 0x3cc83c1756730557,
# 0x3cb4ae32974df1c6,
# 0xbc468a7f73f5be41,
# 0xbc2eba46ae458bcf,
# 0x3bc0a770636ddc58,
# 0x3ba29388d9fcba29,
# 0xbb34040dedb7be93,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc60029860edf394, 0x3fba9e13a0db642a),
# a1: (0x3929e7e658ba3e8c, 0x3c948c42853d5b30),
# a2: (0x3c591dfc4f8c56bc, 0xbfaa9c1ca2161b9c),
# a3: (0xbbd0dc34a8f64ca6, 0x3f3344a09efdc55a),
# a4: (0xbc2abe4bb8fe18ed, 0x3f71b82c430a2382),
# a5: (0x3b9ec0a9f94633bc, 0xbefebfb97bca0144),
# a6: (0xbbbdeadd4d21daf0, 0xbf22dcdb1bc1d038),
# c: [
# 0x3eb180047f0b796c,
# 0x3ec57eeeee84d0d0,
# 0xbe54a0c699c83151,
# 0xbe5e7594e8a2c761,
# 0x3dedccbbb4c0ba3a,
# 0x3ded6766337b5c96,
# 0xbd7d1a05cea189cb,
# 0xbd74922fb50a29f2,
# 0x3d047fa35bf627ac,
# 0x3cf5cfa087122294,
# 0xbc85d009937bf58c,
# 0xbc72200b01fdbf9e,
# 0x3c02265f004c1d31,
# 0x3be83df71ae8ab7b,
# 0xbb7843800001ddda,
# 0xbb5aa6f0e2f25142,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3969731a6ee8f67a, 0xbccb25abf0fd94d8),
# a1: (0xbc5c5c7d59a89402, 0xbfba4407e04298d0),
# a2: (0x3bdd7f84e44e2f08, 0x3f4bcc9df0cf0e42),
# a3: (0xbc445d82d1be9419, 0x3f917f0266db2148),
# a4: (0xbbc6be351c407ae6, 0xbf2280a052234e88),
# a5: (0xbbc75d54e05fe960, 0xbf4bf2ada1f4406e),
# a6: (0x3b7245f90e8cec88, 0x3edd83d58032b95a),
# c: [
# 0x3ef53dd972d8f22f,
# 0xbe8663c1fe2022e5,
# 0xbe92d1fbf2203ff3,
# 0x3e23c9f0b759c7e9,
# 0x3e25cfe1b0126968,
# 0xbdb6ddc0795783c8,
# 0xbdb1cfd495042667,
# 0x3d429b7af521510b,
# 0x3d3598302ab3ac84,
# 0xbcc677f6a604aca6,
# 0xbcb432ecc122bbbe,
# 0x3c44ec114bfb6d1d,
# 0x3c2e0887f8c2f573,
# 0xbbbef44a37f8509d,
# 0xbba22b91f5f44494,
# 0x3b32a03f80301b7a,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc6b72fefdd93f81, 0xbfb9ef3bb2213b0a),
# a1: (0xb93b3a22d2a809f0, 0x3cc8ef687dc4d0da),
# a2: (0x3c46a94081f0f480, 0x3fa9ed82007a9a44),
# a3: (0x3bd67404bf38c0bc, 0xbf31d2fdeeb2a7d8),
# a4: (0x3c1d01759baa1476, 0xbf71446866ff1b82),
# a5: (0x3ba6e30d8c193639, 0x3efc73b684f938fa),
# a6: (0x3bdda9a9d49a2d95, 0x3f22628de594b6c6),
# c: [
# 0xbeb03303c14276cf,
# 0xbec4f51007c51085,
# 0x3e531adfa36f244e,
# 0x3e5db4f306b1908f,
# 0xbdeb9e33598f8c34,
# 0xbdecb09ed6ecb892,
# 0x3d7afe1183148cb5,
# 0x3d7414e442aa8d52,
# 0xbd0307c1294184df,
# 0xbcf54ddabca7b725,
# 0x3c84455c623817ab,
# 0x3c71b70264da3827,
# 0xbc00e2cfa963d5aa,
# 0xbbe7b5896de34575,
# 0x3b7699efca5cd9db,
# 0x3b5a15ae188cedbd,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xb972b24c96f6106e, 0x3cc33e24f9eceebe),
# a1: (0xbc4f1fa01d7b0870, 0x3fb99be744018c90),
# a2: (0x3bf13dddc9d14c38, 0xbf49c3f52a2b00c2),
# a3: (0x3c41fc7e8b11cbe6, 0xbf910f5ca51f98b0),
# a4: (0x3bdc8b153e1b770e, 0x3f2126c8e8ca2a98),
# a5: (0xbbfcd3d174c2f925, 0x3f4b416f7d4fc312),
# a6: (0xbb50ae2be8f60cb8, 0xbedb5e2e5580e536),
# c: [
# 0xbef4b862279de755,
# 0x3e84c5071b39de03,
# 0x3e925d2fc3b1901e,
# 0xbe225df322279ad2,
# 0xbe254a971eb6fe39,
# 0x3db53cc6c992307f,
# 0x3db164f95180d8be,
# 0xbd414b9ef404ee77,
# 0xbd3519623b4e50a8,
# 0x3cc4e7271a71f338,
# 0x3cb3bf2a1b859193,
# 0xbc437bc0d8e44c56,
# 0xbc2d6104b94c47d2,
# 0x3bbcdb4b3544bd98,
# 0x3ba1c93567462ab5,
# 0xbb31623ef2938109,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c65fb489bce40fe, 0x3fb94d3276914e50),
# a1: (0xb8ebe72978784f58, 0x3c4955c15e2c3c2a),
# a2: (0xbc52416cf222cb8b, 0xbfa94bac1950e318),
# a3: (0x3b36b97e215c2000, 0x3f308d4ff8f20596),
# a4: (0x3c21bc07c2cd9fd1, 0x3f70d90d29bfeecc),
# a5: (0x3b96c471f59956ac, 0xbefa6d56162f7fae),
# a6: (0x3bd3d7ab3b7be1f0, 0xbf21f107da23807e),
# c: [
# 0x3eae1a6262774376,
# 0x3ec474eafd0cc642,
# 0xbe51c27144f42d76,
# 0xbe5d01999b1a4fe9,
# 0x3de9b014801da877,
# 0x3dec061740bc8a45,
# 0xbd791f8c2972547c,
# 0xbd739fb558b7aa4d,
# 0x3d01b9f74d47b35e,
# 0x3cf4d425557e1f1c,
# 0xbc82e617ae27952d,
# 0xbc715432898c29d0,
# 0x3bff843f6347963d,
# 0x3be734c130fc648e,
# 0xbb751d395949afbc,
# 0xbb598c0f03028f01,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x396fac4c615d8510, 0xbcd349fc58b50330),
# a1: (0xbc57e57efb0d158a, 0xbfb8ffc9bd24fe06),
# a2: (0x3b7d182df374f000, 0x3f47f7d46ab34a68),
# a3: (0x3c4694f15c29a8dd, 0x3f90a7a725d3fbc2),
# a4: (0x3bb591a2239d9eb6, 0xbf1fea1728f2238a),
# a5: (0xbbf1f0c0c52574db, 0xbf4a9cac69f0ed60),
# a6: (0x3b4cf3f300929870, 0x3ed977f48ff10c40),
# c: [
# 0x3ef43c2d8e698c0c,
# 0xbe8355d1a676628b,
# 0xbe91f0553501d11d,
# 0x3e211b47f6a44aeb,
# 0x3e24ce23303889a3,
# 0xbdb3ca98df6224ca,
# 0xbdb100fc746529d2,
# 0x3d4020f11e2dcbe5,
# 0x3d34a26ef2219c24,
# 0xbcc38203ff52c942,
# 0xbcb35244c153aa22,
# 0x3c4232dbbbea37a0,
# 0x3c2cc2f30d7e4a79,
# 0xbbbafaa22e043aaf,
# 0xbba16c1420a026b4,
# 0x3b3044e17b707ab4,
# ],
# },
# TaylorExtendedSeries {
# a0: (0xbc6bb71343c60d7e, 0xbfb8b67a2481077c),
# a1: (0x393efc8b89de2e79, 0xbc8fff42db388fa2),
# a2: (0xbc478ddcf791d282, 0x3fa8b51f21068ea2),
# a3: (0x3bb3abe279a5795c, 0xbf2ed935c7aef8dc),
# a4: (0x3c2b44d9fde7eb03, 0xbf707522a5037f2e),
# a5: (0x3b8ba46f75aee2c4, 0x3ef8a196061f8b34),
# a6: (0xbbd18460a3d8fa0b, 0x3f21874a47e3c1e4),
# c: [
# 0xbeac10cf34c04eb0,
# 0xbec3fd6c2d4fa2a5,
# 0x3e50906d55522756,
# 0x3e5c5a1c124dfa08,
# 0xbde7f883b31a5f24,
# 0xbdeb668cf53028e5,
# 0x3d7775372d05b231,
# 0x3d7331d871d677e0,
# 0xbd009010248989b9,
# 0xbcf461c4067c742e,
# 0x3c81abf993696e5e,
# 0x3c70f715fa383b8a,
# 0xbbfd7ed2f30db014,
# 0xbbe6bb0b4da7d6b9,
# 0x3b73c73f0e157e45,
# 0x3b5909945c395947,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3963dd46e8420900, 0x3cb735bc851f7830),
# a1: (0xbc6d1200bd04de5a, 0x3fb86e51be0a9154),
# a2: (0xbbfe05daa1cb3e77, 0xbf465ed1b387eba6),
# a3: (0x3c3f8731839c48ae, 0xbf9046fc5a218a86),
# a4: (0xbb87e07b9e780530, 0x3f1dca617fefacf0),
# a5: (0xbbe7d74a7852bd36, 0x3f4a0300221528a6),
# a6: (0xbb6e5792fad4d150, 0xbed7c7618906f3f0),
# c: [
# 0xbef3c838897d0a1d,
# 0x3e820ede9f9dd908,
# 0x3e918a94165592ba,
# 0xbe1ff762051190b2,
# 0xbe24599dfeef01a0,
# 0x3db2803e59983201,
# 0x3db0a33202feb041,
# 0xbd3e2bff73868218,
# 0xbd34329cf32bcb6d,
# 0x3cc2424890fb6d93,
# 0x3cb2eba657649d98,
# 0xbc410bda49bebea6,
# 0xbc2c2d96d94f34d3,
# 0x3bb94a9b8509de4e,
# 0x3ba113d205a63bde,
# 0xbb2e87a2990f49a5,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c48caabfef06c34, 0x3fb829d06fee9266),
# a1: (0x3961a0d102d999b6, 0x3cc43f9165469190),
# a2: (0x3c231ac383a241f0, 0xbfa8289a526d7786),
# a3: (0x3bd878e697c4d570, 0x3f2cd680355c9138),
# a4: (0x3c0438a44e6d778c, 0x3f7017d70f512862),
# a5: (0xbb96f7be6baff3ac, 0xbef707978e2a0854),
# a6: (0xbbc926f73f9bcbfe, 0xbf21247ce15e7386),
# c: [
# 0x3eaa3f6125485aa8,
# 0x3ec38da848401bea,
# 0xbe4efe39d8db4937,
# 0xbe5bbd40f1db0e98,
# 0x3de66f7d49436d67,
# 0x3dead0e8148229b6,
# 0xbd75f78595133b53,
# 0xbd72ca9bb10321b6,
# 0x3cff09e49c887c79,
# 0x3cf3f60eeb66f74a,
# 0xbc8091d689cc52d9,
# 0xbc709f335e86201e,
# 0x3bfbad342a8e0606,
# 0x3be647de871fcaee,
# 0xbb7292e08798803f,
# 0xbb588dc30bd642e9,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x397d08dbc17e0063, 0xbccd30316971622e),
# a1: (0x3c6aacaf80752567, 0xbfb7e656efb009ae),
# a2: (0x3bea07a1a1e980da, 0x3f44f15066f3e70c),
# a3: (0xbc1474faf159eabc, 0x3f8fd932c26aad92),
# a4: (0xbbc6500ad3a0df8f, 0xbf1be460dd86aa5a),
# a5: (0x3bf8fe261cbf6661, 0xbf49733b591879f6),
# a6: (0x3b7629645c96e5b0, 0x3ed64488c560280c),
# c: [
# 0x3ef35ba58bf2f990,
# 0xbe80ea47bceb9d83,
# 0xbe912b327055d0e7,
# 0x3e1df42fc4e24c5a,
# 0x3e23ec3e76876db6,
# 0xbdb1580393f475c9,
# 0xbdb04b0353c35932,
# 0x3d3c4ca30ffe2ce6,
# 0x3d33c947b936c2f7,
# 0xbcc122c73f770be2,
# 0xbcb28ac72950269b,
# 0x3c4002243876ba49,
# 0x3c2ba04294d5257b,
# 0xbbb7c4c63a56d10c,
# 0xbba0c0178f4adc52,
# 0x3b2cb6cf025abba9,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3c6e06adcbe5bdde, 0xbfb7a62320798176),
# a1: (0x397567ab6c144efc, 0x3cc348e07c61e1f2),
# a2: (0xbc0b8ee98e6e8b00, 0x3fa7a50ca4504bb8),
# a3: (0x3bd98e397896d5a9, 0xbf2b095ccb50b366),
# a4: (0xbc076753290e1248, 0xbf6f80ef11daa378),
# a5: (0xbb93b396999f2216, 0x3ef59822dc75b586),
# a6: (0xbbda10b2e1d8d3a2, 0x3f20c7e6a7c66630),
# c: [
# 0xbea89e00b5c35cb7,
# 0xbec324d5238b26cf,
# 0x3e4d13a888d5e0a6,
# 0x3e5b29f941a95b04,
# 0xbde50e6ebb3d1ff8,
# 0xbdea4434c6b929da,
# 0x3d74a03fe2c479e6,
# 0x3d7269628f2df989,
# 0xbcfd28cc08ef4477,
# 0xbcf390706334abc0,
# 0x3c7f26c3ea44409c,
# 0x3c704c1cd334447f,
# 0xbbfa08922dcea46a,
# 0xbbe5dabbff6c2bf7,
# 0x3b717bccb6cd03aa,
# 0x3b5818261a2214db,
# ],
# },
# TaylorExtendedSeries {
# a0: (0x3951ad50c69ee6a0, 0x3cc566cd2934202a),
# a1: (0xbc29e532a002c770, 0x3fb766dc36547ccc),
# a2: (0xbbecc406e35f696e, 0xbf43a919bc2a11da),
# a3: (0x3c2a2c06cab4314a, 0xbf8f2faf2b20556c),
# a4: (0x3bcab2936d134974, 0x3f1a2fdcc0cb5bce),
# a5: (0xbbeb7f18d3b48142, 0x3f48ec5a10ee00ce),
# a6: (0x3b8fcdf244231aeb, 0xbed4e8eec45400cc),
# c: [
# 0xbef2f5b5f4303778,
# 0x3e7fc66ddcbc56e0,
# 0x3e90d18f69c2056a,
# 0xbe1c249c3896bdfb,
# 0xbe2385557a0fd5b5,
# 0x3db04d34debaa05e,
# 0x3dafefd817961497,
# 0xbd3a9c64cec66b63,
# 0xbd3365dd2417d1a0,
# 0x3cc01f31a4a8c262,
# 0x3cb22f2d0083a4f2,
# 0xbc3e23c47e194733,
# 0xbc2b1a572e84068e,
# 0x3bb663b7fd7ce9bf,
# 0x3ba070929fa849f8,
# 0xbb2b111a6b2716e7,
# ],
# },
# ];

# %%
def print_expansion_at_0_f():
    print(f"pub(crate) const J1_MACLAURIN_SERIES: [u64; 13] = [")
    from mpmath import mp, j1, taylor, expm1
    mp.prec = 53
    poly = taylor(lambda val: j1(val), 0, 46)
    # print(poly)
    real_i = 0
    z = 0
    for i in range(1, 46, 2):
        print(f"{double_to_hex(poly[i])},")
        real_i = real_i + 1
    print("];")

    print(f"poly {poly}")

print_expansion_at_0_f()
# Out:
# pub(crate) static J1_MACLAURIN_SERIES: [u64; 13] = [
# 0x3fe0000000000000,
# 0xbfb0000000000000,
# 0x3f65555555555555,
# 0xbf0c71c71c71c71c,
# 0x3ea6c16c16c16c17,
# 0xbe3845c8a0ce5129,
# 0x3dc27e4fb7789f5c,
# 0xbd4522a43f65486a,
# 0x3cc2c9758daf5cd0,
# 0xbc3ab81ea75fcdf4,
# 0x3baf17697cf1cf13,
# 0xbb1e2637bef9ff1a,
# 0x3a88bce58901a35e,
# 0xb9f165e7c2d153f3,
# 0x39553585cdcbfb10,
# 0xb8b69f7da8510bcd,
# 0x38154ad09e6a6576,
# 0xb771d028acb00491,
# 0x36caaae78f4066a6,
# 0xb621f72d8389b3a3,
# 0x3575e69de22df5ce,
# 0xb4c84564b82a1184,
# 0x34188f11edf3ed4c,
# ];
# poly [mpf('0.0'), mpf('0.5'), mpf('0.0'), mpf('-0.0625'), mpf('0.0'), mpf('0.0026041666666666665'), mpf('0.0'), mpf('-5.4253472222222219e-5'), mpf('0.0'), mpf('6.781684027777778e-7'), mpf('0.0'), mpf('-5.6514033564814812e-9'), mpf('0.0'), mpf('3.3639305693342149e-11'), mpf('0.0'), mpf('-1.5017547184527747e-13'), mpf('0.0'), mpf('5.2144261057388011e-16'), mpf('0.0'), mpf('-1.4484516960385557e-18'), mpf('0.0'), mpf('3.2919356728148996e-21'), mpf('0.0'), mpf('-6.2347266530585217e-24'), mpf('0.0'), mpf('9.9915491234912214e-27'), mpf('0.0'), mpf('-1.3724655389411017e-29'), mpf('0.0'), mpf('1.6338875463584545e-32'), mpf('0.0'), mpf('-1.7019661941233902e-35'), mpf('0.0'), mpf('1.5643071637163513e-38'), mpf('0.0'), mpf('-1.2780287285264307e-41'), mpf('0.0'), mpf('9.3423152670060721e-45'), mpf('0.0'), mpf('-6.1462600440829421e-48'), mpf('0.0'), mpf('3.6584881214779417e-51'), mpf('0.0'), mpf('-1.9797013644361157e-54'), mpf('0.0'), mpf('9.7811332234985954e-58'), mpf('0.0')]

# %%
# Taylor series for f32
mp.prec = 53
print(f"pub(crate) static J1F_COEFFS: [[u64; 13]; {len(j1_zeros)}] = [")

def get_constant_term(poly, y):
    for term in poly.operands():
        if term.is_constant():
            return term

def print_taylor_coeffsf(poly, x0):
    print("[")
    for i in range(0, 13):
        coeff = poly[i]
        print(f"{double_to_hex(coeff)},")
    print("],")

prev_zero = 0

for i in range(0, len(j1_zeros)):
    k_range = j1_zeros[i]
    range_diff = k_range - prev_zero
    g_c = 1

    f_poly = bessel_J(1, x)
    x0 = mp.mpf(k_range)
    from mpmath import mp, j1, taylor, expm1
    # The j1 (Bessel J_1) function from mpmath will compute with mp.dps precision
    # The Taylor series computation will also respect mp.dps
    poly = taylor(lambda val: j1(val), x0, 23)
    # print(poly)
    print_taylor_coeffsf(poly, CDR(k_range))
    prev_zero = j1_zeros[i]

print("];")
# Out:
# pub(crate) static J1F_COEFFS: [[u64; 13]; 51] = [
# [
# 0x3fe29ea3d19f035f,
# 0xbd1905281527b4c2,
# 0xbfca41115c5df220,
# 0x3f78d1448e6ffac0,
# 0x3f8c441a2f9de1f1,
# 0xbf386671c18b11ca,
# 0xbf39e2504ddc75c7,
# 0x3ee34ccbca0c7c14,
# 0x3eda4973784d103e,
# 0xbe81045322aab053,
# 0xbe70fae0da6cdcbc,
# 0x3e13546cef5ed578,
# 0x3dfe5ee82e6676a8,
# ],
# [
# 0x0000000000000000,
# 0xbfd9c6cf582cbf81,
# 0x3faae8a39f51ace8,
# 0x3fab589d1da13908,
# 0xbf7537544c331d97,
# 0xbf624b3409959066,
# 0x3f26e4c2d5354217,
# 0x3f083a06e30c410e,
# 0xbec9799d4c9f253b,
# 0xbea33825cd2e2c1a,
# 0x3e617069233e9163,
# 0x3e34569b22afc3cc,
# 0xbdf03b9e96510562,
# ],
# [
# 0xbfd626ee83500bf2,
# 0xbd30b63e708daa6a,
# 0x3fc55f6bec9efa1c,
# 0xbf83d23336fcfd84,
# 0xbf88c77a983a0968,
# 0x3f45cdc98db1be46,
# 0x3f373576ff46efcb,
# 0xbef2461447d7aadd,
# 0xbed7b853456b707f,
# 0x3e90abfc6827431b,
# 0x3e6ea7a1ee2614e8,
# 0xbe235c0413e00c13,
# 0xbdfb5c5d512fbd7b,
# ],
# [
# 0x0000000000000000,
# 0x3fd33518b3874e8b,
# 0xbf95e70dc603629f,
# 0xbfa80c83bdeee5b1,
# 0x3f69a4b292e3de2f,
# 0x3f613fbc7d698219,
# 0xbf207358bbdbff88,
# 0xbf0796a751f89053,
# 0x3ec4255b015adeca,
# 0x3ea3026e0ce97abb,
# 0xbe5d48dcdae92f1f,
# 0xbe344639d7eeb0a8,
# 0x3dec62ccb4a32ea9,
# ],
# [
# 0x3fd17dbf09d40d25,
# 0xbd30b93c9bcb6b75,
# 0xbfc1404bf647c215,
# 0x3f74f4df276a2267,
# 0x3f85c6285429b550,
# 0xbf3d68ab7228a0e1,
# 0xbf356acb6452d6e4,
# 0x3eec10b47cf80538,
# 0x3ed67eaae97bbaa3,
# 0xbe8bb6530c6404c3,
# 0xbe6d87201e450c09,
# 0x3e20f47c83ec5eb6,
# 0x3dfa98331f6ea4cc,
# ],
# [
# 0xbd33b1f774616baa,
# 0xbfcff654544ebbd9,
# 0x3f89223ff2c0c4da,
# 0x3fa4b0c5d5da6651,
# 0xbf5f91a9ee0d58d7,
# 0xbf5f51c2489b9bcf,
# 0x3f16b4c9ca0f8f08,
# 0x3f063c5475439a5d,
# 0xbebe3725daf6b1db,
# 0xbea25c1238b32c1b,
# 0x3e57486f6b9aba2b,
# 0x3e33e3bf24827536,
# 0xbde78a38a73e8b51,
# ],
# [
# 0xbfcddceb4ce1bf4a,
# 0x0000000000000000,
# 0x3fbda52116c0a63f,
# 0xbf6a9da4603b6845,
# 0xbf8331e74ea59ab7,
# 0x3f33e5cb6eba6ecd,
# 0x3f33885fe9afa540,
# 0xbee494c0f4b06825,
# 0xbed512b9d37762d5,
# 0x3e85a861082bfb94,
# 0x3e6c323ea0a042c0,
# 0xbe1bcc962f7b9203,
# 0xbdf9bc94e2f29a4f,
# ],
# [
# 0x0000000000000000,
# 0x3fcbf3337873a7da,
# 0xbf80c83a2d7adcb5,
# 0xbfa251858011816c,
# 0x3f559eb160bf7287,
# 0x3f5c5bce33af2d7b,
# 0xbf10413e306e0010,
# 0xbf04a6704d05ad0f,
# 0x3eb6c43eedfed69b,
# 0x3ea16abd7815de78,
# 0xbe5257f16f5d4328,
# 0xbe332db1b4b2ff90,
# 0x3de33acccf7bfdb2,
# ],
# [
# 0x3fca7f63fea81f26,
# 0x0000000000000000,
# 0xbfba60afb06640cf,
# 0x3f62c1e930935d6d,
# 0x3f814506466d7f1f,
# 0xbf2cca8c0c0eaa64,
# 0xbf31df821cc1377e,
# 0x3edee8814ed0ac60,
# 0x3ed3a365a4199dd0,
# 0xbe80ed2f9c3e459a,
# 0xbe6ab3b37c5271b2,
# 0x3e1684d6e62b5c73,
# 0x3df8b105a5120ed0,
# ],
# [
# 0x0000000000000000,
# 0xbfc925c6fca08f55,
# 0x3f786dd32e059a35,
# 0x3fa09463bbd03680,
# 0xbf4fda0298c875fd,
# 0xbf59f4be60758fb4,
# 0x3f0877991af9d172,
# 0x3f032cb00ee8c1f5,
# 0xbeb19d8ce8c35f30,
# 0xbea06a042fbba457,
# 0x3e4d3a689e6776f9,
# 0x3e325108c4ce2b66,
# 0xbddf7b8e9ab5311f,
# ],
# [
# 0xbfc810f50225b04b,
# 0x0000000000000000,
# 0x3fb7fdf97ac36b21,
# 0xbf5c3c256a8ca81b,
# 0xbf7f98feb7286b4b,
# 0x3f25f6559e568622,
# 0x3f3080f57ac215b1,
# 0xbed80c51397e5e2c,
# 0xbed256db543cd143,
# 0x3e7af7598a2197aa,
# 0x3e69398226ca230c,
# 0xbe1260985d925839,
# 0xbdf792bb3eea6f70,
# ],
# [
# 0x0000000000000000,
# 0x3fc70c511227d5ab,
# 0xbf72ccb0e97557d3,
# 0xbf9e7dc08e70e99c,
# 0x3f48acdc5b058b61,
# 0x3f580503724ad30d,
# 0xbf032ee4ca1fcaa1,
# 0xbf01e5d2836c8d9b,
# 0x3eac129f077bb0ff,
# 0x3e9ef161591181a7,
# 0xbe47b9bb07f19f3d,
# 0xbe316f3937595d99,
# 0x3dda0bc8665b683a,
# ],
# [
# 0x3fc633e7f7f05301,
# 0x0000000000000000,
# 0xbfb6273784c1c060,
# 0x3f563ae94ade3191,
# 0x3f7d4666536c8894,
# 0xbf216d528345d3d0,
# 0xbf2ec0dcdbb7c5c4,
# 0x3ed34e966b0b113d,
# 0x3ed135c64dc2d8a6,
# 0xbe75f7bc78b60278,
# 0xbe67dc35b0764050,
# 0x3e0e6d697361f173,
# 0x3df679e370498766,
# ],
# [
# 0x0000000000000000,
# 0xbfc5664e13b70621,
# 0x3f6e16555e108e24,
# 0x3f9c5e1ad9fb2f40,
# 0xbf43d369f958e589,
# 0xbf566f4ec27a96e9,
# 0x3eff0de0532652f5,
# 0x3f00cf264341409e,
# 0xbea6f46d51e57680,
# 0xbe9d407f7c248d45,
# 0x3e43a33cd9df66a3,
# 0x3e309901b0a816e5,
# 0xbdd5d856a5844401,
# ],
# [
# 0xbfc4b71d4ca2cc69,
# 0x0000000000000000,
# 0x3fb4ae245697fb9f,
# 0xbf5215e4e1a5ffa8,
# 0xbf7b633ed6d9cf4f,
# 0x3f1c7f17b4b7e6ab,
# 0x3f2ce01b8b6aa330,
# 0xbecfced71b11eb8d,
# 0xbed03c9d58232608,
# 0x3e72450809106743,
# 0x3e66a2d20111e2e0,
# 0xbe0995a18f8e6c96,
# 0xbdf572d1a074f61f,
# ],
# [
# 0x0000000000000000,
# 0x3fc40f90793605bb,
# 0xbf68c833077fbe56,
# 0xbf9aa0ce0421d1a8,
# 0x3f405fa598ef5cff,
# 0x3f551d30d78ab526,
# 0xbef9c5807675c5d7,
# 0xbeffc1bbf57e3ae4,
# 0x3ea32dfea2518cd5,
# 0x3e9bc212085dcbc7,
# 0xbe408b946d64c5b7,
# 0xbe2fa8f9d8da736b,
# 0x3dd293fe14af1d03,
# ],
# [
# 0x3fc37dfa8f5a550a,
# 0x0000000000000000,
# 0xbfb3775c1a04f09d,
# 0x3f4e2b4810a46b88,
# 0x3f79d151a72b83a8,
# 0xbf17d8e5a090e490,
# 0xbf2b49a6427386a1,
# 0x3ecac10957ddd2ab,
# 0x3ececa620745d3d4,
# 0xbe6eefc7e795dca4,
# 0xbe658c5d2a0da41e,
# 0x3e05d4721f44a8d9,
# 0x3df481ce2314af5a,
# ],
# [
# 0x0000000000000000,
# 0xbfc2f2072e638cf4,
# 0x3f64df208bbd4521,
# 0x3f992bb5e1e159fc,
# 0xbf3ba181c06897ec,
# 0xbf53fe9d5baa4a3d,
# 0x3ef5d17602b01cbc,
# 0x3efe26d3747fe829,
# 0xbea0509768ab6ed5,
# 0xbe9a70f232d9d06c,
# 0x3e3c509252de3407,
# 0x3e2e454fee07116e,
# 0xbdd0015b062ba12c,
# ],
# [
# 0xbfc2768d29c69936,
# 0x0000000000000000,
# 0x3fb271811730b0ef,
# 0xbf49a8df96a12203,
# 0xbf787c81cf1c6fc4,
# 0x3f14549cdbb77954,
# 0x3f29ed2568116e18,
# 0xbec6e4136f033ab3,
# 0xbecd53330316cde8,
# 0x3e6a983b5782dfb2,
# 0x3e64952ba7c5a1dd,
# 0xbe02df3ad6f82dff,
# 0xbdf3a70f9a89d2c3,
# ],
# [
# 0x0000000000000000,
# 0x3fc1ff5eec6a01cd,
# 0xbf61e438b722c4af,
# 0xbf97ed5fffc1c773,
# 0x3f37b7997babda6f,
# 0x3f53081def9612c4,
# 0xbef2c5f5edafc541,
# 0xbefcc11a59e13738,
# 0x3e9c2c3a1b801506,
# 0x3e9946d1dab7bcff,
# 0xbe388db61946bea9,
# 0xbe2d04d33be580e5,
# 0x3dcbe64386d2c612,
# ],
# [
# 0x3fc194eba75b32f9,
# 0x0000000000000000,
# 0xbfb190f7dc27362a,
# 0x3f462bb47a5c6190,
# 0x3f7756ef20f5d2e1,
# 0xbf1198b0ba97edcd,
# 0xbf28be8cf9358d54,
# 0x3ec3dd6f7c8cc45f,
# 0x3ecc09c80ee7f9ad,
# 0xbe6728e46a451ebe,
# 0xbe63b91113508620,
# 0x3e0080fddad62c48,
# 0x3df2e111e88dae1d,
# ],
# [
# 0x0000000000000000,
# 0xbfc12dd57bf18ad8,
# 0x3f5f1e1e7f394b03,
# 0x3f96d9afe88301f7,
# 0xbf34a538a4829bc1,
# 0xbf52316250b4ae32,
# 0x3ef05f11577b4859,
# 0x3efb86bad42fc217,
# 0xbe98a1b3a9e929c5,
# 0xbe983dcaf3f8fcbb,
# 0x3e3589a7ca5fdeb0,
# 0x3e2be3ee3298bb8c,
# 0xbdc8913f1d0ff2d6,
# ],
# [
# 0xbfc0d0d36473e98c,
# 0x0000000000000000,
# 0x3fb0cda9974abe2b,
# 0xbf4367f38f201b1b,
# 0xbf7656b75e3c242f,
# 0x3f0ed82abf74891d,
# 0x3f27b4e5b83eeb36,
# 0xbec171fd0fb67096,
# 0xbecae62b4ad017fd,
# 0x3e64648495a7b458,
# 0x3e62f42a577135ae,
# 0xbdfd286e7fa32605,
# 0xbdf22dbcbf76a1c8,
# ],
# [
# 0x0000000000000000,
# 0x3fc076826cc2c191,
# 0xbf5b62885e006ff0,
# 0xbf95e7f53001e4b1,
# 0x3f322ebeb8dc21bb,
# 0x3f517444a7a04cd0,
# 0xbeece06f1f1fcd33,
# 0xbefa7006e6ad9cff,
# 0x3e95c42f02cf159f,
# 0x3e9750ca5e1366b4,
# 0xbe3314982df7ea85,
# 0xbe2aded75306b3b3,
# 0x3dc5d47847d8ebd5,
# ],
# [
# 0x3fc02455675ab6d2,
# 0x0000000000000000,
# 0xbfb021c155a720de,
# 0x3f412be56fc15127,
# 0x3f75749d556ad617,
# 0xbf0b51f1f9beb33e,
# 0xbf26c96a07e236b5,
# 0x3ebef3a7abd5b3fd,
# 0x3ec9e207c257432e,
# 0xbe6220b96eef83af,
# 0xbe624317cb29672d,
# 0x3df9fc2f2cd39558,
# 0x3df18ae8347e824b,
# ],
# [
# 0x0000000000000000,
# 0xbfbfa8b41711c83a,
# 0x3f5857d39699972e,
# 0x3f9511c6dadaaa12,
# 0xbf302c289dbdbd19,
# 0xbf50cc2238d229f9,
# 0x3ee9b64d5c636655,
# 0x3ef976fb023f0f79,
# 0xbe93693ba0b5ba50,
# 0xbe967b952987350c,
# 0x3e310cb79a2add94,
# 0x3e29f2079f8e3980,
# 0xbdc38d957eaa5398,
# ],
# [
# 0xbfbf161d0c28b48c,
# 0x0000000000000000,
# 0x3faf11d837aa6f65,
# 0xbf3eab76da4d0547,
# 0xbf74ab329f067aea,
# 0x3f086ada57bc1b61,
# 0x3f25f6e78f11ab9b,
# 0xbebbb271f54c88b0,
# 0xbec8f85328c26cb8,
# 0x3e603f82aebdea71,
# 0x3e61a3010279a196,
# 0xbdf75660809cde82,
# 0xbdf0f6931774a060,
# ],
# [
# 0x0000000000000000,
# 0x3fbe8727daa3daec,
# 0xbf55d353e2854f56,
# 0xbf94524d4813cc23,
# 0x3f2d037574e286d8,
# 0x3f50356bb747a762,
# 0xbee7156bfccef544,
# 0xbef896d7dc819fac,
# 0x3e9172c6dadf4250,
# 0x3e95baae8efc2e2d,
# 0xbe2eb347eb4d6ab4,
# 0xbe291a60a72a20db,
# 0x3dc1a345a9a6a6aa,
# ],
# [
# 0x3fbe0357c158b119,
# 0x0000000000000000,
# 0xbfadffc2fc1a91f5,
# 0x3f3b9b82ae07dcf8,
# 0x3f73f64e05320ac5,
# 0xbf05fe4b66cf1aed,
# 0xbf2539518e1b00f5,
# 0x3eb8f8d01c4879d6,
# 0x3ec825045b97e2db,
# 0xbe5d565f3bb61ea2,
# 0xbe611186586f4f73,
# 0x3df51a6691581986,
# 0x3df06ef52f6715aa,
# ],
# [
# 0x0000000000000000,
# 0xbfbd8293aa55d18e,
# 0x3f53b6beb83f308c,
# 0x3f93a5ccbc12a679,
# 0xbf2a3765d26aab74,
# 0xbf4f5ab33748c20f,
# 0x3ee4df6f1c257e3b,
# 0x3ef7cbd49c315bda,
# 0xbe8f96098cf075dc,
# 0xbe950b37dd435318,
# 0x3e2bd2e6405c6379,
# 0x3e285530df0d4b66,
# 0xbdc0029e219310a4,
# ],
# [
# 0xbfbd0b36e5737458,
# 0x0000000000000000,
# 0x3fad082ce3c6b599,
# 0xbf3905d00c5e7779,
# 0xbf7352b073fdac79,
# 0x3f03f1ccfec302b4,
# 0x3f248d74583834b8,
# 0xbeb6a9ef0d89705d,
# 0xbec764d9798d6a7b,
# 0x3e5aa785d6737380,
# 0x3e608cae36118cd6,
# 0xbdf332ddfb39cf65,
# 0xbdefe502ff1a8f00,
# ],
# [
# 0x0000000000000000,
# 0x3fbc96700bf039e2,
# 0xbf51ec0b5de4bc46,
# 0xbf93095734a24497,
# 0x3f27d74e12285ae3,
# 0x3f4e636fe259352e,
# 0xbee2fe11972bbfd0,
# 0xbef712e4d44c4a75,
# 0x3e8cc3adabae033a,
# 0x3e946ad2d9cbeb5e,
# 0xbe295d81ae83f55b,
# 0xbe27a02aefea3d62,
# 0x3dbd3a949a7222de,
# ],
# [
# 0x3fbc29ae8400a320,
# 0x0000000000000000,
# 0xbfac27138da31c2b,
# 0x3f36d141fcbeabb5,
# 0x3f72bdc71062acd6,
# 0xbf0231cf643ffd70,
# 0xbf23f0bf3b3fe8bd,
# 0x3eb4b05e955de27b,
# 0x3ec6b52b868fa5e1,
# 0xbe585a7aa3e84dab,
# 0xbe6012d3384c9163,
# 0x3df18f8c487254d5,
# 0x3deeffc4029f2f03,
# ],
# [
# 0x0000000000000000,
# 0xbfbbbf246914235f,
# 0x3f5062daee353ef4,
# 0x3f927a96f174b6d1,
# 0xbf25cdb5dea9bfb3,
# 0xbf4d818348f98a10,
# 0x3ee160aab8293fda,
# 0x3ef6698d6ee99eb9,
# 0xbe8a5633d8f0b2e2,
# 0xbe93d788d61154a8,
# 0x3e273ec2ae00841c,
# 0x3e26f958f6235dec,
# 0xbdbad0939c43a967,
# ],
# [
# 0xbfbb5b8273b75055,
# 0x0000000000000000,
# 0x3fab59418c36a684,
# 0xbf34eafeaa92aca2,
# 0xbf7235801af9be44,
# 0x3f00af9747d0bf6f,
# 0x3f23611db0e1566e,
# 0xbeb2fbe414da12f8,
# 0xbec613ccbb9cbe59,
# 0x3e565cf274e84dc5,
# 0x3e5f452996e3dc29,
# 0xbdf023f5382da402,
# 0xbdee2be24fbad63d,
# ],
# [
# 0x0000000000000000,
# 0x3fbaf9cb49c4f935,
# 0xbf4e1d930b512f68,
# 0xbf91f7a8fec6eba9,
# 0x3f240a5531086611,
# 0x3f4cb20c812fd3ab,
# 0xbedff51953c6b5d2,
# 0xbef5cdc48f5d75ec,
# 0x3e883b091952c693,
# 0x3e934fb685e58ab8,
# 0xbe2566fc4369ab0d,
# 0xbe265f0f7de29720,
# 0x3db8b61e5f9b799f,
# ],
# [
# 0x3fba9e13a0db6429,
# 0x0000000000000000,
# 0xbfaa9c1ca2161b9b,
# 0x3f3344a09efdc559,
# 0x3f71b82c430a2381,
# 0xbefebfb97bca0143,
# 0xbf22dcdb1bc1d038,
# 0x3eb180047f0b796c,
# 0x3ec57eeeee84d0d0,
# 0xbe54a0c699c83150,
# 0xbe5e7594e8a2c761,
# 0x3dedccbbb4c0ba3a,
# 0x3ded6766337b5c96,
# ],
# [
# 0x0000000000000000,
# 0xbfba4407e04298d0,
# 0x3f4bcc9df0cf0e41,
# 0x3f917f0266db2147,
# 0xbf2280a052234e88,
# 0xbf4bf2ada1f4406e,
# 0x3edd83d58032b95a,
# 0x3ef53dd972d8f22f,
# 0xbe8663c1fe2022e4,
# 0xbe92d1fbf2203ff3,
# 0x3e23c9f0b759c7e9,
# 0x3e25cfe1b0126969,
# 0xbdb6ddc0795783c7,
# ],
# [
# 0xbfb9ef3bb2213b0b,
# 0x0000000000000000,
# 0x3fa9ed82007a9a44,
# 0xbf31d2fdeeb2a7d7,
# 0xbf71446866ff1b81,
# 0x3efc73b684f938fb,
# 0x3f22628de594b6c7,
# 0xbeb03303c14276ce,
# 0xbec4f51007c51084,
# 0x3e531adfa36f244e,
# 0x3e5db4f306b19090,
# 0xbdeb9e33598f8c33,
# 0xbdecb09ed6ecb892,
# ],
# [
# 0x0000000000000000,
# 0x3fb99be744018c90,
# 0xbf49c3f52a2b00c0,
# 0xbf910f5ca51f98af,
# 0x3f2126c8e8ca2a99,
# 0x3f4b416f7d4fc311,
# 0xbedb5e2e5580e536,
# 0xbef4b862279de755,
# 0x3e84c5071b39de03,
# 0x3e925d2fc3b1901e,
# 0xbe225df322279ad2,
# 0xbe254a971eb6fe38,
# 0x3db53cc6c9923080,
# ],
# [
# 0x3fb94d3276914e51,
# 0x0000000000000000,
# 0xbfa94bac1950e319,
# 0x3f308d4ff8f20595,
# 0x3f70d90d29bfeecd,
# 0xbefa6d56162f7fad,
# 0xbf21f107da23807d,
# 0x3eae1a6262774376,
# 0x3ec474eafd0cc643,
# 0xbe51c27144f42d76,
# 0xbe5d01999b1a4fe9,
# 0x3de9b014801da877,
# 0x3dec061740bc8a45,
# ],
# [
# 0x0000000000000000,
# 0xbfb8ffc9bd24fe06,
# 0x3f47f7d46ab34a67,
# 0x3f90a7a725d3fbc3,
# 0xbf1fea1728f22389,
# 0xbf4a9cac69f0ed61,
# 0x3ed977f48ff10c40,
# 0x3ef43c2d8e698c0c,
# 0xbe8355d1a676628a,
# 0xbe91f0553501d11d,
# 0x3e211b47f6a44aeb,
# 0x3e24ce23303889a3,
# 0xbdb3ca98df6224c9,
# ],
# [
# 0xbfb8b67a2481077d,
# 0x0000000000000000,
# 0x3fa8b51f21068ea2,
# 0xbf2ed935c7aef8db,
# 0xbf707522a5037f2d,
# 0x3ef8a196061f8b33,
# 0x3f21874a47e3c1e4,
# 0xbeac10cf34c04eb0,
# 0xbec3fd6c2d4fa2a4,
# 0x3e50906d55522757,
# 0x3e5c5a1c124dfa08,
# 0xbde7f883b31a5f24,
# 0xbdeb668cf53028e4,
# ],
# [
# 0x0000000000000000,
# 0x3fb86e51be0a9153,
# 0xbf465ed1b387eba6,
# 0xbf9046fc5a218a85,
# 0x3f1dca617fefacef,
# 0x3f4a0300221528a5,
# 0xbed7c7618906f3f0,
# 0xbef3c838897d0a1c,
# 0x3e820ede9f9dd909,
# 0x3e918a94165592bb,
# 0xbe1ff762051190b2,
# 0xbe24599dfeef019f,
# 0x3db2803e59983202,
# ],
# [
# 0x3fb829d06fee9266,
# 0x0000000000000000,
# 0xbfa8289a526d7786,
# 0x3f2cd680355c9138,
# 0x3f7017d70f512862,
# 0xbef707978e2a0854,
# 0xbf21247ce15e7386,
# 0x3eaa3f6125485aa7,
# 0x3ec38da848401beb,
# 0xbe4efe39d8db4936,
# 0xbe5bbd40f1db0e98,
# 0x3de66f7d49436d68,
# 0x3dead0e8148229b6,
# ],
# [
# 0x0000000000000000,
# 0xbfb7e656efb009ad,
# 0x3f44f15066f3e70b,
# 0x3f8fd932c26aad91,
# 0xbf1be460dd86aa5b,
# 0xbf49733b591879f5,
# 0x3ed64488c560280c,
# 0x3ef35ba58bf2f991,
# 0xbe80ea47bceb9d82,
# 0xbe912b327055d0e6,
# 0x3e1df42fc4e24c5a,
# 0x3e23ec3e76876db6,
# 0xbdb1580393f475c9,
# ],
# [
# 0xbfb7a62320798175,
# 0x0000000000000000,
# 0x3fa7a50ca4504bb8,
# 0xbf2b095ccb50b364,
# 0xbf6f80ef11daa378,
# 0x3ef59822dc75b585,
# 0x3f20c7e6a7c6662f,
# 0xbea89e00b5c35cb7,
# 0xbec324d5238b26ce,
# 0x3e4d13a888d5e0a6,
# 0x3e5b29f941a95b05,
# 0xbde50e6ebb3d1ff8,
# 0xbdea4434c6b929da,
# ],
# [
# 0x0000000000000000,
# 0x3fb766dc36547ccc,
# 0xbf43a919bc2a11d9,
# 0xbf8f2faf2b20556c,
# 0x3f1a2fdcc0cb5bcf,
# 0x3f48ec5a10ee00ce,
# 0xbed4e8eec45400cb,
# 0xbef2f5b5f4303778,
# 0x3e7fc66ddcbc56e0,
# 0x3e90d18f69c2056a,
# 0xbe1c249c3896bdfa,
# 0xbe2385557a0fd5b4,
# 0x3db04d34debaa05e,
# ],
# [
# 0x3fb72a8738bf5a25,
# 0x0000000000000000,
# 0xbfa7298c0721b762,
# 0x3f296a4d7d200c8d,
# 0x3f6edcd5007548f9,
# 0xbef44d4ab6fbb412,
# 0xbf2070e85baa8245,
# 0x3ea72606352e1633,
# 0x3ec2c24409460696,
# 0xbe4b5973606f31cd,
# 0xbe5a9f5998ed05f7,
# 0x3de3cfe929763102,
# 0x3de9bf9dc1e7123d,
# ],
# [
# 0x0000000000000000,
# 0xbfb6ef07e88e9a03,
# 0x3f42810f9619c144,
# 0x3f8e904f0426ed8c,
# 0xbf18a60ed6dbf0fd,
# 0xbf486d7bff5ee34a,
# 0x3ed3af3a46e8697e,
# 0x3ef295c4c41b1bf4,
# 0xbe7deb59c41f14ec,
# 0xbe907d1f2a0fad67,
# 0x3e1a81b9a8f15772,
# 0x3e232449e38344f3,
# 0xbdaeb7d4458a1dcf,
# ],
# ];
