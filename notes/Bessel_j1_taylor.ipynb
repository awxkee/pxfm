# %%
from scipy.special import j1
from scipy.optimize import brentq
from sage.all import *
import struct

DR = RealField(52)

DD = RealField(157)

def double_to_hex(f):
    # Converts Python float (f64) to hex string
    packed = struct.pack('>d', float(f))
    return '0x' + packed.hex()

def split_double_double(x):
    # Split RR value x into hi + lo (double-double)
    x_hi = DR(x)  # convert to f64
    x_lo = x - DD(x_hi)
    return (x_lo,x_hi)

# %%
# from scipy.special import j1, jvp
# from scipy.optimize import brentq
from mpmath import mp, mpf, findroot, j1, besselj
from sage.all import *
import struct

DR = RealField(53)

DD = RealField(190)

def double_to_hex(f):
    packed = struct.pack('>d', float(f))
    return '0x' + packed.hex()

def split_double_double(x):
    # Split RR value x into hi + lo (double-double)
    x_hi = DR(x)  # convert to f64
    x_lo = x - DD(x_hi)
    return (x_lo,x_hi)

def split_triple_double(x):
    # Split RR value x into hi + lo (double-double)
    x_hi = DR(x)  # convert to f64
    x_mid = DR(x - DD(x_hi))
    x_lo = x - DD(x_hi) - DD(x_mid)
    return (x_lo, x_mid, x_hi)

def print_double_double(mark, x):
    splat = split_double_double(x)
    print(f"{mark}({double_to_hex(splat[0])}, {double_to_hex(splat[1])}),")

def print_triple_double(mark, x):
    splat = split_triple_double(x)
    print(f"{mark}({double_to_hex(splat[0])}, {double_to_hex(splat[1])}, {double_to_hex(splat[2])}),")
    
# Use Sage's RDF for high-precision floats
R120 = RealField(120)

# List of zeros
zeros = []

# Step size to detect sign changes
# step = R120(0.001)
# x = R120(0.0)

mp.prec = 150

step = mpf("0.001")
epsilon = mpf("1e-35")
x = mpf("0.0")

def j1_prime(x):
    return diff(lambda t: besselj(1, t), x)

previous_zero = R120(0)
# epsilon = 1e-12
j1_zeros = []

# while x < 77:
#     if j1(float(x)) * j1(float(x + step)) < 0:  # Sign change => zero in interval
#         previous_zero = brentq(j1, x, x + step)
#         j1_zeros.append(R120(previous_zero))
#     if abs(x - round(x)) < epsilon:
#         zeros.append(R120(previous_zero))
#     x += step

while x < mpf("76.0"):
    f1 = besselj(1, x)
    f2 = besselj(1, x + step)
    if f1 * f2 < 0:
        zero = findroot(lambda t: j1(t), (x, x + step), solver='bisect', tol=mp.mpf("1e-41"))
        previous_zero = zero
        j1_zeros.append(zero)
    if previous_zero is not None and abs(x - mpf(f'{round(x)}')) < epsilon:
        zeros.append(previous_zero)
    x += step

j1_extrema = []

# x = R120(0.0)
# while x < 77:
#     dfx = jvp(1, float(x), n=1)  # Derivative of J1
#     dfx_next = jvp(1, float(x + step), n=1)
#     if dfx * dfx_next < 0:
#         extremum = brentq(lambda x: jvp(1, x, n=1), float(x), float(x + step))
#         j1_extrema.append(R120(extremum))
#     x += step

x = mpf("0.0")
while x < mpf("76.0"):
    d1 = mp.diff(lambda t: j1(t), x)
    d2 = mp.diff(lambda t: j1(t), x + step)
    if d1 * d2 < 0:
        extremum = findroot(lambda t: mp.diff(lambda u: j1(u), t), (x, x + step), solver='bisect', tol=mp.mpf("1e-41"))
        j1_extrema.append(extremum)
    x += step

# Print results
for i, z in enumerate(j1_zeros):
    print(f"Zero {i+1}: x ≈ {z}")

print("Extrema (peaks/valleys) of J1(x):")
for e in j1_extrema:
    print(f"nExtrema: {e}")

j1_zeros.extend(j1_extrema)

j1_zeros = sorted(j1_zeros)

# Print results
for i, z in enumerate(j1_zeros):
    print(f"Peak or zero {i+1}: x ≈ {z}")

print("")

print("pub(crate) static J1_ZEROS: [(u64, u64); 48] = [")
for z in j1_zeros:
    k = split_double_double(z)
    hi = double_to_hex(k[1])
    lo = double_to_hex(k[0])
    print(f"({lo}, {hi}),")
    
print("];")

from mpmath import *
from sage.all import *

from mpmath import mp, j1, taylor, expm1

prev_zero = 0

CDR = RealField(120)

var('x')

def get_constant_term(poly, y):
    for term in poly.operands():
        if term.is_constant():
            return term

def print_taylor_coeffs(poly, x0):
    print("J1TaylorExtendedSeries {")
    print_double_double("a0: ", poly[0])
    print_double_double("a1: ", poly[1])
    print_double_double("a2: ", poly[2])
    print_double_double("a3: ", poly[3])
    print_double_double("a4: ", poly[4])
    print_double_double("a5: ", poly[5])
    print_double_double("a6: ", poly[6])
    print_double_double("a7: ", poly[7])
    print_double_double("a8: ", poly[8])
    print_double_double("a9: ", poly[9])
    print_double_double("a10: ", poly[10])
    print_double_double("a11: ", poly[11])
    print_double_double("a12: ", poly[12])
    print_double_double("a13: ", poly[13])
    print_double_double("a14: ", poly[14])
    print_double_double("a15: ", poly[15])
    print("c: [")
    for i in range(16, 24):
        coeff = poly[i]
        print(f"{double_to_hex(coeff)},")
    print("],")
    print("},")

def print_expansion_at_0():
    print(f"pub(crate) static J1_MACLAURIN_SERIES: J1MaclaurinSeries = J1MaclaurinSeries {{")
    from mpmath import mp, j1, taylor, expm1
    poly = taylor(lambda val: j1(val), 0, 48)
    # print(poly)
    real_i = 0
    print_double_double("a0: ", DD(poly[1]))
    print_double_double("a1: ", DD(poly[3]))
    print_double_double("a2: ", DD(poly[5]))
    print_double_double("a3: ", DD(poly[7]))
    print_double_double("a4: ", DD(poly[9]))
    print("series: [")
    for i in range(11, 48, 2):
        print(f"{double_to_hex(poly[i])},")
        real_i = real_i + 1
    print("],")

    print("};")

mp.prec = 180

print_expansion_at_0()

print(f"pub(crate) static J1_COEFFS: [J1TaylorExtendedSeries; {len(j1_zeros)}] = [")

for i in range(0, len(j1_zeros)):
    k_range = j1_zeros[i]
    range_diff = k_range - prev_zero
    g_c = 1

    x0 = mp.mpf(k_range)
    from mpmath import mp, j1, taylor
    poly = taylor(lambda val: j1(val), x0, 25)
    print_taylor_coeffs(poly, CDR(k_range))
    prev_zero = j1_zeros[i]

print("];")
# Out:
# Zero 1: x ≈ 3.8317059702075123156144358863081605638606567
# Zero 2: x ≈ 7.0155866698156187535370499814765249743343443
# Zero 3: x ≈ 10.173468135062722077185711776775844057409686
# Zero 4: x ≈ 13.323691936314223032393684126947876441816528
# Zero 5: x ≈ 16.470630050877632812552460470989551841565766
# Zero 6: x ≈ 19.615858510468242021125065884137509740170716
# Zero 7: x ≈ 22.760084380592771898053005152182257271181704
# Zero 8: x ≈ 25.903672087618382625495855445979874037559629
# Zero 9: x ≈ 29.046828534916855066647819883531961126175072
# Zero 10: x ≈ 32.189679910974403626622984104460369114464945
# Zero 11: x ≈ 35.332307550083865102634479022519014605953498
# Zero 12: x ≈ 38.474766234771615112052197557716612761601455
# Zero 13: x ≈ 41.617094212814450885863516805060289043752123
# Zero 14: x ≈ 44.759318997652821732779352713212144411096444
# Zero 15: x ≈ 47.901460887185447121274008722507507056216055
# Zero 16: x ≈ 51.043535183571509468733034633224060674066057
# Zero 17: x ≈ 54.185553641061320532099966214533889117293725
# Zero 18: x ≈ 57.327525437901010745090504243750525540068925
# Zero 19: x ≈ 60.469457845347491559398749808383150187416642
# Zero 20: x ≈ 63.611356698481232631039762417873625837725927
# Zero 21: x ≈ 66.753226734098493415305259750042396633601678
# Zero 22: x ≈ 69.895071837495773969730536435499811953149608
# Zero 23: x ≈ 73.036895225573834826506117569092048737315876
# Extrema (peaks/valleys) of J1(x):
# nExtrema: 1.8411837813406593026436295136444430708388916
# nExtrema: 5.3314427735250326368840161834339112360024654
# nExtrema: 8.5363163663462858343589608864120510575969004
# nExtrema: 11.706004902592064100192670477239522028296672
# nExtrema: 14.863588633909033105004905304985979663579632
# nExtrema: 18.015527862681803727025625542010496573845942
# nExtrema: 21.164369859188790027767973293705131220128291
# nExtrema: 24.311326857210776091733221673753677489669893
# nExtrema: 27.457050571059245888223275587901978404801327
# nExtrema: 30.601922972669094192330163628525056457456796
# nExtrema: 33.746182898667382556147730594290579095262643
# nExtrema: 36.889987409236810736184291115055097951034107
# nExtrema: 40.03344405335067548359557782482102401175484
# nExtrema: 43.17662896544882206517132667093450433207941
# nExtrema: 46.319597561173912431514896922520700501125422
# nExtrema: 49.462391139702755522817961514250936991248047
# nExtrema: 52.605041111556684816016445795619378498050585
# nExtrema: 55.747571792251006871041271951261260386005014
# nExtrema: 58.890002299185703524557516663955601793125035
# nExtrema: 62.032347870661986904980183177973295014951029
# nExtrema: 65.174620802544453140913079699161236759856333
# nExtrema: 68.316831125951808310075532836203916922785006
# nExtrema: 71.458987105851000181223748893951481306196536
# nExtrema: 74.601095613456402477925006047822592800861904
# Peak or zero 1: x ≈ 1.8411837813406593026436295136444430708388916
# Peak or zero 2: x ≈ 3.8317059702075123156144358863081605638606567
# Peak or zero 3: x ≈ 5.3314427735250326368840161834339112360024654
# Peak or zero 4: x ≈ 7.0155866698156187535370499814765249743343443
# Peak or zero 5: x ≈ 8.5363163663462858343589608864120510575969004
# Peak or zero 6: x ≈ 10.173468135062722077185711776775844057409686
# Peak or zero 7: x ≈ 11.706004902592064100192670477239522028296672
# Peak or zero 8: x ≈ 13.323691936314223032393684126947876441816528
# Peak or zero 9: x ≈ 14.863588633909033105004905304985979663579632
# Peak or zero 10: x ≈ 16.470630050877632812552460470989551841565766
# Peak or zero 11: x ≈ 18.015527862681803727025625542010496573845942
# Peak or zero 12: x ≈ 19.615858510468242021125065884137509740170716
# Peak or zero 13: x ≈ 21.164369859188790027767973293705131220128291
# Peak or zero 14: x ≈ 22.760084380592771898053005152182257271181704
# Peak or zero 15: x ≈ 24.311326857210776091733221673753677489669893
# Peak or zero 16: x ≈ 25.903672087618382625495855445979874037559629
# Peak or zero 17: x ≈ 27.457050571059245888223275587901978404801327
# Peak or zero 18: x ≈ 29.046828534916855066647819883531961126175072
# Peak or zero 19: x ≈ 30.601922972669094192330163628525056457456796
# Peak or zero 20: x ≈ 32.189679910974403626622984104460369114464945
# Peak or zero 21: x ≈ 33.746182898667382556147730594290579095262643
# Peak or zero 22: x ≈ 35.332307550083865102634479022519014605953498
# Peak or zero 23: x ≈ 36.889987409236810736184291115055097951034107
# Peak or zero 24: x ≈ 38.474766234771615112052197557716612761601455
# Peak or zero 25: x ≈ 40.03344405335067548359557782482102401175484
# Peak or zero 26: x ≈ 41.617094212814450885863516805060289043752123
# Peak or zero 27: x ≈ 43.17662896544882206517132667093450433207941
# Peak or zero 28: x ≈ 44.759318997652821732779352713212144411096444
# Peak or zero 29: x ≈ 46.319597561173912431514896922520700501125422
# Peak or zero 30: x ≈ 47.901460887185447121274008722507507056216055
# Peak or zero 31: x ≈ 49.462391139702755522817961514250936991248047
# Peak or zero 32: x ≈ 51.043535183571509468733034633224060674066057
# Peak or zero 33: x ≈ 52.605041111556684816016445795619378498050585
# Peak or zero 34: x ≈ 54.185553641061320532099966214533889117293725
# Peak or zero 35: x ≈ 55.747571792251006871041271951261260386005014
# Peak or zero 36: x ≈ 57.327525437901010745090504243750525540068925
# Peak or zero 37: x ≈ 58.890002299185703524557516663955601793125035
# Peak or zero 38: x ≈ 60.469457845347491559398749808383150187416642
# Peak or zero 39: x ≈ 62.032347870661986904980183177973295014951029
# Peak or zero 40: x ≈ 63.611356698481232631039762417873625837725927
# Peak or zero 41: x ≈ 65.174620802544453140913079699161236759856333
# Peak or zero 42: x ≈ 66.753226734098493415305259750042396633601678
# Peak or zero 43: x ≈ 68.316831125951808310075532836203916922785006
# Peak or zero 44: x ≈ 69.895071837495773969730536435499811953149608
# Peak or zero 45: x ≈ 71.458987105851000181223748893951481306196536
# Peak or zero 46: x ≈ 73.036895225573834826506117569092048737315876
# Peak or zero 47: x ≈ 74.601095613456402477925006047822592800861904
#
# pub(crate) static J1_ZEROS: [(u64, u64); 48] = [
# (0x3c5616d820cfdaeb, 0x3ffd757d1fec8a3a),
# (0xbca60155a9d1b257, 0x400ea75575af6f09),
# (0x3ca5c646a75d7539, 0x40155365bc032467),
# (0xbc9b226d9d243828, 0x401c0ff5f3b47250),
# (0xbca63e17ec20a31d, 0x402112980f0b88a1),
# (0x3cc02610a51562b6, 0x402458d0d0bdfc29),
# (0x3cc9a84d3a5fedc1, 0x40276979797ee5ac),
# (0x3cb2bce7fd18e693, 0x402aa5baf310e5a2),
# (0xbcc6932b987094f1, 0x402dba284a17ac59),
# (0xbcdd2a68e88ab318, 0x4030787b360508c5),
# (0xbca022f6b2b54db9, 0x403203f9a24e6527),
# (0xbcd21830197e9e86, 0x40339da8e7416ca4),
# (0x3cdeaafeaf8ec1af, 0x40352a1424a1a9fa),
# (0xbcc1bf33afef88f2, 0x4036c294e3d4d8ac),
# (0xbcb2d773b50cf8b9, 0x40384fb31dee1635),
# (0x3cc1a2686480d882, 0x4039e7570dcea106),
# (0x3cd0bdee27293d79, 0x403b75014427514d),
# (0xbcb42ce39ec976fb, 0x403d0bfcf471fccc),
# (0x3cbda49c2c143483, 0x403e9a179fba532a),
# (0xbcdbe3a1cd066b67, 0x404018476e6b2bf0),
# (0xbce6b00c1279ef0a, 0x4040df82ebd54e32),
# (0xbced5fbbff045068, 0x4041aa890dc5e97c),
# (0x3cd7d864bbf17a30, 0x404271eb1b80430e),
# (0x3cc9eafeca0ca4fc, 0x40433cc523d5cb69),
# (0xbce5cecac300a9a1, 0x40440447e50db184),
# (0x3cc489bd556e5109, 0x4044cefcf1734b62),
# (0x3cdd0fd96f29c211, 0x4045969bc7271083),
# (0x3ce4f716f3179d90, 0x404661315d6b133f),
# (0xbce158b763edd0e8, 0x404728e892a88fc9),
# (0xbcef3950a842db79, 0x4047f36312028ad6),
# (0x3ce97656bbc2396e, 0x4048bb2fa2037de3),
# (0x3ce85d7bdb30baf1, 0x404985928f96d51e),
# (0xbce71f8560ac9f18, 0x404a4d71fcb56f8c),
# (0x3ce3d41e041caa68, 0x404b17c038c2018c),
# (0xbcde6d04716d8d21, 0x404bdfb06eb790aa),
# (0x3cda139ce2cd08ac, 0x404ca9ec5a82324b),
# (0x3cc8b5cc7b4501c1, 0x404d71eb98682f07),
# (0xbcb12e6ef2e594e2, 0x404e3c1731d64f1e),
# (0x3cb399bfca430021, 0x404f0423f99b4b53),
# (0x3cdfd1ee8286358a, 0x404fce40efb1156e),
# (0x3c800660b51502f0, 0x40504b2cfcbb084d),
# (0x3ced3cacfc720418, 0x4050b034dde75b42),
# (0x3cc4b877d4f6d900, 0x40511446f60f1458),
# (0xbcee669304bfe748, 0x40517948db63675c),
# (0x3cfad20ca758a714, 0x4051dd600b743a9b),
# (0x3cf8eb4a94b63936, 0x4052425c7dcacdf6),
# (0xbcfa196892f68386, 0x4052a67859bc641e),
# ];
# pub(crate) static J1_MACLAURIN_SERIES: J1MaclaurinSeries = J1MaclaurinSeries {
# a0: (0x0000000000000000, 0x3fe0000000000000),
# a1: (0x0000000000000000, 0xbfb0000000000000),
# a2: (0x3c05555555555555, 0x3f65555555555555),
# a3: (0xbbac71c71c71c71c, 0xbf0c71c71c71c71c),
# a4: (0xbb3f49f49f49f49f, 0x3ea6c16c16c16c17),
# series: [
# 0xbe3845c8a0ce512a,
# 0x3dc27e4fb7789f5c,
# 0xbd4522a43f65486a,
# 0x3cc2c9758daf5ccf,
# 0xbc3ab81ea75fcdf5,
# 0x3baf17697cf1cf12,
# 0xbb1e2637bef9ff1b,
# 0x3a88bce58901a35d,
# 0xb9f165e7c2d153f4,
# 0x39553585cdcbfb0f,
# 0xb8b69f7da8510bcd,
# 0x38154ad09e6a6575,
# 0xb771d028acb00492,
# 0x36caaae78f4066a6,
# 0xb621f72d8389b3a4,
# 0x3575e69de22df5ce,
# 0xb4c84564b82a1185,
# 0x34188f11edf3ed4c,
# 0xb366c77c3976a829,
# ],
# };
# pub(crate) static J1_COEFFS: [J1TaylorExtendedSeries; 47] = [
# J1TaylorExtendedSeries {
# a0: (0x3c61f1c324453b30, 0x3fe29ea3d19f035f),
# a1: (0xb57b7e47416004f5, 0x38e12617a766cdd1),
# a2: (0xbc6e3631ae171271, 0xbfca41115c5df243),
# a3: (0xbc18acc5100eb0af, 0x3f78d1448e6fed48),
# a4: (0x3c0e85a7d0bc098e, 0x3f8c441a2f9de22b),
# a5: (0x3bd94ca1b691248f, 0xbf386671c18b088a),
# a6: (0x3bd950cc4e8482d1, 0xbf39e2504ddc7608),
# a7: (0xbb61b481438e4082, 0x3ee34ccbca0c75d1),
# a8: (0x3b7aba05e287d16f, 0x3eda4973784d1087),
# a9: (0x3b1ffacaebcbb727, 0xbe81045322aaab45),
# a10: (0x3b03dabae8fea73d, 0xbe70fae0da6cdcef),
# a11: (0x3abc719b8692aa75, 0x3e13546cef5ed00a),
# a12: (0xba8ac75d7c570056, 0x3dfe5ee82e667708),
# a13: (0xba263b1d65111e52, 0xbd9ec80cc8b63c39),
# a14: (0xba145e6e27b1490b, 0xbd83eb2e99629b44),
# a15: (0x39b7626e428b4f5a, 0x3d222bfcdb19561c),
# c: [
# 0x3d03fb3376a42e34,
# 0xbca0901287d105af,
# 0xbc7fa6a90c6a0c33,
# 0x3c180774f17c486a,
# 0x3bf44b79578fc6fb,
# 0xbb8c6ab05fe77308,
# 0xbb65805fbd38e218,
# 0x3afbed5bcea231a2,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb5152766d1ebfdc4, 0x38db213d4317cbc2),
# a1: (0x3c62de1143765a96, 0xbfd9c6cf582cbf7f),
# a2: (0xbc46b8d73329ae53, 0x3faae8a39f51ad04),
# a3: (0xbc47767d9698b536, 0x3fab589d1da13905),
# a4: (0x3c0e65e41f8b156f, 0xbf7537544c331da7),
# a5: (0x3bc117d15907382a, 0xbf624b3409959064),
# a6: (0x3bb8c81b03584e43, 0x3f26e4c2d5354224),
# a7: (0x3b9859e8c0ae37ce, 0x3f083a06e30c4109),
# a8: (0x3b51fe68ee4dfe26, 0xbec9799d4c9f2549),
# a9: (0xbb4ffb11fda5bef4, 0xbea33825cd2e2c16),
# a10: (0x3ae8a5cec4a77c6b, 0x3e617069233e916c),
# a11: (0xbaabdbb69c094018, 0x3e34569b22afc3c8),
# a12: (0x3a76236a521c1ecc, 0xbdf03b9e9651056a),
# a13: (0xba58526061a7319e, 0xbdbec62310af5f52),
# a14: (0x39f8c0813d01aca5, 0x3d75ec84e47b6f4f),
# a15: (0x39df157bfc6eaf25, 0x3d417a40c9422e17),
# c: [
# 0xbcf67cb1d0030c9c,
# 0xbcbee7ff918f9b6a,
# 0x3c721fb8bdc4d7f9,
# 0x3c35e0517dd0b5c9,
# 0xbbe792595a1eec68,
# 0xbba95a682022dcb9,
# 0x3b59438c464a0b99,
# 0x3b187f5c94382543,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc782d627160714a, 0xbfd626ee83500bf2),
# a1: (0x3527a1c8aeec9a3a, 0xb8cd2ef56c8c2f09),
# a2: (0x3c6ae8952e6f1d98, 0x3fc55f6bec9ef962),
# a3: (0x3c0d30f1a30652b3, 0xbf83d23336fd10e4),
# a4: (0x3c2695c3589cdcfd, 0xbf88c77a983a0814),
# a5: (0x3bea1200f3887330, 0x3f45cdc98db1cbe2),
# a6: (0x3bd343248cea52bc, 0x3f373576ff46ee3b),
# a7: (0x3b8a8cd6bedb881c, 0xbef2461447d7b423),
# a8: (0x3b6a8a902c87e6ba, 0xbed7b853456b6eaa),
# a9: (0xbaff7253673d7fa7, 0x3e90abfc68274a98),
# a10: (0xbae9e22e3ad66ed4, 0x3e6ea7a1ee26124d),
# a11: (0xbac56987dde26b61, 0xbe235c0413e01418),
# a12: (0x3a9eb6867453dd1b, 0xbdfb5c5d512fbb00),
# a13: (0x3a3a4481d08d2197, 0x3daf4c5e26fd6e90),
# a14: (0xba21e34f6852a2b7, 0x3d81e4c43397be51),
# a15: (0x39d14c360485170c, 0xbd32addefc4d51c5),
# c: [
# 0xbd01e4fadc0e435d,
# 0x3cb12a0b88508f36,
# 0x3c7c4246a0342e39,
# 0xbc290ede5816f2cf,
# 0xbbf211307906e315,
# 0x3b9dc7bf70396b28,
# 0x3b6316e7f158a264,
# 0xbb0d623edc3b24ad,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb57fedc176c356a1, 0x38d70b25f90f361c),
# a1: (0x3c7af22d033ee0a4, 0x3fd33518b3874e8a),
# a2: (0xbc23b4d6298472b3, 0xbf95e70dc60362bf),
# a3: (0xbc476d8715df682d, 0xbfa80c83bdeee5b0),
# a4: (0x3c03dac20ab22d50, 0x3f69a4b292e3de42),
# a5: (0x3bd887eed6e68809, 0x3f613fbc7d698217),
# a6: (0xbbac52a925910e78, 0xbf207358bbdbff91),
# a7: (0xbb64763d026d3261, 0xbf0796a751f89051),
# a8: (0xbb6df65f1fdd48ef, 0x3ec4255b015aded4),
# a9: (0xbb3ae816d26784fe, 0x3ea3026e0ce97ab9),
# a10: (0xbaf57b3883b98fa4, 0xbe5d48dcdae92f2c),
# a11: (0x3aca4c50b5ee02fb, 0xbe344639d7eeb0a6),
# a12: (0xba8fd8f34b9ecafc, 0x3dec62ccb4a32eb5),
# a13: (0xba5032cb87171f64, 0x3dbecae92e854457),
# a14: (0xba1beb1ed7eaf161, 0xbd73bb6898d73cd2),
# a15: (0xb9dd5420c79c50f6, 0xbd4183edbb8ef55e),
# c: [
# 0x3cf4ae3e7e4cce3d,
# 0x3cbefbb1e7007309,
# 0xbc70f28da3efa3c8,
# 0xbc35ec318df9b467,
# 0x3be6555a952345fa,
# 0x3ba9633c7f133c92,
# 0xbb583145f93c70ae,
# 0xbb1881cb99e6a1d9,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc7d48dbfa0ea1a5, 0x3fd17dbf09d40d25),
# a1: (0x357b2ae544113ef3, 0x38d242bd184e9506),
# a2: (0xbc61eb914d33c2fa, 0xbfc1404bf647c28f),
# a3: (0x3c098a23a3934c85, 0x3f74f4df2769f830),
# a4: (0x3c24ae93dcbae42d, 0x3f85c6285429b66d),
# a5: (0x3bdddb259d6919ab, 0xbf3d68ab722881bd),
# a6: (0xbbd8cd731f6bf400, 0xbf356acb6452d860),
# a7: (0x3b60d2b8ff5b8f4c, 0x3eec10b47cf7ef69),
# a8: (0xbb3cc7e8d830a4e9, 0x3ed67eaae97bbc86),
# a9: (0x3b0230ef0e6803f6, 0xbe8bb6530c63f2df),
# a10: (0xbaf83f73085e8893, 0xbe6d87201e450edd),
# a11: (0xbaaefe243bce74ca, 0x3e20f47c83ec550b),
# a12: (0x3a995905da4f9c7f, 0x3dfa98331f6ea799),
# a13: (0x3a40b4039f32743e, 0xbdac70414a236a67),
# a14: (0xba249d55aee4b10f, 0xbd817c057a5fcd3d),
# a15: (0x39d02164b46fc11f, 0x3d316fea14d1fe7c),
# c: [
# 0x3d0189bd3ec36234,
# 0xbcb05af44aaf2ab4,
# 0xbc7bbdb47ae6b94d,
# 0x3c28435e8461ed36,
# 0x3bf1bfd66fba7b36,
# 0xbb9d3526fa2c65e3,
# 0xbb62c1e2b3f208ce,
# 0x3b0d1f12fb9ae97d,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x351b4791e9813f47, 0x389079dc35faae0a),
# a1: (0xbc5052a3a2541c57, 0xbfcff654544ebcd1),
# a2: (0xbc01b402d42ea503, 0x3f89223ff2c0785b),
# a3: (0xbc323a275590a85f, 0x3fa4b0c5d5da6789),
# a4: (0x3bb3ea54ac68ef72, 0xbf5f91a9ee0d2897),
# a5: (0x3bfc41f7f61682c1, 0xbf5f51c2489b9e6f),
# a6: (0x3bad7af9f28c7681, 0x3f16b4c9ca0f770d),
# a7: (0xbbadd3415a058d7c, 0x3f063c5475439cb2),
# a8: (0x3b59f6c7b33666e6, 0xbebe3725daf69867),
# a9: (0x3b21f2a7db95aa23, 0xbea25c1238b32e59),
# a10: (0xbaeb35e7c5937060, 0x3e57486f6b9aa951),
# a11: (0x3ad95c3e197deb05, 0x3e33e3bf248277ee),
# a12: (0xba77b9fdb9bee259, 0xbde78a38a73e7c0a),
# a13: (0xba480ea277e7ec50, 0xbdbe844eb6b211b0),
# a14: (0x3a0c6dae4342e4f7, 0x3d70e24abb40708e),
# a15: (0xb9e5f9316e1c5efb, 0x3d41797e5eacddfb),
# c: [
# 0xbcf21fc0f1265a7c,
# 0xbcbf0c12e445cb42,
# 0x3c6e4423559080b2,
# 0x3c36080463b41f1d,
# 0xbbe43e38b263073f,
# 0xbba98fa121c815cb,
# 0x3b56325cba16fa62,
# 0x3b18b3fd438c6ab3,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c50f8942d3f902a, 0xbfcddceb4ce1bf4a),
# a1: (0x3577d5c3ff338b90, 0xb8d2ccc4f0f8e4a5),
# a2: (0x3c433d5334b42c83, 0x3fbda52116c0a640),
# a3: (0xbbe72468a28942eb, 0xbf6a9da4603b67ea),
# a4: (0xbc0c5e08317c5bc1, 0xbf8331e74ea59ab8),
# a5: (0xbbdac4579bb7d321, 0x3f33e5cb6eba6eaa),
# a6: (0x3bd0ad973dfed7a8, 0x3f33885fe9afa541),
# a7: (0xbb74d72fe9613aba, 0xbee494c0f4b0680b),
# a8: (0x3b783e70ffbfc8f7, 0xbed512b9d37762d7),
# a9: (0x3b137aef4175871e, 0x3e85a861082bfb7f),
# a10: (0xbb059fce2a743f34, 0x3e6c323ea0a042c3),
# a11: (0xbaaeb25b7edb5f5b, 0xbe1bcc962f7b91eb),
# a12: (0x3a6a5caf0a45be45, 0xbdf9bc94e2f29a52),
# a13: (0x3a4115f7a8e1da36, 0x3da82bc6fcfa8e89),
# a14: (0x3a2ca2e9a78a230c, 0x3d81141ce7b78460),
# a15: (0x3996491884870584, 0xbd2e79ccb1860d7a),
# c: [
# 0xbd013e1fbe0a5971,
# 0x3cad36d12b0d249c,
# 0x3c7b66072bbdf477,
# 0xbc260cb923a35433,
# 0xbbf196237500b24e,
# 0x3b9aeba1005e1830,
# 0x3b62a07d164c6a6f,
# 0xbb0b27ac12f04a32,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb5768e85e5c49b40, 0xb8d67367ca0908e0),
# a1: (0x3c6c8c66d2e42062, 0x3fcbf3337873a7d8),
# a2: (0x3c25e81c4baa84e8, 0xbf80c83a2d7add33),
# a3: (0x3c44192692d7c9da, 0xbfa251858011816b),
# a4: (0x3bd0475c4916a7f0, 0x3f559eb160bf72d8),
# a5: (0x3b9e04d41bf0d87c, 0x3f5c5bce33af2d77),
# a6: (0x3b7eb490c328247a, 0xbf10413e306e0039),
# a7: (0xbb9e3a426e412d42, 0xbf04a6704d05ad0b),
# a8: (0xbb5a4f33202681b3, 0x3eb6c43eedfed6c9),
# a9: (0x3b2d2f110d38d23b, 0x3ea16abd7815de74),
# a10: (0xbae416eabc41ca79, 0xbe5257f16f5d4346),
# a11: (0xbad1043744ab6130, 0xbe332db1b4b2ff8b),
# a12: (0xba872ca31e31d0a7, 0x3de33acccf7bfdce),
# a13: (0x3a00b03336c2218e, 0x3dbdc8f5682566ba),
# a14: (0xb9e9cd15ad06d38b, 0xbd6c6513386daae2),
# a15: (0x39d8466ad52efa61, 0xbd413585a9b7473f),
# c: [
# 0x3cef322ea2e20db5,
# 0x3cbec749ba31d0ed,
# 0xbc6a8abab44a5a16,
# 0xbc35f2aba27d0156,
# 0x3be20705169a0884,
# 0x3ba98e9c9fa1064a,
# 0xbb540557c89d65ca,
# 0xbb18c41cdedb0d3e,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc26397095487bb9, 0x3fca7f63fea81f26),
# a1: (0x352d9eff53131d35, 0xb885d323c61ec531),
# a2: (0x3c4341d92ebaf0e5, 0xbfba60afb06640cf),
# a3: (0x3c0aa0cf7edfc4b1, 0x3f62c1e930935d3c),
# a4: (0x3c2253175b5dc28b, 0x3f814506466d7f1f),
# a5: (0x3bcf594f6cb1e045, 0xbf2cca8c0c0eaa3f),
# a6: (0xbbc23306ba391f44, 0xbf31df821cc1377e),
# a7: (0xbb6f4273eb18d483, 0x3edee8814ed0ac45),
# a8: (0x3b3531e00c0b1e90, 0x3ed3a365a4199dd1),
# a9: (0xbb2539aeb3d4946c, 0xbe80ed2f9c3e458e),
# a10: (0xbae7dc7c41800a98, 0xbe6ab3b37c5271b3),
# a11: (0xbabe3080b40ebc8e, 0x3e1684d6e62b5c66),
# a12: (0xba980fe8dabe0c37, 0x3df8b105a5120ed2),
# a13: (0xba34afb054573de1, 0xbda42dc5991b9d01),
# a14: (0x3a24e165917f0851, 0xbd808d6405ffe3dc),
# a15: (0xb9bea36c059d9a66, 0x3d2a15203365a9e0),
# c: [
# 0x3d00d7c118bbeb37,
# 0xbca984ffd2857b4d,
# 0xbc7aecb2d3226940,
# 0x3c2396ff2d246041,
# 0x3bf15cbae441ca23,
# 0xbb9841be044fa28e,
# 0xbb627467b799ccfd,
# 0x3b08c28575d745a6,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3571317a32214d54, 0xb8d999cbca009df3),
# a1: (0x3c6e9557ccd1703e, 0xbfc925c6fca08f55),
# a2: (0x3c091bef69239ae4, 0x3f786dd32e059b0e),
# a3: (0x3c3dac1b118bb946, 0x3fa09463bbd0367f),
# a4: (0x3be231ff19225465, 0xbf4fda0298c8768b),
# a5: (0xbbf0185527e9208f, 0xbf59f4be60758fb1),
# a6: (0xbbac474063460806, 0x3f0877991af9d1bb),
# a7: (0x3b85632e0e751036, 0x3f032cb00ee8c1f3),
# a8: (0x3b46a0371f5eb5df, 0xbeb19d8ce8c35f58),
# a9: (0x3b44398edcd31b45, 0xbea06a042fbba455),
# a10: (0xbaeabb097c7d4aad, 0x3e4d3a689e677731),
# a11: (0x3adf851e84662873, 0x3e325108c4ce2b63),
# a12: (0x3a700c6a94a96472, 0xbddf7b8e9ab53152),
# a13: (0xb9e39398140885bb, 0xbdbcc40d05652642),
# a14: (0xb9debdd38ee83cc4, 0x3d67cd76e2d7e2cb),
# a15: (0xb9d4060b8e456ec8, 0x3d40c58770231c0a),
# c: [
# 0xbceaafec4cd92007,
# 0xbcbe36dd57088c43,
# 0x3c67199e80bb8ec2,
# 0x3c35ab8b86951bb1,
# 0xbbdfd7377ba12be3,
# 0xbba9595b17afa78e,
# 0x3b51e6cee419b352,
# 0x3b18a74f87d027a3,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c2a5f1938003f5c, 0xbfc810f50225b04b),
# a1: (0x3558eb136cb858ef, 0x38b5ef5b6dbf6258),
# a2: (0x3c5462bc86c50f0a, 0x3fb7fdf97ac36b1f),
# a3: (0x3beaefb0d3d06c93, 0xbf5c3c256a8caa05),
# a4: (0xbc191dbdbe4ca6da, 0xbf7f98feb7286b47),
# a5: (0xbbcd0c6b4f6c3ad6, 0x3f25f6559e5686e2),
# a6: (0xbbd9de4a645cf979, 0x3f3080f57ac215af),
# a7: (0xbb69ed06d60efe8d, 0xbed80c51397e5eba),
# a8: (0x3ae04eb6bd1f24bc, 0xbed256db543cd140),
# a9: (0x3b1af2db1b084be5, 0x3e7af7598a219824),
# a10: (0x3b0693a9fa38dfa0, 0x3e69398226ca2305),
# a11: (0x3a95f5676bd10cd2, 0xbe1260985d92587d),
# a12: (0x3a8d5612be0b4b05, 0xbdf792bb3eea6f6a),
# a13: (0x3a4432d95d96cbda, 0x3da0d862695e1a7a),
# a14: (0x39d7cd101d99d4e2, 0x3d7fe52adc2baacf),
# a15: (0x39baa545a1a5eb61, 0xbd263801377398f0),
# c: [
# 0xbd005a1befdbe42d,
# 0x3ca6205041739aa5,
# 0x3c7a4e1503b6d0e4,
# 0xbc213ef141f6d641,
# 0xbbf10ccc96cd4c02,
# 0x3b95a2fe023aea26,
# 0x3b6232d7c90d33bc,
# 0xbb0656435697f160,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb558a05a90c259a6, 0xb8ba58a96fb0a152),
# a1: (0x3c62da0057f84d3b, 0x3fc70c511227d5aa),
# a2: (0xbbfb574e506cf74d, 0xbf72ccb0e97558da),
# a3: (0x3c2e61277dedf705, 0xbf9e7dc08e70e99a),
# a4: (0x3ba77952da42c6c4, 0x3f48acdc5b058c0e),
# a5: (0xbbf340f4df9939b6, 0x3f580503724ad30a),
# a6: (0xbba115f69745949a, 0xbf032ee4ca1fcafb),
# a7: (0x3ba6a66de44f6f2a, 0xbf01e5d2836c8d99),
# a8: (0xbb2b264207f7cf5f, 0x3eac129f077bb163),
# a9: (0x3b3381f3bd8fb4b5, 0x3e9ef161591181a2),
# a10: (0x3ae466d818a45b44, 0xbe47b9bb07f19f82),
# a11: (0x3ac2d952a84a8f20, 0xbe316f3937595d96),
# a12: (0xba7571ae406938c5, 0x3dda0bc8665b687b),
# a13: (0x3a588295d4921561, 0x3dbba135f99a9e19),
# a14: (0xb9ff299934254ca7, 0xbd640d543d2cbdf0),
# a15: (0x3982fb1c3cc08575, 0xbd403d0592185f1c),
# c: [
# 0x3ce6db5e22d3be74,
# 0x3cbd745a1f77858f,
# 0xbc64141c4b5a4106,
# 0xbc353f4e6ca53f65,
# 0x3bdc09c1732e9344,
# 0x3ba8f971fa1f374a,
# 0xbb4fe39c23f51b6d,
# 0xbb1862f419e2ba54,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc6b166d180d579d, 0x3fc633e7f7f05301),
# a1: (0x35570161b9881bbb, 0xb8ca15b6e16d5dac),
# a2: (0xbc100659a075d9a7, 0xbfb6273784c1c06e),
# a3: (0x3bfcb74bd0872e28, 0x3f563ae94ade18d4),
# a4: (0x3c02a45d712a2f90, 0x3f7d4666536c88b9),
# a5: (0x3b825e9acb600aca, 0xbf216d528345ca11),
# a6: (0x3bbb9405b8c58d56, 0xbf2ec0dcdbb7c5fe),
# a7: (0xbb7cb6e04f4b97e7, 0x3ed34e966b0b09f8),
# a8: (0xbb7a79e09bd0a7d3, 0x3ed135c64dc2d8d0),
# a9: (0x3b01284c6af65ed7, 0xbe75f7bc78b5fc2b),
# a10: (0xbaf68597192a53a4, 0xbe67dc35b0764096),
# a11: (0xbaab08d1b3bdd3d7, 0x3e0e6d697361ea54),
# a12: (0x3a825acf92327a4d, 0x3df679e3704987b4),
# a13: (0x3a25a180ac4a2898, 0xbd9c595f278a4d6c),
# a14: (0xba0b8a094432fbc2, 0xbd7ea36aef56eec0),
# a15: (0x39c8d7c90342cb96, 0x3d22fd66b4e62185),
# c: [
# 0x3cffa04c9faacec0,
# 0xbca32f47f03857d7,
# 0xbc799658479ebb31,
# 0x3c1e4c26032e5de4,
# 0x3bf0ab1b47f9c785,
# 0xbb933a3c78295757,
# 0xbb61de19b957005e,
# 0x3b040e310c05ed67,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x35686614aa8bf583, 0x38d1dfb66aad7a37),
# a1: (0x3c6a47ab4241a9f4, 0xbfc5664e13b70622),
# a2: (0x3c04d78c254f4418, 0x3f6e16555e108dc6),
# a3: (0x3c1fe75afd6ce0f9, 0x3f9c5e1ad9fb2f40),
# a4: (0x3be099fe50e43635, 0xbf43d369f958e56a),
# a5: (0xbbf3ed70de366684, 0xbf566f4ec27a96e9),
# a6: (0xbb9b30f071ce70bf, 0x3eff0de0532652d5),
# a7: (0xbb747f8eea3cc056, 0x3f00cf264341409e),
# a8: (0x3b4f2ff7c971467f, 0xbea6f46d51e5766f),
# a9: (0xbb3708c3f9c7bd35, 0xbe9d407f7c248d45),
# a10: (0xbaee70df563a5b11, 0x3e43a33cd9df6696),
# a11: (0x3ad300d61c332faf, 0x3e309901b0a816e5),
# a12: (0x3a69fdf1dd8c15b5, 0xbdd5d856a58443f5),
# a13: (0xba3f02f5ec08db44, 0xbdba7cbcd8fc0758),
# a14: (0xb9fcaa58f7c81513, 0x3d610b62c2fd47f6),
# a15: (0xb9bf896eb454c48a, 0x3d3f56a09da19f70),
# c: [
# 0xbce3ae6849b36427,
# 0xbcbc977524a64328,
# 0x3c617fc9db74cefd,
# 0x3c34bbe426d77a28,
# 0xbbd8b5659628a8e3,
# 0xbba87bcc22e21172,
# 0x3b4c62cff42626ad,
# 0x3b1800b5df5b52ae,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc4f6f339127993e, 0xbfc4b71d4ca2cc69),
# a1: (0x3547dd9bc5a49937, 0xb8cdf1921c3caa19),
# a2: (0x3c5422c1a1ae8ec3, 0x3fb4ae245697fba6),
# a3: (0xbbf4ff572c18742d, 0xbf5215e4e1a5f1d6),
# a4: (0xbbf259ec9ab217a9, 0xbf7b633ed6d9cf61),
# a5: (0x3bab33aa46f3e72d, 0x3f1c7f17b4b7dbbd),
# a6: (0xbb79333ace27b68e, 0x3f2ce01b8b6aa34c),
# a7: (0x3b5f4e5e8507bc84, 0xbecfced71b11e35b),
# a8: (0x3b57f324d6293b06, 0xbed03c9d5823261d),
# a9: (0xbb15cd82948c15bb, 0x3e724508091063b2),
# a10: (0x3b02ba31739f7dab, 0x3e66a2d20111e303),
# a11: (0x3aae84f884334dbc, 0xbe0995a18f8e6888),
# a12: (0x3a67a35968d37627, 0xbdf572d1a074f647),
# a13: (0xba3a336c953bedde, 0x3d981df03c1911f1),
# a14: (0xba104dc5bcacab30, 0x3d7d6895e48f475d),
# a15: (0x39c36eea9cd69fea, 0xbd205887f0b3df78),
# c: [
# 0xbcfe86703ddf1bbc,
# 0x3ca0b3c70ca73df2,
# 0x3c78d28ba328c188,
# 0xbc1aa9275d6882a0,
# 0xbbf03e89774aa978,
# 0x3b911679204a4a38,
# 0x3b617bd36a04e548,
# 0xbb01fc50745d8566,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb559aa5e66e19a02, 0xb8ca13908374acd4),
# a1: (0x3c6316f8ffd294bb, 0x3fc40f90793605bb),
# a2: (0xbbd411ad350e6dd0, 0xbf68c833077fbeae),
# a3: (0x3c051eb6f09db1a0, 0xbf9aa0ce0421d1a8),
# a4: (0xbbec0fe78acda46b, 0x3f405fa598ef5d1d),
# a5: (0x3bff2085596ae957, 0x3f551d30d78ab526),
# a6: (0x3b92b31b33779fc9, 0xbef9c5807675c5f6),
# a7: (0xbb7cb5b0088841fe, 0xbeffc1bbf57e3ae2),
# a8: (0x3b3cc2b42d9f0f18, 0x3ea32dfea2518ce6),
# a9: (0x3b18c85914c086a7, 0x3e9bc212085dcbc6),
# a10: (0xbaed44a5431df5e5, 0xbe408b946d64c5c2),
# a11: (0x3ac14bfc6bd39224, 0xbe2fa8f9d8da736a),
# a12: (0xba679104007a668f, 0x3dd293fe14af1d0f),
# a13: (0x3a2b5ef4a8a2fdf9, 0x3db96544cb75a58d),
# a14: (0xb9d2b2107643b63f, 0xbd5d4750748e2ce8),
# a15: (0xb9d8369e87f01d71, 0xbd3e341812329072),
# c: [
# 0x3ce112aa495187a4,
# 0x3cbbb1656dc67703,
# 0xbc5ea7b98f478c96,
# 0xbc342cad7eaaf63a,
# 0x3bd5d798d87eadd3,
# 0x3ba7ec2199e9d0d9,
# 0xbb494f3573e03532,
# 0xbb178a4eaef852c1,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c4f5ffd019535e2, 0x3fc37dfa8f5a550a),
# a1: (0xb5469e936560cdf2, 0x38a958ea443705b2),
# a2: (0xbc5c4cd2161ee713, 0xbfb3775c1a04f09c),
# a3: (0x3bd3d562913301f0, 0x3f4e2b4810a46c60),
# a4: (0xbc1b976f3317abba, 0x3f79d151a72b83a8),
# a5: (0x3bbcef8b523f5a0a, 0xbf17d8e5a090e4e6),
# a6: (0xbbcb7ef16d9cb058, 0xbf2b49a6427386a0),
# a7: (0x3b59248209e494f4, 0x3ecac10957ddd2eb),
# a8: (0x3b424396e09f7470, 0x3ececa620745d3d3),
# a9: (0xbaf3438d41f60803, 0xbe6eefc7e795dcdd),
# a10: (0x3ae3b35ebff03a31, 0xbe658c5d2a0da41d),
# a11: (0x3aa0b413dedd34fc, 0x3e05d4721f44a8f9),
# a12: (0x3a892a275db60361, 0x3df481ce2314af59),
# a13: (0x3a3feec436d1ef8e, 0xbd94c0d3279e920d),
# a14: (0x3a19e07a129c683e, 0xbd7c3ea707530563),
# a15: (0x39a52b925c059e39, 0x3d1c61d5b165f7da),
# c: [
# 0x3cfd72bf189b67b3,
# 0xbc9d427a9769e9ee,
# 0xbc780c9653705699,
# 0x3c178e36fc02b9df,
# 0x3bef9a2c168b6442,
# 0xbb8e71f82f6f0229,
# 0xbb6111ac11e28162,
# 0x3b0025a92b5f22a5,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x353573a3312e9e2f, 0xb89445d98a4886cc),
# a1: (0x3c689d1f48185c7d, 0xbfc2f2072e638cf4),
# a2: (0x3c0f48257333accc, 0x3f64df208bbd44f1),
# a3: (0xbc282c4cf012e7ab, 0x3f992bb5e1e159fc),
# a4: (0x3bb5967313b48e4b, 0xbf3ba181c06897cd),
# a5: (0xbbea6566cfb06bee, 0xbf53fe9d5baa4a3d),
# a6: (0xbb98b4ff1892c880, 0x3ef5d17602b01cac),
# a7: (0xbb84f1d79d1c68d0, 0x3efe26d3747fe829),
# a8: (0xbb47899cac28d06d, 0xbea0509768ab6ecb),
# a9: (0xbb30edc18e594fda, 0xbe9a70f232d9d06c),
# a10: (0x3adf4967ed4b4059, 0x3e3c509252de33f9),
# a11: (0x3ac643cb92fae2ea, 0x3e2e454fee07116e),
# a12: (0xba7c2d5f536fab40, 0xbdd0015b062ba125),
# a13: (0xba43993ecbbb44ab, 0xbdb860e95adf840f),
# a14: (0x39fd1ca7896c45b2, 0x3d59691e90f7d9c0),
# a15: (0x39bccb74999a40d8, 0x3d3d1ce7997b3c0d),
# c: [
# 0xbcdddcd1c54cee54,
# 0xbcbacd10a03552dd,
# 0x3c5b043a7a089619,
# 0x3c3399ba2ef94a8a,
# 0xbbd3650fec070f68,
# 0xbba7538b0e0444f2,
# 0x3b46a2dce760f8a5,
# 0x3b1707ea3ba222e3,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc6b9fbd89653a0b, 0xbfc2768d29c69936),
# a1: (0xb4d7c66732a6b6ff, 0xb87dd3d74e2c76bb),
# a2: (0xbc592c5350d4d776, 0x3fb271811730b0ef),
# a3: (0xbbcd42067c3280dc, 0xbf49a8df96a1225e),
# a4: (0xbbde819659787fc8, 0xbf787c81cf1c6fc4),
# a5: (0x3ba0986868518e78, 0x3f14549cdbb77978),
# a6: (0xbbcc0c937839cf2f, 0x3f29ed2568116e19),
# a7: (0xbb638a1daff4bf5e, 0xbec6e4136f033ace),
# a8: (0xbb692b821c2e6f37, 0xbecd53330316cde7),
# a9: (0x3af82b5a8a9ea4e2, 0x3e6a983b5782dfca),
# a10: (0x3b0d6817ea51c39a, 0x3e64952ba7c5a1dc),
# a11: (0x3a858779f386d0c2, 0xbe02df3ad6f82e0d),
# a12: (0xba85be3593e2be88, 0xbdf3a70f9a89d2c2),
# a13: (0xba32f63410f44e43, 0x3d920e086c17f5dc),
# a14: (0xb9feeb5c5526cc87, 0x3d7b29a554c1159f),
# a15: (0xb9b6a518f14f6a06, 0xbd18dbe08f4a9f69),
# c: [
# 0xbcfc6bd9fc45c380,
# 0x3c99ce5a735b2911,
# 0x3c774ade0ebbb04a,
# 0xbc14eb88e02b008f,
# 0xbbeeb63f264071fb,
# 0x3b8b39319da680c5,
# 0x3b60a4325ae8cea6,
# 0xbafd11021ccd9833,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x35538f32e1119302, 0xb8b38c146367638f),
# a1: (0x3c51f9b16832f362, 0x3fc1ff5eec6a01cd),
# a2: (0xbc0f89ce0d1cb837, 0xbf61e438b722c3b5),
# a3: (0x3c39a4b7b3ed5b9c, 0xbf97ed5fffc1c774),
# a4: (0xbbdc35d9a8dca903, 0x3f37b7997babd9ca),
# a5: (0xbbe39da4066981e2, 0x3f53081def9612c5),
# a6: (0x3b8551b9a497b587, 0xbef2c5f5edafc4e9),
# a7: (0xbb9dbae692eab5c4, 0xbefcc11a59e13739),
# a8: (0x3b351580930803f1, 0x3e9c2c3a1b8014a3),
# a9: (0xbb333a214b9dbd87, 0x3e9946d1dab7bd01),
# a10: (0x3ad8fc5f68299917, 0xbe388db61946be64),
# a11: (0x3ac5620984f97781, 0xbe2d04d33be580e8),
# a12: (0xba6d7f1c30d157ba, 0x3dcbe64386d2c5d0),
# a13: (0xba48b7e9cdf3e557, 0x3db77142e0e4497b),
# a14: (0x39fe42ca4fdc0821, 0xbd56458476679697),
# a15: (0x39cde02178f2e8a7, 0xbd3c15e96b25adba),
# c: [
# 0x3cda545e6ec71d20,
# 0x3cb9f0a9b74e034e,
# 0xbc57f751eaad5944,
# 0xbc33083bfba900b3,
# 0x3bd14f7886799e5d,
# 0x3ba6b8756a3461e9,
# 0xbb44533c12e31411,
# 0xbb167fc01d26c703,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c54fa3fb220c497, 0x3fc194eba75b32f9),
# a1: (0x355d99c1354abe76, 0xb8bb0eec1c01864f),
# a2: (0x3c59f5fdd12caa11, 0xbfb190f7dc27362b),
# a3: (0xbbd96244746ca19e, 0x3f462bb47a5c5f7f),
# a4: (0x3c106edbe0bb689d, 0x3f7756ef20f5d2e2),
# a5: (0x3bb1231bc44f6f4c, 0xbf1198b0ba97ecfb),
# a6: (0xbbafcaf4935a1753, 0xbf28be8cf9358d55),
# a7: (0x3b341ada5c144f25, 0x3ec3dd6f7c8cc3c0),
# a8: (0xbb22797862876f1a, 0x3ecc09c80ee7f9af),
# a9: (0xbb04005395d49e07, 0xbe6728e46a451e32),
# a10: (0xbb056333198576a9, 0xbe63b91113508622),
# a11: (0xbaa195a6693f0d84, 0x3e0080fddad62bf8),
# a12: (0x3a8352e1bf38cbc8, 0x3df2e111e88dae1f),
# a13: (0xba2109236d67d661, 0xbd8fbae88bdab215),
# a14: (0x39fdc60e2c5c7d37, 0xbd7a2a4fbea868a8),
# a15: (0x39b8e39633481265, 0x3d15f540e9769e8b),
# c: [
# 0x3cfb74c0b2686df3,
# 0xbc96eb75a7dd13a3,
# 0xbc76910c1dc865c3,
# 0x3c12af36490b5c70,
# 0x3bedd7036ea48d55,
# 0xbb88734f1fdd1069,
# 0xbb6036af368c39fd,
# 0x3afa3fd8a11def51,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb545e51f723ab58f, 0xb8b848c0672fd956),
# a1: (0x3c6e71c482be67bd, 0xbfc12dd57bf18ada),
# a2: (0xbbe9a8a827c4a2d9, 0x3f5f1e1e7f393e83),
# a3: (0x3c3286f932bea2b1, 0x3f96d9afe88301fa),
# a4: (0xbbd360330deffaa0, 0xbf34a538a482979b),
# a5: (0x3bef838ddd540b10, 0xbf52316250b4ae37),
# a6: (0xbb94c13fb3eaf5ac, 0x3ef05f11577b4627),
# a7: (0x3b6771ef99211bf9, 0x3efb86bad42fc220),
# a8: (0x3b1a6b7e5cebbbf9, 0xbe98a1b3a9e92749),
# a9: (0x3b32d778489fadee, 0xbe983dcaf3f8fcc5),
# a10: (0x3abceef7b37a4149, 0x3e3589a7ca5fdcf1),
# a11: (0x3ac97ff4495956a3, 0x3e2be3ee3298bb99),
# a12: (0x3a6770b1a9ab05ca, 0xbdc8913f1d0ff12a),
# a13: (0x3a430c1f9492528a, 0xbdb695c386660813),
# a14: (0xb9fd8f50c7d974de, 0x3d53b25d364762e7),
# a15: (0xb9d664d160d01e33, 0x3d3b20c42e642ccd),
# c: [
# 0xbcd7650532b4f1e0,
# 0xbcb91f514b70b40b,
# 0x3c55661aac4dcfde,
# 0x3c327b48d9478b05,
# 0xbbcf11115f1e0760,
# 0xbba61f1bd02130ad,
# 0x3b4254646f0f97c7,
# 0x3b15f63be5634cd2,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc27736b1f56d701, 0xbfc0d0d36473e98c),
# a1: (0xb56a0fe87caaca31, 0x38c13529ba198546),
# a2: (0xbc517d3bbb8e7765, 0x3fb0cda9974abe2b),
# a3: (0xbbe2a43b589b2a06, 0xbf4367f38f201c25),
# a4: (0xbc17d1323005eae8, 0xbf7656b75e3c242e),
# a5: (0x3b94b9f5a7acb7e0, 0x3f0ed82abf7489f1),
# a6: (0xbbcb0bedf1c81293, 0x3f27b4e5b83eeb36),
# a7: (0x3b0621247626b31d, 0xbec171fd0fb670e7),
# a8: (0xbb638b7d64b281f7, 0xbecae62b4ad017fb),
# a9: (0x3b0b83d61a6ff725, 0x3e64648495a7b49e),
# a10: (0x3b05f0212db7e5c2, 0x3e62f42a577135ad),
# a11: (0xba76b0fd54cd9d6b, 0xbdfd286e7fa32656),
# a12: (0xba30ca02b11abb0f, 0xbdf22dbcbf76a1c7),
# a13: (0x3a27e83235238ba5, 0x3d8c222accc0d2d2),
# a14: (0x3a056929761e3d77, 0x3d793fc7f6c8d355),
# a15: (0x39bc237122bbb78d, 0xbd138c7e1f668eb4),
# c: [
# 0xbcfa8e4efc6deb62,
# 0x3c947e808eb72ce3,
# 0x3c75e0f075f73392,
# 0xbc10c866ba43aebc,
# 0xbbecffe1c0e02084,
# 0x3b86102f988e0a87,
# 0x3b5f96a57efd09fa,
# 0xbaf7cbac5fb57a91,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x35418d07eaf0b099, 0x38c1a9942c22535e),
# a1: (0x3c61a13e2fee5687, 0x3fc076826cc2c191),
# a2: (0xbbcb789ffb667f6a, 0xbf5b62885e0070c6),
# a3: (0x3c35dbe9d7210c2e, 0xbf95e7f53001e4b1),
# a4: (0xbbddb8eb1d2032f3, 0x3f322ebeb8dc2202),
# a5: (0xbbf72618e87154fd, 0x3f517444a7a04cd0),
# a6: (0x3b7b01e81c8c370b, 0xbeece06f1f1fcd7e),
# a7: (0x3b80168184fb2a2f, 0xbefa7006e6ad9cfe),
# a8: (0x3b13ac36b9efbb36, 0x3e95c42f02cf15ca),
# a9: (0x3b08b69b698a2f2e, 0x3e9750ca5e1366b4),
# a10: (0xbac08a205d6fbd29, 0xbe3314982df7eaa2),
# a11: (0x3abf2c98d7c5b0b0, 0xbe2aded75306b3b3),
# a12: (0xba2551d965dce664, 0x3dc5d47847d8ebf1),
# a13: (0x3a2b475ee50f9af1, 0x3db5ccf44d287a21),
# a14: (0x39d9490ac846b5f9, 0xbd518fce3e04028a),
# a15: (0xb9d525cc1707dd4e, 0xbd3a3d6bcad0c3fc),
# c: [
# 0x3cd4efbd76727c05,
# 0x3cb85a4b163fcc04,
# 0xbc5339ddeca79d0b,
# 0xbc31f48b47bc441a,
# 0x3bcc06bd6710b45b,
# 0x3ba58a1ad9e65448,
# 0xbb409abe2b8be0ee,
# 0xbb156e575d965e89,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c61a6e02553980e, 0x3fc02455675ab6d2),
# a1: (0x353f95dac941c8b7, 0x38b4bb152f35a087),
# a2: (0xbc5a58b3083e7e3d, 0xbfb021c155a720df),
# a3: (0xbbea19c1039d30b9, 0x3f412be56fc1449a),
# a4: (0x3c01bad3e8f9abb9, 0x3f75749d556ad61c),
# a5: (0xbb75621370147e19, 0xbf0b51f1f9bea93e),
# a6: (0x3bc81ccb29b6a850, 0xbf26c96a07e236bd),
# a7: (0xbb218064e9ecad18, 0x3ebef3a7abd5ac6b),
# a8: (0xbb6f6ed0aeaecba5, 0x3ec9e207c257433a),
# a9: (0xbaf0aed16a933271, 0xbe6220b96eef8058),
# a10: (0xbad4d7e3d546f2c4, 0xbe624317cb296737),
# a11: (0xba91f73fb3d22bec, 0x3df9fc2f2cd3917f),
# a12: (0x3a9403e6cf9143a4, 0x3df18ae8347e8256),
# a13: (0x3a2f17c7d5411c24, 0xbd892540423f2dda),
# a14: (0x3a04a4080028f5b2, 0xbd78687dcdc2e3a9),
# a15: (0x39a201bd34791754, 0x3d1187909103d474),
# c: [
# 0x3cf9b8362872c324,
# 0xbc92711ecdaaeca0,
# 0xbc753b342a24814e,
# 0x3c0e50eba2ee4760,
# 0x3bec32aa5f596a61,
# 0xbb8400cf17d2fcd4,
# 0xbb5ec6ef456ce7f9,
# 0x3af5a82ff0aad8bc,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb555c8c81444cce9, 0x38b9b5971f998214),
# a1: (0x3c5d7cc41717159f, 0xbfbfa8b41711c83a),
# a2: (0x3bf6219a48a25ba2, 0x3f5857d3969997d1),
# a3: (0xbc395ccf34fc85bb, 0x3f9511c6dadaaa12),
# a4: (0x3bd13cc55ae24368, 0xbf302c289dbdbd4f),
# a5: (0xbbde8aacf9357450, 0xbf50cc2238d229f9),
# a6: (0x3b831f1c91d27574, 0x3ee9b64d5c63668f),
# a7: (0xbb967f7ad529fbab, 0x3ef976fb023f0f79),
# a8: (0xbb26431725df20f1, 0xbe93693ba0b5ba70),
# a9: (0xbb30bc5202714831, 0xbe967b952987350c),
# a10: (0xbadfac3d160cee71, 0x3e310cb79a2addac),
# a11: (0x3abbc10a636cca3b, 0x3e29f2079f8e397f),
# a12: (0xba6f1f3686791203, 0xbdc38d957eaa53ad),
# a13: (0x3a5a464b4d5f0cbc, 0xbdb51511e93ba74c),
# a14: (0xb9d76cb5fc51dd5d, 0x3d4f8bb4d9d2f3a4),
# a15: (0x39d5f6bc31063164, 0x3d396afe82155a3c),
# c: [
# 0xbcd2dc3c5a412fc9,
# 0xbcb7a1c8dec76ff7,
# 0x3c51600c3d779ccc,
# 0x3c3174c64bf0b16a,
# 0xbbc969e37524ef7d,
# 0xbba4faf03e3cc2d6,
# 0x3b3e37a63e276939,
# 0x3b14e9f8e51a9731,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c50e4250a158a22, 0xbfbf161d0c28b48c),
# a1: (0xb5457b141b3f0d22, 0xb8b05b0583668356),
# a2: (0x3c421e360c4c70dd, 0x3faf11d837aa6f64),
# a3: (0x3bd18f48c3547c32, 0xbf3eab76da4d07a0),
# a4: (0x3c1ebe3b9893ac4d, 0xbf74ab329f067aea),
# a5: (0xbb5e80c3b0d6f5db, 0x3f086ada57bc1c51),
# a6: (0x3bc03960ef6e6bc0, 0x3f25f6e78f11ab9a),
# a7: (0x3b5e77180c5644f0, 0xbebbb271f54c8965),
# a8: (0x3b5cfd1d7da5a2ed, 0xbec8f85328c26cb7),
# a9: (0x3b05a5d710343232, 0x3e603f82aebdeac1),
# a10: (0x3b008f5133b080de, 0x3e61a3010279a195),
# a11: (0x3a8746b6f6e07b6a, 0xbdf75660809cdedf),
# a12: (0xba824b566432a315, 0xbdf0f6931774a05f),
# a13: (0xb9f3c0bb6b052f1a, 0x3d86a2e61267070b),
# a14: (0xba1950de7a0ba4a4, 0x3d77a2a8e0311c3a),
# a15: (0xb9a048f7d1f2b255, 0xbd0fa4c8e3ce0140),
# c: [
# 0xbcf8f1926f4e33ae,
# 0x3c90b165b2615bc8,
# 0x3c749fd329a93d0d,
# 0xbc0b864a393597be,
# 0xbbeb70236cfe6bd7,
# 0x3b823801bcba96ad,
# 0x3b5dffc2deb31091,
# 0xbaf3c9fe3b84a659,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x355635d4f1de5ba1, 0x38be9421c32bac67),
# a1: (0x3c0020b4016594ac, 0x3fbe8727daa3daed),
# a2: (0xbbea4d873618788c, 0xbf55d353e2854a37),
# a3: (0x3c3361836c532513, 0xbf94524d4813cc25),
# a4: (0xbbb70735fa989566, 0x3f2d037574e28370),
# a5: (0x3bf7f1d7c0f30b40, 0x3f50356bb747a763),
# a6: (0x3b73015c07f2d91c, 0xbee7156bfccef376),
# a7: (0xbb99523f4f9b360a, 0xbef896d7dc819faf),
# a8: (0x3b307f0e451ebc29, 0x3e9172c6dadf4149),
# a9: (0xbb334d6933f971d7, 0x3e95baae8efc2e31),
# a10: (0x3aba01d72c453107, 0xbe2eb347eb4d6941),
# a11: (0x3acc3dd30f660e50, 0xbe291a60a72a20e0),
# a12: (0xba0f68f511402aa1, 0x3dc1a345a9a6a5f7),
# a13: (0x3a3173892dc95a65, 0x3db46c56b01906be),
# a14: (0x39d1db37247899b5, 0xbd4c84bb37677838),
# a15: (0x39de56935f64b194, 0xbd38a83e6e4c168c),
# c: [
# 0x3cd11796d017a52b,
# 0x3cb6f5675cf3bead,
# 0xbc4f936d06630983,
# 0xbc30fc2f8042c9fa,
# 0x3bc7281c276f90d6,
# 0x3ba4725b73c87823,
# 0xbb3b9d22918ceebb,
# 0xbb146a436f16dfe0,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc5b4c98f0d3c4c3, 0x3fbe0357c158b119),
# a1: (0x356f8923942baa28, 0x38ca791244af7fb5),
# a2: (0xbc410072ccb88631, 0xbfadffc2fc1a91f5),
# a3: (0x3bd769e0c0dbfe0f, 0x3f3b9b82ae07da44),
# a4: (0xbc02d8dbfa194097, 0x3f73f64e05320ac6),
# a5: (0x3bafe44f6e4f7a72, 0xbf05fe4b66cf19d9),
# a6: (0xbbc540e88468d2a6, 0xbf2539518e1b00f5),
# a7: (0xbb397c60f4bd9fdd, 0x3eb8f8d01c487905),
# a8: (0xbb5e1765287d55c9, 0x3ec825045b97e2dc),
# a9: (0xbad349d279137fb0, 0xbe5d565f3bb61dea),
# a10: (0x3af6ef17211ae45b, 0xbe611186586f4f74),
# a11: (0x3a9d5c753068eef9, 0x3df51a669158191b),
# a12: (0xba9c8af441d79379, 0x3df06ef52f6715ac),
# a13: (0x3a0be37a7ebfa585, 0xbd848215e95caa77),
# a14: (0xba12aea2c5547dd9, 0xbd76ec8422019b0d),
# a15: (0xb995ce432bf4ea48, 0x3d0cbaf5fc139339),
# c: [
# 0x3cf8393ffa4f5afc,
# 0xbc8e6232fb7e093c,
# 0xbc740e69bcb200c9,
# 0x3c091cd1de02ebf5,
# 0x3beab86d72560db8,
# 0xbb80aa949dd60552,
# 0xbb5d41db239438ed,
# 0x3af2270328ec903d,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb53793a2093de94e, 0x38b46acaa2db12e5),
# a1: (0xbc5cb1f28997ca39, 0xbfbd8293aa55d18f),
# a2: (0xbbd0e0b711c0f05f, 0x3f53b6beb83f2596),
# a3: (0x3c36c091c5e2bd3a, 0x3f93a5ccbc12a67b),
# a4: (0x3bc80bb5066b1ab2, 0xbf2a3765d26aa42b),
# a5: (0x3bc464654b3f4247, 0xbf4f5ab33748c215),
# a6: (0xbb86c3ad1bc53ee6, 0x3ee4df6f1c257a5c),
# a7: (0xbb9372510d6e3ed7, 0x3ef7cbd49c315be0),
# a8: (0x3b1dfc7e29b94b01, 0xbe8f96098cf07175),
# a9: (0x3b0aec3564d78715, 0xbe950b37dd43531f),
# a10: (0x3aaa5efe8cd0d0b6, 0x3e2bd2e6405c605d),
# a11: (0xbab9fdafce391124, 0x3e285530df0d4b70),
# a12: (0x3a6ec037594c88d7, 0xbdc0029e21930f25),
# a13: (0xba5f6bee6aa06bbf, 0xbdb3d11aeba731a1),
# a14: (0xb9ee33d66b9efc7b, 0x3d49ef077e065d17),
# a15: (0xb9c765f6255cb3d1, 0x3d37f3d211d80ca6),
# c: [
# 0xbccf2617ced04ef8,
# 0xbcb654785f90474e,
# 0x3c4cd5d490baf361,
# 0x3c308aa98d1885fa,
# 0xbbc53243b8f4a2cf,
# 0xbba3f0a1e04e0f85,
# 0x3b39568fa5547980,
# 0x3b13efd3e10a8fae,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc57ac02118ce035, 0xbfbd0b36e5737458),
# a1: (0xb510255e31430033, 0x38bc78c490092f41),
# a2: (0xbc494ec699987c68, 0x3fad082ce3c6b59b),
# a3: (0x3bdbdb6b7d6d9eda, 0xbf3905d00c5e6800),
# a4: (0xbc14d8fddd68c49e, 0xbf7352b073fdac7b),
# a5: (0x3ba8a390eb7c2b90, 0x3f03f1ccfec2fc88),
# a6: (0xbb8f7492cb6fd0c2, 0x3f248d74583834bc),
# a7: (0x3b536c4ae37b379b, 0xbeb6a9ef0d896bae),
# a8: (0xbb686d0e0d1bf502, 0xbec764d9798d6a80),
# a9: (0xbaf460a4621e0350, 0x3e5aa785d6736f5c),
# a10: (0x3b035fd3f6a4b201, 0x3e608cae36118cdb),
# a11: (0x3a9d857819eb2175, 0xbdf332ddfb39cd01),
# a12: (0x3a737fa058aa2bf7, 0xbdefe502ff1a8f0d),
# a13: (0xb9e58926244b72c7, 0x3d82afc83348eeb2),
# a14: (0x3a12be94371e2b15, 0x3d764468c0a31511),
# a15: (0x39a6e4a5223f4daa, 0xbd0a399e849c3f2a),
# c: [
# 0xbcf78e09772ae1e8,
# 0x3c8bc9dea67a7451,
# 0x3c738663e180417d,
# 0xbc07042a23846065,
# 0xbbea0b467e151132,
# 0x3b7e9e53f034f206,
# 0x3b5c8d6dc762abf8,
# 0xbaf0b68e9fe150d5,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb54bdfd7a08d53ee, 0xb8a032fe7cac75b4),
# a1: (0xbc49df1f0f8d2108, 0x3fbc96700bf039e2),
# a2: (0x3bd298b7ed2d1706, 0xbf51ec0b5de4befe),
# a3: (0xbc26397704521ddc, 0xbf93095734a24496),
# a4: (0xbbbe43e747e8c9ce, 0x3f27d74e12285cb2),
# a5: (0x3bbff97a4e7e808e, 0x3f4e636fe259352c),
# a6: (0x3b74153b68748e9f, 0xbee2fe11972bc0c6),
# a7: (0x3b833d879080abe8, 0xbef712e4d44c4a74),
# a8: (0xbb0f13d052064a04, 0x3e8cc3adabae0452),
# a9: (0x3b2bb2db97d7803d, 0x3e946ad2d9cbeb5c),
# a10: (0x3aba42349462615d, 0xbe295d81ae83f621),
# a11: (0xbab425671ce4734e, 0xbe27a02aefea3d60),
# a12: (0xba5a8cbe0759645c, 0x3dbd3a949a72239d),
# a13: (0xba589ce4399c7b24, 0x3db341e0bb193b49),
# a14: (0x39c60f1c6ee12744, 0xbd47b550a4f77497),
# a15: (0x39b9524731c89f49, 0xbd374c654a2656ac),
# c: [
# 0x3ccc861736a2cb66,
# 0x3cb5be2db467cb27,
# 0xbc4a7433021b81a9,
# 0xbc301fe901a012cf,
# 0x3bc37bf8ae8852f8,
# 0x3ba375bd0bad91a1,
# 0xbb37570ac69055a0,
# 0xbb137aed9b4389e6,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c2c279ff462c3c0, 0x3fbc29ae8400a320),
# a1: (0x356543134310e8c5, 0xb8c57225c95bf1fd),
# a2: (0xbc47ac9bcf34430d, 0xbfac27138da31c2b),
# a3: (0xbbbe5ab192b01365, 0x3f36d141fcbea853),
# a4: (0x3c12b724fd75b152, 0x3f72bdc71062acd6),
# a5: (0x3baf5f2a5ef8fa69, 0xbf0231cf643ffc17),
# a6: (0x3b6e53f54e3bf9fc, 0xbf23f0bf3b3fe8be),
# a7: (0xbb4cfe2b683d9566, 0x3eb4b05e955de175),
# a8: (0x3b6d19f537fcf89e, 0x3ec6b52b868fa5e2),
# a9: (0x3afd6a6cb52830e5, 0xbe585a7aa3e84cc3),
# a10: (0x3afd15d476513524, 0xbe6012d3384c9164),
# a11: (0x3a5b65df2e4e4329, 0x3df18f8c4872544f),
# a12: (0xba81d06080a51e9d, 0x3deeffc4029f2f06),
# a13: (0x3a249fcb796b8760, 0xbd811d5a3daf70fa),
# a14: (0x3a00e5fc84cbd7df, 0xbd75a8d84ce12a33),
# a15: (0x39aac0f727b50a5d, 0x3d080dfa27f213b4),
# c: [
# 0x3cf6eec07f1e9fec,
# 0xbc8987d6f3b6b977,
# 0xbc7307196963d25a,
# 0x3c052f0ef3a48696,
# 0x3be968357fda6847,
# 0xbb7c3bf907642446,
# 0xbb5be25cb690eabc,
# 0x3aeee27d7ef3ffbf,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb5509faad40c4610, 0xb8b9d9a58cfbeaef),
# a1: (0x3c58fff4515190b4, 0xbfbbbf246914235f),
# a2: (0xbbb59d638f727e7a, 0x3f5062daee35411a),
# a3: (0x3c1bef9e896a9a49, 0x3f927a96f174b6d1),
# a4: (0x3bc79c688e785f38, 0xbf25cdb5dea9c121),
# a5: (0x3bd1f78082ebf798, 0xbf4d818348f98a0f),
# a6: (0xbb8cf93ea6c33ca2, 0x3ee160aab829409d),
# a7: (0xbb9dfe5ed028776c, 0x3ef6698d6ee99eb9),
# a8: (0xbb0db3033371a008, 0xbe8a5633d8f0b3bf),
# a9: (0x3b3148bb33e218be, 0xbe93d788d61154a7),
# a10: (0xbabbfbbbe3dfb01e, 0x3e273ec2ae0084b9),
# a11: (0x3a5bb0a123073439, 0x3e26f958f6235deb),
# a12: (0x3a36a5b33f99627b, 0xbdbad0939c43a9fe),
# a13: (0xba4257e147ffea34, 0xbdb2bd56309cf195),
# a14: (0xb9e2488ea9163776, 0x3d45c709d717f2e4),
# a15: (0xb9d93a6f276892ca, 0x3d36b0b8fe737496),
# c: [
# 0xbcca3cece6eae9d2,
# 0xbcb531b157cc8876,
# 0x3c485f3495a556d8,
# 0x3c2f771622298661,
# 0xbbc1fb1e956ae1b5,
# 0xbba30179264b3e35,
# 0x3b3593d8b3319ae6,
# 0x3b130b99b87c3b96,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc4b1bd5a08c4698, 0xbfbb5b8273b75055),
# a1: (0xb548ca14643a6631, 0xb8b8573433fec47d),
# a2: (0xbc19066393ec82d2, 0x3fab59418c36a684),
# a3: (0x3bd4c6e4a4b62a00, 0xbf34eafeaa92aa79),
# a4: (0xbc1e8c2463f82478, 0xbf7235801af9be44),
# a5: (0x3b9bcf2d21045070, 0x3f00af9747d0be92),
# a6: (0xbbaf406893c94aca, 0x3f23611db0e1566f),
# a7: (0xbb5fa294e3a6cf60, 0xbeb2fbe414da1250),
# a8: (0xbb6579c1dd810ff2, 0xbec613ccbb9cbe59),
# a9: (0xbafba31f9ef26cbc, 0x3e565cf274e84d31),
# a10: (0xbae9213eec3645d6, 0x3e5f452996e3dc2b),
# a11: (0x3a93719707a6b399, 0xbdf023f5382da3ad),
# a12: (0x3a83d3a0c57bd4cc, 0xbdee2be24fbad63f),
# a13: (0x3a1e0d9a1a424f50, 0x3d7f7ed3740f8cf5),
# a14: (0xba195448240988bf, 0x3d75187e998a1997),
# a15: (0xb9a83d289fab0c85, 0xbd06293c9e781b76),
# c: [
# 0xbcf65a49786c4515,
# 0x3c878dbf02334229,
# 0x3c728fde2c70ddb6,
# 0xbc0392b8f6167154,
# 0xbbe8cea59f44a3e3,
# 0x3b7a213dbaca9263,
# 0x3b5b40576765c08d,
# 0xbaeca1b39264a34c,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x35534d172ad7c725, 0x38babc7d343ffcff),
# a1: (0xbc5024304247ada4, 0x3fbaf9cb49c4f935),
# a2: (0x3bd43675d81a38ce, 0xbf4e1d930b513228),
# a3: (0xbc26b1ae600584f3, 0xbf91f7a8fec6eba8),
# a4: (0xbbccaafb65ee5664, 0x3f240a55310866fc),
# a5: (0xbbe93eb318fc691b, 0x3f4cb20c812fd3aa),
# a6: (0x3b7bc11f6acb6ae2, 0xbedff51953c6b6cc),
# a7: (0x3b7ca6d60de07627, 0xbef5cdc48f5d75eb),
# a8: (0xbb1e5c798f5702b7, 0x3e883b091952c721),
# a9: (0x3b392f384e40f60e, 0x3e934fb685e58ab7),
# a10: (0x3abc9afeb4201719, 0xbe2566fc4369ab71),
# a11: (0x3ac8555b1f6751cb, 0xbe265f0f7de29720),
# a12: (0x3a505976fb73241e, 0x3db8b61e5f9b7a00),
# a13: (0xba04a898dd824082, 0x3db24253069b78a9),
# a14: (0x39bb5929dac6afd8, 0xbd441732d722b422),
# a15: (0xb9d662b0ae22d5ef, 0xbd361fa985a16926),
# c: [
# 0x3cc83c175673059e,
# 0x3cb4ae32974df1c5,
# 0xbc468a7f73f5be7d,
# 0xbc2eba46ae458bcd,
# 0x3bc0a770636ddc80,
# 0x3ba29388d9fcba28,
# 0xbb34040dedb7bebf,
# 0xbb12a1bc8335b315,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c5ffacf3e2418f7, 0x3fba9e13a0db6429),
# a1: (0xb5360d8e3fbefaa2, 0xb8a1caa984239a44),
# a2: (0xbc305f5aef327444, 0xbfaa9c1ca2161b9b),
# a3: (0xbbd5ab98ac97fae4, 0x3f3344a09efdc635),
# a4: (0x3be8bf0e556cf4b8, 0x3f71b82c430a2381),
# a5: (0xbb93a9945508473a, 0xbefebfb97bca01f2),
# a6: (0xbb99136a1ed7b5fa, 0xbf22dcdb1bc1d038),
# a7: (0x3b5ea30ecc612717, 0x3eb180047f0b79ae),
# a8: (0x3b46ae074e2d9e22, 0x3ec57eeeee84d0d0),
# a9: (0xbadb1941bb0e0bc9, 0xbe54a0c699c8318b),
# a10: (0x3adc2d735741fdde, 0xbe5e7594e8a2c760),
# a11: (0xba8de62221d00ec7, 0x3dedccbbb4c0ba7f),
# a12: (0x3a8cf847ee673437, 0x3ded6766337b5c95),
# a13: (0xba0200bd41d3e523, 0xbd7d1a05cea18a02),
# a14: (0xba1f3622c8b76f5f, 0xbd74922fb50a29f1),
# a15: (0xb99416959af186e4, 0x3d047fa35bf627ce),
# c: [
# 0x3cf5cfa087122294,
# 0xbc85d009937bf5ac,
# 0xbc72200b01fdbf9d,
# 0x3c02265f004c1d48,
# 0x3be83df71ae8ab7a,
# 0xbb7843800001ddf6,
# 0xbb5aa6f0e2f25141,
# 0x3aeaa04878c515a9,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb564665fe6c93993, 0xb8c719f487108c6e),
# a1: (0xbc55d35a88f1e0a3, 0xbfba4407e04298d1),
# a2: (0x3bdf6dddc07add6d, 0x3f4bcc9df0cf00b2),
# a3: (0xbc3c3cb8ccc39cf2, 0x3f917f0266db2149),
# a4: (0x3ba3d974ad0c21e7, 0xbf2280a052234a05),
# a5: (0x3bb902b669103937, 0xbf4bf2ada1f44071),
# a6: (0xbb64ad3fa1509166, 0x3edd83d58032b48d),
# a7: (0x3b3d6efd04461269, 0x3ef53dd972d8f232),
# a8: (0xbb230c11b6006895, 0xbe8663c1fe202028),
# a9: (0xbb26dbba4ce8bd7e, 0xbe92d1fbf2203ff6),
# a10: (0x3ac866e6e348b7b9, 0x3e23c9f0b759c5f9),
# a11: (0x3ac489ff33dfce8f, 0x3e25cfe1b012696d),
# a12: (0x3a4981337ac79655, 0xbdb6ddc0795781e9),
# a13: (0xba4b13e076398cc3, 0xbdb1cfd49504266a),
# a14: (0x39edb765a45cfad6, 0x3d429b7af5214fbc),
# a15: (0x39bd594b3ede144a, 0x3d3598302ab3ac8a),
# c: [
# 0xbcc677f6a604ab43,
# 0xbcb432ecc122bbc4,
# 0x3c44ec114bfb6bf7,
# 0x3c2e0887f8c2f57d,
# 0xbbbef44a37f84f12,
# 0xbba22b91f5f4449b,
# 0x3b32a03f80301aa1,
# 0x3b123d23f8f7ad2e,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c423404089aea01, 0xbfb9ef3bb2213b0b),
# a1: (0xb5113e62cb830a3e, 0xb8c2d44e50225df3),
# a2: (0x3c342c5cb51f2b57, 0x3fa9ed82007a9a45),
# a3: (0xbbad41b75b8a8d9b, 0xbf31d2fdeeb29f8a),
# a4: (0x3c189945952fed1e, 0xbf71446866ff1b83),
# a5: (0x3b94bf0ff761bac5, 0x3efc73b684f93259),
# a6: (0xbbc79edfb80bfc5e, 0x3f22628de594b6c9),
# a7: (0xbb2bef93c666f49f, 0xbeb03303c1427449),
# a8: (0x3b69194ecd6aac53, 0xbec4f51007c51087),
# a9: (0x3af53d1fa2147ee0, 0x3e531adfa36f2213),
# a10: (0xbafbf005f05fcc98, 0x3e5db4f306b19095),
# a11: (0x3a88f72949d1398c, 0xbdeb9e33598f899e),
# a12: (0xba8457c3274ebd5a, 0xbdecb09ed6ecb896),
# a13: (0xba159f6f24f89872, 0x3d7afe1183148a99),
# a14: (0x3a11bfaf9fbcb95f, 0x3d7414e442aa8d57),
# a15: (0x39ae38a755a019da, 0xbd0307c129418397),
# c: [
# 0xbcf54ddabca7b72a,
# 0x3c84455c62381678,
# 0x3c71b70264da382c,
# 0xbc00e2cfa963d4c6,
# 0xbbe7b5896de3457c,
# 0x3b7699efca5cd8c7,
# 0x3b5a15ae188cedc6,
# 0xbae8d5720aed06a7,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb507a3fe0e95f092, 0xb8bd8f3ad463fd69),
# a1: (0x3c5728ab934a269f, 0x3fb99be744018c90),
# a2: (0xbbdb8852614fe887, 0xbf49c3f52a2af724),
# a3: (0xbc2f281d89ca12e4, 0xbf910f5ca51f98b0),
# a4: (0xbbc3c6681ac39dae, 0x3f2126c8e8ca2766),
# a5: (0x3babb471b2b6cf3e, 0x3f4b416f7d4fc313),
# a6: (0xbb677b33eb16ceb5, 0xbedb5e2e5580e1ce),
# a7: (0xbb988d4663776f74, 0xbef4b862279de756),
# a8: (0xbb2b43c42f7f04b9, 0x3e84c5071b39dc13),
# a9: (0xbb3de6264de806d8, 0x3e925d2fc3b19021),
# a10: (0x3ac879393dd83f24, 0xbe225df322279972),
# a11: (0xbac3ec23ad6e970a, 0xbe254a971eb6fe3b),
# a12: (0x3a5048109b74bd8d, 0x3db53cc6c9922f2b),
# a13: (0xba43610ec595546f, 0x3db164f95180d8c1),
# a14: (0x39e236638a339574, 0xbd414b9ef404ed89),
# a15: (0x39d5e32a69772db7, 0xbd3519623b4e50ac),
# c: [
# 0x3cc4e7271a71f23c,
# 0x3cb3bf2a1b859197,
# 0xbc437bc0d8e44b84,
# 0xbc2d6104b94c47d8,
# 0x3bbcdb4b3544bc7f,
# 0x3ba1c93567462ab9,
# 0xbb31623ef293806f,
# 0xbb11dd917bc85327,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc54096ec8637e04, 0x3fb94d3276914e51),
# a1: (0x3538aa8ed3b4cf1a, 0xb8b1a9f8a8304b37),
# a2: (0x3c4baee1d6c0d38a, 0xbfa94bac1950e319),
# a3: (0x3bdbfe3ad50b1c09, 0x3f308d4ff8f2059e),
# a4: (0xbc1cca1c2770b226, 0x3f70d90d29bfeecd),
# a5: (0xbb987fee6225f406, 0xbefa6d56162f7fb4),
# a6: (0xbbc7e723313bf861, 0xbf21f107da23807d),
# a7: (0x3b42cbddeb0fac98, 0x3eae1a626277437b),
# a8: (0x3b665fad37433b78, 0x3ec474eafd0cc642),
# a9: (0x3acb91aaa2286dd9, 0xbe51c27144f42d78),
# a10: (0x3af7189d5fa17edf, 0xbe5d01999b1a4fe9),
# a11: (0x3a35f0e0348c76d3, 0x3de9b014801da87a),
# a12: (0x3a8958b840cda80a, 0x3dec061740bc8a45),
# a13: (0x3a16875708b7d88f, 0xbd791f8c2972547e),
# a14: (0x3a1c0289b9700b83, 0xbd739fb558b7aa4d),
# a15: (0x39a9d6b95b5ce531, 0x3d01b9f74d47b35f),
# c: [
# 0x3cf4d425557e1f1c,
# 0xbc82e617ae27952e,
# 0xbc715432898c29d0,
# 0x3bff843f6347963f,
# 0x3be734c130fc648e,
# 0xbb751d395949afbd,
# 0xbb598c0f03028f01,
# 0x3ae739cc4684a5bc,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x352d3f2882952335, 0xb8852fc1696745c4),
# a1: (0x3c5e213a1a4b3671, 0xbfb8ffc9bd24fe08),
# a2: (0x3be5e8a5d70cf558, 0x3f47f7d46ab33721),
# a3: (0x3c2f532ddb23dab3, 0x3f90a7a725d3fbc4),
# a4: (0xbbb3f089aa8f2ae1, 0xbf1fea1728f216b4),
# a5: (0xbbdf63ef3319327d, 0xbf4a9cac69f0ed64),
# a6: (0x3b78f775cf86e9c7, 0x3ed977f48ff1056b),
# a7: (0x3b8a77447ea6fe43, 0x3ef43c2d8e698c10),
# a8: (0x3b293f5e91559671, 0xbe8355d1a6765ea6),
# a9: (0x3b177401cf3aa17c, 0xbe91f0553501d121),
# a10: (0xba823a3e8101b9ca, 0x3e211b47f6a44829),
# a11: (0xbaa6a02fffa2b5eb, 0x3e24ce23303889a9),
# a12: (0xba42b03ad2eec176, 0xbdb3ca98df62221f),
# a13: (0xba50afdcc563be7a, 0xbdb100fc746529d7),
# a14: (0xb9edcbe05d10e11a, 0x3d4020f11e2dca08),
# a15: (0xb9da9e6748bc0beb, 0x3d34a26ef2219c2c),
# c: [
# 0xbcc38203ff52c747,
# 0xbcb35244c153aa2a,
# 0x3c4232dbbbea35fa,
# 0x3c2cc2f30d7e4a86,
# 0xbbbafaa22e04387b,
# 0xbba16c1420a026bc,
# 0x3b3044e17b70797e,
# 0x3b1182c036f66e44,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c4123b2f0e7c9dc, 0xbfb8b67a2481077d),
# a1: (0xb554ea83bc7afbd2, 0x38c185a68fae71b3),
# a2: (0xbc4b4ca91be60b3f, 0x3fa8b51f21068ea2),
# a3: (0x3bb25eeb0c780ce8, 0xbf2ed935c7aefa31),
# a4: (0xbbf1e97629a4fbd3, 0xbf707522a5037f2d),
# a5: (0x3b9aa02b2936e0e1, 0x3ef8a196061f8bbc),
# a6: (0x3bc503ddcb9034df, 0x3f21874a47e3c1e3),
# a7: (0x3b255f9307a25e7f, 0xbeac10cf34c04f17),
# a8: (0xbb5b1d5a1969a1b0, 0xbec3fd6c2d4fa2a4),
# a9: (0xbaeb932c5947d655, 0x3e50906d55522785),
# a10: (0xbabb5acdea3816e3, 0x3e5c5a1c124dfa08),
# a11: (0xba561fcb9b3ed17b, 0xbde7f883b31a5f59),
# a12: (0xba75531c808efbb8, 0xbdeb668cf53028e4),
# a13: (0x3a104761ec9ef342, 0x3d7775372d05b25d),
# a14: (0xba0f2cfa85a363c6, 0x3d7331d871d677e0),
# a15: (0xb9a6539a2342e3b2, 0xbd009010248989d3),
# c: [
# 0xbcf461c4067c742d,
# 0x3c81abf993696e77,
# 0x3c70f715fa383b8a,
# 0xbbfd7ed2f30db038,
# 0xbbe6bb0b4da7d6b8,
# 0x3b73c73f0e157e5b,
# 0x3b5909945c395946,
# 0xbae5c71cc3e16dfe,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xb54a740fe50fa555, 0x38a27e3681fe12ca),
# a1: (0x3c5b1c9821974147, 0x3fb86e51be0a9153),
# a2: (0xbbeaa494385dab37, 0xbf465ed1b387e5da),
# a3: (0x3c09cfc1363faa0e, 0xbf9046fc5a218a86),
# a4: (0x3bbf17fc55a88ba0, 0x3f1dca617fefa913),
# a5: (0xbbe411ddd3f224d8, 0x3f4a0300221528a7),
# a6: (0xbb35922d57d34f7d, 0xbed7c7618906f1e2),
# a7: (0x3b985c37a3fcd2c9, 0xbef3c838897d0a1e),
# a8: (0xbb1cfc9e9ef07542, 0x3e820ede9f9dd7dd),
# a9: (0x3b3d338a91461c92, 0x3e918a94165592bb),
# a10: (0x3ab91bf2c08f3e73, 0xbe1ff76205118f09),
# a11: (0x3ab5cfc207f32cd6, 0xbe24599dfeef01a1),
# a12: (0x3a40b7bcb17c141e, 0x3db2803e59983134),
# a13: (0xba1b8c9ffd59054b, 0x3db0a33202feb043),
# a14: (0x39bbb27b9c04cfa9, 0xbd3e2bff738680f8),
# a15: (0xb9daf156baca0aef, 0xbd34329cf32bcb6e),
# c: [
# 0x3cc2424890fb6cfa,
# 0x3cb2eba657649d9a,
# 0xbc410bda49bebe27,
# 0xbc2c2d96d94f34d7,
# 0x3bb94a9b8509dda4,
# 0x3ba113d205a63be0,
# 0xbb2e87a2990f48e9,
# 0xbb112c694684c14c,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3c48caabfef07d2c, 0x3fb829d06fee9266),
# a1: (0xb547dbd5a5623558, 0xb8c2d5a6dd062143),
# a2: (0xbc46f7f245223686, 0xbfa8289a526d7785),
# a3: (0xbbbd55f59362110c, 0x3f2cd680355c9eb6),
# a4: (0x3c19dafafbc85033, 0x3f7017d70f512861),
# a5: (0x3b94ef924915594f, 0xbef707978e2a0db8),
# a6: (0xbbb84f6dd554027b, 0xbf21247ce15e7385),
# a7: (0x3b3c1549321f5893, 0x3eaa3f6125485ec1),
# a8: (0xbb6485c950af11e4, 0x3ec38da848401be9),
# a9: (0xbae81c7e658ccb43, 0xbe4efe39d8db4cd8),
# a10: (0xbaf106727152dad3, 0xbe5bbd40f1db0e94),
# a11: (0x3a7e01f9c4e4c0e1, 0x3de66f7d49436f83),
# a12: (0xba6a9de5073f8785, 0x3dead0e8148229b3),
# a13: (0xb9edea6b298d9cb0, 0xbd75f78595133d0b),
# a14: (0x3a0ffda12b15058b, 0xbd72ca9bb10321b3),
# a15: (0xb995d841a594fd99, 0x3cff09e49c887e91),
# c: [
# 0x3cf3f60eeb66f746,
# 0xbc8091d689cc53d4,
# 0xbc709f335e86201a,
# 0x3bfbad342a8e077c,
# 0x3be647de871fcae9,
# 0xbb7292e087988121,
# 0xbb588dc30bd642e3,
# 0x3ae4781fefecc3ab,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0x3552ab3e13b3068d, 0x38ba0483c1f34e39),
# a1: (0x3c21907f595a0829, 0xbfb7e656efb009ae),
# a2: (0x3bea53822a52d92c, 0x3f44f15066f3d876),
# a3: (0xbbef8f1c9736150f, 0x3f8fd932c26aad94),
# a4: (0xbba4e6bbdf1f4ff7, 0xbf1be460dd86a0a4),
# a5: (0x3bdda15b3eedcfa3, 0xbf49733b591879f8),
# a6: (0x3b7b0e620a043147, 0x3ed64488c56022e0),
# a7: (0xbb74588b63a38eb4, 0x3ef35ba58bf2f993),
# a8: (0xbb2d01494564929e, 0xbe80ea47bceb9a8f),
# a9: (0xbb1839787899a71c, 0xbe912b327055d0e9),
# a10: (0xbaaeacb6c41bd115, 0x3e1df42fc4e2482c),
# a11: (0xba6bbde5a22c7136, 0x3e23ec3e76876dba),
# a12: (0xba4c4c84b112be52, 0xbdb1580393f473c3),
# a13: (0x3a22a6076d63b081, 0xbdb04b0353c35935),
# a14: (0xb9c9681ae93e12ce, 0x3d3c4ca30ffe2a12),
# a15: (0xb9d1f206b8c5d3a1, 0x3d33c947b936c2fd),
# c: [
# 0xbcc122c73f770a61,
# 0xbcb28ac7295026a0,
# 0x3c4002243876b909,
# 0x3c2ba04294d52584,
# 0xbbb7c4c63a56cf5e,
# 0xbba0c0178f4adc58,
# 0x3b2cb6cf025ab9d0,
# 0x3b10da465bbcd445,
# ],
# },
# J1TaylorExtendedSeries {
# a0: (0xbc2f952341a46110, 0xbfb7a62320798175),
# a1: (0x354e7a56e25719c2, 0xb8a2b84e38e4848c),
# a2: (0x3c4f5aadff868986, 0x3fa7a50ca4504bb8),
# a3: (0xbbc425ed1e2ffb94, 0xbf2b095ccb50a68c),
# a4: (0x3c0088e41711bdb6, 0xbf6f80ef11daa37a),
# a5: (0xbb8b1b49cdffeccf, 0x3ef59822dc75b064),
# a6: (0x3bc22455dc1dd149, 0x3f20c7e6a7c66630),
# a7: (0x3b4cb7b87c0d2233, 0xbea89e00b5c358d0),
# a8: (0x3b4c5e752b8da3c2, 0xbec324d5238b26d0),
# a9: (0x3ae195d9c7c418a8, 0x3e4d13a888d5dd30),
# a10: (0xbac402a4638ae536, 0x3e5b29f941a95b07),
# a11: (0x3a831332fd18127e, 0xbde50e6ebb3d1df6),
# a12: (0xba87a4d1a4734619, 0xbdea4434c6b929dd),
# a13: (0x3a1460d05df6e758, 0x3d74a03fe2c47842),
# a14: (0x3a08550d3cb8e7ab, 0x3d7269628f2df98c),
# a15: (0x398caf5ddb7a6635, 0xbcfd28cc08ef4278),
# c: [
# 0xbcf390706334abc4,
# 0x3c7f26c3ea443ebd,
# 0x3c704c1cd3344482,
# 0xbbfa08922dcea306,
# 0xbbe5dabbff6c2bfb,
# 0x3b717bccb6cd02d2,
# 0x3b5818261a2214e1,
# 0xbae3485ef660d33b,
# ],
# },
# ];

# %%
def print_expansion_at_0_f():
    print(f"pub(crate) const J1_MACLAURIN_SERIES: [u64; 13] = [")
    from mpmath import mp, j1, taylor, expm1
    mp.prec = 53
    poly = taylor(lambda val: j1(val), 0, 46)
    # print(poly)
    real_i = 0
    z = 0
    for i in range(1, 46, 2):
        print(f"{double_to_hex(poly[i])},")
        real_i = real_i + 1
    print("];")

    print(f"poly {poly}")

print_expansion_at_0_f()
# Out:
# pub(crate) const J1_MACLAURIN_SERIES: [u64; 13] = [
# 0x3fe0000000000000,
# 0xbfb0000000000000,
# 0x3f65555555555555,
# 0xbf0c71c71c71c71c,
# 0x3ea6c16c16c16c17,
# 0xbe3845c8a0ce5129,
# 0x3dc27e4fb7789f5c,
# 0xbd4522a43f65486a,
# 0x3cc2c9758daf5cd0,
# 0xbc3ab81ea75fcdf4,
# 0x3baf17697cf1cf13,
# 0xbb1e2637bef9ff1a,
# 0x3a88bce58901a35e,
# 0xb9f165e7c2d153f3,
# 0x39553585cdcbfb10,
# 0xb8b69f7da8510bcd,
# 0x38154ad09e6a6576,
# 0xb771d028acb00491,
# 0x36caaae78f4066a6,
# 0xb621f72d8389b3a3,
# 0x3575e69de22df5ce,
# 0xb4c84564b82a1184,
# 0x34188f11edf3ed4c,
# ];
# poly [mpf('0.0'), mpf('0.5'), mpf('0.0'), mpf('-0.0625'), mpf('0.0'), mpf('0.0026041666666666665'), mpf('0.0'), mpf('-5.4253472222222219e-5'), mpf('0.0'), mpf('6.781684027777778e-7'), mpf('0.0'), mpf('-5.6514033564814812e-9'), mpf('0.0'), mpf('3.3639305693342149e-11'), mpf('0.0'), mpf('-1.5017547184527747e-13'), mpf('0.0'), mpf('5.2144261057388011e-16'), mpf('0.0'), mpf('-1.4484516960385557e-18'), mpf('0.0'), mpf('3.2919356728148996e-21'), mpf('0.0'), mpf('-6.2347266530585217e-24'), mpf('0.0'), mpf('9.9915491234912214e-27'), mpf('0.0'), mpf('-1.3724655389411017e-29'), mpf('0.0'), mpf('1.6338875463584545e-32'), mpf('0.0'), mpf('-1.7019661941233902e-35'), mpf('0.0'), mpf('1.5643071637163513e-38'), mpf('0.0'), mpf('-1.2780287285264307e-41'), mpf('0.0'), mpf('9.3423152670060721e-45'), mpf('0.0'), mpf('-6.1462600440829421e-48'), mpf('0.0'), mpf('3.6584881214779417e-51'), mpf('0.0'), mpf('-1.9797013644361157e-54'), mpf('0.0'), mpf('9.7811332234985954e-58'), mpf('0.0')]

# %%
# Taylor series for f32
mp.prec = 60
print(f"pub(crate) static J1F_COEFFS: [[u64; 15]; {len(j1_zeros)}] = [")

def get_constant_term(poly, y):
    for term in poly.operands():
        if term.is_constant():
            return term

def print_taylor_coeffsf(poly, x0):
    print("[")
    for i in range(0, 15):
        coeff = poly[i]
        print(f"{double_to_hex(coeff)},")
    print("],")

prev_zero = 0

for i in range(0, len(j1_zeros)):
    k_range = j1_zeros[i]
    range_diff = k_range - prev_zero
    g_c = 1

    x0 = mp.mpf(k_range)
    from mpmath import mp, j1, taylor, expm1
    # The j1 (Bessel J_1) function from mpmath will compute with mp.dps precision
    # The Taylor series computation will also respect mp.dps
    poly = taylor(lambda val: j1(val), x0, 23)
    # print(poly)
    print_taylor_coeffsf(poly, CDR(k_range))
    prev_zero = j1_zeros[i]

print("];")
# Out:
# pub(crate) static J1F_COEFFS: [[u64; 15]; 48] = [
# [
# 0x3fe29ea3d19f035f,
# 0x0000000000000000,
# 0xbfca41115c5df243,
# 0x3f78d1448e6fed48,
# 0x3f8c441a2f9de22b,
# 0xbf386671c18b088a,
# 0xbf39e2504ddc7608,
# 0x3ee34ccbca0c75d1,
# 0x3eda4973784d1087,
# 0xbe81045322aaab45,
# 0xbe70fae0da6cdcef,
# 0x3e13546cef5ed00a,
# 0x3dfe5ee82e667708,
# 0xbd9ec80cc8b63c39,
# 0xbd83eb2e99629b44,
# ],
# [
# 0x0000000000000000,
# 0xbfd9c6cf582cbf7f,
# 0x3faae8a39f51ad04,
# 0x3fab589d1da13905,
# 0xbf7537544c331da7,
# 0xbf624b3409959064,
# 0x3f26e4c2d5354224,
# 0x3f083a06e30c4109,
# 0xbec9799d4c9f2549,
# 0xbea33825cd2e2c16,
# 0x3e617069233e916c,
# 0x3e34569b22afc3c8,
# 0xbdf03b9e9651056a,
# 0xbdbec62310af5f52,
# 0x3d75ec84e47b6f4f,
# ],
# [
# 0xbfd626ee83500bf2,
# 0x0000000000000000,
# 0x3fc55f6bec9ef962,
# 0xbf83d23336fd10e4,
# 0xbf88c77a983a0814,
# 0x3f45cdc98db1cbe2,
# 0x3f373576ff46ee3b,
# 0xbef2461447d7b423,
# 0xbed7b853456b6eaa,
# 0x3e90abfc68274a98,
# 0x3e6ea7a1ee26124d,
# 0xbe235c0413e01418,
# 0xbdfb5c5d512fbb00,
# 0x3daf4c5e26fd6e90,
# 0x3d81e4c43397be51,
# ],
# [
# 0x0000000000000000,
# 0x3fd33518b3874e8a,
# 0xbf95e70dc60362bf,
# 0xbfa80c83bdeee5b0,
# 0x3f69a4b292e3de42,
# 0x3f613fbc7d698217,
# 0xbf207358bbdbff91,
# 0xbf0796a751f89051,
# 0x3ec4255b015aded4,
# 0x3ea3026e0ce97ab9,
# 0xbe5d48dcdae92f2c,
# 0xbe344639d7eeb0a6,
# 0x3dec62ccb4a32eb4,
# 0x3dbecae92e854457,
# 0xbd73bb6898d73cd2,
# ],
# [
# 0x3fd17dbf09d40d25,
# 0x0000000000000000,
# 0xbfc1404bf647c28f,
# 0x3f74f4df2769f830,
# 0x3f85c6285429b66d,
# 0xbf3d68ab722881bd,
# 0xbf356acb6452d860,
# 0x3eec10b47cf7ef69,
# 0x3ed67eaae97bbc86,
# 0xbe8bb6530c63f2df,
# 0xbe6d87201e450edd,
# 0x3e20f47c83ec550b,
# 0x3dfa98331f6ea799,
# 0xbdac70414a236a67,
# 0xbd817c057a5fcd3d,
# ],
# [
# 0x0000000000000000,
# 0xbfcff654544ebcd1,
# 0x3f89223ff2c0785b,
# 0x3fa4b0c5d5da6789,
# 0xbf5f91a9ee0d2897,
# 0xbf5f51c2489b9e6f,
# 0x3f16b4c9ca0f770d,
# 0x3f063c5475439cb2,
# 0xbebe3725daf69867,
# 0xbea25c1238b32e59,
# 0x3e57486f6b9aa951,
# 0x3e33e3bf248277ee,
# 0xbde78a38a73e7c0a,
# 0xbdbe844eb6b211b0,
# 0x3d70e24abb40708e,
# ],
# [
# 0xbfcddceb4ce1bf4a,
# 0x0000000000000000,
# 0x3fbda52116c0a640,
# 0xbf6a9da4603b67ea,
# 0xbf8331e74ea59ab8,
# 0x3f33e5cb6eba6eaa,
# 0x3f33885fe9afa541,
# 0xbee494c0f4b0680b,
# 0xbed512b9d37762d7,
# 0x3e85a861082bfb7f,
# 0x3e6c323ea0a042c3,
# 0xbe1bcc962f7b91eb,
# 0xbdf9bc94e2f29a52,
# 0x3da82bc6fcfa8e89,
# 0x3d81141ce7b78460,
# ],
# [
# 0x0000000000000000,
# 0x3fcbf3337873a7d8,
# 0xbf80c83a2d7add33,
# 0xbfa251858011816b,
# 0x3f559eb160bf72d8,
# 0x3f5c5bce33af2d77,
# 0xbf10413e306e0039,
# 0xbf04a6704d05ad0b,
# 0x3eb6c43eedfed6c9,
# 0x3ea16abd7815de74,
# 0xbe5257f16f5d4346,
# 0xbe332db1b4b2ff8b,
# 0x3de33acccf7bfdce,
# 0x3dbdc8f5682566ba,
# 0xbd6c6513386daae2,
# ],
# [
# 0x3fca7f63fea81f26,
# 0x0000000000000000,
# 0xbfba60afb06640cf,
# 0x3f62c1e930935d3c,
# 0x3f814506466d7f1f,
# 0xbf2cca8c0c0eaa3f,
# 0xbf31df821cc1377e,
# 0x3edee8814ed0ac45,
# 0x3ed3a365a4199dd1,
# 0xbe80ed2f9c3e458e,
# 0xbe6ab3b37c5271b3,
# 0x3e1684d6e62b5c66,
# 0x3df8b105a5120ed2,
# 0xbda42dc5991b9d01,
# 0xbd808d6405ffe3dc,
# ],
# [
# 0x0000000000000000,
# 0xbfc925c6fca08f55,
# 0x3f786dd32e059b0e,
# 0x3fa09463bbd0367f,
# 0xbf4fda0298c8768b,
# 0xbf59f4be60758fb1,
# 0x3f0877991af9d1bb,
# 0x3f032cb00ee8c1f3,
# 0xbeb19d8ce8c35f58,
# 0xbea06a042fbba455,
# 0x3e4d3a689e677731,
# 0x3e325108c4ce2b63,
# 0xbddf7b8e9ab53152,
# 0xbdbcc40d05652642,
# 0x3d67cd76e2d7e2cb,
# ],
# [
# 0xbfc810f50225b04b,
# 0x0000000000000000,
# 0x3fb7fdf97ac36b1f,
# 0xbf5c3c256a8caa05,
# 0xbf7f98feb7286b47,
# 0x3f25f6559e5686e2,
# 0x3f3080f57ac215af,
# 0xbed80c51397e5eba,
# 0xbed256db543cd140,
# 0x3e7af7598a219824,
# 0x3e69398226ca2305,
# 0xbe1260985d92587d,
# 0xbdf792bb3eea6f6a,
# 0x3da0d862695e1a7a,
# 0x3d7fe52adc2baacf,
# ],
# [
# 0x0000000000000000,
# 0x3fc70c511227d5aa,
# 0xbf72ccb0e97558da,
# 0xbf9e7dc08e70e99a,
# 0x3f48acdc5b058c0e,
# 0x3f580503724ad30a,
# 0xbf032ee4ca1fcafb,
# 0xbf01e5d2836c8d99,
# 0x3eac129f077bb163,
# 0x3e9ef161591181a2,
# 0xbe47b9bb07f19f82,
# 0xbe316f3937595d96,
# 0x3dda0bc8665b687b,
# 0x3dbba135f99a9e19,
# 0xbd640d543d2cbdf0,
# ],
# [
# 0x3fc633e7f7f05301,
# 0x0000000000000000,
# 0xbfb6273784c1c06e,
# 0x3f563ae94ade18d4,
# 0x3f7d4666536c88b9,
# 0xbf216d528345ca11,
# 0xbf2ec0dcdbb7c5fe,
# 0x3ed34e966b0b09f8,
# 0x3ed135c64dc2d8d0,
# 0xbe75f7bc78b5fc2b,
# 0xbe67dc35b0764096,
# 0x3e0e6d697361ea54,
# 0x3df679e3704987b4,
# 0xbd9c595f278a4d6c,
# 0xbd7ea36aef56eec0,
# ],
# [
# 0x0000000000000000,
# 0xbfc5664e13b70622,
# 0x3f6e16555e108dc6,
# 0x3f9c5e1ad9fb2f40,
# 0xbf43d369f958e56a,
# 0xbf566f4ec27a96e9,
# 0x3eff0de0532652d5,
# 0x3f00cf264341409e,
# 0xbea6f46d51e5766f,
# 0xbe9d407f7c248d45,
# 0x3e43a33cd9df6696,
# 0x3e309901b0a816e5,
# 0xbdd5d856a58443f5,
# 0xbdba7cbcd8fc0758,
# 0x3d610b62c2fd47f6,
# ],
# [
# 0xbfc4b71d4ca2cc69,
# 0x0000000000000000,
# 0x3fb4ae245697fba6,
# 0xbf5215e4e1a5f1d6,
# 0xbf7b633ed6d9cf61,
# 0x3f1c7f17b4b7dbbd,
# 0x3f2ce01b8b6aa34c,
# 0xbecfced71b11e35b,
# 0xbed03c9d5823261d,
# 0x3e724508091063b2,
# 0x3e66a2d20111e303,
# 0xbe0995a18f8e6888,
# 0xbdf572d1a074f647,
# 0x3d981df03c1911f1,
# 0x3d7d6895e48f475d,
# ],
# [
# 0x0000000000000000,
# 0x3fc40f90793605bb,
# 0xbf68c833077fbeae,
# 0xbf9aa0ce0421d1a8,
# 0x3f405fa598ef5d1d,
# 0x3f551d30d78ab526,
# 0xbef9c5807675c5f6,
# 0xbeffc1bbf57e3ae2,
# 0x3ea32dfea2518ce6,
# 0x3e9bc212085dcbc6,
# 0xbe408b946d64c5c2,
# 0xbe2fa8f9d8da736a,
# 0x3dd293fe14af1d0f,
# 0x3db96544cb75a58d,
# 0xbd5d4750748e2ce8,
# ],
# [
# 0x3fc37dfa8f5a550a,
# 0x0000000000000000,
# 0xbfb3775c1a04f09c,
# 0x3f4e2b4810a46c60,
# 0x3f79d151a72b83a8,
# 0xbf17d8e5a090e4e6,
# 0xbf2b49a6427386a0,
# 0x3ecac10957ddd2eb,
# 0x3ececa620745d3d3,
# 0xbe6eefc7e795dcdd,
# 0xbe658c5d2a0da41d,
# 0x3e05d4721f44a8f9,
# 0x3df481ce2314af59,
# 0xbd94c0d3279e920c,
# 0xbd7c3ea707530563,
# ],
# [
# 0x0000000000000000,
# 0xbfc2f2072e638cf4,
# 0x3f64df208bbd44f1,
# 0x3f992bb5e1e159fc,
# 0xbf3ba181c06897cd,
# 0xbf53fe9d5baa4a3d,
# 0x3ef5d17602b01cac,
# 0x3efe26d3747fe829,
# 0xbea0509768ab6ecb,
# 0xbe9a70f232d9d06c,
# 0x3e3c509252de33f9,
# 0x3e2e454fee07116e,
# 0xbdd0015b062ba125,
# 0xbdb860e95adf840f,
# 0x3d59691e90f7d9c0,
# ],
# [
# 0xbfc2768d29c69936,
# 0x0000000000000000,
# 0x3fb271811730b0ef,
# 0xbf49a8df96a1225e,
# 0xbf787c81cf1c6fc4,
# 0x3f14549cdbb77978,
# 0x3f29ed2568116e19,
# 0xbec6e4136f033ace,
# 0xbecd53330316cde7,
# 0x3e6a983b5782dfca,
# 0x3e64952ba7c5a1dc,
# 0xbe02df3ad6f82e0d,
# 0xbdf3a70f9a89d2c2,
# 0x3d920e086c17f5dc,
# 0x3d7b29a554c1159f,
# ],
# [
# 0x0000000000000000,
# 0x3fc1ff5eec6a01cd,
# 0xbf61e438b722c3b5,
# 0xbf97ed5fffc1c774,
# 0x3f37b7997babd9ca,
# 0x3f53081def9612c5,
# 0xbef2c5f5edafc4e9,
# 0xbefcc11a59e13739,
# 0x3e9c2c3a1b8014a3,
# 0x3e9946d1dab7bd01,
# 0xbe388db61946be64,
# 0xbe2d04d33be580e8,
# 0x3dcbe64386d2c5d0,
# 0x3db77142e0e4497b,
# 0xbd56458476679697,
# ],
# [
# 0x3fc194eba75b32f9,
# 0x0000000000000000,
# 0xbfb190f7dc27362b,
# 0x3f462bb47a5c5f7f,
# 0x3f7756ef20f5d2e2,
# 0xbf1198b0ba97ecfb,
# 0xbf28be8cf9358d55,
# 0x3ec3dd6f7c8cc3c0,
# 0x3ecc09c80ee7f9af,
# 0xbe6728e46a451e32,
# 0xbe63b91113508622,
# 0x3e0080fddad62bf8,
# 0x3df2e111e88dae1f,
# 0xbd8fbae88bdab215,
# 0xbd7a2a4fbea868a8,
# ],
# [
# 0x0000000000000000,
# 0xbfc12dd57bf18ada,
# 0x3f5f1e1e7f393e83,
# 0x3f96d9afe88301fa,
# 0xbf34a538a482979b,
# 0xbf52316250b4ae37,
# 0x3ef05f11577b4627,
# 0x3efb86bad42fc220,
# 0xbe98a1b3a9e92749,
# 0xbe983dcaf3f8fcc5,
# 0x3e3589a7ca5fdcf1,
# 0x3e2be3ee3298bb99,
# 0xbdc8913f1d0ff12a,
# 0xbdb695c386660813,
# 0x3d53b25d364762e7,
# ],
# [
# 0xbfc0d0d36473e98c,
# 0x0000000000000000,
# 0x3fb0cda9974abe2b,
# 0xbf4367f38f201c25,
# 0xbf7656b75e3c242e,
# 0x3f0ed82abf7489f1,
# 0x3f27b4e5b83eeb36,
# 0xbec171fd0fb670e7,
# 0xbecae62b4ad017fb,
# 0x3e64648495a7b49e,
# 0x3e62f42a577135ad,
# 0xbdfd286e7fa32656,
# 0xbdf22dbcbf76a1c7,
# 0x3d8c222accc0d2d2,
# 0x3d793fc7f6c8d355,
# ],
# [
# 0x0000000000000000,
# 0x3fc076826cc2c191,
# 0xbf5b62885e0070c6,
# 0xbf95e7f53001e4b1,
# 0x3f322ebeb8dc2202,
# 0x3f517444a7a04cd0,
# 0xbeece06f1f1fcd7e,
# 0xbefa7006e6ad9cfe,
# 0x3e95c42f02cf15ca,
# 0x3e9750ca5e1366b4,
# 0xbe3314982df7eaa2,
# 0xbe2aded75306b3b3,
# 0x3dc5d47847d8ebf1,
# 0x3db5ccf44d287a21,
# 0xbd518fce3e04028a,
# ],
# [
# 0x3fc02455675ab6d2,
# 0x0000000000000000,
# 0xbfb021c155a720df,
# 0x3f412be56fc1449a,
# 0x3f75749d556ad61c,
# 0xbf0b51f1f9bea93e,
# 0xbf26c96a07e236bd,
# 0x3ebef3a7abd5ac6b,
# 0x3ec9e207c257433a,
# 0xbe6220b96eef8058,
# 0xbe624317cb296737,
# 0x3df9fc2f2cd3917f,
# 0x3df18ae8347e8256,
# 0xbd892540423f2dda,
# 0xbd78687dcdc2e3a9,
# ],
# [
# 0x0000000000000000,
# 0xbfbfa8b41711c83a,
# 0x3f5857d3969997d1,
# 0x3f9511c6dadaaa12,
# 0xbf302c289dbdbd4f,
# 0xbf50cc2238d229f9,
# 0x3ee9b64d5c63668f,
# 0x3ef976fb023f0f79,
# 0xbe93693ba0b5ba70,
# 0xbe967b952987350c,
# 0x3e310cb79a2addac,
# 0x3e29f2079f8e397f,
# 0xbdc38d957eaa53ad,
# 0xbdb51511e93ba74c,
# 0x3d4f8bb4d9d2f3a4,
# ],
# [
# 0xbfbf161d0c28b48c,
# 0x0000000000000000,
# 0x3faf11d837aa6f64,
# 0xbf3eab76da4d07a0,
# 0xbf74ab329f067aea,
# 0x3f086ada57bc1c51,
# 0x3f25f6e78f11ab9a,
# 0xbebbb271f54c8965,
# 0xbec8f85328c26cb7,
# 0x3e603f82aebdeac1,
# 0x3e61a3010279a195,
# 0xbdf75660809cdedf,
# 0xbdf0f6931774a05f,
# 0x3d86a2e61267070b,
# 0x3d77a2a8e0311c3a,
# ],
# [
# 0x0000000000000000,
# 0x3fbe8727daa3daed,
# 0xbf55d353e2854a37,
# 0xbf94524d4813cc25,
# 0x3f2d037574e28370,
# 0x3f50356bb747a763,
# 0xbee7156bfccef376,
# 0xbef896d7dc819faf,
# 0x3e9172c6dadf4149,
# 0x3e95baae8efc2e31,
# 0xbe2eb347eb4d6941,
# 0xbe291a60a72a20e0,
# 0x3dc1a345a9a6a5f7,
# 0x3db46c56b01906be,
# 0xbd4c84bb37677838,
# ],
# [
# 0x3fbe0357c158b119,
# 0x0000000000000000,
# 0xbfadffc2fc1a91f5,
# 0x3f3b9b82ae07da44,
# 0x3f73f64e05320ac6,
# 0xbf05fe4b66cf19d8,
# 0xbf2539518e1b00f5,
# 0x3eb8f8d01c487905,
# 0x3ec825045b97e2dc,
# 0xbe5d565f3bb61dea,
# 0xbe611186586f4f74,
# 0x3df51a669158191b,
# 0x3df06ef52f6715ac,
# 0xbd848215e95caa77,
# 0xbd76ec8422019b0d,
# ],
# [
# 0x0000000000000000,
# 0xbfbd8293aa55d18f,
# 0x3f53b6beb83f2596,
# 0x3f93a5ccbc12a67b,
# 0xbf2a3765d26aa42b,
# 0xbf4f5ab33748c215,
# 0x3ee4df6f1c257a5c,
# 0x3ef7cbd49c315be0,
# 0xbe8f96098cf07175,
# 0xbe950b37dd43531f,
# 0x3e2bd2e6405c605d,
# 0x3e285530df0d4b70,
# 0xbdc0029e21930f25,
# 0xbdb3d11aeba731a1,
# 0x3d49ef077e065d17,
# ],
# [
# 0xbfbd0b36e5737458,
# 0x0000000000000000,
# 0x3fad082ce3c6b59b,
# 0xbf3905d00c5e6800,
# 0xbf7352b073fdac7b,
# 0x3f03f1ccfec2fc88,
# 0x3f248d74583834bc,
# 0xbeb6a9ef0d896bae,
# 0xbec764d9798d6a80,
# 0x3e5aa785d6736f5c,
# 0x3e608cae36118cdb,
# 0xbdf332ddfb39cd01,
# 0xbdefe502ff1a8f0d,
# 0x3d82afc83348eeb2,
# 0x3d764468c0a31511,
# ],
# [
# 0x0000000000000000,
# 0x3fbc96700bf039e2,
# 0xbf51ec0b5de4befe,
# 0xbf93095734a24496,
# 0x3f27d74e12285cb2,
# 0x3f4e636fe259352c,
# 0xbee2fe11972bc0c6,
# 0xbef712e4d44c4a74,
# 0x3e8cc3adabae0452,
# 0x3e946ad2d9cbeb5c,
# 0xbe295d81ae83f621,
# 0xbe27a02aefea3d60,
# 0x3dbd3a949a72239d,
# 0x3db341e0bb193b49,
# 0xbd47b550a4f77497,
# ],
# [
# 0x3fbc29ae8400a320,
# 0x0000000000000000,
# 0xbfac27138da31c2b,
# 0x3f36d141fcbea853,
# 0x3f72bdc71062acd6,
# 0xbf0231cf643ffc17,
# 0xbf23f0bf3b3fe8be,
# 0x3eb4b05e955de175,
# 0x3ec6b52b868fa5e2,
# 0xbe585a7aa3e84cc3,
# 0xbe6012d3384c9164,
# 0x3df18f8c4872544f,
# 0x3deeffc4029f2f06,
# 0xbd811d5a3daf70fa,
# 0xbd75a8d84ce12a33,
# ],
# [
# 0x0000000000000000,
# 0xbfbbbf246914235f,
# 0x3f5062daee35411a,
# 0x3f927a96f174b6d1,
# 0xbf25cdb5dea9c121,
# 0xbf4d818348f98a0f,
# 0x3ee160aab829409d,
# 0x3ef6698d6ee99eb9,
# 0xbe8a5633d8f0b3bf,
# 0xbe93d788d61154a7,
# 0x3e273ec2ae0084b9,
# 0x3e26f958f6235deb,
# 0xbdbad0939c43a9fe,
# 0xbdb2bd56309cf195,
# 0x3d45c709d717f2e4,
# ],
# [
# 0xbfbb5b8273b75055,
# 0x0000000000000000,
# 0x3fab59418c36a684,
# 0xbf34eafeaa92aa79,
# 0xbf7235801af9be44,
# 0x3f00af9747d0be92,
# 0x3f23611db0e1566f,
# 0xbeb2fbe414da1250,
# 0xbec613ccbb9cbe59,
# 0x3e565cf274e84d31,
# 0x3e5f452996e3dc2b,
# 0xbdf023f5382da3ad,
# 0xbdee2be24fbad63f,
# 0x3d7f7ed3740f8cf5,
# 0x3d75187e998a1997,
# ],
# [
# 0x0000000000000000,
# 0x3fbaf9cb49c4f935,
# 0xbf4e1d930b513228,
# 0xbf91f7a8fec6eba8,
# 0x3f240a55310866fc,
# 0x3f4cb20c812fd3aa,
# 0xbedff51953c6b6cc,
# 0xbef5cdc48f5d75eb,
# 0x3e883b091952c721,
# 0x3e934fb685e58ab7,
# 0xbe2566fc4369ab71,
# 0xbe265f0f7de29720,
# 0x3db8b61e5f9b7a00,
# 0x3db24253069b78a9,
# 0xbd441732d722b422,
# ],
# [
# 0x3fba9e13a0db642a,
# 0x0000000000000000,
# 0xbfaa9c1ca2161b9b,
# 0x3f3344a09efdc635,
# 0x3f71b82c430a2381,
# 0xbefebfb97bca01f2,
# 0xbf22dcdb1bc1d038,
# 0x3eb180047f0b79ae,
# 0x3ec57eeeee84d0d0,
# 0xbe54a0c699c8318b,
# 0xbe5e7594e8a2c760,
# 0x3dedccbbb4c0ba7f,
# 0x3ded6766337b5c95,
# 0xbd7d1a05cea18a02,
# 0xbd74922fb50a29f1,
# ],
# [
# 0x0000000000000000,
# 0xbfba4407e04298d1,
# 0x3f4bcc9df0cf00b2,
# 0x3f917f0266db2149,
# 0xbf2280a052234a05,
# 0xbf4bf2ada1f44071,
# 0x3edd83d58032b48d,
# 0x3ef53dd972d8f232,
# 0xbe8663c1fe202028,
# 0xbe92d1fbf2203ff6,
# 0x3e23c9f0b759c5f9,
# 0x3e25cfe1b012696d,
# 0xbdb6ddc0795781e9,
# 0xbdb1cfd49504266a,
# 0x3d429b7af5214fbc,
# ],
# [
# 0xbfb9ef3bb2213b0b,
# 0x0000000000000000,
# 0x3fa9ed82007a9a45,
# 0xbf31d2fdeeb29f8a,
# 0xbf71446866ff1b83,
# 0x3efc73b684f93259,
# 0x3f22628de594b6c9,
# 0xbeb03303c1427449,
# 0xbec4f51007c51087,
# 0x3e531adfa36f2213,
# 0x3e5db4f306b19095,
# 0xbdeb9e33598f899e,
# 0xbdecb09ed6ecb896,
# 0x3d7afe1183148a99,
# 0x3d7414e442aa8d57,
# ],
# [
# 0x0000000000000000,
# 0x3fb99be744018c90,
# 0xbf49c3f52a2af724,
# 0xbf910f5ca51f98b0,
# 0x3f2126c8e8ca2766,
# 0x3f4b416f7d4fc313,
# 0xbedb5e2e5580e1ce,
# 0xbef4b862279de756,
# 0x3e84c5071b39dc13,
# 0x3e925d2fc3b19021,
# 0xbe225df322279972,
# 0xbe254a971eb6fe3b,
# 0x3db53cc6c9922f2b,
# 0x3db164f95180d8c1,
# 0xbd414b9ef404ed89,
# ],
# [
# 0x3fb94d3276914e51,
# 0x0000000000000000,
# 0xbfa94bac1950e319,
# 0x3f308d4ff8f2059e,
# 0x3f70d90d29bfeecd,
# 0xbefa6d56162f7fb4,
# 0xbf21f107da23807d,
# 0x3eae1a626277437b,
# 0x3ec474eafd0cc642,
# 0xbe51c27144f42d78,
# 0xbe5d01999b1a4fe9,
# 0x3de9b014801da87a,
# 0x3dec061740bc8a45,
# 0xbd791f8c2972547e,
# 0xbd739fb558b7aa4d,
# ],
# [
# 0x0000000000000000,
# 0xbfb8ffc9bd24fe08,
# 0x3f47f7d46ab33721,
# 0x3f90a7a725d3fbc4,
# 0xbf1fea1728f216b4,
# 0xbf4a9cac69f0ed64,
# 0x3ed977f48ff1056b,
# 0x3ef43c2d8e698c10,
# 0xbe8355d1a6765ea6,
# 0xbe91f0553501d121,
# 0x3e211b47f6a44829,
# 0x3e24ce23303889a9,
# 0xbdb3ca98df62221f,
# 0xbdb100fc746529d7,
# 0x3d4020f11e2dca08,
# ],
# [
# 0xbfb8b67a2481077d,
# 0x0000000000000000,
# 0x3fa8b51f21068ea2,
# 0xbf2ed935c7aefa31,
# 0xbf707522a5037f2d,
# 0x3ef8a196061f8bbc,
# 0x3f21874a47e3c1e3,
# 0xbeac10cf34c04f17,
# 0xbec3fd6c2d4fa2a4,
# 0x3e50906d55522785,
# 0x3e5c5a1c124dfa08,
# 0xbde7f883b31a5f59,
# 0xbdeb668cf53028e4,
# 0x3d7775372d05b25d,
# 0x3d7331d871d677e0,
# ],
# [
# 0x0000000000000000,
# 0x3fb86e51be0a9153,
# 0xbf465ed1b387e5da,
# 0xbf9046fc5a218a86,
# 0x3f1dca617fefa913,
# 0x3f4a0300221528a7,
# 0xbed7c7618906f1e2,
# 0xbef3c838897d0a1e,
# 0x3e820ede9f9dd7dd,
# 0x3e918a94165592bb,
# 0xbe1ff76205118f09,
# 0xbe24599dfeef01a1,
# 0x3db2803e59983134,
# 0x3db0a33202feb043,
# 0xbd3e2bff738680f8,
# ],
# [
# 0x3fb829d06fee9266,
# 0x0000000000000000,
# 0xbfa8289a526d7785,
# 0x3f2cd680355c9eb6,
# 0x3f7017d70f512861,
# 0xbef707978e2a0db8,
# 0xbf21247ce15e7385,
# 0x3eaa3f6125485ec1,
# 0x3ec38da848401be9,
# 0xbe4efe39d8db4cd8,
# 0xbe5bbd40f1db0e94,
# 0x3de66f7d49436f83,
# 0x3dead0e8148229b3,
# 0xbd75f78595133d0b,
# 0xbd72ca9bb10321b3,
# ],
# [
# 0x0000000000000000,
# 0xbfb7e656efb009ae,
# 0x3f44f15066f3d876,
# 0x3f8fd932c26aad94,
# 0xbf1be460dd86a0a4,
# 0xbf49733b591879f8,
# 0x3ed64488c56022e0,
# 0x3ef35ba58bf2f993,
# 0xbe80ea47bceb9a8f,
# 0xbe912b327055d0e9,
# 0x3e1df42fc4e2482c,
# 0x3e23ec3e76876dba,
# 0xbdb1580393f473c3,
# 0xbdb04b0353c35935,
# 0x3d3c4ca30ffe2a12,
# ],
# [
# 0xbfb7a62320798175,
# 0x0000000000000000,
# 0x3fa7a50ca4504bb8,
# 0xbf2b095ccb50a68c,
# 0xbf6f80ef11daa37a,
# 0x3ef59822dc75b064,
# 0x3f20c7e6a7c66630,
# 0xbea89e00b5c358d0,
# 0xbec324d5238b26d0,
# 0x3e4d13a888d5dd30,
# 0x3e5b29f941a95b07,
# 0xbde50e6ebb3d1df6,
# 0xbdea4434c6b929dd,
# 0x3d74a03fe2c47842,
# 0x3d7269628f2df98c,
# ],
# [
# 0x0000000000000000,
# 0x3fb766dc36547ccd,
# 0xbf43a919bc2a0728,
# 0xbf8f2faf2b20556d,
# 0x3f1a2fdcc0cb54af,
# 0x3f48ec5a10ee00cf,
# 0xbed4e8eec453fd00,
# 0xbef2f5b5f430377a,
# 0x3e7fc66ddcbc528d,
# 0x3e90d18f69c2056c,
# 0xbe1c249c3896bae9,
# 0xbe2385557a0fd5b7,
# 0x3db04d34deba9ee2,
# 0x3dafefd81796149d,
# 0xbd3a9c64cec6694e,
# ],
# ];

# %%
from mpmath import mp, j1, taylor, linspace, chebyfit

# Set precision (decimal places)
mp.prec = 120

# Generate degree-46 Taylor series of J1(x) at x = 0
poly = taylor(lambda val: j1(val), mp.mpf('1.8411837813407134767373918293742463'), 25)

def polyeval(coeffs, x, center):
    """Evaluate Taylor polynomial centered at `center` using Horner's method."""
    u = x - center
    result = mpf(0)
    for c in reversed(coeffs):
        result = result * u + c
    return result

# Evaluate max relative error over [0, 1]
# xs = linspace(0.991, 2, 100000)  # 1000 evenly spaced points
# max_rel_error = 0
# max_abs_error = 0
# worst_x = None

# for x in xs:
#     true_val = j1(x)
#     approx_val = polyeval(poly, x, DD('1.8411837813407134767373918293742463'))
#     if true_val != 0:
#         rel_error = abs((approx_val - true_val) / true_val)
#         if rel_error > max_rel_error:
#             max_rel_error = rel_error
#             worst_x = x

# print(f"Max relative error over [0, 1]: {max_rel_error}")
# print(f"Occurs at x = {worst_x}")
# worst_x = None

# for x in xs:
#     true_val = j1(x)
#     approx_val = polyeval(poly, x, DD('1.8411837813407134767373918293742463'))
#     abs_error = abs(approx_val - true_val)
#     if abs_error > max_abs_error:
#         max_abs_error = abs_error
#         worst_x = x

# print(f"Max abs error over [0, 1]: {max_rel_error}")
# print(f"Occurs at x = {worst_x}")

# print(double_to_hex(DD(max_rel_error)))
print(polyeval(poly, mp.mpf('0.9750000000213042'), mp.mpf('1.8411837813407134767373918293742463')))
def make_e(eps, p):
    return float((DD(1) + DD(2)**DD(-p)) / (DD(1) - eps - DD(2) ** DD(p + 1)*eps)) * 2**(-p)
print(double_to_hex(make_e(DD('1.192857060732688978535982892962e-26'), 55)))
# Out:
# 0.43182090258033493836803603680518589
# 0x3c800000003b1143
