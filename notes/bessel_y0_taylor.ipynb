# %%
from mpmath import mp, mpf, findroot, bessely
from sage.all import *
import struct

DR = RealField(53)

DD = RealField(190)

def double_to_hex(f):
    packed = struct.pack('>d', float(f))
    return '0x' + packed.hex()

def split_double_double(x):
    # Split RR value x into hi + lo (double-double)
    x = RealField(190)(x).exact_rational()
    x_hi = DR(x)  # convert to f64
    x_lo = x - DD(x_hi)
    return (x_lo,x_hi)

def split_triple_double(x):
    # Split RR value x into hi + lo (double-double)
    x_hi = DR(x)  # convert to f64
    x_mid = DR(x - DD(x_hi))
    x_lo = x - DD(x_hi) - DD(x_mid)
    return (x_lo, x_mid, x_hi)

def print_double_double(mark, x):
    splat = split_double_double(x)
    print(f"{mark}({double_to_hex(splat[0])}, {double_to_hex(splat[1])}),")

def print_triple_double(mark, x):
    splat = split_triple_double(x)
    print(f"{mark}({double_to_hex(splat[0])}, {double_to_hex(splat[1])}, {double_to_hex(splat[2])}),")

def format_dyadic_hex(value):
    l = hex(value)[2:]
    n = 8
    x = [l[i:i + n] for i in range(0, len(l), n)]
    return "0x" + "_".join(x) + "_u128"

def print_dyadic(value):
    (s, m, e) = RealField(128)(value).sign_mantissa_exponent();
    print("DyadicFloat128 {")
    print(f"    sign: DyadicSign::{'Pos' if s >= 0 else 'Neg'},")
    print(f"    exponent: {e},")
    print(f"    mantissa: {format_dyadic_hex(m)},")
    print("},")

# %%
from sage.all import *

R = LaurentSeriesRing(RealField(300), 'x',default_prec=300)
x = R.gen()
N = 16  # Number of terms (adjust as needed)
gamma = RealField(300)(euler_gamma)
d2 = RealField(300)(2)
pi = RealField(300).pi()

# Define J0(x) Taylor expansion at x = 0
def j_series(n, x):
    return sum([(-1)**m * (x/2)**(ZZ(n) + ZZ(2)*ZZ(m)) / (ZZ(m).factorial() * (ZZ(m) + ZZ(n)).factorial()) for m in range(N)])

J0_series = j_series(0, x)

def z_series(x):
    return sum([(-1)**m * (x/2)**(ZZ(2)*ZZ(m)) / ZZ(m).factorial()**ZZ(2) * sum(RealField(300)(1)/RealField(300)(k) for k in range(1, m+1)) for m in range(1, N)])

W0 = (d2/pi) * J0_series
Z0 = -gamma * (d2/pi) * J0_series + RealField(300)(2).log() * (d2/pi) * J0_series + (d2/pi) * z_series(x)

# print("W0(x) =", W0)
# print("Z0(x) =", Z0)

terms = 30

from mpmath import mp, bessely, taylor

def Y0_approx(val):
    # Substitute numeric value and convert to high precision real
    w = W0.truncate(terms)(val)
    z = Z0.truncate(terms)(val)
    return RealField(107)(w) * RealField(107)(val).log() - RealField(107)(z)

mp.prec = 120

print("W = ", RealField(64)(W0.truncate(terms)(0.89357696627916749)))
print("Z = ", RealField(64)(Z0.truncate(terms)(0.89357696627916749)))
print("LOG = ", RealField(110)(0.89357696627916749).log())
print_double_double("", RealField(110)(2).log())
print("r = ", Y0_approx(RealField(100)(0.89357696627916749)))
print("t = ", bessely(0, 0.89357696627916749))

def print_series(z, N):
    for i in range(N):
        coeff = z[i]
        if coeff != 0:
            # print(double_to_hex(RealField(300)(coeff)) + ",")
            print_double_double("", RealField(300)(coeff))

print_series(Z0, 30)

# W0_series = W0.series(x, 2*N)
# Z0_series_expanded = Z0.series(x, 2*N)

# print("W0(x) power series:")
# for i in range(0, 2*N):
#     coeff = W0_series.coefficient(x, i)
#     if coeff != 0:
#         print(f"x^{i}: {coeff}")
# Out:
# W =  0.515740866931212572
# Z =  -0.0580326104859750086
# LOG =  -0.11252280788079415479644853102767
# (0x3c7abc9e3b39803f, 0x3fe62e42fefa39ef),
# r =  -2.338927928406201408822986214495e-17
# t =  -2.338927928406210311869215576136051e-17
# (0xbc5ddfd831a70821, 0x3fb2e4d699cbd01f),
# (0xbc6d93e63489aea6, 0xbfc6bbcb41034286),
# (0xbc1b88525c2e130b, 0x3f9075b1bbf41364),
# (0x3be097334e26e578, 0xbf41a6206b7b973d),
# (0x3b51c64a34c78cda, 0x3ee3e99794203bbd),
# (0xbb1c407b0f5b2805, 0xbe7bce4a600d3ea4),
# (0xbaa57d1e1e88c9ca, 0x3e0a6ee796b871b6),
# (0x3a3b6e7030a77899, 0xbd92393d82c6b2e4),
# (0x397fcfedacb03781, 0x3d131085da82054c),
# (0xb8e45f51f6118e46, 0xbc8f4ed4b492ebcc),
# (0xb89bd46046c3c8de, 0x3c04b7ac8a1b15d0),
# (0x37d1a206fb205e32, 0xbb769201941d0d49),
# (0x3782f38acbf23993, 0x3ae4987e587ab039),
# (0x36b691bdabf5672b, 0xba4ff1953e0a7c5b),
# (0x3636e1c8cd260e18, 0x39b55031dc5e1967),

# %%
# log coeffs

print_double_double("", RealField(107)('0.33333333333333333333333333701941430830813680984317'))
print_double_double("", RealField(107)('-0.25000000000000000000000000927469621095374516819563'))
print_double_double("", RealField(107)('0.19999999999999999999736148023407947320974191411113'))
print_double_double("", RealField(107)('-0.166666666666666666661740817355617089084687157682226'))
print_double_double("", RealField(107)('0.142857142857143514208845068731577058039341433616166'))
print_double_double("", RealField(107)('-0.125000000000000975543372027000681903260219080482025'))
print_double_double("", RealField(107)('0.111111111036972084401481914727934733718551705198942'))
print_double_double("", RealField(107)('-9.9999999908474789172229905677506311880264028108553e-2'))
print_double_double("", RealField(107)('9.0912976618933058600055577564907185974457745483036e-2'))
print_double_double("", RealField(107)('-8.333744694635135507057149825265760651408947697174e-2'))
print_double_double("", RealField(107)('7.6927691777549212280402265589168123489454885488853e-2'))
print_double_double("", RealField(107)('-7.1432719425306658106725949877427166499943643429565e-2'))
# Out:
# (0x3c755555556795ff, 0x3fd5555555555555),
# (0xba86f68980000000, 0xbfd0000000000000),
# (0xbc699b285263b391, 0x3fc999999999999a),
# (0xbc65526cf5c49dc3, 0xbfc5555555555555),
# (0xbc34fc756f340748, 0x3fc24924924924aa),
# (0xbc52e654a63b293e, 0xbfc0000000000023),
# (0xbc5c73c13a9c2171, 0x3fbc71c71c2042d5),
# (0xbc3d2af5e7ee68d8, 0xbfb999999934f78b),
# (0xbc590d76077808da, 0x3fb74612a55c3e99),
# (0xbc3447161ca8047c, 0xbfb5559a592aadc7),
# (0x3c18760148059540, 0x3fb3b18880576230),
# (0xbc3b2424b7665f98, 0xbfb2496a29cbc904),

# %%
R120 = RealField(120)

zeros = []

mp.prec = 150

step = mpf("0.1")
epsilon = mpf("1e-35")
x = mpf("1.25")

previous_zero = R120(0)
y0_zeros = []

while x < mpf("76.0"):
    f1 = bessely(0, x)
    f2 = bessely(0, x + step)
    if f1 * f2 < 0:
        zero = findroot(lambda t: bessely(0, t), (x, x + step), solver='secant', tol=mp.mpf("1e-41"))
        previous_zero = zero
        y0_zeros.append(zero)
    if previous_zero is not None and abs(x - mpf(f'{round(x)}')) < epsilon:
        zeros.append(previous_zero)
    x += step

y0_extrema = []

x = mpf("1.25")
while x < mpf("76.0"):
    d1 = mp.diff(lambda t: bessely(0, t), x)
    d2 = mp.diff(lambda t: bessely(0, t), x + step)
    if d1 * d2 < 0:
        extremum = findroot(lambda t: mp.diff(lambda u: bessely(0, u), t), (x, x + step), solver='secant', tol=mp.mpf("1e-41"))
        y0_extrema.append(extremum)
    x += step

# Print results
for i, z in enumerate(y0_zeros):
    print(f"Zero {i+1}: x ≈ {z}")

print("Extrema (peaks/valleys) of Y0(x):")
for e in y0_extrema:
    print(f"nExtrema: {e}")

y0_zeros.extend(y0_extrema)

y0_zeros = sorted(y0_zeros)

# Print results
for i, z in enumerate(y0_zeros):
    print(f"Peak or zero {i+1}: x ≈ {z}")

print("")

# print("pub(crate) static Y0_ZEROS: [(u64, u64); 48] = [")
# print(f"(0x0, 0x0),")
# for z in y0_zeros:
#     k = split_double_double(z)
#     hi = double_to_hex(k[1])
#     lo = double_to_hex(k[0])
#     print(f"({lo}, {hi}),")
    
# print("];")

print("pub(crate) static Y0_ZEROS_RATIONAL128: [DyadicFloat128; 48] = [")
print(f"DyadicFloat128 {{ sign: DyadicSign::Pos, exponent: 0, mantissa: 0x0u128, }},")
for z in y0_zeros:
    print_dyadic(z)
    
print("];")
# Out:
# Zero 1: x ≈ 3.9576784193148578683756771869174012814186038
# Zero 2: x ≈ 7.0860510603017726976236245968203524689715104
# Zero 3: x ≈ 10.22234504349641701899204227634218712599406
# Zero 4: x ≈ 13.361097473872763478267694585713786426579135
# Zero 5: x ≈ 16.500922441528090753421143666489774115751333
# Zero 6: x ≈ 19.641309700887939773776045472285980025441517
# Zero 7: x ≈ 22.782028047291559316932081968396516662816306
# Zero 8: x ≈ 25.922957653180922706872191146269373317052509
# Zero 9: x ≈ 29.064030252728398055304718405181344393605068
# Zero 10: x ≈ 32.205204116493280650953559661516194096980979
# Zero 11: x ≈ 35.346452305214320508799868706358214091282447
# Zero 12: x ≈ 38.487756653081537176464556122066562157372007
# Zero 13: x ≈ 41.629104466213807963834028403266947835118214
# Zero 14: x ≈ 44.770486607221993156366801616102992110196472
# Zero 15: x ≈ 47.911896331516480342150305098366009288219297
# Zero 16: x ≈ 51.053328552362362084622730461625767074078664
# Zero 17: x ≈ 54.19477936108705429869041017135112434866769
# Zero 18: x ≈ 57.336245704766280522194469751655579045492095
# Zero 19: x ≈ 60.477725164223475733312929993890880111162984
# Zero 20: x ≈ 63.61921579772037911632668674172406195191179
# Zero 21: x ≈ 66.760716028729644657324380151732884086510259
# Zero 22: x ≈ 69.902224563938499423840189433441406124611816
# Zero 23: x ≈ 73.043740332392073461652359520761344876173305
# Extrema (peaks/valleys) of Y0(x):
# nExtrema: 2.1971413260310170351490335626989662730530183
# nExtrema: 5.4296810407941351327720051908525841965837575
# nExtrema: 8.5960058683311689264296061801639678511029216
# nExtrema: 11.749154830839881243399421939922350714301166
# nExtrema: 14.897442128336725378844819156429870879807151
# nExtrema: 18.043402276727855564304555507889508902163088
# nExtrema: 21.188068934142213016142481528685423196935025
# nExtrema: 24.331942571356912035992944051850129651414333
# nExtrema: 27.475294980449223512212285525410668235700897
# nExtrema: 30.61828649164111471576162569644744831027794
# nExtrema: 33.761017796109325692471759911249650993879821
# nExtrema: 36.903555316142950053588159309844303659060545
# nExtrema: 40.045944640266876089064214537312936172020628
# nExtrema: 43.188218097393211268477533200127597207456358
# nExtrema: 46.330399250701686587724463565243621670014636
# nExtrema: 49.472505679924095824128003887609267273294894
# nExtrema: 52.614550767172957805120284895640403531617011
# nExtrema: 55.756544879208134886631236807492075985298424
# nExtrema: 58.898496171433054036050631513576196116955149
# nExtrema: 62.040411147670693473712823944067304389825849
# nExtrema: 65.18229505809561451746542971638249026690812
# nExtrema: 68.324152187403298603979275237541495840929062
# nExtrema: 71.465986066986123729425683592774276298807768
# nExtrema: 74.607799633511720751283338348407684418490569
# Peak or zero 1: x ≈ 2.1971413260310170351490335626989662730530183
# Peak or zero 2: x ≈ 3.9576784193148578683756771869174012814186038
# Peak or zero 3: x ≈ 5.4296810407941351327720051908525841965837575
# Peak or zero 4: x ≈ 7.0860510603017726976236245968203524689715104
# Peak or zero 5: x ≈ 8.5960058683311689264296061801639678511029216
# Peak or zero 6: x ≈ 10.22234504349641701899204227634218712599406
# Peak or zero 7: x ≈ 11.749154830839881243399421939922350714301166
# Peak or zero 8: x ≈ 13.361097473872763478267694585713786426579135
# Peak or zero 9: x ≈ 14.897442128336725378844819156429870879807151
# Peak or zero 10: x ≈ 16.500922441528090753421143666489774115751333
# Peak or zero 11: x ≈ 18.043402276727855564304555507889508902163088
# Peak or zero 12: x ≈ 19.641309700887939773776045472285980025441517
# Peak or zero 13: x ≈ 21.188068934142213016142481528685423196935025
# Peak or zero 14: x ≈ 22.782028047291559316932081968396516662816306
# Peak or zero 15: x ≈ 24.331942571356912035992944051850129651414333
# Peak or zero 16: x ≈ 25.922957653180922706872191146269373317052509
# Peak or zero 17: x ≈ 27.475294980449223512212285525410668235700897
# Peak or zero 18: x ≈ 29.064030252728398055304718405181344393605068
# Peak or zero 19: x ≈ 30.61828649164111471576162569644744831027794
# Peak or zero 20: x ≈ 32.205204116493280650953559661516194096980979
# Peak or zero 21: x ≈ 33.761017796109325692471759911249650993879821
# Peak or zero 22: x ≈ 35.346452305214320508799868706358214091282447
# Peak or zero 23: x ≈ 36.903555316142950053588159309844303659060545
# Peak or zero 24: x ≈ 38.487756653081537176464556122066562157372007
# Peak or zero 25: x ≈ 40.045944640266876089064214537312936172020628
# Peak or zero 26: x ≈ 41.629104466213807963834028403266947835118214
# Peak or zero 27: x ≈ 43.188218097393211268477533200127597207456358
# Peak or zero 28: x ≈ 44.770486607221993156366801616102992110196472
# Peak or zero 29: x ≈ 46.330399250701686587724463565243621670014636
# Peak or zero 30: x ≈ 47.911896331516480342150305098366009288219297
# Peak or zero 31: x ≈ 49.472505679924095824128003887609267273294894
# Peak or zero 32: x ≈ 51.053328552362362084622730461625767074078664
# Peak or zero 33: x ≈ 52.614550767172957805120284895640403531617011
# Peak or zero 34: x ≈ 54.19477936108705429869041017135112434866769
# Peak or zero 35: x ≈ 55.756544879208134886631236807492075985298424
# Peak or zero 36: x ≈ 57.336245704766280522194469751655579045492095
# Peak or zero 37: x ≈ 58.898496171433054036050631513576196116955149
# Peak or zero 38: x ≈ 60.477725164223475733312929993890880111162984
# Peak or zero 39: x ≈ 62.040411147670693473712823944067304389825849
# Peak or zero 40: x ≈ 63.61921579772037911632668674172406195191179
# Peak or zero 41: x ≈ 65.18229505809561451746542971638249026690812
# Peak or zero 42: x ≈ 66.760716028729644657324380151732884086510259
# Peak or zero 43: x ≈ 68.324152187403298603979275237541495840929062
# Peak or zero 44: x ≈ 69.902224563938499423840189433441406124611816
# Peak or zero 45: x ≈ 71.465986066986123729425683592774276298807768
# Peak or zero 46: x ≈ 73.043740332392073461652359520761344876173305
# Peak or zero 47: x ≈ 74.607799633511720751283338348407684418490569
#
# pub(crate) static Y0_ZEROS_RATIONAL128: [DyadicFloat; 48] = [
# DyadicFloat128 { sign: DyadicSign::Pos, exponent: 0, mantissa: 0x0u128, },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -126,
#     mantissa: 0x8c9df6a6_ff921721_70d796f3_2017e155_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -126,
#     mantissa: 0xfd4a9a6c_c2b4de0f_95187fbc_7b23405a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -125,
#     mantissa: 0xadbff274_3d8173bf_cf758451_d17ddc12_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -125,
#     mantissa: 0xe2c0ee27_39081734_45adb505_49881acc_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -124,
#     mantissa: 0x89893d73_0b4da147_9cc068d9_0466df5b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -124,
#     mantissa: 0xa38eb9ad_23eabc69_6c010dc7_6d6f6ad3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -124,
#     mantissa: 0xbbfc89c6_a1903021_f8f0d9c0_c1004d6b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -124,
#     mantissa: 0xd5c70e25_0f3a4d04_0fc42f21_b652c247_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -124,
#     mantissa: 0xee5bec46_f4245543_edcb5e0e_3f61c303_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0x8401e3a0_0190a24b_446fa242_b3576c07_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0x9058e34a_f8f1d4bc_236756f0_2443a2d1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0x9d2166fa_ff5eb4e8_0da55c08_a2ad07a8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0xa9812a49_0c466a72_3628820a_51d726a6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0xb64197eb_bd603b94_ea1019ea_75071211_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0xc2a7d181_c10650a9_7baf812d_902b3e46_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0xcf62379f_400a2f7e_0fd6a131_fa8945f0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0xdbcd6774_67dbe718_767820ae_26dd1f44_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0xe883224b_0b627a15_562fd94e_971537db_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -123,
#     mantissa: 0xf4f24030_2941dfc3_0b11f705_3d347846_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0x80d22107_255f73a5_e3155151_e5d892e3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0x870b483f_c7daacd2_82a82102_617f3d05_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0x8d62c464_a213c7cc_45d50ff9_25debfa4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0x939d3d9a_d3d7f924_81e87adf_e5728360_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0x99f3767a_e59104c7_8457834d_d50a09ba_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xa02f0c1c_9d7da9a8_ffacaac8_460e01b5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xa68433f6_109f9515_8900655b_5e80e9a0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xacc0bc3e_b346d87f_918feb38_b06e7e1f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xb314fa70_f0190b85_d6ddc7c9_8e042c17_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xb952542e_618bedb3_8de1b41f_c6aa4a1f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xbfa5c826_e4d297ca_0422f662_55b48e77_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xc5e3d887_69cafe33_9981aa85_e88e1e1a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xcc369bc2_915b8377_95352db8_354bd3b1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xd2754ccb_daf5504d_ddc5f4bc_dbdd757b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xd8c7743d_a737fc41_cf46ecb7_f33e383f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xdf06b3b3_689eef4b_abdf2ea8_7ffc6b1b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xe55850cb_45910bb1_50f1d21d_b471f3c5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xeb980f61_5f8b71dc_c8dd083c_434699b9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xf1e930c9_1343a494_74e9bb0d_6a192158_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xf829618a_368ecd4d_cc957993_351501b6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -122,
#     mantissa: 0xfe7a13b4_c18097f4_25599c4d_0177b3b7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -121,
#     mantissa: 0x825d55c7_217c758e_c0d144c4_0bcdb6aa_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -121,
#     mantissa: 0x85857c92_41dfa6e6_aacb2f94_f7661be1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -121,
#     mantissa: 0x88a5f746_87a5e758_f802fa31_68b9cc60_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -121,
#     mantissa: 0x8bcdf060_c78705c7_f126991d_5358881d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -121,
#     mantissa: 0x8eee95b9_cc31b2ba_1bc86205_b537adc7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -121,
#     mantissa: 0x92166522_0247be75_b0e61b82_f4233602_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -121,
#     mantissa: 0x95373183_78e841b3_79dbe48b_8f49ccd7_u128,
# },
# ];

# %%
# Taylor series for f32
mp.prec = 60
terms = 28
print(f"pub(crate) static Y0F_COEFFS: [[u64; {terms}]; {len(j0_zeros)}] = [")

def get_constant_term(poly, y):
    for term in poly.operands():
        if term.is_constant():
            return term

def print_taylor_coeffsf(poly, n):
    print("[")
    for i in range(0, n):
        coeff = poly[i]
        print(f"{double_to_hex(coeff)},")
    print("],")

prev_zero = 0

for i in range(0, len(y0_zeros)):
    k_range = y0_zeros[i]
    range_diff = k_range - prev_zero

    x0 = mp.mpf(k_range)
    from mpmath import mp, bessely, taylor
    poly = taylor(lambda val: bessely(0, val), x0, terms)
    # print(poly)
    print_taylor_coeffsf(poly, terms)
    prev_zero = y0_zeros[i]

print("];")
# Out:
# pub(crate) static Y0F_COEFFS: [[u64; 41]; 47] = [
# [mpf('0.52078641240226751110715073692607'), mpf('0.0'), mpf('-0.26039320620113375555357536846304'), mpf('0.0395048485830322028364602785614'), mpf('0.0082143493513216024279099048784476'), mpf('0.00095956233402108751324624666282015'), mpf('-0.0012370922221179114212488122443617'), mpf('0.00037074881260917165021899792834161'), mpf('-0.00013335662500684747464830109816763'), mpf('0.00005662236715064509475652994381275'), mpf('-0.00002358699837551760903508966274673'), mpf('0.0000097964034682169090390241456552774'), mpf('-0.0000041036905126218338307613733655675'), mpf('0.0000017300870834862234846237408636078'), mpf('-0.00000073313228183263465617037950680149'), mpf('0.00000031208598237787635042276363091502'), mpf('-0.00000013339044438352910154921218452208'), mpf('0.000000057219051205514850171026599282661'), mpf('-0.00000002462396619372747864989152467005'), mpf('0.000000010627628156707689361120006498825'), mpf('-0.0000000045989070057707728409573379625272'), mpf('0.000000001994839239593058546947191175894'), mpf('-8.6717095952456776554834474872814e-10'), mpf('3.7771565687842002083162911306619e-10'), mpf('-1.6482313365323497970848669030869e-10'), mpf('7.2044676218846789163201632336255e-11'), mpf('-3.1539932955022028060267738432361e-11'), mpf('1.3827554040986096536616843642946e-11'), mpf('-6.0703179384600914491330249325004e-12'), mpf('2.6682051385400796496642634533752e-12'), mpf('-1.1741750035573949903069624065507e-12'), mpf('5.172730216232396724988440928256e-13'), mpf('-2.2811337768270027689991896988382e-13'), mpf('1.0069288888350707009122056291205e-13'), mpf('-4.4487653061604646921371659201182e-14'), mpf('1.9672087375694825673405871491965e-14'), mpf('-8.7058485256468931375712774795299e-15'), mpf('3.8556942807890320993122021161774e-15'), mpf('-1.7088639621125691633685720190179e-15'), mpf('7.5789620088817533016344611167521e-16'), mpf('-3.3635232341051059573800322085719e-16'), mpf('1.4936464286421332686929521327555e-16')]
# [
# 0x3fe0aa48442f014a,
# 0x0000000000000000,
# 0xbfd0aa48442f014b,
# 0x3fa439fac16525f6,
# 0x3f80d2af4e932386,
# 0x3f4f71646bea8111,
# 0xbf5444bda8b664a9,
# 0x3f384c220672ab82,
# 0xbf217ab4afac0736,
# 0x3f0dafb9b8983d86,
# 0xbef8bb962fa6c505,
# 0x3ee48b6770c210be,
# 0xbed1364ddbddf33c,
# 0x3ebd06aadd881cef,
# 0xbea8998eefe8caa1,
# 0x3e94f198aa7c73a8,
# 0xbe81e742c1cf6acb,
# 0x3e6eb820636013a9,
# 0xbe5a709593e5d778,
# 0x3e46d299b1a6ab0d,
# 0xbe33c08d3e0a3e4c,
# 0x3e2122b2a831eedc,
# 0xbe0dcbb767b405d5,
# 0x3df9f4d817711bdf,
# 0xbde6a732ce7db296,
# 0x3dd3cdb1820544fc,
# 0xbdc156d9d7a9603b,
# 0x3dae68388d1e7163,
# 0xbd9ab29205d3c902,
# 0x3d8778438a9d4c3f,
# 0xbd74a8039c9d2a24,
# 0x3d62332e6179cd25,
# 0xbd500d53464407ad,
# 0x3d3c57aff386dbcb,
# 0xbd290b58b370769d,
# 0x3d162617d848c516,
# 0xbd039a947a4277c5,
# 0x3cf15d5017096190,
# 0xbcdec8be79807012,
# 0x3ccb4e5bceebb7f1,
# 0xbcb83c9af0422255,
# ],
# ];

# %%
def compute_intervals(zeros):
    intervals = []
    for i in range(0, len(zeros)):
        if i == 0:
            a = 1.35 - zeros[i]
            b = (zeros[i] + zeros[i + 1]) / 2 + 0.05 - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
        elif i + 1 > len(zeros) - 1:
            a = (zeros[i - 1] + zeros[i]) / 2 - 0.05 - zeros[i]
            b = (zeros[i]) + 0.83 + 0.05 - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
        else:
            a = (zeros[i - 1] + zeros[i]) / 2 - zeros[i] - 0.05
            b = (zeros[i] + zeros[i + 1]) / 2 + 0.05  - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
    return intervals

intervals = compute_intervals(y0_zeros)
print(intervals)

def build_sollya_script(a, b, zero, deg):
    return f"""
prec = 500;
bessel_y0 = library("/Users/radzivon/RustroverProjects/pxfm/notes/bessel_sollya/cmake-build-release/libbessel_sollya.dylib");
f = bessel_y0(x + {zero});
d = [{a}, {b}];
pf = remez(f, {deg}, d);
for i from 0 to degree(pf) do {{
    write(coeff(pf, i)) >> "coefficients.txt";
    write("\\n") >> "coefficients.txt";
}};
"""

def load_coefficients(filename):
    with open(filename, "r") as f:
        return [RR(line.strip()) for line in f if line.strip()]

def call_sollya_on_interval(a, b, zero, degree=12):
    sollya_script = build_sollya_script(a, b, zero, degree)
    with open("tmp_interval.sollya", "w") as f:
        f.write(sollya_script)
    import subprocess
    if os.path.exists("coefficients.txt"):
        os.remove("coefficients.txt")
    try:
        result = subprocess.run(
            ["sollya", "tmp_interval.sollya"],
            check=True,
            capture_output=True,
            text=True
        )
    except subprocess.CalledProcessError as e:
        return

degree = 19

print(f"pub(crate) static Y0F_COEFFS: [[u64;{degree + 1}]; {len(intervals)}] = [")
for i in range(0, len(intervals)):
    interval = intervals[i]
    call_sollya_on_interval(interval[0], interval[1], interval[2], degree)
    coeffs = load_coefficients(f"coefficients.txt")
    print("[")
    for c in coeffs:
        print(double_to_hex(c) + ",")
    print("],")
print("];")
# Out:
# [(-0.84714, 0.93027, 2.1971413260310170351490335626990), (-0.93027, 0.78600, 3.9576784193148578683756771869174), (-0.78600, 0.87819, 5.4296810407941351327720051908526), (-0.87819, 0.80498, 7.0860510603017726976236245968204), (-0.80498, 0.86317, 8.5960058683311689264296061801640), (-0.86317, 0.81340, 10.222345043496417018992042276342), (-0.81340, 0.85597, 11.749154830839881243399421939922), (-0.85597, 0.81817, 13.361097473872763478267694585714), (-0.81817, 0.85174, 14.897442128336725378844819156430), (-0.85174, 0.82124, 16.500922441528090753421143666490), (-0.82124, 0.84895, 18.043402276727855564304555507890), (-0.84895, 0.82338, 19.641309700887939773776045472286), (-0.82338, 0.84698, 21.188068934142213016142481528685), (-0.84698, 0.82496, 22.782028047291559316932081968397), (-0.82496, 0.84551, 24.331942571356912035992944051850), (-0.84551, 0.82617, 25.922957653180922706872191146269), (-0.82617, 0.84437, 27.475294980449223512212285525411), (-0.84437, 0.82713, 29.064030252728398055304718405181), (-0.82713, 0.84346, 30.618286491641114715761625696447), (-0.84346, 0.82791, 32.205204116493280650953559661516), (-0.82791, 0.84272, 33.761017796109325692471759911250), (-0.84272, 0.82855, 35.346452305214320508799868706358), (-0.82855, 0.84210, 36.903555316142950053588159309844), (-0.84210, 0.82909, 38.487756653081537176464556122067), (-0.82909, 0.84158, 40.045944640266876089064214537313), (-0.84158, 0.82956, 41.629104466213807963834028403267), (-0.82956, 0.84113, 43.188218097393211268477533200128), (-0.84113, 0.82996, 44.770486607221993156366801616103), (-0.82996, 0.84075, 46.330399250701686587724463565244), (-0.84075, 0.83030, 47.911896331516480342150305098366), (-0.83030, 0.84041, 49.472505679924095824128003887609), (-0.84041, 0.83061, 51.053328552362362084622730461626), (-0.83061, 0.84011, 52.614550767172957805120284895640), (-0.84011, 0.83088, 54.194779361087054298690410171351), (-0.83088, 0.83985, 55.756544879208134886631236807492), (-0.83985, 0.83112, 57.336245704766280522194469751656), (-0.83112, 0.83961, 58.898496171433054036050631513576), (-0.83961, 0.83134, 60.477725164223475733312929993891), (-0.83134, 0.83940, 62.040411147670693473712823944067), (-0.83940, 0.83154, 63.619215797720379116326686741724), (-0.83154, 0.83921, 65.182295058095614517465429716382), (-0.83921, 0.83172, 66.760716028729644657324380151733), (-0.83172, 0.83904, 68.324152187403298603979275237541), (-0.83904, 0.83188, 69.902224563938499423840189433441), (-0.83188, 0.83888, 71.465986066986123729425683592774), (-0.83888, 0.83203, 73.043740332392073461652359520761), (-0.83203, 0.88000, 74.607799633511720751283338348408)]

# %%
def compute_intervals(zeros):
    intervals = []
    for i in range(0, len(zeros)):
        if i == 0:
            a = 1.35 - zeros[i]
            b = (zeros[i] + zeros[i + 1]) / 2 + 0.03 - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
        elif i + 1 > len(zeros) - 1:
            a = (zeros[i - 1] + zeros[i]) / 2 - 0.03 - zeros[i]
            b = (zeros[i]) + 0.83 + 0.03 - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
        else:
            a = (zeros[i - 1] + zeros[i]) / 2 - zeros[i] - 0.03
            b = (zeros[i] + zeros[i + 1]) / 2 + 0.03  - zeros[i]
            intervals.append((RealField(18)(a), RealField(18)(b), RealField(110)(zeros[i])))
    return intervals

intervals = compute_intervals(y0_zeros)
# print(intervals)

def build_sollya_script(a, b, zero, deg):
    return f"""
prec = 200;
bessel_y0 = library("/Users/radzivon/RustroverProjects/pxfm/notes/bessel_sollya/cmake-build-release/libbessel_sollya.dylib");
f = bessel_y0(x + {zero});
d = [{a}, {b}];
pf = remez(f, {deg}, d);
for i from 0 to degree(pf) do {{
    write(coeff(pf, i)) >> "coefficients.txt";
    write("\\n") >> "coefficients.txt";
}};
"""

def load_coefficients(filename):
    with open(filename, "r") as f:
        return [RealField(500)(line.strip()) for line in f if line.strip()]

def call_sollya_on_interval(a, b, zero, degree=12):
    sollya_script = build_sollya_script(a, b, zero, degree)
    with open("tmp_interval.sollya", "w") as f:
        f.write(sollya_script)
    import subprocess
    if os.path.exists("coefficients.txt"):
        os.remove("coefficients.txt")
    try:
        result = subprocess.run(
            ["sollya", "tmp_interval.sollya"],
            check=True,
            capture_output=True,
            text=True
        )
    except subprocess.CalledProcessError as e:
        return

def print_remez_coeffs(poly):
    print("[")
    for i in range(len(poly)):
        coeff = poly[i]
        print_double_double("", coeff)
    print("],")
    
def print_remez_coeffs(poly):
    print("[")
    for i in range(len(poly)):
        coeff = poly[i]
        print_double_double("", coeff)
    print("],")

degree = 27

print(f"pub(crate) static Y0_COEFFS: [[(u64, u64); {degree + 1}]; {len(intervals)}] = [")
for i in range(0, len(intervals)):
    interval = intervals[i]
    call_sollya_on_interval(interval[0], interval[1], interval[2], degree)
    coeffs = load_coefficients(f"coefficients.txt")
    print_remez_coeffs(coeffs)
print("];")
# Out:
# pub(crate) static Y0_COEFFS_RATIONAL128: [[DyadicFloat128; 30]; 47] = [
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -128,
#     mantissa: 0x85524221_780a56b6_c9205cc1_b78aab9f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0xabcd8153_5673ae25_0ec01d46_2f5d77aa_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -129,
#     mantissa: 0x85524221_780a56b5_05c81cec_c8e94874_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0xa1cfd60b_292fb294_419fdc54_a2f3eb1d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -134,
#     mantissa: 0x86957a74_991c17e1_c90d6924_dfc2aec1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -138,
#     mantissa: 0xfb8b235f_54015d66_1771ef94_462936bd_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0xa225ed45_b30b8605_21ec3cfe_eb985b68_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -139,
#     mantissa: 0xc2611033_96d4386f_9c3e8baf_bcc9d825_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0x8bd5a57d_7083720f_68f493c5_5669d95b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0xed7dcdc4_14959788_8087d0ab_7639e4ab_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -143,
#     mantissa: 0xc5dcb176_fbad2e05_970a4aec_97fdca79_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -144,
#     mantissa: 0xa45b3b9e_e1d9254d_3c0112cd_62218859_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0x89b26fa6_82d5ecc8_32168cd2_b02ade11_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -147,
#     mantissa: 0xe835523d_9760d11d_877b9104_02256157_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -148,
#     mantissa: 0xc4cc552b_709bf25d_1386ce8b_abcfe3f9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -149,
#     mantissa: 0xa78d123d_566c8490_0ca9cc96_4b1e3c46_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -150,
#     mantissa: 0x8f3c2c78_aee364b7_7e6e145a_45f0a6a9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -152,
#     mantissa: 0xf5ba39f0_70b5d7d0_d1b83b38_c54ab277_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -153,
#     mantissa: 0xd3560dbc_0b3d826f_d2dcea7c_c62170ea_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -154,
#     mantissa: 0xb6c8d040_72c4958e_d296efdb_5c505c77_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -155,
#     mantissa: 0x9f7a509f_764339ef_00c71598_623c5981_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -156,
#     mantissa: 0x88155d7d_4e8e3f86_24601d7c_d4daf38a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -158,
#     mantissa: 0xddc13237_ce7591b2_14c8eaca_c668e1c7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -159,
#     mantissa: 0xd4e88f2d_795ea6e5_954a95ef_835c4078_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -160,
#     mantissa: 0xf609486a_4843d53e_590c5419_64c9ad49_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -161,
#     mantissa: 0x9eae3912_6945c7f7_a42949cb_7b52a6d1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -165,
#     mantissa: 0xb8c6fefe_6c131b49_6486dbbf_41c3ea1b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -164,
#     mantissa: 0x9643a466_d47e8e31_82d72208_0488e8fe_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -163,
#     mantissa: 0xa316459a_79cc4d79_f50b76e8_a7f0e895_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -165,
#     mantissa: 0xd67468e8_27df221c_5c6969bd_8d5e0c80_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -228,
#     mantissa: 0xb2992e3e_1dba0b1b_3465e8c1_5fdb7485_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -129,
#     mantissa: 0xce1a12b5_095060d2_013721b5_0454ff53_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0xd04e4948_1b3f74c4_2522f9d1_9c8fbbad_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0xefb6acdf_a875e756_27e96313_5112f398_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -135,
#     mantissa: 0xe08b7ee2_cc04b31b_7e1d4496_23d888de_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -136,
#     mantissa: 0x8f195e27_7c5206bf_24d4e4a6_4e810046_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -140,
#     mantissa: 0xccc13b28_b3129c89_1cd80124_add06537_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0xd5960ff6_6e7e1f49_07d2a2b1_6469f437_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0xa431b8f3_5331ed22_fd757f04_df03ab44_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -149,
#     mantissa: 0x9d90b420_44da59aa_9fa5053c_a60f756d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -153,
#     mantissa: 0xbbb82c3a_0e00e454_b02be524_000e9e45_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -153,
#     mantissa: 0xa2975004_a2cc8da7_f23e2874_7d511a57_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -156,
#     mantissa: 0xfb49c414_b20ebe43_694981dc_6ec82a47_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -158,
#     mantissa: 0xd2d0f9d1_58379733_7bf52e4a_62e27d3c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -160,
#     mantissa: 0xcca739b7_57ea8064_908cc95b_8d4131cd_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -162,
#     mantissa: 0xc4572e3f_38c0a716_6fc97122_ae453496_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -164,
#     mantissa: 0xba994998_9879cdd9_e2a9b2ec_c7879a52_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -166,
#     mantissa: 0xb21e3dbe_5a456105_5e1a0af8_ff086cc4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -168,
#     mantissa: 0xaaa40a61_b5d599d7_82c1e651_55cd856b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -170,
#     mantissa: 0xa3e0c6e3_99377e77_2d3f834e_14f1ff4a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -172,
#     mantissa: 0x9dbe12dd_c6b1f5c1_adb33ad8_c0ee142e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -174,
#     mantissa: 0x982e0930_27fce8d1_941abb26_97ecd23c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -176,
#     mantissa: 0x931d2634_7c4dadc3_b5a0e871_a0a451c3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -178,
#     mantissa: 0x8e1d2c08_6f3ea2a8_0fa9dce7_3aceee68_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -180,
#     mantissa: 0x89b195a1_de34f954_60e72277_f00d912d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -182,
#     mantissa: 0x8aaef3a4_dac5475c_4ec34969_28f41aae_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -184,
#     mantissa: 0x8495f26d_ee37ce7b_d61abeda_5e455cb3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -187,
#     mantissa: 0xadd05d6c_338c63da_7f9bbd2c_6af2bd87_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -188,
#     mantissa: 0x8760dca5_a14dc08d_b8c08bbc_e0972712_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -189,
#     mantissa: 0x935d9d61_06d3be73_4ea7c18c_a3f313f8_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -129,
#     mantissa: 0xae3e2ab7_860ccc8e_5abc76d2_ff0ad7d2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -235,
#     mantissa: 0xd5c2e70d_8e115bdf_9fed2675_1a0ce6a0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -130,
#     mantissa: 0xae3e2ab7_860ccc8e_5abc76d2_ff01d9f5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -134,
#     mantissa: 0xab26a58f_686bf369_a89555b7_39eafe3d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -134,
#     mantissa: 0xd0aec96f_f1f13437_aec78a68_cab08e1f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -138,
#     mantissa: 0xda1c2182_34ffb448_2adb07fa_033e1f11_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -139,
#     mantissa: 0xbd449266_17c8a382_ec0a2688_f45e6fe1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -143,
#     mantissa: 0xafb4da54_51e02881_0cd0bcdd_fa47b703_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0xc2dca075_b03fcae5_3326b7a6_d23a9a12_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -149,
#     mantissa: 0xaad607ae_18b163ab_4824aec0_7feeb9ba_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -152,
#     mantissa: 0xeab1f0c5_a3f5c415_25880e42_f19affb2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -156,
#     mantissa: 0x9f561d22_f0377728_85273c01_a6396db7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -158,
#     mantissa: 0x803b38ea_ad45eee7_208ad2ed_de823192_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -162,
#     mantissa: 0x82709f46_9674d11b_672aebfa_96f3abfc_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -170,
#     mantissa: 0xb7159836_5d2207b5_f200b8a0_70c12e62_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -169,
#     mantissa: 0xa68c7be4_89786392_64b11244_a1f53c9a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -171,
#     mantissa: 0xa4c044ad_ad3f561b_a5212a23_07b5035d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -174,
#     mantissa: 0xd2da1ce6_7a62df81_e20d0cef_d2ecbd5e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -176,
#     mantissa: 0x8e4e2604_11130e50_65656c02_896751af_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -179,
#     mantissa: 0xc99e6379_4c70eb01_994a844e_dc8882b8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -181,
#     mantissa: 0x8e338a08_28e7a4f5_e9b673ee_d1a2374f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -184,
#     mantissa: 0xc82734a9_2789d35e_146f1735_fbe621ab_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -186,
#     mantissa: 0x8d2fbd6c_01a3534d_7f661e0a_309e56b1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -189,
#     mantissa: 0xc79536ba_a6e15918_4e990a8a_36dbeb51_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -191,
#     mantissa: 0x8d4d0d0b_2779e978_59fa30d2_d3b8384a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -194,
#     mantissa: 0xc7f1c0d4_072fd89e_b3d6eab4_64a7622c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0x8ced796a_db418243_d21e5bb4_f646d2ca_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -199,
#     mantissa: 0xce5ca24d_d38ccab9_056013f1_e4575b0c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -201,
#     mantissa: 0xa41fe0c7_91622f26_3a281934_ce4c0eea_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -204,
#     mantissa: 0xbd3a00b2_eb3cd7e8_b13b0fbe_131ad26d_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -233,
#     mantissa: 0x942013d1_eb3bfaf9_0e9b29aa_f7ac1b64_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -129,
#     mantissa: 0x99a66503_4bd2d4e5_76f69065_ab208f1d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -133,
#     mantissa: 0xad77b08f_e26aba83_8cd90da7_dc1dbe3c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -132,
#     mantissa: 0xc4b4e326_5fa29292_53687556_ff3162f6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -136,
#     mantissa: 0xd978a54a_a93e59ab_353487eb_39670b05_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -136,
#     mantissa: 0x8e9af42f_ef151b54_cf4c5f5a_ed6f518e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0x936eb8f1_c8e45927_0ba54459_2cdccd11_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -142,
#     mantissa: 0xc0bbf27f_29192023_0c7611d2_46e15299_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -146,
#     mantissa: 0xb549139a_97cb50ca_4aa512bd_73d06e0e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -148,
#     mantissa: 0x9a553ab9_f78a6d6b_49c56edc_d43e85b5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -152,
#     mantissa: 0x85140a6b_d62242d3_08bef974_01b1414b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -155,
#     mantissa: 0xa2151e99_acd6cb24_ab53408f_766d263a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -160,
#     mantissa: 0xfd36284a_b36392de_ec6e18ce_607167b9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -163,
#     mantissa: 0xf8a72ac2_411ed763_24515200_b6d46691_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -167,
#     mantissa: 0xb8a61495_f1c9aacd_c9ef3958_dfb44420_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -170,
#     mantissa: 0x833ce6ac_2a8c2b12_7bb93101_a20064f8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -175,
#     mantissa: 0x99b2ead3_c347f1bc_e81b0d30_0f97b7de_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -178,
#     mantissa: 0x9c67835a_401f1ac5_adfde96a_7f9b2aab_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -182,
#     mantissa: 0x95ead41d_9cb5deef_0020bddf_ad9a8c9f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -187,
#     mantissa: 0x93749670_f9dc3bc5_30c1724b_9dbd913f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -189,
#     mantissa: 0x9388b0ae_5807243d_0ae90698_a4cfdd86_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -192,
#     mantissa: 0xc6fa7b8a_d81850b8_b4a1c6eb_da6d8b8c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -195,
#     mantissa: 0xcd863291_cca8418e_1cf59554_824ecea9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -198,
#     mantissa: 0xd9d745d9_4da07ffe_6ac9b027_b66717a5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -201,
#     mantissa: 0xeded60d6_b6b71e8b_71418d46_120b5b5c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -203,
#     mantissa: 0x81c678c7_751f8133_d023cc62_56506177_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -206,
#     mantissa: 0x8cb82375_a2b75212_955cbc4f_e9f65564_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -209,
#     mantissa: 0x96c7926e_9773bf16_7f2c571a_1e366a11_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -212,
#     mantissa: 0xb677bcca_84b5fbe6_215c0132_6db54467_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -215,
#     mantissa: 0xec6a822b_a3d2b709_cc1d2875_21ee2a4d_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -129,
#     mantissa: 0x8afcc9fe_755ae11d_c672a53c_58fddb21_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -234,
#     mantissa: 0xb54169cf_14a8f2a3_e1b61fd7_3698d264_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0x8afcc9fe_755ae11d_c672a53c_58f3501a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -135,
#     mantissa: 0xac77b77d_f6bcb62e_3c6fe763_50a3a21d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -134,
#     mantissa: 0xb1caeff2_4fe69d78_2433690f_a4bf9099_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -139,
#     mantissa: 0xfd8a8825_20e000da_2422c161_379e5f30_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -139,
#     mantissa: 0xafc4508e_aab27a88_21cea57c_a5f1e204_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -144,
#     mantissa: 0xf9be9135_4125b49a_4c8f8bdc_f9db247b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -145,
#     mantissa: 0xb7bdd588_279aa6e0_4e87d878_48507969_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -150,
#     mantissa: 0xf8622d1c_126b7c4b_a691475a_072d6290_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -152,
#     mantissa: 0xeff08ef8_9638a822_2657c258_8fb74b63_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -156,
#     mantissa: 0x988d6e17_3a9f6d5a_de1f5b56_914344af_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -159,
#     mantissa: 0xd69a70c2_8270adbf_8d7c711e_34e041de_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -164,
#     mantissa: 0xfee4030d_7458abad_caf9252c_a017a95e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -166,
#     mantissa: 0x8ca4c653_677cd987_9e51e7e5_a2b69929_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -171,
#     mantissa: 0x9d148eac_c8fb9eea_35d64cea_1ce34326_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -174,
#     mantissa: 0x8b7bd740_656bb1f7_44db4435_78b82907_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0x8fc6c06f_6678e596_c05e7010_f76beb90_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -183,
#     mantissa: 0xe13da9a8_54623c1d_673eb14d_e3160d41_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -188,
#     mantissa: 0xe8401a73_8f89c4ee_b8e2805d_8b16d2b7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -192,
#     mantissa: 0xfd610036_2cf0b334_fb802240_f93ad512_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -197,
#     mantissa: 0x9f493453_323a0b14_85928e2e_21f1f620_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -200,
#     mantissa: 0xee6fca76_7fd7ffc2_e7a6e6a4_cdc9359d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -204,
#     mantissa: 0xe2334040_b4caf0ef_bb8a240e_4695d5d4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -208,
#     mantissa: 0xe02af414_67ebfecb_669dbe84_10175ef2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -211,
#     mantissa: 0xf6ab1f2a_f862ba0e_fa2dc322_6fde0760_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -214,
#     mantissa: 0xefc446c6_7b0d8ea8_314654b3_4946993c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -217,
#     mantissa: 0xd4822185_5f24397d_13459f5c_3046c28a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -220,
#     mantissa: 0xc8a6bc5e_e31d1485_0bcee5b2_5e0f4912_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -223,
#     mantissa: 0xa5a8bd77_22981d9d_29b46bb7_5426b1bc_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -232,
#     mantissa: 0xf29cf723_b52a1611_11b94251_912f9ea6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xffb1ae63_95cf85c2_e152e0e7_29373034_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -134,
#     mantissa: 0xc81b228f_fabe28fd_375f45ba_a54fc06b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0xa7333d38_aab57ac6_8b79e78b_70155fdf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -136,
#     mantissa: 0x8192f720_f4885d34_38f2fac1_eefbb6d4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0xff11c8a7_dc893c43_292f724a_c70a4152_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -141,
#     mantissa: 0xbfc26be2_87261cc7_af5ba756_a064ad59_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0xb57eeabd_f0f09c2a_9fade6cc_901f8a4b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -146,
#     mantissa: 0x82029d5f_a1c35037_7bf6d899_ca0d886f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -148,
#     mantissa: 0x95754f62_46c7e687_83b49494_e730bcba_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -153,
#     mantissa: 0xc9f5cf8e_eda745d0_b939a3f6_85da40e7_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -155,
#     mantissa: 0xa1451d1f_18509b3f_063c0c2a_c8ab617b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -160,
#     mantissa: 0xccec6217_bd010033_95ce8e67_14739ae1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -163,
#     mantissa: 0xf64c0282_2d52c323_d6c63016_250717bf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -167,
#     mantissa: 0x9309b2ce_74ca7679_4f2ff4e6_0da93d37_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -170,
#     mantissa: 0x8c79815e_dd4bfc97_91396ac3_dfb6a002_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -175,
#     mantissa: 0x9de4e65b_82129816_0c9492e4_98f4334c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0xf86e2033_df458a97_dd4e1dd2_64f6c726_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0x837248fa_2c4afb89_55479b70_30f078df_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -187,
#     mantissa: 0xb009dd63_b48bd928_e7e4590b_40f411c4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -192,
#     mantissa: 0xb0b5a6b1_539a6af6_c78fdcd4_b4eec668_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0xc9fdb7d2_8e96eb1e_9a456ffe_c413ff89_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -201,
#     mantissa: 0xbcb1d449_fecb3a34_fa3dabfd_c4757c6f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -205,
#     mantissa: 0xc9bf7a28_12aaa565_e1e29c03_158b0331_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -210,
#     mantissa: 0xc1c3eb4e_ff0cde03_36beb7f9_745f7a44_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -214,
#     mantissa: 0x8508b5ff_bae81a06_47dd0006_1c0c51cf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -221,
#     mantissa: 0xdea7698c_97cecf47_218875cf_5eb3efc9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -223,
#     mantissa: 0xe9e8cef7_c12e9422_618031d0_5025eb9c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -227,
#     mantissa: 0xef847a47_0631f65f_4b98f314_514435e8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -230,
#     mantissa: 0x8e1a8ac9_8654e097_a80abfed_01447fd9_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xee0a750a_744fc6b2_eb38843e_96f24072_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -231,
#     mantissa: 0xd3a86d8b_f9c44135_2fe9b393_b8ec92ea_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -131,
#     mantissa: 0xee0a750a_744fc6b2_eb38843e_97825ea0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -136,
#     mantissa: 0xd81bff4e_79528de0_1f80d14f_9c928dba_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -134,
#     mantissa: 0x9b3ebeb0_4725d3e3_351eb626_f46af658_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -139,
#     mantissa: 0xa55f7ab1_b727bbb1_2462fe52_1e89695e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -139,
#     mantissa: 0x9ec53309_1492cab7_4b6b6c12_d16c2124_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -144,
#     mantissa: 0xae7f4950_d1622900_a3f00979_db3ef925_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -145,
#     mantissa: 0xab8c0a50_d5180908_7e84c57d_2c1db9e0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -150,
#     mantissa: 0xba0a719e_4dd66a56_ce81b4c8_b27407e0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -152,
#     mantissa: 0xe53834f3_9e8ec9a4_836a36f7_52bbfcca_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -157,
#     mantissa: 0xf059d382_ff923433_40528526_0e3f8ca4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -159,
#     mantissa: 0xd0aeeb16_7cf87d51_1669b291_cd8e32ff_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -164,
#     mantissa: 0xd19ca475_6d095e66_04214b27_e72d51de_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -166,
#     mantissa: 0x8a0cd8fe_a1477a48_1e6e728d_91bb1146_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -171,
#     mantissa: 0x84417b05_c53ba63b_ee3eefc2_699153f2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -174,
#     mantissa: 0x8af2e057_ba4ea11b_f0cdd913_efb1ee38_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -180,
#     mantissa: 0xfd8f08af_044ca0e7_a65a0948_01809e62_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -183,
#     mantissa: 0xdc1c131b_8443269b_d06e09b9_78aefb0a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -188,
#     mantissa: 0xbf2ea9cc_38785a0d_ce8e88e5_fdbd6428_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -191,
#     mantissa: 0x8ced71c9_22b82e87_24115a6e_ee4c3f65_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -197,
#     mantissa: 0xe95b93bc_8058cca9_cf40a52a_fee5954f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -200,
#     mantissa: 0x94c5dbf1_0359fecf_be7e705d_84314f1a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -206,
#     mantissa: 0xea85d7b3_2ce1e689_03809901_91fb5d72_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -209,
#     mantissa: 0x8456a9b5_8c1a53f1_b529391a_474f566d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -215,
#     mantissa: 0xc8a0c6a8_377cdde4_4bb9b0a3_c445b345_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -219,
#     mantissa: 0xc557d90d_0ff8e682_ce1634e7_1d277443_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -224,
#     mantissa: 0x8a2915ab_7f85b3ee_c7f0d386_0f0454e0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -228,
#     mantissa: 0x88d7af7e_dc6b3a96_75016e57_74649f7e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -234,
#     mantissa: 0xde8fd915_9513a53c_6b240df7_776acd5a_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -232,
#     mantissa: 0xf2253ffa_b18d496b_10e3e19f_74c7d741_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -130,
#     mantissa: 0xdf99513a_ca003889_cc656551_965add8e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -134,
#     mantissa: 0x85e16c27_32909f86_8c6d4236_f193278e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -132,
#     mantissa: 0x936559c5_459b3ca6_55d6e290_2bf2fce9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -137,
#     mantissa: 0xaf81f238_b2eb9357_342207c4_13602540_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -137,
#     mantissa: 0xe5553b71_a4c967ae_99faf970_1e0258fb_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -141,
#     mantissa: 0x862f8c62_3681836f_56abd10c_ce4b12ca_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -142,
#     mantissa: 0xa7857bea_366a419f_58bad5e7_a980151d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -147,
#     mantissa: 0xbe8f1404_a710cf7d_f87fa81b_0514db65_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -148,
#     mantissa: 0x8d683989_1423c60e_d21255d4_5d8afa4a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -153,
#     mantissa: 0x9b010e46_59e1a19f_e69a365f_9a09207d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -155,
#     mantissa: 0x9b8d7363_ac8c04da_8181cf8a_9ff07449_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -160,
#     mantissa: 0xa36703bd_45f6b898_663e039f_acbb983d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -163,
#     mantissa: 0xf11ae9ab_25b1c402_925ef3dc_94b854f3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -168,
#     mantissa: 0xf204712c_e397d85e_b82286db_455c8303_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -170,
#     mantissa: 0x8af83d64_3f4190c3_b6350bea_f1a85abd_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -175,
#     mantissa: 0x85227bbf_b54777fb_d75cc834_8c27ebd5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -179,
#     mantissa: 0xf7ec55a9_7c75c8a5_89c4e2fc_016db684_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -184,
#     mantissa: 0xe2a75dad_69c3422d_603e7fdd_c38fe5da_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -187,
#     mantissa: 0xb05a1e5d_afaf68ed_b56dac2f_173b57f9_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -192,
#     mantissa: 0x99eba556_5ab41a38_4e7da937_af2002c1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -196,
#     mantissa: 0xccdfdd9f_f3875277_157afa84_b8403d41_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -201,
#     mantissa: 0xaae04b4e_93f46f68_21822d6a_52343205_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -205,
#     mantissa: 0xc614e919_df76f84f_9a37245d_38383285_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -210,
#     mantissa: 0x9e03a814_bdd544b0_db601291_dcdf3bff_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -214,
#     mantissa: 0xa1fd35fd_887032b3_c12129f7_ee8ad2af_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -220,
#     mantissa: 0xf7a46e2d_ff9c8d71_1e9e9211_ad957c4a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -224,
#     mantissa: 0xe2bf3f4e_31554d37_f4197623_656f5885_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -229,
#     mantissa: 0xa4eec162_6eaa5fc7_c95a650f_4afdfd10_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -233,
#     mantissa: 0x8b25c0fa_b668c8de_e4bce4d9_7245e75a_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -130,
#     mantissa: 0xd38115f0_426cc97b_a12cd0fc_91ee0039_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -232,
#     mantissa: 0x8a79b77b_86f6b417_8f3991d8_8a63508c_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -131,
#     mantissa: 0xd38115f0_426cc97b_a12cd0fc_91c8d1e3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -136,
#     mantissa: 0x97703ce8_10588c99_9b1cd06c_626892dc_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -134,
#     mantissa: 0x8b18c8e1_855313a1_f1e6ce26_23d235f2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -140,
#     mantissa: 0xebc03753_97e3b38f_e5b76706_5232ad5e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -139,
#     mantissa: 0x907cab81_58ea6e06_13a7ebcb_2c3b6473_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -144,
#     mantissa: 0x80308441_14a55333_c341e781_11728871_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -145,
#     mantissa: 0x9f1cc65e_23975115_05ce3b29_a6d06001_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -150,
#     mantissa: 0x8ddf0c0e_328b1020_a18ef0c9_d92c84c2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -152,
#     mantissa: 0xd87c4dbe_30f9d387_f7067230_e7c0ad56_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -157,
#     mantissa: 0xbe1fc2c4_1024db23_6f91c81a_da8d500a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -159,
#     mantissa: 0xc811b30a_6426dd12_b06f7246_09a971ba_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -164,
#     mantissa: 0xab249068_9c3ee275_67651a11_6e61720e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -166,
#     mantissa: 0x85f0c089_2ae7ec9d_1546ff21_2bb0d943_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -172,
#     mantissa: 0xddcb892c_35fd6134_35fcb1b1_5f7d0efb_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -174,
#     mantissa: 0x880e18f0_ef911636_4475d737_6602c36b_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -180,
#     mantissa: 0xd94c66d3_b73bd87f_7c87379c_37fb209e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -183,
#     mantissa: 0xd9156622_0ec38959_583f33a2_5f1d5fdf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -188,
#     mantissa: 0xa6e51bd1_974c3f00_deae03ba_f74fb6ec_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -191,
#     mantissa: 0x8bb74a77_0fe8bcec_bc7261ce_8bb8b0d6_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -197,
#     mantissa: 0xcea786ba_75cbbb96_c2adc269_32f537a2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -200,
#     mantissa: 0x943ac2d8_8cd1448a_8b5ff194_7785b07a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -206,
#     mantissa: 0xd2e00afc_1f83493b_94f690d2_65f6b27e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -209,
#     mantissa: 0x83e60001_6c373a94_23ac51ef_d6a4b2c2_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -215,
#     mantissa: 0xb485012c_0d5f0e0c_dbe1f3dd_73159f6d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -219,
#     mantissa: 0xc7c35ce9_12a630d9_26f0fb3e_22e14ae8_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -224,
#     mantissa: 0x839ca1d0_2a1848ad_011e2f49_80192575_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -228,
#     mantissa: 0x819c4536_85d37f30_5f4adb7d_d74e8d64_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -234,
#     mantissa: 0xa900f4ad_15a6a782_8bc2350f_90f2dcc9_u128,
# },
# ],
# [
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -232,
#     mantissa: 0xe66cecd5_bf5bbc56_1497edb3_d460597d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -130,
#     mantissa: 0xc92e1acc_47714ab7_3873c84e_337da5d1_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -135,
#     mantissa: 0xc312a49b_3ac8efc4_ac7f4ee8_a9969e53_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -132,
#     mantissa: 0x85228901_ceb51342_85dad4aa_438d74ac_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0x809d9c67_dc948e6b_31acc39a_47e99346_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -137,
#     mantissa: 0xd125090a_fb3421a2_a14cf0f6_1a41330e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0xc7c8a109_bbfd6430_96776e97_b60beec0_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -142,
#     mantissa: 0x9ae8be76_00b97bee_5fa1ea41_33cba19e_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -147,
#     mantissa: 0x9141d498_8a04af19_6de8d851_99634486_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -148,
#     mantissa: 0x84cf389c_97aa6f53_112e031e_1bf35d61_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -154,
#     mantissa: 0xf2ef00f1_732b2e92_31e40518_d213eecf_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -155,
#     mantissa: 0x9442c2a7_54582f56_889c4926_87eee82a_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -160,
#     mantissa: 0x8398614c_2fe90f43_51abe5a8_a42fdc40_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -163,
#     mantissa: 0xe8ba1e5d_9708ce1f_927e0dfe_dcd2679f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -168,
#     mantissa: 0xc7c3943a_2f0f3226_88c28224_850406da_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -170,
#     mantissa: 0x878b3659_4d3e89d9_a2d27c5f_2d8b85f3_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -176,
#     mantissa: 0xe08733e0_0271d444_0141a6b4_e383cf2d_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -179,
#     mantissa: 0xf3d760dd_19f41a8e_9ac5e1d7_af82f377_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -184,
#     mantissa: 0xc2a1f096_4dfcc868_99bb1580_7606f3d4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -187,
#     mantissa: 0xae9c9cfb_68f6a769_9096d294_c7783958_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -192,
#     mantissa: 0x863dd08c_c0c5ad1e_c6652820_843105c5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -196,
#     mantissa: 0xcbec8bb9_11a14be9_f3c755e9_ae685dd5_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -201,
#     mantissa: 0x96fdcafa_320f9ff6_a0cf2ba4_2c61a053_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -205,
#     mantissa: 0xc60279bb_90a075cd_04fbb396_d8a87c66_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -210,
#     mantissa: 0x8d3ccdbc_308f587e_6722ba89_8509b051_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -214,
#     mantissa: 0xa26e4f4a_577449ce_9c14b653_926036ee_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -220,
#     mantissa: 0xdf53469c_4233576d_f7f6082f_86374825_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Pos,
#     exponent: -224,
#     mantissa: 0xe42eb08a_9c13f952_10b14606_fb50c41f_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -229,
#     mantissa: 0x966d86a5_80dea007_078fa900_68ed32b4_u128,
# },
# DyadicFloat128 {
#     sign: DyadicSign::Neg,
#     exponent: -233,
#     mantissa: 0x8b460608_2d0592e0_84e3945c_d1b6bd0d_u128,
# },
# ],
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 82
#      80 for i in range(0, len(intervals)):
#      81     interval = intervals[i]
# ---> 82     call_sollya_on_interval(interval[0], interval[1], interval[2], degree)
#      83     coeffs = load_coefficients(f"coefficients.txt")
#      84     print_remez_coeffs_dyadic(coeffs)
#
# Cell In[5], line 46, in call_sollya_on_interval(a, b, zero, degree)
#      44     os.remove("coefficients.txt")
#      45 try:
# ---> 46     result = subprocess.run(
#      47         ["sollya", "tmp_interval.sollya"],
#      48         check=True,
#      49         capture_output=True,
#      50         text=True
#      51     )
#      52 except subprocess.CalledProcessError as e:
#      53     return
#
# File /private/var/tmp/sage-10.6-current/venv/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /private/var/tmp/sage-10.6-current/venv/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /private/var/tmp/sage-10.6-current/venv/lib/python3.12/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /private/var/tmp/sage-10.6-current/venv/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
# # Taylor series for f64
# mp.prec = 110
# terms = 50
# print(f"pub(crate) static Y0_COEFFS: [[(u64, u64); {terms}]; {len(y0_zeros)}] = [")

# def get_constant_term(poly, y):
#     for term in poly.operands():
#         if term.is_constant():
#             return term

# def print_taylor_coeffs(poly, n):
#     print("[")
#     for i in range(0, n):
#         coeff = poly[i]
#         print_double_double("", RealField(300)(coeff))
#         # print(f"{double_to_hex(coeff)},")
#     print("],")

# prev_zero = 0

# for i in range(0, len(y0_zeros)):
#     k_range = y0_zeros[i]
#     range_diff = k_range - prev_zero

#     x0 = mp.mpf(k_range)
#     from mpmath import mp, bessely, taylor, chebyfit
#     poly = taylor(lambda val: bessely(0, val), x0, terms)
#     print_taylor_coeffs(poly, terms)
#     prev_zero = y0_zeros[i]

# print("];")

# Taylor series for f64
mp.prec = 140
terms = 28
print(f"pub(crate) static Y0_COEFFS_RATIONAL128: [[DyadicFloat128; {terms}]; {len(y0_zeros)}] = [")

def get_constant_term(poly, y):
    for term in poly.operands():
        if term.is_constant():
            return term

def print_taylor_dyadic_cef(poly, n):
    print("[")
    for i in range(0, n):
        coeff = poly[i]
        print_dyadic(coeff)
        # print(f"{double_to_hex(coeff)},")
    print("],")

prev_zero = 0

for i in range(0, len(y0_zeros)):
    k_range = y0_zeros[i]
    range_diff = k_range - prev_zero

    x0 = mp.mpf(k_range)
    from mpmath import mp, bessely, taylor, chebyfit
    poly = taylor(lambda val: bessely(0, val), x0, terms)
    print_taylor_dyadic_cef(poly, terms)
    prev_zero = y0_zeros[i]

print("];")
# Out:
# pub(crate) static Y0_COEFFS_RATIONAL128: [[DyadicFloat128; 28]; 47] = [
# ];
